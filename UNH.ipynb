# %%
import my_portfolio; my_portfolio.run("UNH")
# Out:
# No operations found for ticker 'UNH'
# Prices: 298.61 | 313.54 | 329.22 | 324.83 | 341.08 | 358.13 | 376.04
# Buy score: 1.55%
# No operations found.
#                                                   UNH
# Company Name                       UnitedHealth Group
# Current Price                                 319.885
# Forward EPS                                      29.9
# Gross Profit (ttm)                     85,731,000,320
# Industry                             Healthcare Plans
# Revenue (ttm)                         435,159,007,232
# Target High Price                               440.0
# Target Low Price                                198.0
# Target Mean Price                               385.4
# Trailing EPS                                    19.19
# Website             https://www.unitedhealthgroup.com
#                                            UNH
# Currency                                   USD
# Dayhigh                                 324.25
# ...
