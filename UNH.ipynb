# %%
import my_portfolio; my_portfolio.run("UNH")
# Out:
# No operations found for ticker 'UNH'
# Prices: 284.59 | 298.82 | 313.76 | 314.84 | 330.58 | 347.11 | 364.46
# Buy score: 8.73%
# No operations found.
#                                                   UNH
# Company Name                       UnitedHealth Group
# Current Price                                 289.565
# Forward EPS                                   20.2388
# Gross Profit (ttm)                     82,916,999,168
# Industry                             Healthcare Plans
# Revenue (ttm)                         447,567,003,648
# Target High Price                               440.0
# Target Low Price                                280.0
# Target Mean Price                               373.6
# Trailing EPS                                     19.2
# Website             https://www.unitedhealthgroup.com
#                                            UNH
# Currency                                   USD
# Dayhigh                                 295.60
# ...
