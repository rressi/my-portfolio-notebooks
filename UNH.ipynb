# %%
import my_portfolio; my_portfolio.run("UNH")
# Out:
# No operations found for ticker 'UNH'
# Prices: 310.73 | 326.27 | 342.58 | 359.71 | 377.70 | 396.58 | 416.41
# Buy score: -1.24%
# No operations found.
#                                                   UNH
# Company Name                       UnitedHealth Group
# Current Price                                364.2194
# Forward EPS                                      29.9
# Gross Profit (ttm)                     88,122,998,784
# Industry                             Healthcare Plans
# Revenue (ttm)                         422,817,988,608
# Target High Price                               626.0
# Target Low Price                                198.0
# Target Mean Price                              372.04
# Trailing EPS                                    23.11
# Website             https://www.unitedhealthgroup.com
#                                            UNH
# Currency                                   USD
# Dayhigh                                 365.57
# ...
