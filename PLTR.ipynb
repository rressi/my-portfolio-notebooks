# %%
import workflow
workflow.run(
    security = "PLTR",
)
# Out:
# Prices: 136.79 | 143.63 | 150.81 | 158.3540 | 166.27 | 174.59 | 183.31
# Buy score: -3.65%
#                                           PLTR
# Company Name        Palantir Technologies Inc.
# Industry             Software - Infrastructure
# Revenue (ttm)                    3,440,587,008
# Gross Profit (ttm)               2,753,510,912
# Current Price                           164.36
# Target Mean Price                    151.74318
# Target High Price                        200.0
# Target Low Price                          45.0
# Trailing EPS                               0.3
# Forward EPS                               0.47
# Website               https://www.palantir.com
#                                           PLTR
# Currency                                   USD
# Dayhigh                                 167.46
# Daylow                                  163.22
# Exchange                                   NMS
# Fiftydayaverage                         158.16
# ...
