# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 159.52 | 167.49 | 175.87 | 184.00 | 193.20 | 202.86 | 213.00
# Buy score: -2.20%
# Sell score: 2.62%
# Current return: 22.68 USD
# Breakeven price: 186.55 USD
# <style type="text/css">
# #T_05e48_row44_col0, #T_05e48_row44_col1, #T_05e48_row44_col2, #T_05e48_row44_col3, #T_05e48_row44_col4, #T_05e48_row44_col5, #T_05e48_row44_col6, #T_05e48_row44_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_05e48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05e48_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_05e48_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_05e48_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_05e48_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_05e48_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
