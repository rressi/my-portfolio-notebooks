# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 171.06 | 179.61 | 188.60 | 198.43 | 208.36 | 218.77 | 229.71
# Buy score: -4.19%
# Sell score: 4.16%
# Current return: 107.00 USD
# Breakeven price: 201.33 USD
# <style type="text/css">
# #T_e3669_row40_col0, #T_e3669_row40_col1, #T_e3669_row40_col2, #T_e3669_row40_col3, #T_e3669_row40_col4, #T_e3669_row40_col5, #T_e3669_row40_col6, #T_e3669_row40_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_e3669">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3669_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_e3669_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_e3669_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_e3669_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_e3669_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
