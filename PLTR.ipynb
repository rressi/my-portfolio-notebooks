# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 155.09 | 162.84 | 170.98 | 178.56 | 187.49 | 196.86 | 206.71
# Buy score: -1.63%
# Sell score: -5.67%
# Current return: -253.12 USD
# Breakeven price: 181.10 USD
# <style type="text/css">
# #T_cecb5_row46_col0, #T_cecb5_row46_col1, #T_cecb5_row46_col2, #T_cecb5_row46_col3, #T_cecb5_row46_col4, #T_cecb5_row46_col5, #T_cecb5_row46_col6, #T_cecb5_row46_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_cecb5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cecb5_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_cecb5_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_cecb5_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_cecb5_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_cecb5_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
