# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 153.96 | 161.66 | 169.74 | 178.82 | 187.76 | 197.15 | 207.01
# Buy score: 2.84%
# Sell score: -3.62%
# Current return: -410.07 USD
# Breakeven price: 180.56 USD
# <style type="text/css">
# #T_3284d_row49_col0, #T_3284d_row49_col1, #T_3284d_row49_col2, #T_3284d_row49_col3, #T_3284d_row49_col4, #T_3284d_row49_col5, #T_3284d_row49_col6, #T_3284d_row49_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_3284d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3284d_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_3284d_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_3284d_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_3284d_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_3284d_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
