# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 154.28 | 162.00 | 170.10 | 178.82 | 187.76 | 197.15 | 207.01
# Buy score: 0.04%
# Sell score: -0.35%
# Current return: -117.82 USD
# Breakeven price: 180.56 USD
# <style type="text/css">
# #T_8dc6e_row49_col0, #T_8dc6e_row49_col1, #T_8dc6e_row49_col2, #T_8dc6e_row49_col3, #T_8dc6e_row49_col4, #T_8dc6e_row49_col5, #T_8dc6e_row49_col6, #T_8dc6e_row49_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_8dc6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dc6e_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_8dc6e_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_8dc6e_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_8dc6e_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_8dc6e_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
