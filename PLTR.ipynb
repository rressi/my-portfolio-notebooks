# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 155.07 | 162.82 | 170.96 | 180.13 | 189.14 | 198.60 | 208.53
# Buy score: -1.32%
# Sell score: 0.99%
# Current return: -3.78 USD
# Breakeven price: 182.68 USD
# <style type="text/css">
# #T_54cb8_row36_col0, #T_54cb8_row36_col1, #T_54cb8_row36_col2, #T_54cb8_row36_col3, #T_54cb8_row36_col4, #T_54cb8_row36_col5, #T_54cb8_row36_col6, #T_54cb8_row36_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_54cb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54cb8_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_54cb8_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_54cb8_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_54cb8_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_54cb8_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
