# %%
import workflow
workflow.run(
    security = "PLTR",
)
# Out:
# Prices: 139.13 | 146.09 | 153.39 | 161.0645 | 169.12 | 177.57 | 186.45
# Buy score: -2.01%
#                                          PLTR
# Company Name            Palantir Technologies
# Industry            Software - Infrastructure
# Revenue (ttm)                   3,440,587,008
# Gross Profit (ttm)              2,753,510,912
# Current Price                          164.36
# Target Mean Price                   151.74318
# Target High Price                       200.0
# Target Low Price                         45.0
# Trailing EPS                              0.3
# Forward EPS                              0.47
# Website              https://www.palantir.com
#                                           PLTR
# Currency                                   USD
# Dayhigh                                 167.46
# Daylow                                  163.22
# Exchange                                   NMS
# Fiftydayaverage                         158.16
# ...
