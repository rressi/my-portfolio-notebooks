# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 156.22 | 164.04 | 172.24 | 178.56 | 187.49 | 196.86 | 206.71
# Buy score: -1.17%
# Sell score: -3.65%
# Current return: -181.02 USD
# Breakeven price: 181.10 USD
# <style type="text/css">
# #T_c7dce_row46_col0, #T_c7dce_row46_col1, #T_c7dce_row46_col2, #T_c7dce_row46_col3, #T_c7dce_row46_col4, #T_c7dce_row46_col5, #T_c7dce_row46_col6, #T_c7dce_row46_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_c7dce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7dce_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c7dce_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c7dce_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c7dce_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c7dce_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
