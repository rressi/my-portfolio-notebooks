# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 151.09 | 158.64 | 166.57 | 174.67 | 183.40 | 192.57 | 202.20
# Buy score: 5.63%
# Sell score: -14.10%
# Current return: -2,635.39 USD
# Breakeven price: 176.39 USD
# <style type="text/css">
# #T_c9d37_row50_col0, #T_c9d37_row50_col1, #T_c9d37_row50_col2, #T_c9d37_row50_col3, #T_c9d37_row50_col4, #T_c9d37_row50_col5, #T_c9d37_row50_col6, #T_c9d37_row50_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_c9d37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9d37_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c9d37_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c9d37_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c9d37_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c9d37_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
