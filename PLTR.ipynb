# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 152.79 | 160.43 | 168.45 | 174.67 | 183.40 | 192.57 | 202.20
# Buy score: -0.21%
# Sell score: -3.74%
# Current return: -826.39 USD
# Breakeven price: 176.39 USD
# <style type="text/css">
# #T_2b90a_row50_col0, #T_2b90a_row50_col1, #T_2b90a_row50_col2, #T_2b90a_row50_col3, #T_2b90a_row50_col4, #T_2b90a_row50_col5, #T_2b90a_row50_col6, #T_2b90a_row50_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_2b90a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b90a_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_2b90a_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_2b90a_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_2b90a_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_2b90a_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
