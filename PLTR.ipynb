# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 162.57 | 170.70 | 179.24 | 190.50 | 200.03 | 210.03 | 220.53
# Buy score: -4.54%
# Sell score: 3.49%
# Current return: 34.62 USD
# Breakeven price: 193.29 USD
# <style type="text/css">
# #T_452f5_row38_col0, #T_452f5_row38_col1, #T_452f5_row38_col2, #T_452f5_row38_col3, #T_452f5_row38_col4, #T_452f5_row38_col5, #T_452f5_row38_col6, #T_452f5_row38_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_452f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_452f5_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_452f5_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_452f5_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_452f5_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_452f5_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
