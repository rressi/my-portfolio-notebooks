# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 155.32 | 163.08 | 171.24 | 180.13 | 189.14 | 198.60 | 208.53
# Buy score: -0.29%
# Sell score: 0.10%
# Current return: -11.78 USD
# Breakeven price: 182.68 USD
# <style type="text/css">
# #T_5e0a4_row36_col0, #T_5e0a4_row36_col1, #T_5e0a4_row36_col2, #T_5e0a4_row36_col3, #T_5e0a4_row36_col4, #T_5e0a4_row36_col5, #T_5e0a4_row36_col6, #T_5e0a4_row36_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_5e0a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e0a4_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_5e0a4_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_5e0a4_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_5e0a4_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_5e0a4_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
