# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 153.24 | 160.91 | 168.95 | 174.67 | 183.40 | 192.57 | 202.20
# Buy score: 1.79%
# Sell score: -4.54%
# Current return: -964.89 USD
# Breakeven price: 176.39 USD
# <style type="text/css">
# #T_6f5c3_row50_col0, #T_6f5c3_row50_col1, #T_6f5c3_row50_col2, #T_6f5c3_row50_col3, #T_6f5c3_row50_col4, #T_6f5c3_row50_col5, #T_6f5c3_row50_col6, #T_6f5c3_row50_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_6f5c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f5c3_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_6f5c3_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_6f5c3_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_6f5c3_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_6f5c3_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
