# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 170.83 | 179.37 | 188.34 | 195.31 | 205.07 | 215.33 | 226.09
# Buy score: 5.31%
# Sell score: -3.85%
# Current return: -258.59 USD
# Breakeven price: 198.13 USD
# <style type="text/css">
# #T_692c2_row41_col0, #T_692c2_row41_col1, #T_692c2_row41_col2, #T_692c2_row41_col3, #T_692c2_row41_col4, #T_692c2_row41_col5, #T_692c2_row41_col6, #T_692c2_row41_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_692c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_692c2_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_692c2_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_692c2_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_692c2_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_692c2_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
