# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 154.77 | 162.51 | 170.63 | 178.56 | 187.49 | 196.86 | 206.71
# Buy score: -2.93%
# Sell score: -0.78%
# Current return: -78.52 USD
# Breakeven price: 181.10 USD
# <style type="text/css">
# #T_8f9e2_row46_col0, #T_8f9e2_row46_col1, #T_8f9e2_row46_col2, #T_8f9e2_row46_col3, #T_8f9e2_row46_col4, #T_8f9e2_row46_col5, #T_8f9e2_row46_col6, #T_8f9e2_row46_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_8f9e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f9e2_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_8f9e2_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_8f9e2_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_8f9e2_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_8f9e2_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
