# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 150.69 | 158.22 | 166.13 | 174.67 | 183.40 | 192.57 | 202.20
# Buy score: -2.66%
# Sell score: -9.51%
# Current return: -1,833.59 USD
# Breakeven price: 176.39 USD
# <style type="text/css">
# #T_9a9d9_row50_col0, #T_9a9d9_row50_col1, #T_9a9d9_row50_col2, #T_9a9d9_row50_col3, #T_9a9d9_row50_col4, #T_9a9d9_row50_col5, #T_9a9d9_row50_col6, #T_9a9d9_row50_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_9a9d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a9d9_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_9a9d9_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_9a9d9_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_9a9d9_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_9a9d9_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
