# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 171.34 | 179.91 | 188.90 | 198.43 | 208.36 | 218.77 | 229.71
# Buy score: 7.18%
# Sell score: -6.74%
# Current return: -325.40 USD
# Breakeven price: 201.33 USD
# <style type="text/css">
# #T_1e94d_row40_col0, #T_1e94d_row40_col1, #T_1e94d_row40_col2, #T_1e94d_row40_col3, #T_1e94d_row40_col4, #T_1e94d_row40_col5, #T_1e94d_row40_col6, #T_1e94d_row40_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_1e94d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e94d_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_1e94d_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_1e94d_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_1e94d_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_1e94d_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
