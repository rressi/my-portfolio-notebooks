# %%
import my_portfolio; my_portfolio.run("PLTR")
# Out:
# Prices: 151.83 | 159.43 | 167.40 | 174.67 | 183.40 | 192.57 | 202.20
# Buy score: 4.10%
# Sell score: -9.15%
# Current return: -1,770.39 USD
# Breakeven price: 176.39 USD
# <style type="text/css">
# #T_25604_row50_col0, #T_25604_row50_col1, #T_25604_row50_col2, #T_25604_row50_col3, #T_25604_row50_col4, #T_25604_row50_col5, #T_25604_row50_col6, #T_25604_row50_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_25604">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25604_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_25604_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_25604_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_25604_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_25604_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
