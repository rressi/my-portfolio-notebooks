# %%
import workflow
workflow.run(
    security = "COHR",
)
# Out:
# Prices: 80.20 | 84.21 | 88.42 | 92.8413 | 97.48 | 102.36 | 107.48
# Buy score: -10.29%
#                                                   COHR
# Company Name                            Coherent Corp.
# Industry            Scientific & Technical Instruments
# Revenue (ttm)                            5,810,115,072
# Gross Profit (ttm)                       2,057,321,984
# Current Price                                   103.49
# Target Mean Price                            113.36842
# Target High Price                                135.0
# Target Low Price                                  85.0
# Trailing EPS                                     -0.52
# Forward EPS                                       4.36
# Website                       https://www.coherent.com
#                                          COHR
# Currency                                  USD
# Dayhigh                                106.80
# Daylow                                 102.16
# ...
