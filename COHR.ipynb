# %%
import my_portfolio; my_portfolio.run("COHR")
# Out:
# No operations found for ticker 'COHR'
# Prices: 329.10 | 345.56 | 362.84 | 380.98 | 400.03 | 420.03 | 441.03
# Buy score: 8.55%
# No operations found.
#                                                   COHR
# Company Name                                  Coherent
# Current Price                                  350.955
# Forward EPS                                    8.09572
# Gross Profit (ttm)                       2,442,114,048
# Industry            Scientific & Technical Instruments
# Revenue (ttm)                            6,602,083,840
# Target High Price                                462.0
# Target Low Price                                 230.0
# Target Mean Price                            380.61905
# Trailing EPS                                       2.1
# Website                       https://www.coherent.com
#                                          COHR
# Currency                                  USD
# Dayhigh                                365.94
# ...
