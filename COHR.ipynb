# %%
import my_portfolio; my_portfolio.run("COHR")
# Out:
# No operations found for ticker 'COHR'
# Prices: 152.46 | 160.08 | 168.09 | 176.49 | 185.32 | 194.58 | 204.31
# Buy score: -3.38%
# No operations found.
#                                                   COHR
# Company Name                                  Coherent
# Current Price                                   182.66
# Forward EPS                                    6.34165
# Gross Profit (ttm)                       2,176,389,888
# Industry            Scientific & Technical Instruments
# Revenue (ttm)                            6,043,358,208
# Target High Price                                220.0
# Target Low Price                                 113.0
# Target Mean Price                            178.47368
# Trailing EPS                                       0.7
# Website                       https://www.coherent.com
#                                          COHR
# Currency                                  USD
# Dayhigh                                185.50
# ...
