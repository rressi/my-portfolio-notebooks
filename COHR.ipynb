# %%
import my_portfolio; my_portfolio.run("COHR")
# Out:
# No operations found for ticker 'COHR'
# Prices: 190.82 | 200.36 | 210.38 | 220.90 | 231.94 | 243.54 | 255.72
# Buy score: 0.82%
# No operations found.
#                                                   COHR
# Company Name                                  Coherent
# Current Price                                   219.25
# Forward EPS                                    7.33916
# Gross Profit (ttm)                       2,289,859,072
# Industry            Scientific & Technical Instruments
# Revenue (ttm)                            6,294,322,176
# Target High Price                                345.0
# Target Low Price                                 170.0
# Target Mean Price                            251.16667
# Trailing EPS                                      1.02
# Website                       https://www.coherent.com
#                                          COHR
# Currency                                  USD
# Dayhigh                                222.40
# ...
