# %%
import workflow
workflow.run("COHR")
# Out:
# Prices: 80.80 | 84.84 | 89.08 | 93.5385 | 98.22 | 103.13 | 108.28
# Buy score: -9.18%
#                                                   COHR
# Company Name                                  Coherent
# Current Price                                   102.99
# Forward EPS                                       4.36
# Gross Profit (ttm)                       2,057,321,984
# Industry            Scientific & Technical Instruments
# Revenue (ttm)                            5,810,115,072
# Target High Price                                135.0
# Target Low Price                                  85.0
# Target Mean Price                            113.36842
# Trailing EPS                                     -0.51
# Website                       https://www.coherent.com
#                                          COHR
# Currency                                  USD
# Dayhigh                                103.92
# Daylow                                 101.20
# ...
