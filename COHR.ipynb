# %%
import my_portfolio; my_portfolio.run("COHR")
# Out:
# No operations found for ticker 'COHR'
# Prices: 186.73 | 196.07 | 205.87 | 216.17 | 226.98 | 238.33 | 250.24
# Buy score: 4.92%
# No operations found.
#                                                   COHR
# Company Name                                  Coherent
# Current Price                                   206.04
# Forward EPS                                    7.08341
# Gross Profit (ttm)                       2,176,389,888
# Industry            Scientific & Technical Instruments
# Revenue (ttm)                            6,043,358,208
# Target High Price                                325.0
# Target Low Price                                 125.0
# Target Mean Price                                234.0
# Trailing EPS                                      1.01
# Website                       https://www.coherent.com
#                                          COHR
# Currency                                  USD
# Dayhigh                                209.99
# ...
