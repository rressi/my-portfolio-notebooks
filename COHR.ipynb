# %%
import my_portfolio; my_portfolio.run("COHR")
# Out:
# No operations found for ticker 'COHR'
# Prices: 95.32 | 100.09 | 105.09 | 110.35 | 115.87 | 121.66 | 127.74
# Buy score: -3.55%
# No operations found.
#                                                   COHR
# Company Name                                  Coherent
# Current Price                                   114.41
# Forward EPS                                       4.36
# Gross Profit (ttm)                       2,057,321,984
# Industry            Scientific & Technical Instruments
# Revenue (ttm)                            5,810,115,072
# Target High Price                                135.0
# Target Low Price                                  85.0
# Target Mean Price                            113.36842
# Trailing EPS                                     -0.55
# Website                       https://www.coherent.com
#                                          COHR
# Currency                                  USD
# Dayhigh                                118.49
# ...
