# %%
import workflow
workflow.run(
    security = "COIN",
    start_date = "2025-01-01",
    ops=
"""
    date, quantity, price
"""
)
# Out:
# Prices: 267.63 | 281.01 | 295.07 | 309.8190 | 325.31 | 341.58 | 358.65
# Buy score: -4.09%
#                                                 COIN
# Company Name                         Coinbase Global
# Current Price                                 323.04
# Forward EPS                                     3.57
# Gross Profit (ttm)                     5,668,932,096
# Industry            Financial Data & Stock Exchanges
# Revenue (ttm)                          6,706,041,856
# Target High Price                              510.0
# Target Low Price                               185.0
# Target Mean Price                          366.53586
# Trailing EPS                                   10.37
# Website                     https://www.coinbase.com
#                                          COIN
# Currency                                  USD
# Dayhigh                                329.49
# Daylow                                 319.80
# Exchange                                  NMS
# ...
