# %%
import my_portfolio; my_portfolio.run("COIN")
# Out:
# No operations found for ticker 'COIN'
# Prices: 314.75 | 330.49 | 347.01 | 364.36 | 382.58 | 401.71 | 421.80
# Buy score: -5.38%
# No operations found.
#                                                 COIN
# Company Name                         Coinbase Global
# Current Price                                 386.07
# Forward EPS                                     3.57
# Gross Profit (ttm)                     5,668,932,096
# Industry            Financial Data & Stock Exchanges
# Revenue (ttm)                          6,706,041,856
# Target High Price                              510.0
# Target Low Price                               185.0
# Target Mean Price                           374.0531
# Trailing EPS                                   10.38
# Website                     https://www.coinbase.com
#                                          COIN
# Currency                                  USD
# Dayhigh                                392.56
# ...
