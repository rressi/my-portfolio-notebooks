# %%
import my_portfolio; my_portfolio.run("COIN")
# Out:
# Prices: 297.52 | 312.40 | 328.02 | 350.04 | 367.54 | 385.92 | 405.21
# Buy score: 5.01%
# Sell score: -6.30%
#                  Quantity   Price     Value Wallet Avg. price Inv. Cost  \
# Time
# 2025-10-14 12:52       10  350.04  3,500.36     10     350.04     35.25
# 2025-10-17 00:00       10  328.00  3,280.00     10        NaN     35.25
#
#                  Inv. Balance  Balance
# Time
# 2025-10-14 12:52       -35.25   -35.25
# 2025-10-17 00:00      -255.61  -255.61
#                                                 COIN
# Company Name                         Coinbase Global
# Current Price                                 330.25
# Forward EPS                                     3.57
# Gross Profit (ttm)                     5,668,932,096
# Industry            Financial Data & Stock Exchanges
# Revenue (ttm)                          6,706,041,856
# Target High Price                              510.0
# Target Low Price                               185.0
# ...
