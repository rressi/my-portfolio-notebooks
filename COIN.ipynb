# %%
import workflow
workflow.run(
    security = "COIN",
    # start_date = "2025-01-01",
    ops=
"""
    date, quantity, price
"""
)
# Out:
# Prices: 271.80 | 285.39 | 299.66 | 314.64 | 330.37 | 346.89 | 364.24
# Buy score: -4.05%
#                                                 COIN
# Company Name                         Coinbase Global
# Current Price                                 327.91
# Forward EPS                                     3.57
# Gross Profit (ttm)                     5,668,932,096
# Industry            Financial Data & Stock Exchanges
# Revenue (ttm)                          6,706,041,856
# Target High Price                              510.0
# Target Low Price                               185.0
# Target Mean Price                          368.91214
# Trailing EPS                                   10.37
# Website                     https://www.coinbase.com
#                                          COIN
# Currency                                  USD
# Dayhigh                                333.60
# Daylow                                 321.30
# Exchange                                  NMS
# ...
