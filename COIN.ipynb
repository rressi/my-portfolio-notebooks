# %%
import my_portfolio; my_portfolio.run("COIN")
# Out:
# Prices: 317.85 | 333.74 | 350.43 | 350.04 | 367.54 | 385.92 | 405.21
# Buy score: 4.69%
# Sell score: 0.41%
#                  Quantity   Price       Tot Wallet Avg. price Balance
# Time
# 2025-10-14 12:52       10  350.04  3,500.36     10     350.04  -35.25
# 2025-10-14 15:28       10  351.47  3,514.70     10        NaN  -20.91
#                                                 COIN
# Company Name                         Coinbase Global
# Current Price                                 351.47
# Forward EPS                                     3.57
# Gross Profit (ttm)                     5,668,932,096
# Industry            Financial Data & Stock Exchanges
# Revenue (ttm)                          6,706,041,856
# Target High Price                              510.0
# Target Low Price                               185.0
# Target Mean Price                           374.6738
# Trailing EPS                                   10.39
# Website                     https://www.coinbase.com
# ...
