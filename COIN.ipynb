# %%
import workflow
workflow.run(
    security = "COIN",
    # start_date = "2025-01-01",
    ops=
"""
    date, quantity, price
"""
)
# Out:
# Prices: 276.51 | 290.34 | 304.86 | 320.10 | 336.11 | 352.91 | 370.56
# Buy score: -6.71%
#                                                 COIN
# Company Name                         Coinbase Global
# Current Price                                 343.13
# Forward EPS                                     3.57
# Gross Profit (ttm)                     5,668,932,096
# Industry            Financial Data & Stock Exchanges
# Revenue (ttm)                          6,706,041,856
# Target High Price                              510.0
# Target Low Price                               185.0
# Target Mean Price                          368.91214
# Trailing EPS                                   10.39
# Website                     https://www.coinbase.com
#                                          COIN
# Currency                                  USD
# Dayhigh                                351.89
# Daylow                                 323.52
# Exchange                                  NMS
# ...
