# %%
import workflow
workflow.run(
    security = "COIN",
    # start_date = "2025-01-01",
    ops=
"""
    date, quantity, price
"""
)
# Out:
# Prices: 273.38 | 287.04 | 301.40 | 316.47 | 332.29 | 348.90 | 366.35
# Buy score: -1.28%
#                                                 COIN
# Company Name                         Coinbase Global
# Current Price                                 320.56
# Forward EPS                                     3.57
# Gross Profit (ttm)                     5,668,932,096
# Industry            Financial Data & Stock Exchanges
# Revenue (ttm)                          6,706,041,856
# Target High Price                              510.0
# Target Low Price                               185.0
# Target Mean Price                          368.91214
# Trailing EPS                                   10.39
# Website                     https://www.coinbase.com
#                                          COIN
# Currency                                  USD
# Dayhigh                                328.49
# Daylow                                 311.30
# Exchange                                  NMS
# ...
