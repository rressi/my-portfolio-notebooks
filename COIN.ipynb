# %%
import workflow
workflow.run(
    security = "COIN",
    # start_date = "2025-01-01",
    ops=
"""
    date, quantity, price
"""
)
# Out:
# Prices: 268.04 | 281.44 | 295.52 | 310.29 | 325.81 | 342.10 | 359.20
# Buy score: -5.12%
#                                                 COIN
# Company Name                         Coinbase Global
# Current Price                                 327.02
# Forward EPS                                     3.57
# Gross Profit (ttm)                     5,668,932,096
# Industry            Financial Data & Stock Exchanges
# Revenue (ttm)                          6,706,041,856
# Target High Price                              510.0
# Target Low Price                               185.0
# Target Mean Price                          366.53586
# Trailing EPS                                    10.5
# Website                     https://www.coinbase.com
#                                          COIN
# Currency                                  USD
# Dayhigh                                328.44
# Daylow                                 320.96
# Exchange                                  NMS
# ...
