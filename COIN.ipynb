# %%
import my_portfolio; my_portfolio.run("COIN")
# Out:
# Prices: 291.11 | 305.66 | 320.95 | 350.04 | 367.54 | 385.92 | 405.21
# Buy score: 0.90%
# Sell score: -4.58%
# Current return: -230.86 USD
# Breakeven price: 357.09 USD
# <style type="text/css">
# #T_38bcb_row1_col0, #T_38bcb_row1_col1, #T_38bcb_row1_col2, #T_38bcb_row1_col3, #T_38bcb_row1_col4, #T_38bcb_row1_col5, #T_38bcb_row1_col6, #T_38bcb_row1_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_38bcb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38bcb_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_38bcb_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_38bcb_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_38bcb_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_38bcb_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
