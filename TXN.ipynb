# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 166.73 | 175.07 | 183.82 | 193.02 | 202.67 | 212.80 | 223.44
# Buy score: -0.77%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   194.51
# Forward EPS                    6.16859
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 140.0
# Target Mean Price            194.07242
# Trailing EPS                       5.5
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 196.40
# Daylow                                  193.83
# Exchange                                   NMS
# Fiftydayaverage                         175.89
# Lastprice                               194.51
# ...
