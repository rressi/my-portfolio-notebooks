# %%
import workflow
workflow.run(
    security = "TXN",  # Texas Instruments Incorporated
)
# Out:
# Prices: 169.31 | 177.78 | 186.67 | 196.0030 | 205.80 | 216.09 | 226.90
# Buy score: 6.32%
#                                    TXN
# Company Name         Texas Instruments
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Gross Profit (ttm)       9,676,000,256
# Current Price                   184.35
# Target Mean Price            205.42273
# Target High Price                260.0
# Target Low Price                 125.0
# Trailing EPS                      5.48
# Forward EPS                       5.88
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 184.81
# Daylow                                  182.26
# Exchange                                   NMS
# Fiftydayaverage                         199.38
# Lastprice                               184.35
# Lastvolume                           6,593,900
# ...
