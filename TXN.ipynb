# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 155.99 | 163.79 | 171.98 | 180.58 | 189.61 | 199.09 | 209.04
# Buy score: 0.45%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   179.77
# Forward EPS                    6.17248
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            188.92091
# Trailing EPS                      5.49
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 181.18
# Daylow                                  177.50
# Exchange                                   NMS
# Fiftydayaverage                         169.69
# Lastprice                               179.79
# ...
