# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 151.83 | 159.42 | 167.39 | 175.76 | 184.55 | 193.78 | 203.47
# Buy score: -0.89%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  177.335
# Forward EPS                    6.17248
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.10274
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 178.24
# Daylow                                  174.91
# Exchange                                   NMS
# Fiftydayaverage                         169.41
# Lastprice                               177.34
# ...
