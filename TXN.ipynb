# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 147.17 | 154.53 | 162.26 | 156.43 | 164.25 | 172.46 | 181.08
# Buy score: -2.23%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                    159.4
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.55727
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 161.16
# Daylow                                  153.41
# Exchange                                   NMS
# Fiftydayaverage                         171.43
# Lastprice                               159.40
# ...
