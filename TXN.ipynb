# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 152.99 | 160.64 | 168.67 | 177.10 | 185.96 | 195.25 | 205.02
# Buy score: -0.16%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   177.13
# Forward EPS                    6.17248
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.10274
# Trailing EPS                      5.49
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 178.02
# Daylow                                  176.79
# Exchange                                   NMS
# Fiftydayaverage                         169.45
# Lastprice                               177.13
# ...
