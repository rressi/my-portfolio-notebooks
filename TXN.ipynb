# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 176.32 | 185.14 | 194.39 | 204.11 | 214.32 | 225.04 | 236.29
# Buy score: -6.28%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   217.79
# Forward EPS                    7.90243
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                260.0
# Target Low Price                 160.0
# Target Mean Price            211.61787
# Trailing EPS                      5.45
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 222.00
# Daylow                                  214.82
# Exchange                                   NMS
# Fiftydayaverage                         179.03
# Lastprice                               217.87
# ...
