# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 151.19 | 158.75 | 166.69 | 175.03 | 183.78 | 192.97 | 202.61
# Buy score: -3.21%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   180.84
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            188.92091
# Trailing EPS                       5.5
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 183.91
# Daylow                                  179.71
# Exchange                                   NMS
# Fiftydayaverage                         169.91
# Lastprice                               180.84
# ...
