# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 152.61 | 160.24 | 168.25 | 176.67 | 185.50 | 194.78 | 204.51
# Buy score: -0.26%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                 177.1275
# Forward EPS                    6.17248
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            188.49667
# Trailing EPS                       5.5
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 178.24
# Daylow                                  176.03
# Exchange                                   NMS
# Fiftydayaverage                         169.32
# Lastprice                               177.13
# ...
