# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 164.62 | 172.85 | 181.50 | 190.57 | 200.10 | 210.10 | 220.61
# Buy score: 0.21%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   190.17
# Forward EPS                    6.13081
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            191.34515
# Trailing EPS                       5.5
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 191.59
# Daylow                                  189.47
# Exchange                                   NMS
# Fiftydayaverage                         174.02
# Lastprice                               190.17
# ...
