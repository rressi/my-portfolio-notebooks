# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 148.05 | 155.46 | 163.23 | 158.19 | 166.10 | 174.41 | 183.13
# Buy score: -0.07%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   157.09
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.55727
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 159.17
# Daylow                                  155.13
# Exchange                                   NMS
# Fiftydayaverage                         172.52
# Lastprice                               157.09
# ...
