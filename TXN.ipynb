# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 193.06 | 202.71 | 212.85 | 223.49 | 234.67 | 246.40 | 258.72
# Buy score: 1.92%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   219.29
# Forward EPS                    7.91002
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            220.67468
# Trailing EPS                      5.45
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 222.04
# Daylow                                  219.21
# Exchange                                   NMS
# Fiftydayaverage                         195.30
# Lastprice                               219.29
# ...
