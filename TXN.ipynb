# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 178.52 | 187.45 | 196.82 | 203.58 | 213.76 | 224.45 | 235.67
# Buy score: -4.69%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   214.98
# Forward EPS                     7.9086
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                286.0
# Target Low Price                 160.0
# Target Mean Price            223.76843
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 215.93
# Daylow                                  210.88
# Exchange                                   NMS
# Fiftydayaverage                         206.72
# Lastprice                               214.98
# ...
