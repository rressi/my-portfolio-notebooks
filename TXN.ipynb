# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 161.88 | 169.97 | 178.47 | 181.02 | 190.07 | 199.57 | 209.55
# Buy score: -1.75%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  184.435
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            205.27121
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 185.16
# Daylow                                  181.10
# Exchange                                   NMS
# Fiftydayaverage                         192.91
# Lastprice                               184.43
# ...
