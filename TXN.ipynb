# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 164.41 | 172.63 | 181.26 | 190.32 | 199.84 | 209.83 | 220.32
# Buy score: -0.58%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   191.44
# Forward EPS                    6.13081
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.22394
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 192.22
# Daylow                                  190.07
# Exchange                                   NMS
# Fiftydayaverage                         173.38
# Lastprice                               191.44
# ...
