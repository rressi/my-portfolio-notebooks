# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 161.65 | 169.73 | 178.22 | 174.30 | 183.02 | 192.17 | 201.77
# Buy score: -0.49%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   175.48
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price             203.0591
# Trailing EPS                      5.47
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 177.50
# Daylow                                  174.06
# Exchange                                   NMS
# Fiftydayaverage                         187.34
# Lastprice                               175.48
# ...
