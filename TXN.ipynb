# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 163.02 | 171.18 | 179.73 | 183.00 | 192.15 | 201.76 | 211.84
# Buy score: -0.05%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   183.09
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            205.27121
# Trailing EPS                      5.38
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 184.61
# Daylow                                  179.84
# Exchange                                   NMS
# Fiftydayaverage                         188.92
# Lastprice                               183.09
# ...
