# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 194.10 | 203.81 | 214.00 | 224.70 | 235.93 | 247.73 | 260.11
# Buy score: 1.18%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  222.075
# Forward EPS                    7.91002
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            218.70593
# Trailing EPS                      5.44
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 230.00
# Daylow                                  221.36
# Exchange                                   NMS
# Fiftydayaverage                         194.44
# Lastprice                               222.13
# ...
