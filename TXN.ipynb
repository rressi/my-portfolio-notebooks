# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 165.91 | 174.21 | 182.92 | 192.06 | 201.67 | 211.75 | 222.34
# Buy score: -1.82%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   195.62
# Forward EPS                    6.16859
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            191.34515
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 199.38
# Daylow                                  194.78
# Exchange                                   NMS
# Fiftydayaverage                         175.20
# Lastprice                               195.62
# ...
