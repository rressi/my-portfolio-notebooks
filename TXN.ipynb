# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 160.86 | 168.91 | 177.35 | 180.79 | 189.83 | 199.32 | 209.28
# Buy score: -0.69%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   182.04
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            205.27121
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 183.66
# Daylow                                  180.11
# Exchange                                   NMS
# Fiftydayaverage                         192.23
# Lastprice                               182.04
# ...
