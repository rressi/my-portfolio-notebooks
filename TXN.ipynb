# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 161.83 | 169.92 | 178.41 | 174.97 | 183.71 | 192.90 | 202.55
# Buy score: -0.09%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   175.12
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            203.81667
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 176.16
# Daylow                                  171.13
# Exchange                                   NMS
# Fiftydayaverage                         187.54
# Lastprice                               175.12
# ...
