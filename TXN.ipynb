# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 164.82 | 173.07 | 181.72 | 190.80 | 200.35 | 210.36 | 220.88
# Buy score: -0.97%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  192.665
# Forward EPS                    6.13086
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.10274
# Trailing EPS                      5.49
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 196.64
# Daylow                                  192.07
# Exchange                                   NMS
# Fiftydayaverage                         172.83
# Lastprice                               192.66
# ...
