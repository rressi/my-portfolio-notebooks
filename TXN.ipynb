# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 162.03 | 170.13 | 178.64 | 176.58 | 185.41 | 194.68 | 204.41
# Buy score: 0.61%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  175.515
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            203.81667
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 176.27
# Daylow                                  171.45
# Exchange                                   NMS
# Fiftydayaverage                         187.72
# Lastprice                               175.52
# ...
