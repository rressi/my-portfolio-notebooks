# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 163.63 | 171.81 | 180.40 | 183.60 | 192.78 | 202.42 | 212.54
# Buy score: 0.83%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   183.73
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            205.27121
# Trailing EPS                      5.44
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 183.97
# Daylow                                  181.31
# Exchange                                   NMS
# Fiftydayaverage                         189.61
# Lastprice                               183.73
# ...
