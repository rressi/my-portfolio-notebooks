# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 161.37 | 169.44 | 177.91 | 176.33 | 185.14 | 194.40 | 204.12
# Buy score: -2.24%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  180.375
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            201.33182
# Trailing EPS                      5.47
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 181.11
# Daylow                                  172.51
# Exchange                                   NMS
# Fiftydayaverage                         186.94
# Lastprice                               180.34
# ...
