# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 146.07 | 153.38 | 161.05 | 165.14 | 173.40 | 182.07 | 191.17
# Buy score: -2.31%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  169.045
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.55727
# Trailing EPS                      5.49
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 169.37
# Daylow                                  166.53
# Exchange                                   NMS
# Fiftydayaverage                         170.21
# Lastprice                               169.04
# ...
