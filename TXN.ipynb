# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 162.94 | 171.09 | 179.64 | 182.00 | 191.10 | 200.65 | 210.69
# Buy score: 1.04%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   180.32
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            205.27121
# Trailing EPS                      5.47
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 185.46
# Daylow                                  180.15
# Exchange                                   NMS
# Fiftydayaverage                         188.84
# Lastprice                               180.32
# ...
