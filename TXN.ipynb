# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 151.91 | 159.51 | 167.48 | 175.86 | 184.65 | 193.88 | 203.58
# Buy score: -1.48%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   177.17
# Forward EPS                    6.17248
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.10274
# Trailing EPS                      5.47
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 182.89
# Daylow                                  176.89
# Exchange                                   NMS
# Fiftydayaverage                         169.34
# Lastprice                               177.17
# ...
