# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 164.13 | 172.34 | 180.96 | 183.26 | 192.42 | 202.04 | 212.15
# Buy score: -0.01%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   183.23
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            205.27121
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 186.10
# Daylow                                  183.01
# Exchange                                   NMS
# Fiftydayaverage                         190.89
# Lastprice                               183.23
# ...
