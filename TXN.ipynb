# %%
import my_portfolio
my_portfolio.run(
    security = "TXN",  # Texas Instruments Incorporated
    start_date="2025-01-01",
)
# Out:
# Prices: 164.98 | 173.23 | 181.89 | 181.89 | 190.99 | 200.54 | 210.56
# Buy score: 1.62%
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   179.37
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            205.27121
# Trailing EPS                      5.47
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 183.25
# Daylow                                  178.17
# Exchange                                   NMS
# Fiftydayaverage                         194.50
# Lastprice                               179.37
# Lastvolume                          16,188,200
# ...
