# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 159.25 | 167.22 | 175.58 | 170.00 | 178.50 | 187.42 | 196.79
# Buy score: 0.86%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  168.545
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            190.31485
# Trailing EPS                      5.49
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 169.51
# Daylow                                  167.75
# Exchange                                   NMS
# Fiftydayaverage                         184.87
# Lastprice                               168.54
# ...
