# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 172.37 | 180.99 | 190.04 | 199.54 | 209.51 | 219.99 | 230.99
# Buy score: -7.70%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   216.17
# Forward EPS                    7.88617
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                260.0
# Target Low Price                 160.0
# Target Mean Price            210.16333
# Trailing EPS                      5.45
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 216.59
# Daylow                                  203.72
# Exchange                                   NMS
# Fiftydayaverage                         177.96
# Lastprice                               216.17
# ...
