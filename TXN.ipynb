# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 165.62 | 173.90 | 182.59 | 191.72 | 201.31 | 211.38 | 221.94
# Buy score: -1.62%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   194.88
# Forward EPS                    6.13081
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            191.34515
# Trailing EPS                       5.5
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 194.88
# Daylow                                  191.26
# Exchange                                   NMS
# Fiftydayaverage                         174.54
# Lastprice                               194.88
# ...
