# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 192.71 | 202.34 | 212.46 | 223.08 | 234.24 | 245.95 | 258.25
# Buy score: -1.38%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   226.16
# Forward EPS                    7.90288
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            218.70593
# Trailing EPS                      5.45
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 226.89
# Daylow                                  221.54
# Exchange                                   NMS
# Fiftydayaverage                         193.57
# Lastprice                               226.16
# ...
