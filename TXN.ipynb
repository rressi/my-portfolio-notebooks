# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 155.75 | 163.54 | 171.72 | 180.30 | 189.32 | 198.79 | 208.73
# Buy score: -0.39%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  181.005
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            188.92091
# Trailing EPS                      5.49
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 183.70
# Daylow                                  180.96
# Exchange                                   NMS
# Fiftydayaverage                         169.84
# Lastprice                               181.01
# ...
