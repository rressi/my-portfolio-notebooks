# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 156.05 | 163.85 | 172.04 | 180.64 | 189.68 | 199.16 | 209.12
# Buy score: 0.70%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   179.42
# Forward EPS                    6.17248
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            188.92091
# Trailing EPS                      5.42
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 183.23
# Daylow                                  178.66
# Exchange                                   NMS
# Fiftydayaverage                         169.67
# Lastprice                               179.42
# ...
