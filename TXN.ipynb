# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 167.39 | 175.76 | 184.55 | 193.78 | 203.47 | 213.64 | 224.32
# Buy score: -1.62%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   196.59
# Forward EPS                    6.15439
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 140.0
# Target Mean Price            194.98152
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 196.84
# Daylow                                  192.44
# Exchange                                   NMS
# Fiftydayaverage                         177.28
# Lastprice                               196.59
# ...
