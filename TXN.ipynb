# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 156.81 | 164.65 | 172.89 | 181.53 | 190.61 | 200.14 | 210.14
# Buy score: -3.12%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   187.37
# Forward EPS                    6.17248
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.10274
# Trailing EPS                      5.49
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 190.72
# Daylow                                  185.68
# Exchange                                   NMS
# Fiftydayaverage                         169.87
# Lastprice                               187.37
# ...
