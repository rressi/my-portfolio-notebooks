# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 162.26 | 170.37 | 178.89 | 178.22 | 187.14 | 196.49 | 206.32
# Buy score: 3.16%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                    171.7
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            204.66515
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 181.56
# Daylow                                  171.50
# Exchange                                   NMS
# Fiftydayaverage                         188.02
# Lastprice                               171.70
# ...
