# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 148.34 | 155.76 | 163.54 | 171.72 | 180.31 | 189.32 | 198.79
# Buy score: -5.42%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   181.56
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            188.92091
# Trailing EPS                      5.49
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 181.70
# Daylow                                  175.58
# Exchange                                   NMS
# Fiftydayaverage                         169.90
# Lastprice                               181.54
# ...
