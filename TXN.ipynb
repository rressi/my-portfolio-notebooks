# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 161.49 | 169.56 | 178.04 | 175.28 | 184.04 | 193.24 | 202.90
# Buy score: -0.93%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   176.58
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            202.84697
# Trailing EPS                      5.47
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 177.63
# Daylow                                  174.57
# Exchange                                   NMS
# Fiftydayaverage                         186.94
# Lastprice                               176.58
# ...
