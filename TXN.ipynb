# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 162.91 | 171.05 | 179.61 | 181.71 | 190.80 | 200.34 | 210.36
# Buy score: 0.12%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   181.81
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            205.27121
# Trailing EPS                      5.47
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 183.23
# Daylow                                  179.34
# Exchange                                   NMS
# Fiftydayaverage                         188.73
# Lastprice                               181.81
# ...
