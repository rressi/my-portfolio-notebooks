# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 163.38 | 171.54 | 180.12 | 189.13 | 198.58 | 208.51 | 218.94
# Buy score: -0.43%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   189.07
# Forward EPS                    6.14154
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.10274
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 190.82
# Daylow                                  188.00
# Exchange                                   NMS
# Fiftydayaverage                         171.05
# Lastprice                               189.07
# ...
