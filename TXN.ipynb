# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 192.47 | 202.09 | 212.19 | 222.80 | 233.94 | 245.64 | 257.92
# Buy score: -0.87%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   224.77
# Forward EPS                    7.90288
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            218.70593
# Trailing EPS                      5.44
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 225.29
# Daylow                                  221.54
# Exchange                                   NMS
# Fiftydayaverage                         192.56
# Lastprice                               224.77
# ...
