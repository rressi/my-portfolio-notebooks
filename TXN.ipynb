# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 162.76 | 170.90 | 179.44 | 188.41 | 197.83 | 207.73 | 218.11
# Buy score: 0.09%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   188.53
# Forward EPS                    6.13086
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.10274
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 189.75
# Daylow                                  187.65
# Exchange                                   NMS
# Fiftydayaverage                         171.63
# Lastprice                               188.53
# ...
