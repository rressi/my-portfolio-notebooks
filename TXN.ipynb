# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 150.87 | 158.42 | 166.34 | 161.47 | 169.54 | 178.02 | 186.92
# Buy score: 0.12%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  161.275
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.55727
# Trailing EPS                      5.49
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 162.17
# Daylow                                  159.88
# Exchange                                   NMS
# Fiftydayaverage                         176.76
# Lastprice                               161.27
# ...
