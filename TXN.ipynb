# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 162.00 | 170.11 | 178.61 | 176.26 | 185.08 | 194.33 | 204.05
# Buy score: 0.76%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   173.94
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            203.81667
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 176.27
# Daylow                                  171.45
# Exchange                                   NMS
# Fiftydayaverage                         187.54
# Lastprice                               173.94
# ...
