# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 179.29 | 188.26 | 197.67 | 207.55 | 217.93 | 228.83 | 240.27
# Buy score: -3.79%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   214.73
# Forward EPS                     7.9086
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            222.95593
# Trailing EPS                      5.45
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 217.32
# Daylow                                  213.92
# Exchange                                   NMS
# Fiftydayaverage                         206.69
# Lastprice                               214.73
# ...
