# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 154.78 | 162.51 | 170.64 | 179.17 | 188.13 | 197.54 | 207.41
# Buy score: -6.81%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   192.23
# Forward EPS                    6.17248
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.10274
# Trailing EPS                      5.49
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 192.92
# Daylow                                  180.09
# Exchange                                   NMS
# Fiftydayaverage                         169.47
# Lastprice                               192.26
# ...
