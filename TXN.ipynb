# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 149.44 | 156.91 | 164.76 | 160.95 | 169.00 | 177.45 | 186.32
# Buy score: 1.15%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  159.115
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.55727
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 160.88
# Daylow                                  158.37
# Exchange                                   NMS
# Fiftydayaverage                         174.80
# Lastprice                               159.12
# ...
