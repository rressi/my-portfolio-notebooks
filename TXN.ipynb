# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 192.61 | 202.24 | 212.35 | 222.96 | 234.11 | 245.82 | 258.11
# Buy score: 0.76%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  221.275
# Forward EPS                     7.8386
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            216.48094
# Trailing EPS                      5.45
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 221.74
# Daylow                                  218.24
# Exchange                                   NMS
# Fiftydayaverage                         188.04
# Lastprice                               221.27
# ...
