# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 152.20 | 159.81 | 167.80 | 161.26 | 169.33 | 177.79 | 186.68
# Buy score: 0.21%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   160.55
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.55727
# Trailing EPS                      5.49
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 160.60
# Daylow                                  156.89
# Exchange                                   NMS
# Fiftydayaverage                         177.59
# Lastprice                               160.55
# ...
