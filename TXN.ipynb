# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 187.43 | 196.81 | 206.65 | 216.98 | 227.83 | 239.22 | 251.18
# Buy score: 1.43%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                    213.9
# Forward EPS                    7.90645
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            221.45593
# Trailing EPS                      5.45
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 215.90
# Daylow                                  210.23
# Exchange                                   NMS
# Fiftydayaverage                         198.87
# Lastprice                               213.90
# ...
