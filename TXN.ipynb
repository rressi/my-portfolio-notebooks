# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 161.48 | 169.56 | 178.03 | 175.20 | 183.96 | 193.16 | 202.82
# Buy score: -0.58%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   176.22
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            204.49844
# Trailing EPS                      5.47
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 177.62
# Daylow                                  174.57
# Exchange                                   NMS
# Fiftydayaverage                         187.13
# Lastprice                               176.22
# ...
