# %%
import workflow
workflow.run(
    security = "TXN",  # Texas Instruments Incorporated
    start_date="2025-01-01",
)
# Out:
# Prices: 159.69 | 167.67 | 176.06 | 184.86 | 194.10 | 203.81 | 214.00
# Buy score: 4.07%
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   177.63
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price             206.0288
# Trailing EPS                      5.47
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 181.14
# Daylow                                  177.28
# Exchange                                   NMS
# Fiftydayaverage                         197.44
# Lastprice                               177.63
# Lastvolume                           7,918,300
# ...
