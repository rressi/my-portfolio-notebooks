# %%
import workflow
workflow.run(
    security = "TXN",  # Texas Instruments Incorporated
)
# Out:
# Prices: 168.83 | 177.28 | 186.14 | 195.4475 | 205.22 | 215.48 | 226.25
# Buy score: 7.04%
#                                    TXN
# Company Name         Texas Instruments
# Current Price                    182.6
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            205.27121
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 184.34
# Daylow                                  182.34
# Exchange                                   NMS
# Fiftydayaverage                         198.20
# Lastprice                               182.60
# Lastvolume                           6,282,500
# ...
