# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 161.31 | 169.37 | 177.84 | 177.55 | 186.43 | 195.75 | 205.54
# Buy score: 7.35%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   180.84
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            201.33182
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 181.84
# Daylow                                  178.84
# Exchange                                   NMS
# Fiftydayaverage                         186.73
# Lastprice                               180.84
# ...
