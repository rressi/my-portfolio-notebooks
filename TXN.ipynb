# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 153.01 | 160.66 | 168.69 | 177.13 | 185.98 | 195.28 | 205.05
# Buy score: 0.55%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   176.19
# Forward EPS                    6.17248
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            188.49667
# Trailing EPS                       5.5
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 178.90
# Daylow                                  175.90
# Exchange                                   NMS
# Fiftydayaverage                         169.43
# Lastprice                               176.19
# ...
