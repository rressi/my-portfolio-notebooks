# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 147.64 | 155.03 | 162.78 | 157.56 | 165.44 | 173.71 | 182.39
# Buy score: -0.94%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   159.06
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.55727
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 159.06
# Daylow                                  157.86
# Exchange                                   NMS
# Fiftydayaverage                         172.52
# Lastprice                               159.06
# ...
