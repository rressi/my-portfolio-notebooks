# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 159.06 | 167.01 | 175.36 | 184.13 | 193.33 | 203.00 | 213.15
# Buy score: -2.13%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   188.14
# Forward EPS                    6.11764
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.10274
# Trailing EPS                       5.5
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 188.55
# Daylow                                  182.55
# Exchange                                   NMS
# Fiftydayaverage                         170.20
# Lastprice                               188.14
# ...
