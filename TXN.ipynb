# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 191.81 | 201.40 | 211.47 | 222.04 | 233.14 | 244.80 | 257.04
# Buy score: 0.24%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  221.515
# Forward EPS                     7.8386
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            215.37544
# Trailing EPS                      5.44
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 222.97
# Daylow                                  218.90
# Exchange                                   NMS
# Fiftydayaverage                         185.55
# Lastprice                               221.51
# ...
