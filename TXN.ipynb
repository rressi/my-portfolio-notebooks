# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 191.91 | 201.50 | 211.58 | 222.16 | 233.27 | 244.93 | 257.18
# Buy score: 2.11%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   217.48
# Forward EPS                    7.91002
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            220.67468
# Trailing EPS                      5.45
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 220.20
# Daylow                                  216.53
# Exchange                                   NMS
# Fiftydayaverage                         196.01
# Lastprice                               217.57
# ...
