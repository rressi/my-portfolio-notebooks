# %%
import workflow
workflow.run(
    security = "TXN",  # Texas Instruments Incorporated
    start_date="2025-01-01",
)
# Out:
# Prices: 166.73 | 175.07 | 183.82 | 183.32 | 192.48 | 202.11 | 212.21
# Buy score: 1.67%
#                                    TXN
# Company Name         Texas Instruments
# Current Price                    180.3
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price             206.0288
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 182.57
# Daylow                                  177.61
# Exchange                                   NMS
# Fiftydayaverage                         196.73
# Lastprice                               180.30
# Lastvolume                           7,204,300
# ...
