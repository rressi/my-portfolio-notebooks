# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 161.31 | 169.38 | 177.85 | 177.63 | 186.51 | 195.83 | 205.62
# Buy score: -1.98%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   181.21
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            201.33182
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 181.30
# Daylow                                  178.84
# Exchange                                   NMS
# Fiftydayaverage                         186.79
# Lastprice                               181.21
# ...
