# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 149.90 | 157.40 | 165.26 | 161.13 | 169.18 | 177.64 | 186.52
# Buy score: -0.35%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  161.685
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.55727
# Trailing EPS                       5.5
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 165.43
# Daylow                                  161.48
# Exchange                                   NMS
# Fiftydayaverage                         175.30
# Lastprice                               161.68
# ...
