# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 162.16 | 170.26 | 178.78 | 176.88 | 185.73 | 195.01 | 204.77
# Buy score: 0.99%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   175.11
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price             204.1197
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 176.10
# Daylow                                  172.40
# Exchange                                   NMS
# Fiftydayaverage                         187.83
# Lastprice                               175.11
# ...
