# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 174.46 | 179.70 | 185.09 | 182.54 | 188.01 | 193.65 | 199.46
# Buy score: -0.98%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   184.55
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            205.27121
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 187.29
# Daylow                                  183.07
# Exchange                                   NMS
# Fiftydayaverage                         190.89
# Lastprice                               184.55
# ...
