# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 184.56 | 193.78 | 203.47 | 213.65 | 224.33 | 235.55 | 247.32
# Buy score: -5.17%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   225.01
# Forward EPS                     7.8386
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            215.07242
# Trailing EPS                      5.45
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 225.26
# Daylow                                  214.84
# Exchange                                   NMS
# Fiftydayaverage                         182.79
# Lastprice                               225.01
# ...
