# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 168.61 | 177.04 | 185.89 | 195.19 | 204.95 | 215.19 | 225.95
# Buy score: -7.70%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   196.63
# Forward EPS                    7.75176
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                245.0
# Target Low Price                 140.0
# Target Mean Price            199.49667
# Trailing EPS                      5.45
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 198.41
# Daylow                                  194.34
# Exchange                                   NMS
# Fiftydayaverage                         177.96
# Lastprice                               196.63
# ...
