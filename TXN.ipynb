# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 162.72 | 170.86 | 179.40 | 180.38 | 189.40 | 198.87 | 208.81
# Buy score: 1.74%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   177.05
# Forward EPS                       5.88
# Gross Profit (ttm)       9,676,000,256
# Industry                Semiconductors
# Revenue (ttm)           16,675,000,320
# Target High Price                260.0
# Target Low Price                 125.0
# Target Mean Price            205.27121
# Trailing EPS                      5.47
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 182.02
# Daylow                                  176.96
# Exchange                                   NMS
# Fiftydayaverage                         188.43
# Lastprice                               177.05
# ...
