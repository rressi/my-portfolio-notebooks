# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 160.57 | 168.60 | 177.03 | 176.13 | 184.93 | 194.18 | 203.89
# Buy score: 1.86%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                 172.9111
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price               190.83
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 173.76
# Daylow                                  169.75
# Exchange                                   NMS
# Fiftydayaverage                         186.29
# Lastprice                               172.91
# ...
