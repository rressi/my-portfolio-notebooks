# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 191.78 | 201.37 | 211.44 | 222.01 | 233.11 | 244.77 | 257.01
# Buy score: -0.16%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   222.37
# Forward EPS                    7.90288
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            218.70593
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 229.50
# Daylow                                  222.00
# Exchange                                   NMS
# Fiftydayaverage                         191.46
# Lastprice                               222.37
# ...
