# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 153.02 | 160.67 | 168.70 | 177.14 | 185.99 | 195.29 | 205.06
# Buy score: 0.77%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   175.78
# Forward EPS                    6.17248
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.10274
# Trailing EPS                      5.48
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 177.65
# Daylow                                  175.10
# Exchange                                   NMS
# Fiftydayaverage                         169.55
# Lastprice                               175.78
# ...
