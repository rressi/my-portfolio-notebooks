# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 154.37 | 162.09 | 170.20 | 160.26 | 168.27 | 176.68 | 185.52
# Buy score: -0.11%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                  160.425
# Forward EPS                       5.88
# Gross Profit (ttm)       9,925,000,192
# Industry                Semiconductors
# Revenue (ttm)           17,265,999,872
# Target High Price                245.0
# Target Low Price                 125.0
# Target Mean Price            189.55727
# Trailing EPS                       5.5
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 161.00
# Daylow                                  159.39
# Exchange                                   NMS
# Fiftydayaverage                         180.62
# Lastprice                               160.43
# ...
