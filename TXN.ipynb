# %%
import my_portfolio; my_portfolio.run("TXN")
# Out:
# No operations found for ticker 'TXN'
# Prices: 192.10 | 201.70 | 211.78 | 222.37 | 233.49 | 245.17 | 257.43
# Buy score: -1.93%
# No operations found.
#                                    TXN
# Company Name         Texas Instruments
# Current Price                   226.76
# Forward EPS                    7.90288
# Gross Profit (ttm)      10,083,000,320
# Industry                Semiconductors
# Revenue (ttm)           17,681,999,872
# Target High Price                270.0
# Target Low Price                 160.0
# Target Mean Price            218.70593
# Trailing EPS                      5.46
# Website             https://www.ti.com
#                                            TXN
# Currency                                   USD
# Dayhigh                                 231.32
# Daylow                                  223.12
# Exchange                                   NMS
# Fiftydayaverage                         190.29
# Lastprice                               226.76
# ...
