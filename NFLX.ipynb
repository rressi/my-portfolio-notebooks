# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 85.30 | 89.56 | 94.04 | 87.23 | 91.59 | 96.17 | 100.98
# Buy score: 3.50%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                       84.2799
# Forward EPS                          3.8582
# Gross Profit (ttm)           20,858,714,112
# Industry                      Entertainment
# Revenue (ttm)                43,378,786,304
# Target High Price                     151.4
# Target Low Price                       79.0
# Target Mean Price                 119.09475
# Trailing EPS                           2.53
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                                  85.22
# Daylow                                   81.95
# Exchange                                   NMS
# Fiftydayaverage                          99.25
# ...
