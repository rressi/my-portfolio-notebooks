# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 1,032.95 | 1,084.59 | 1,138.82 | 1,102.97 | 1,158.12 | 1,216.03 | 1,276.83
# Buy score: -2.28%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                       1128.73
# Forward EPS                           23.78
# Gross Profit (ttm)           20,858,714,112
# Industry                      Entertainment
# Revenue (ttm)                43,378,786,304
# Target High Price                    1600.0
# Target Low Price                      770.0
# Target Mean Price                 1347.3231
# Trailing EPS                          23.96
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                               1,129.47
# Daylow                                1,101.98
# Exchange                                   NMS
# ...
