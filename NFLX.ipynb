# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 100.70 | 105.73 | 111.02 | 112.20 | 117.81 | 123.70 | 129.89
# Buy score: 1.27%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                         110.0
# Forward EPS                           23.78
# Gross Profit (ttm)           20,858,714,112
# Industry                      Entertainment
# Revenue (ttm)                43,378,786,304
# Target High Price                     160.0
# Target Low Price                       77.0
# Target Mean Price                 134.65277
# Trailing EPS                            2.4
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                                 113.34
# Daylow                                  108.61
# Exchange                                   NMS
# Fiftydayaverage                         116.57
# ...
