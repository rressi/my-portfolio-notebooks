# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 1,049.16 | 1,101.62 | 1,156.70 | 1,213.23 | 1,273.89 | 1,337.59 | 1,404.47
# Buy score: 4.89%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                       1241.35
# Forward EPS                           23.78
# Gross Profit (ttm)           20,217,477,120
# Industry                      Entertainment
# Revenue (ttm)                41,693,184,000
# Target High Price                    1600.0
# Target Low Price                      750.0
# Target Mean Price                 1348.7418
# Trailing EPS                          23.46
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                               1,248.60
# Daylow                                1,231.76
# Exchange                                   NMS
# ...
