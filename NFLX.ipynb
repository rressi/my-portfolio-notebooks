# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 86.01 | 90.31 | 94.83 | 99.57 | 104.55 | 109.78 | 115.26
# Buy score: -2.24%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                        102.05
# Forward EPS                         3.86669
# Gross Profit (ttm)           21,907,707,904
# Industry                      Entertainment
# Revenue (ttm)                45,183,037,440
# Target High Price                     151.4
# Target Low Price                       80.0
# Target Mean Price                 113.78689
# Trailing EPS                           2.53
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                                 102.34
# Daylow                                   99.08
# Exchange                                   NMS
# Fiftydayaverage                          89.33
# ...
