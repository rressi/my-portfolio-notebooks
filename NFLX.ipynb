# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 96.46 | 101.29 | 106.35 | 98.12 | 103.02 | 108.17 | 113.58
# Buy score: 4.80%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                         93.61
# Forward EPS                         3.24025
# Gross Profit (ttm)           20,858,714,112
# Industry                      Entertainment
# Revenue (ttm)                43,378,786,304
# Target High Price                     152.5
# Target Low Price                       77.0
# Target Mean Price                 129.30653
# Trailing EPS                            2.4
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                                  96.96
# Daylow                                   93.56
# Exchange                                   NMS
# Fiftydayaverage                         112.19
# ...
