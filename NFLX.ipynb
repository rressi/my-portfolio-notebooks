# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 1,043.36 | 1,095.53 | 1,150.31 | 1,160.91 | 1,218.96 | 1,279.91 | 1,343.90
# Buy score: 6.16%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                       1094.69
# Forward EPS                           23.78
# Gross Profit (ttm)           20,858,714,112
# Industry                      Entertainment
# Revenue (ttm)                43,378,786,304
# Target High Price                    1600.0
# Target Low Price                      770.0
# Target Mean Price                 1341.6187
# Trailing EPS                          23.97
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                               1,114.51
# Daylow                                1,094.41
# Exchange                                   NMS
# ...
