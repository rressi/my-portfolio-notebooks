# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 1,015.72 | 1,066.50 | 1,119.83 | 1,126.80 | 1,183.14 | 1,242.30 | 1,304.42
# Buy score: 0.94%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                       1116.35
# Forward EPS                           23.78
# Gross Profit (ttm)           20,858,714,112
# Industry                      Entertainment
# Revenue (ttm)                43,378,786,304
# Target High Price                    1600.0
# Target Low Price                      770.0
# Target Mean Price                 1346.6414
# Trailing EPS                          23.89
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                               1,142.22
# Daylow                                1,107.21
# Exchange                                   NMS
# ...
