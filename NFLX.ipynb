# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 98.10 | 103.01 | 108.16 | 106.62 | 111.95 | 117.55 | 123.43
# Buy score: 3.43%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                       103.085
# Forward EPS                           23.78
# Gross Profit (ttm)           20,858,714,112
# Industry                      Entertainment
# Revenue (ttm)                43,378,786,304
# Target High Price                     160.0
# Target Low Price                       77.0
# Target Mean Price                   134.442
# Trailing EPS                           2.39
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                                 103.64
# Daylow                                  101.77
# Exchange                                   NMS
# Fiftydayaverage                         113.91
# ...
