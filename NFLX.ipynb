# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 1,045.69 | 1,097.97 | 1,152.87 | 1,181.59 | 1,240.67 | 1,302.71 | 1,367.84
# Buy score: 6.23%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                      1112.325
# Forward EPS                           23.78
# Gross Profit (ttm)           20,858,714,112
# Industry                      Entertainment
# Revenue (ttm)                43,378,786,304
# Target High Price                    1600.0
# Target Low Price                      770.0
# Target Mean Price                 1341.6187
# Trailing EPS                          23.89
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                               1,127.83
# Daylow                                1,099.73
# Exchange                                   NMS
# ...
