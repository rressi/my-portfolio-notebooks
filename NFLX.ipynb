# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 80.37 | 84.39 | 88.61 | 87.20 | 91.56 | 96.14 | 100.95
# Buy score: 1.41%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                         86.02
# Forward EPS                         3.84287
# Gross Profit (ttm)           22,989,572,096
# Industry                      Entertainment
# Revenue (ttm)                46,889,992,192
# Target High Price                     151.4
# Target Low Price                       80.0
# Target Mean Price                   114.555
# Trailing EPS                            3.1
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                                  86.67
# Daylow                                   85.66
# Exchange                                   NMS
# Fiftydayaverage                          93.04
# ...
