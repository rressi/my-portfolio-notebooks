# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 1,048.30 | 1,100.71 | 1,155.75 | 1,204.12 | 1,264.33 | 1,327.55 | 1,393.92
# Buy score: 0.39%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                       1199.36
# Forward EPS                           23.78
# Gross Profit (ttm)           20,217,477,120
# Industry                      Entertainment
# Revenue (ttm)                41,693,184,000
# Target High Price                    1600.0
# Target Low Price                      750.0
# Target Mean Price                 1349.8782
# Trailing EPS                          23.51
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                               1,203.12
# Daylow                                1,178.95
# Exchange                                   NMS
# ...
