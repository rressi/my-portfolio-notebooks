# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 75.88 | 79.67 | 83.66 | 77.25 | 81.11 | 85.17 | 89.43
# Buy score: -1.63%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                        78.535
# Forward EPS                         3.82081
# Gross Profit (ttm)           21,907,707,904
# Industry                      Entertainment
# Revenue (ttm)                45,183,037,440
# Target High Price                     151.4
# Target Low Price                       79.0
# Target Mean Price                 111.42846
# Trailing EPS                           2.53
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                                  78.70
# Daylow                                   77.37
# Exchange                                   NMS
# Fiftydayaverage                          88.27
# ...
