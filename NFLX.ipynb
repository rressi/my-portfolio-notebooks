# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 86.76 | 91.10 | 95.66 | 100.44 | 105.46 | 110.74 | 116.27
# Buy score: -2.68%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                        103.01
# Forward EPS                         3.86669
# Gross Profit (ttm)           21,907,707,904
# Industry                      Entertainment
# Revenue (ttm)                45,183,037,440
# Target High Price                     151.4
# Target Low Price                       80.0
# Target Mean Price                 114.03133
# Trailing EPS                           2.53
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                                 103.08
# Daylow                                  101.46
# Exchange                                   NMS
# Fiftydayaverage                          89.70
# ...
