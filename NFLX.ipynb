# %%
import my_portfolio; my_portfolio.run("NFLX")
# Out:
# No operations found for ticker 'NFLX'
# Prices: 89.67 | 94.15 | 98.86 | 93.43 | 98.10 | 103.01 | 108.16
# Buy score: 2.51%
# No operations found.
#                                        NFLX
# Company Name                        Netflix
# Current Price                         90.99
# Forward EPS                         3.24255
# Gross Profit (ttm)           20,858,714,112
# Industry                      Entertainment
# Revenue (ttm)                43,378,786,304
# Target High Price                     152.5
# Target Low Price                       77.0
# Target Mean Price                 126.19184
# Trailing EPS                           2.39
# Website             https://www.netflix.com
#                                           NFLX
# Currency                                   USD
# Dayhigh                                  94.13
# Daylow                                   90.81
# Exchange                                   NMS
# Fiftydayaverage                         104.47
# ...
