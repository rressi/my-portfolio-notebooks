# %%
import my_portfolio; my_portfolio.run("AMD")
# Out:
# Prices: 191.92 | 201.51 | 211.59 | 210.51 | 221.04 | 232.09 | 243.69
# Buy score: -5.39%
# Sell score: 5.10%
# Current return: 384.86 USD
# Breakeven price: 213.54 USD
# <style type="text/css">
# #T_56726_row60_col0, #T_56726_row60_col1, #T_56726_row60_col2, #T_56726_row60_col3, #T_56726_row60_col4, #T_56726_row60_col5, #T_56726_row60_col6, #T_56726_row60_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_56726">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56726_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_56726_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_56726_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_56726_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_56726_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
