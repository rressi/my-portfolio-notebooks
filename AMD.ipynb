# %%
import my_portfolio; my_portfolio.run("AMD")
# Out:
# Prices: 222.00 | 233.10 | 244.76 | 253.12 | 265.78 | 279.07 | 293.02
# Buy score: 7.89%
# Sell score: -5.90%
# Current return: -373.66 USD
# Breakeven price: 256.88 USD
# <style type="text/css">
# #T_cfd9c_row56_col0, #T_cfd9c_row56_col1, #T_cfd9c_row56_col2, #T_cfd9c_row56_col3, #T_cfd9c_row56_col4, #T_cfd9c_row56_col5, #T_cfd9c_row56_col6, #T_cfd9c_row56_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_cfd9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfd9c_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_cfd9c_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_cfd9c_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_cfd9c_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_cfd9c_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
