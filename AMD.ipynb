# %%
import my_portfolio; my_portfolio.run("AMD")
# Out:
# Prices: 223.14 | 234.30 | 246.02 | 251.45 | 264.02 | 277.23 | 291.09
# Buy score: 0.65%
# Sell score: 2.06%
# Current return: 36.42 USD
# Breakeven price: 255.12 USD
# <style type="text/css">
# #T_9bc68_row57_col0, #T_9bc68_row57_col1, #T_9bc68_row57_col2, #T_9bc68_row57_col3, #T_9bc68_row57_col4, #T_9bc68_row57_col5, #T_9bc68_row57_col6, #T_9bc68_row57_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_9bc68">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bc68_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_9bc68_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_9bc68_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_9bc68_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_9bc68_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
