# %%
import my_portfolio; my_portfolio.run("AMD")
# Out:
# Prices: 223.46 | 234.64 | 246.37 | 260.95 | 274.00 | 287.70 | 302.09
# Buy score: -0.55%
# Sell score: -0.32%
# Current return: -31.25 USD
# Breakeven price: 264.59 USD
# <style type="text/css">
# #T_853da_row54_col0, #T_853da_row54_col1, #T_853da_row54_col2, #T_853da_row54_col3, #T_853da_row54_col4, #T_853da_row54_col5, #T_853da_row54_col6, #T_853da_row54_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_853da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_853da_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_853da_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_853da_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_853da_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_853da_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
