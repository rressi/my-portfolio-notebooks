# %%
import my_portfolio; my_portfolio.run("AMD")
# Out:
# Prices: 213.89 | 224.58 | 235.81 | 260.95 | 274.00 | 287.70 | 302.09
# Buy score: -4.79%
# Sell score: -0.34%
# Current return: -31.67 USD
# Breakeven price: 264.59 USD
# <style type="text/css">
# #T_f8137_row54_col0, #T_f8137_row54_col1, #T_f8137_row54_col2, #T_f8137_row54_col3, #T_f8137_row54_col4, #T_f8137_row54_col5, #T_f8137_row54_col6, #T_f8137_row54_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_f8137">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8137_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_f8137_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_f8137_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_f8137_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_f8137_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
