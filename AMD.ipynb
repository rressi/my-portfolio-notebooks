# %%
import workflow
workflow.run(
    security = "AMD",
    buy_date = "2025-08-19",
    buy_price = 166.72,
    # start_date = "2025-01-01",
)
# Out:
# Prices: 141.93 | 149.02 | 156.47 | 166.7200 | 175.06 | 183.81 | 193.00
# Buy score: 5.54%
# Sell score: -6.63%
#                                        AMD
# Company Name        Advanced Micro Devices
# Industry                    Semiconductors
# Revenue (ttm)               29,600,000,000
# Gross Profit (ttm)          15,091,999,744
# Current Price                       155.67
# Target Mean Price                185.77432
# Target High Price                    230.0
# Target Low Price                     125.1
# Trailing EPS                          1.68
# Forward EPS                            5.1
# Website                https://www.amd.com
#                                            AMD
# Currency                                   USD
# Dayhigh                                 160.21
# Daylow                                  154.99
# Exchange                                   NMS
# Fiftydayaverage                         161.85
# Lastprice                               155.67
# ...
