# %%
import my_portfolio; my_portfolio.run("AMD")
# Out:
# Prices: 192.50 | 202.13 | 212.23 | 210.51 | 221.04 | 232.09 | 243.69
# Buy score: 0.19%
# Sell score: -1.39%
# Current return: -297.64 USD
# Breakeven price: 213.54 USD
# <style type="text/css">
# #T_b9795_row60_col0, #T_b9795_row60_col1, #T_b9795_row60_col2, #T_b9795_row60_col3, #T_b9795_row60_col4, #T_b9795_row60_col5, #T_b9795_row60_col6, #T_b9795_row60_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_b9795">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9795_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_b9795_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_b9795_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_b9795_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_b9795_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
