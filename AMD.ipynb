# %%
import my_portfolio; my_portfolio.run("AMD")
# Out:
# Prices: 223.00 | 234.15 | 245.85 | 253.12 | 265.78 | 279.07 | 293.02
# Buy score: 0.92%
# Sell score: 1.06%
# Current return: -21.74 USD
# Breakeven price: 256.88 USD
# <style type="text/css">
# #T_d2687_row56_col0, #T_d2687_row56_col1, #T_d2687_row56_col2, #T_d2687_row56_col3, #T_d2687_row56_col4, #T_d2687_row56_col5, #T_d2687_row56_col6, #T_d2687_row56_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_d2687">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2687_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_d2687_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_d2687_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_d2687_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_d2687_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
