# %%
import my_portfolio; my_portfolio.run("AMD")
# Out:
# Prices: 196.12 | 205.92 | 216.22 | 212.19 | 222.80 | 233.94 | 245.64
# Buy score: 2.39%
# Sell score: 0.19%
# Current return: -69.03 USD
# Breakeven price: 214.33 USD
# <style type="text/css">
# #T_ba7bf_row59_col0, #T_ba7bf_row59_col1, #T_ba7bf_row59_col2, #T_ba7bf_row59_col3, #T_ba7bf_row59_col4, #T_ba7bf_row59_col5, #T_ba7bf_row59_col6, #T_ba7bf_row59_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_ba7bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba7bf_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_ba7bf_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_ba7bf_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_ba7bf_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_ba7bf_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
