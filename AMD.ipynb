# %%
import my_portfolio; my_portfolio.run("AMD")
# Out:
# Prices: 138.67 | 145.60 | 152.88 | 160.57 | 168.59 | 177.02 | 185.88
# Buy score: 0.20%
# Sell score: -1.98%
#                                        AMD
# Company Name        Advanced Micro Devices
# Current Price                       157.39
# Forward EPS                            5.1
# Gross Profit (ttm)          15,091,999,744
# Industry                    Semiconductors
# Revenue (ttm)               29,600,000,000
# Target High Price                    230.0
# Target Low Price                     125.1
# Target Mean Price                185.77432
# Trailing EPS                          1.67
# Website                https://www.amd.com
#                                            AMD
# Currency                                   USD
# Dayhigh                                 159.84
# Daylow                                  155.90
# Exchange                                   NMS
# Fiftydayaverage                         164.70
# Lastprice                               157.39
# ...
