# %%
import my_portfolio; my_portfolio.run("BTC-USD")
# Out:
# Prices: 98,703.64 | 103,638.83 | 108,820.77 | 106,935.00 | 112,281.75 | 117,895.84 | 123,790.63
# Buy score: -1.85%
# Sell score: 3.52%
# Current return: 32.55 USD
# Breakeven price: 109,073.00 USD
# <style type="text/css">
# #T_5ad9d_row20_col0, #T_5ad9d_row20_col1, #T_5ad9d_row20_col2, #T_5ad9d_row20_col3, #T_5ad9d_row20_col4, #T_5ad9d_row20_col5, #T_5ad9d_row20_col6, #T_5ad9d_row20_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_5ad9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ad9d_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_5ad9d_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_5ad9d_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_5ad9d_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_5ad9d_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
