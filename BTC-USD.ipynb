# %%
import my_portfolio; my_portfolio.run("BTC-USD")
# Out:
# Prices: 98,697.79 | 103,632.68 | 108,814.31 | 108,204.80 | 113,615.04 | 119,295.79 | 125,260.58
# Buy score: -0.22%
# Sell score: 0.30%
# Current return: -91.75 USD
# Breakeven price: 110,368.80 USD
# <style type="text/css">
# #T_8a112_row23_col0, #T_8a112_row23_col1, #T_8a112_row23_col2, #T_8a112_row23_col3, #T_8a112_row23_col4, #T_8a112_row23_col5, #T_8a112_row23_col6, #T_8a112_row23_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_8a112">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a112_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_8a112_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_8a112_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_8a112_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_8a112_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
