# %%
import my_portfolio; my_portfolio.run("BTC-USD")
# Out:
# Prices: 98,667.55 | 103,600.92 | 108,780.97 | 106,935.00 | 112,281.75 | 117,895.84 | 123,790.63
# Buy score: 2.02%
# Sell score: 0.01%
# Current return: -42.63 USD
# <style type="text/css">
# #T_58ddd_row20_col0, #T_58ddd_row20_col1, #T_58ddd_row20_col2, #T_58ddd_row20_col3, #T_58ddd_row20_col4, #T_58ddd_row20_col5, #T_58ddd_row20_col6, #T_58ddd_row20_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_58ddd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58ddd_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_58ddd_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_58ddd_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_58ddd_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_58ddd_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
