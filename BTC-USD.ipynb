# %%
import workflow
workflow.run(
    security = "BTC-USD",  # Bitcoin
    start_date = "2025-03-01",
)
# Out:
# Prices: 95,929.72 | 100,726.21 | 105,762.52 | 111050.6417 | 116,603.17 | 122,433.33 | 128,555.00
# Buy score: -3.65%
#                         BTC-USD
# Company Name        Bitcoin USD
# Industry                   None
# Revenue (ttm)              None
# Gross Profit (ttm)         None
# Current Price              None
# Target Mean Price          None
# Target High Price          None
# Target Low Price           None
# Trailing EPS               None
# Forward EPS                None
# Website                    None
#                                    BTC-USD
# Currency                               USD
# Dayhigh                         115,265.66
# Daylow                          113,504.38
# Exchange                               CCC
# Fiftydayaverage                 114,679.45
# Lastprice                       115,260.58
# Lastvolume                  46,090,625,024
# Marketcap                             None
# Open                            113,963.09
# ...
