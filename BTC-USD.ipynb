# %%
import workflow
workflow.run(
    security = "BTC-USD",  # Bitcoin
    start_date = "2025-03-01",
)
# Out:
# Prices: 96,235.22 | 101,046.98 | 106,099.33 | 111404.3004 | 116,974.52 | 122,823.24 | 128,964.40
# Buy score: -3.63%
#                         BTC-USD
# Company Name        Bitcoin USD
# Industry                   None
# Revenue (ttm)              None
# Gross Profit (ttm)         None
# Current Price              None
# Target Mean Price          None
# Target High Price          None
# Target Low Price           None
# Trailing EPS               None
# Forward EPS                None
# Website                    None
#                                    BTC-USD
# Currency                               USD
# Dayhigh                         116,287.50
# Daylow                          115,509.01
# Exchange                               CCC
# Fiftydayaverage                 114,596.28
# Lastprice                       115,605.13
# Lastvolume                  49,445,036,032
# Marketcap                             None
# Open                            115,509.01
# ...
