# %%
import workflow
workflow.run(
    security = "BTC-USD",  # Bitcoin
    # start_date = "2025-03-01",
)
# Out:
# Prices: 96,370.37 | 101,188.89 | 106,248.34 | 111560.7543 | 117,138.79 | 122,995.73 | 129,145.52
# Buy score: -3.79%
#                         BTC-USD
# Company Name        Bitcoin USD
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                    BTC-USD
# Currency                               USD
# Dayhigh                         116,310.38
# Daylow                          115,267.88
# Exchange                               CCC
# Fiftydayaverage                 114,569.17
# Lastprice                       115,957.85
# Lastvolume                  36,528,308,224
# Marketcap                             None
# Open                            116,104.31
# ...
