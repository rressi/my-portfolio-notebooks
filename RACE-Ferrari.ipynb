# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 415.68 | 436.47 | 458.29 | 481.21 | 505.27 | 530.53 | 557.06
# Buy score: -2.01%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        490.24
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                  610.3286
# Target Low Price                  445.51172
# Target Mean Price                  534.1318
# Trailing EPS                          10.67
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                490.99
# Daylow                                 481.75
# Exchange                                  NYQ
# Fiftydayaverage                        474.77
# ...
