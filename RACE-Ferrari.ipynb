# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 405.85 | 426.14 | 447.45 | 452.86 | 475.51 | 499.28 | 524.25
# Buy score: 14.44%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        395.34
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                 580.65265
# Target Low Price                  439.88156
# Target Mean Price                  522.5111
# Trailing EPS                          10.39
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                412.98
# Daylow                                 393.38
# Exchange                                  NYQ
# Fiftydayaverage                        470.78
# ...
