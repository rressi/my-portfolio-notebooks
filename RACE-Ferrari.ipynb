# %%
import workflow
workflow.run(
    security = "RACE",  # Ferrari N.V.
    # start_date="2025-04-01",
)
# Out:
# Prices: 417.03 | 437.88 | 459.77 | 482.76 | 506.90 | 532.25 | 558.86
# Buy score: 0.51%
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        480.33
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                  616.6983
# Target Low Price                   450.1613
# Target Mean Price                 537.21545
# Trailing EPS                          10.47
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                488.71
# Daylow                                 480.14
# Exchange                                  NYQ
# Fiftydayaverage                        478.37
# Lastprice                              480.33
# ...
