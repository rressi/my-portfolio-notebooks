# %%
import workflow
workflow.run(
    security = "RACE",  # Ferrari N.V.
)
# Out:
# Prices: 411.32 | 431.89 | 453.48 | 476.1570 | 499.96 | 524.96 | 551.21
# Buy score: -0.39%
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                         478.0
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                 610.04224
# Target Low Price                  445.30267
# Target Mean Price                  531.4173
# Trailing EPS                          10.42
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                479.10
# Daylow                                 476.00
# Exchange                                  NYQ
# Fiftydayaverage                        478.60
# Lastprice                              478.00
# ...
