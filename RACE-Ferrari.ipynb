# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 425.48 | 446.76 | 469.09 | 492.55 | 517.18 | 543.03 | 570.19
# Buy score: -1.29%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        501.15
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                  610.6871
# Target Low Price                   467.8873
# Target Mean Price                  540.5427
# Trailing EPS                          10.43
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                503.78
# Daylow                                 497.69
# Exchange                                  NYQ
# Fiftydayaverage                        473.99
# ...
