# %%
import workflow
workflow.run(
    security = "RACE",  # Ferrari N.V.
)
# Out:
# Prices: 413.58 | 434.26 | 455.97 | 478.7667 | 502.70 | 527.84 | 554.23
# Buy score: -0.12%
#                                        RACE
# Company Name                   Ferrari N.V.
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Gross Profit (ttm)            3,562,913,024
# Current Price                        479.36
# Target Mean Price                  531.9165
# Target High Price                 610.61536
# Target Low Price                    445.721
# Trailing EPS                          10.47
# Forward EPS                            9.53
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                481.38
# Daylow                                 475.07
# Exchange                                  NYQ
# Fiftydayaverage                        479.07
# Lastprice                              479.36
# ...
