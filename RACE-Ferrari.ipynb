# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# Prices: 414.29 | 435.00 | 456.76 | 478.10 | 502.00 | 527.11 | 553.46
# Buy score: -0.09%
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        477.74
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                   614.004
# Target Low Price                  448.19458
# Target Mean Price                  534.8684
# Trailing EPS                          10.46
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                479.45
# Daylow                                 473.70
# Exchange                                  NYQ
# Fiftydayaverage                        477.36
# Lastprice                              477.74
# ...
