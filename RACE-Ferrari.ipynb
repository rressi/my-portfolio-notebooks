# %%
import workflow
workflow.run(
    security = "RACE",  # Ferrari N.V.
    # start_date="2025-04-01",
)
# Out:
# Prices: 413.90 | 434.60 | 456.32 | 479.14 | 503.10 | 528.25 | 554.67
# Buy score: -0.96%
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        483.77
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                 613.13525
# Target Low Price                  447.56042
# Target Mean Price                 534.11163
# Trailing EPS                          10.48
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                485.09
# Daylow                                 475.60
# Exchange                                  NYQ
# Fiftydayaverage                        477.88
# Lastprice                              483.77
# ...
