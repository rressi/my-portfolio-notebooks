# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 404.86 | 425.11 | 446.36 | 430.38 | 451.90 | 474.49 | 498.22
# Buy score: 13.45%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        378.72
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                 579.24005
# Target Low Price                  438.55768
# Target Mean Price                  515.2005
# Trailing EPS                          10.34
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                387.14
# Daylow                                 377.64
# Exchange                                  NYQ
# Fiftydayaverage                        469.83
# ...
