# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 420.16 | 441.17 | 463.23 | 486.39 | 510.71 | 536.25 | 563.06
# Buy score: -2.55%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                       499.095
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                  609.3988
# Target Low Price                  444.83298
# Target Mean Price                   533.318
# Trailing EPS                          10.79
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                502.52
# Daylow                                 496.45
# Exchange                                  NYQ
# Fiftydayaverage                        474.56
# ...
