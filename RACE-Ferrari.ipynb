# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 414.14 | 434.84 | 456.59 | 479.42 | 503.39 | 528.56 | 554.98
# Buy score: -0.54%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        482.09
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                 609.97064
# Target Low Price                   445.2504
# Target Mean Price                  531.4471
# Trailing EPS                          10.46
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                483.11
# Daylow                                 480.11
# Exchange                                  NYQ
# Fiftydayaverage                        475.68
# ...
