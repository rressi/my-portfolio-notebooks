# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 428.10 | 449.50 | 471.98 | 495.57 | 520.35 | 546.37 | 573.69
# Buy score: 0.84%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        490.86
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                 604.15936
# Target Low Price                  462.88602
# Target Mean Price                 534.76483
# Trailing EPS                          10.46
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                495.00
# Daylow                                 488.98
# Exchange                                  NYQ
# Fiftydayaverage                        473.14
# ...
