# %%
import workflow
workflow.run(
    security = "RACE",  # Ferrari N.V.
    # start_date="2025-04-01",
)
# Out:
# Prices: 412.12 | 432.72 | 454.36 | 477.08 | 500.93 | 525.98 | 552.28
# Buy score: -0.39%
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        478.94
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                   612.774
# Target Low Price                   447.2967
# Target Mean Price                 533.79694
# Trailing EPS                          10.44
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                479.81
# Daylow                                 475.11
# Exchange                                  NYQ
# Fiftydayaverage                        478.60
# Lastprice                              478.94
# ...
