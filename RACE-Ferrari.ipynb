# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# Prices: 414.00 | 434.70 | 456.44 | 478.22 | 502.13 | 527.24 | 553.60
# Buy score: 0.26%
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        479.59
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                  610.7587
# Target Low Price                  445.82565
# Target Mean Price                  532.0414
# Trailing EPS                          10.55
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                482.45
# Daylow                                 475.01
# Exchange                                  NYQ
# Fiftydayaverage                        477.36
# Lastprice                              479.59
# ...
