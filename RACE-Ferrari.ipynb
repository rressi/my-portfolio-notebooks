# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 415.66 | 436.44 | 458.26 | 479.49 | 503.46 | 528.63 | 555.06
# Buy score: 0.10%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                         480.6
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                   610.974
# Target Low Price                  445.98282
# Target Mean Price                  532.3213
# Trailing EPS                          10.46
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                481.52
# Daylow                                 477.94
# Exchange                                  NYQ
# Fiftydayaverage                        477.07
# ...
