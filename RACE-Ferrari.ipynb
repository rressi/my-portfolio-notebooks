# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 425.49 | 446.76 | 469.10 | 492.56 | 517.18 | 543.04 | 570.20
# Buy score: -1.71%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        501.19
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                  610.8305
# Target Low Price                   467.9972
# Target Mean Price                 540.23016
# Trailing EPS                          10.43
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                503.78
# Daylow                                 497.70
# Exchange                                  NYQ
# Fiftydayaverage                        474.29
# ...
