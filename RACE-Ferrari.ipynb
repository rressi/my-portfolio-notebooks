# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 415.11 | 435.86 | 457.66 | 478.79 | 502.73 | 527.86 | 554.26
# Buy score: -1.08%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                         486.5
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                   614.004
# Target Low Price                  448.19458
# Target Mean Price                 534.96124
# Trailing EPS                          10.65
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                491.01
# Daylow                                 484.87
# Exchange                                  NYQ
# Fiftydayaverage                        477.10
# ...
