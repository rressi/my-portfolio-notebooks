# %%
import workflow
workflow.run(
    security = "RACE",  # Ferrari N.V.
)
# Out:
# Prices: 410.74 | 431.27 | 452.84 | 475.4785 | 499.25 | 524.22 | 550.43
# Buy score: -0.81%
#                                        RACE
# Company Name                   Ferrari N.V.
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Gross Profit (ttm)            3,562,913,024
# Current Price                        479.36
# Target Mean Price                  531.4173
# Target High Price                 610.04224
# Target Low Price                  445.30267
# Trailing EPS                          10.47
# Forward EPS                            9.53
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                481.38
# Daylow                                 475.07
# Exchange                                  NYQ
# Fiftydayaverage                        479.07
# Lastprice                              479.36
# ...
