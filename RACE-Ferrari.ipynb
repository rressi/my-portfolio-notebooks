# %%
import workflow
workflow.run(
    security = "RACE",  # Ferrari N.V.
    # start_date="2025-04-01",
)
# Out:
# Prices: 414.89 | 435.63 | 457.41 | 480.28 | 504.30 | 529.51 | 555.99
# Buy score: 2.18%
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        470.03
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                 614.51196
# Target Low Price                  448.56534
# Target Mean Price                  535.3109
# Trailing EPS                          10.42
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                473.50
# Daylow                                 467.47
# Exchange                                  NYQ
# Fiftydayaverage                        478.25
# Lastprice                              470.03
# ...
