# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 427.12 | 448.48 | 470.90 | 494.45 | 519.17 | 545.13 | 572.38
# Buy score: 0.59%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        491.53
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                 609.18463
# Target Low Price                  466.73618
# Target Mean Price                  539.2128
# Trailing EPS                          10.42
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                500.23
# Daylow                                 490.50
# Exchange                                  NYQ
# Fiftydayaverage                        473.99
# ...
