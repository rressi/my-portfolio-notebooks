# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 414.02 | 434.72 | 456.46 | 479.28 | 503.24 | 528.40 | 554.82
# Buy score: -0.78%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        485.22
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                 610.25696
# Target Low Price                   445.4594
# Target Mean Price                 534.06903
# Trailing EPS                          10.67
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                485.52
# Daylow                                 480.80
# Exchange                                  NYQ
# Fiftydayaverage                        474.77
# ...
