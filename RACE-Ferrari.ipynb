# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 415.82 | 436.61 | 458.44 | 478.87 | 502.81 | 527.95 | 554.35
# Buy score: 1.20%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                       473.189
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                  606.5555
# Target Low Price                   442.7575
# Target Mean Price                 528.47156
# Trailing EPS                          10.53
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                476.14
# Daylow                                 468.83
# Exchange                                  NYQ
# Fiftydayaverage                        476.94
# ...
