# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 415.64 | 436.43 | 458.25 | 479.46 | 503.43 | 528.60 | 555.03
# Buy score: -0.24%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                         480.5
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                 610.61536
# Target Low Price                    445.721
# Target Mean Price                  532.0088
# Trailing EPS                          10.46
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                481.52
# Daylow                                 477.94
# Exchange                                  NYQ
# Fiftydayaverage                        477.07
# ...
