# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 415.66 | 436.45 | 458.27 | 478.60 | 502.53 | 527.66 | 554.04
# Buy score: 1.18%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        475.36
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                   608.828
# Target Low Price                  444.41632
# Target Mean Price                 530.45154
# Trailing EPS                          10.55
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                476.07
# Daylow                                 472.22
# Exchange                                  NYQ
# Fiftydayaverage                        476.30
# ...
