# %%
import my_portfolio; my_portfolio.run("RACE")
# Out:
# No operations found for ticker 'RACE'
# Prices: 404.88 | 425.12 | 446.38 | 430.52 | 452.04 | 474.64 | 498.38
# Buy score: 13.47%
# No operations found.
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        379.41
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                  578.7707
# Target Low Price                  438.45587
# Target Mean Price                  514.8042
# Trailing EPS                          10.37
# Website             https://www.ferrari.com
#                                          RACE
# Currency                                  USD
# Dayhigh                                387.13
# Daylow                                 377.64
# Exchange                                  NYQ
# Fiftydayaverage                        469.83
# ...
