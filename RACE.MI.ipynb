# %%
import my_portfolio; my_portfolio.run(
    security="RACE.MI",
    trades_isin="NL0011585146",
)
# Out:
# Prices: 277.38 | 291.25 | 305.81 | 319.99 | 335.99 | 352.79 | 370.43
# Buy score: 1.74%
# Sell score: -1.37%
# Current return: -820.08 EUR
# Breakeven price: 323.80 EUR
# <style type="text/css">
# #T_ee9a6_row10_col0, #T_ee9a6_row10_col1, #T_ee9a6_row10_col2, #T_ee9a6_row10_col3, #T_ee9a6_row10_col4, #T_ee9a6_row10_col5, #T_ee9a6_row10_col6, #T_ee9a6_row10_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_ee9a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee9a6_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_ee9a6_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_ee9a6_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_ee9a6_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_ee9a6_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
