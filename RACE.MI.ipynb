# %%
import my_portfolio; my_portfolio.run(
    security="RACE.MI",
    trades_isin="NL0011585146",
)
# Out:
# Prices: 277.84 | 291.74 | 306.32 | 319.99 | 335.99 | 352.79 | 370.43
# Buy score: 1.30%
# Sell score: -0.78%
# Current return: -630.08 EUR
# Breakeven price: 323.80 EUR
# <style type="text/css">
# #T_eb313_row10_col0, #T_eb313_row10_col1, #T_eb313_row10_col2, #T_eb313_row10_col3, #T_eb313_row10_col4, #T_eb313_row10_col5, #T_eb313_row10_col6, #T_eb313_row10_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_eb313">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb313_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_eb313_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_eb313_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_eb313_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_eb313_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
