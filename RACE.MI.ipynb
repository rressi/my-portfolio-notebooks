# %%
import my_portfolio; my_portfolio.run(
    security="RACE.MI",
    trades_isin="NL0011585146",
)
# Out:
# Prices: 270.52 | 284.05 | 298.25 | 324.08 | 340.28 | 357.30 | 375.16
# Buy score: -2.87%
# Sell score: -0.52%
# Current return: -256.00 EUR
# Breakeven price: 327.52 EUR
# <style type="text/css">
# #T_8adb2_row7_col0, #T_8adb2_row7_col1, #T_8adb2_row7_col2, #T_8adb2_row7_col3, #T_8adb2_row7_col4, #T_8adb2_row7_col5, #T_8adb2_row7_col6, #T_8adb2_row7_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_8adb2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8adb2_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_8adb2_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_8adb2_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_8adb2_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_8adb2_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
