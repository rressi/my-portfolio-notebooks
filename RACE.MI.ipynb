# %%
import my_portfolio; my_portfolio.run(
    security="RACE.MI",
    trades_isin="NL0011585146",
)
# Out:
# Prices: 275.65 | 289.43 | 303.90 | 318.59 | 334.52 | 351.25 | 368.81
# Buy score: 2.18%
# Sell score: -1.98%
# Current return: -1,534.16 EUR
# Breakeven price: 322.53 EUR
# <style type="text/css">
# #T_eba55_row14_col0, #T_eba55_row14_col1, #T_eba55_row14_col2, #T_eba55_row14_col3, #T_eba55_row14_col4, #T_eba55_row14_col5, #T_eba55_row14_col6, #T_eba55_row14_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_eba55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eba55_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_eba55_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_eba55_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_eba55_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_eba55_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
