# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 312.24 | 327.85 | 344.25 | 334.84 | 351.58 | 369.16 | 387.62
# Buy score: -0.70%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                        337.185
# Forward EPS                          13.8047
# Gross Profit (ttm)            49,400,999,936
# Industry                      Semiconductors
# Revenue (ttm)                 63,886,999,552
# Target High Price                      535.0
# Target Low Price                       273.4
# Target Mean Price                    453.893
# Trailing EPS                            4.78
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   340.64
# Daylow                                    333.02
# Exchange                                     NMS
# ...
