# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 303.32 | 318.48 | 334.41 | 351.13 | 368.68 | 387.12 | 406.47
# Buy score: 0.33%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         349.33
# Forward EPS                             6.17
# Gross Profit (ttm)            46,253,998,080
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Target High Price                      460.0
# Target Low Price                       218.0
# Target Mean Price                   386.6821
# Trailing EPS                            3.91
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   350.97
# Daylow                                    340.78
# Exchange                                     NMS
# ...
