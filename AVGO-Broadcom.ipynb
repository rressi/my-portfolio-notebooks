# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 290.87 | 305.42 | 320.69 | 330.96 | 347.50 | 364.88 | 383.12
# Buy score: -0.03%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         332.31
# Forward EPS                         14.52319
# Gross Profit (ttm)            49,400,999,936
# Industry                      Semiconductors
# Revenue (ttm)                 63,886,999,552
# Target High Price                      535.0
# Target Low Price                       335.0
# Target Mean Price                   455.0997
# Trailing EPS                            4.79
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   335.91
# Daylow                                    329.28
# Exchange                                     NMS
# ...
