# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 311.94 | 327.53 | 343.91 | 349.54 | 367.01 | 385.37 | 404.63
# Buy score: 1.10%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                          346.1
# Forward EPS                         14.00101
# Gross Profit (ttm)            49,400,999,936
# Industry                      Semiconductors
# Revenue (ttm)                 63,886,999,552
# Target High Price                      535.0
# Target Low Price                       289.0
# Target Mean Price                    456.802
# Trailing EPS                            4.78
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   349.88
# Daylow                                    345.42
# Exchange                                     NMS
# ...
