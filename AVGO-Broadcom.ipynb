# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 294.93 | 309.68 | 325.16 | 331.52 | 348.10 | 365.51 | 383.78
# Buy score: -0.24%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                        332.317
# Forward EPS                          14.5001
# Gross Profit (ttm)            49,400,999,936
# Industry                      Semiconductors
# Revenue (ttm)                 63,886,999,552
# Target High Price                      535.0
# Target Low Price                       335.0
# Target Mean Price                   456.0997
# Trailing EPS                            4.78
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   340.11
# Daylow                                    329.58
# Exchange                                     NMS
# ...
