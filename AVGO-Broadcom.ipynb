# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 320.67 | 336.71 | 353.54 | 371.22 | 389.78 | 409.27 | 429.73
# Buy score: 2.70%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         361.47
# Forward EPS                             6.17
# Gross Profit (ttm)            46,253,998,080
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Target High Price                      480.0
# Target Low Price                       273.4
# Target Mean Price                    393.967
# Trailing EPS                            3.91
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   364.00
# Daylow                                    350.09
# Exchange                                     NMS
# ...
