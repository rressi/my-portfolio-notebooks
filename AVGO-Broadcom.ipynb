# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 343.23 | 360.39 | 378.41 | 397.33 | 417.20 | 438.06 | 459.96
# Buy score: 11.24%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         359.93
# Forward EPS                         13.57893
# Gross Profit (ttm)            49,400,999,936
# Industry                      Semiconductors
# Revenue (ttm)                 63,886,999,552
# Target High Price                      535.0
# Target Low Price                       273.4
# Target Mean Price                   444.8964
# Trailing EPS                            4.21
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   380.92
# Daylow                                    355.15
# Exchange                                     NMS
# ...
