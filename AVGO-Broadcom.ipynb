# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 384.48 | 403.70 | 423.89 | 445.08 | 467.34 | 490.70 | 515.24
# Buy score: 15.60%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         385.73
# Forward EPS                         19.32136
# Gross Profit (ttm)            57,568,002,048
# Industry                      Semiconductors
# Revenue (ttm)                 75,464,998,912
# Target High Price                      650.0
# Target Low Price                      215.88
# Target Mean Price                   512.7291
# Trailing EPS                            6.02
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   410.50
# Daylow                                    385.59
# Exchange                                     NMS
# ...
