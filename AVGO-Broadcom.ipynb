# %%
import workflow
workflow.run(
    security="AVGO", # Broadcom Inc.
    # start_date="2025-01-01",
)
# Out:
# Prices: 274.31 | 288.03 | 302.43 | 317.55 | 333.43 | 350.10 | 367.61
# Buy score: -12.78%
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         364.09
# Forward EPS                             6.17
# Gross Profit (ttm)            46,253,998,080
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Target High Price                      420.0
# Target Low Price                       218.0
# Target Mean Price                  367.80392
# Trailing EPS                            3.93
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   365.50
# Daylow                                    356.34
# Exchange                                     NMS
# Fiftydayaverage                           299.87
# ...
