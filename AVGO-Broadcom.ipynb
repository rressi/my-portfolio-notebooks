# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 349.92 | 367.42 | 385.79 | 386.43 | 405.75 | 426.04 | 447.34
# Buy score: 0.18%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         385.57
# Forward EPS                         19.35046
# Gross Profit (ttm)            57,568,002,048
# Industry                      Semiconductors
# Revenue (ttm)                 75,464,998,912
# Target High Price                      650.0
# Target Low Price                      215.88
# Target Mean Price                  522.06226
# Trailing EPS                            6.01
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   389.50
# Daylow                                    370.55
# Exchange                                     NMS
# ...
