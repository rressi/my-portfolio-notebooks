# %%
import workflow
workflow.run(
    security="AVGO", # Broadcom Inc.
    # start_date="2025-01-01",
)
# Out:
# Prices: 304.23 | 319.45 | 335.42 | 352.19 | 369.80 | 388.29 | 407.70
# Buy score: 1.98%
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         345.35
# Forward EPS                             6.17
# Gross Profit (ttm)            46,253,998,080
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Target High Price                      420.0
# Target Low Price                       218.0
# Target Mean Price                  367.80392
# Trailing EPS                            3.91
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   350.69
# Daylow                                    343.81
# Exchange                                     NMS
# Fiftydayaverage                           304.85
# ...
