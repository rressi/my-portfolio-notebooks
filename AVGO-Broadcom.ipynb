# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 336.73 | 353.57 | 371.25 | 389.81 | 409.30 | 429.77 | 451.26
# Buy score: 2.33%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                       380.9352
# Forward EPS                             6.17
# Gross Profit (ttm)            46,253,998,080
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Target High Price                      535.0
# Target Low Price                       273.4
# Target Mean Price                   407.2535
# Trailing EPS                            3.89
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   380.95
# Daylow                                    370.65
# Exchange                                     NMS
# ...
