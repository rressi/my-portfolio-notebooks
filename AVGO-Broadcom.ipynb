# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 312.36 | 327.98 | 344.38 | 361.60 | 379.68 | 398.66 | 418.60
# Buy score: -3.49%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         374.56
# Forward EPS                             6.17
# Gross Profit (ttm)            46,253,998,080
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Target High Price                      475.0
# Target Low Price                       273.4
# Target Mean Price                  392.38165
# Trailing EPS                            3.92
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   383.63
# Daylow                                    373.20
# Exchange                                     NMS
# ...
