# %%
import workflow
workflow.run(
    security="AVGO", # Broadcom Inc.
    # start_date="2025-01-01",
)
# Out:
# Prices: 300.84 | 315.89 | 331.68 | 348.26 | 365.68 | 383.96 | 403.16
# Buy score: 0.60%
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         346.17
# Forward EPS                             6.17
# Gross Profit (ttm)            46,253,998,080
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Target High Price                      420.0
# Target Low Price                       218.0
# Target Mean Price                  367.80392
# Trailing EPS                            3.91
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   359.93
# Daylow                                    341.50
# Exchange                                     NMS
# Fiftydayaverage                           303.36
# ...
