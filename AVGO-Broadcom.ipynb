# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 368.23 | 386.64 | 405.97 | 426.27 | 447.59 | 469.96 | 493.46
# Buy score: -4.51%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         446.77
# Forward EPS                          18.4407
# Gross Profit (ttm)            52,389,998,592
# Industry                      Semiconductors
# Revenue (ttm)                 68,281,999,360
# Target High Price                      630.0
# Target Low Price                      215.88
# Target Mean Price                   481.9678
# Trailing EPS                            5.14
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   448.90
# Daylow                                    431.47
# Exchange                                     NMS
# ...
