# %%
import workflow
workflow.run(
    security="AVGO", # Broadcom Inc.
    # start_date="2025-01-01",
)
# Out:
# Prices: 297.06 | 311.91 | 327.51 | 343.89 | 361.08 | 379.13 | 398.09
# Buy score: -4.48%
#                                         AVGO
# Company Name                        Broadcom
# Current Price                          360.0
# Forward EPS                             6.17
# Gross Profit (ttm)            46,253,998,080
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Target High Price                      420.0
# Target Low Price                       218.0
# Target Mean Price                  367.80392
# Trailing EPS                             3.9
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   365.69
# Daylow                                    356.99
# Exchange                                     NMS
# Fiftydayaverage                           301.65
# ...
