# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 305.96 | 321.26 | 337.32 | 330.87 | 347.42 | 364.79 | 383.03
# Buy score: -0.49%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         332.75
# Forward EPS                         14.32775
# Gross Profit (ttm)            49,400,999,936
# Industry                      Semiconductors
# Revenue (ttm)                 63,886,999,552
# Target High Price                      535.0
# Target Low Price                       370.0
# Target Mean Price                  459.92014
# Trailing EPS                            4.76
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   334.12
# Daylow                                    331.08
# Exchange                                     NMS
# ...
