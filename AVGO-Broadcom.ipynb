# %%
import workflow
workflow.run(
    security = "AVGO", # Broadcom Inc.
    #  sstart_date = "2025-01-01",
)
# Out:
# Prices: 269.72 | 283.21 | 297.37 | 312.2340 | 327.85 | 344.24 | 361.45
# Buy score: -13.18%
#                                         AVGO
# Company Name                        Broadcom
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Gross Profit (ttm)            46,244,999,168
# Current Price                         359.63
# Target Mean Price                  360.33234
# Target High Price                  415.56076
# Target Low Price                       218.0
# Trailing EPS                            3.88
# Forward EPS                             6.17
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   374.23
# Daylow                                    358.76
# Exchange                                     NMS
# Fiftydayaverage                           296.17
# ...
