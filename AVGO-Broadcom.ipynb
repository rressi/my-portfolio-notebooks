# %%
import workflow
workflow.run(
    security="AVGO", # Broadcom Inc.
    # start_date="2025-01-01",
)
# Out:
# Prices: 271.82 | 285.41 | 299.68 | 314.6660 | 330.40 | 346.92 | 364.27
# Buy score: -12.56%
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         359.87
# Forward EPS                             6.17
# Gross Profit (ttm)            46,253,998,080
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Target High Price                      420.0
# Target Low Price                       218.0
# Target Mean Price                  366.49902
# Trailing EPS                            3.89
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   364.39
# Daylow                                    357.16
# Exchange                                     NMS
# Fiftydayaverage                           299.87
# ...
