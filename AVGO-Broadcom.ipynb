# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 356.28 | 374.09 | 392.80 | 412.44 | 433.06 | 454.71 | 477.45
# Buy score: -0.73%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         421.28
# Forward EPS                         18.11795
# Gross Profit (ttm)            52,389,998,592
# Industry                      Semiconductors
# Revenue (ttm)                 68,281,999,360
# Target High Price                      630.0
# Target Low Price                       360.0
# Target Mean Price                  475.49295
# Trailing EPS                            5.14
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   423.17
# Daylow                                    413.28
# Exchange                                     NMS
# ...
