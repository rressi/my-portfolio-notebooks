# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 303.29 | 318.45 | 334.37 | 320.58 | 336.61 | 353.44 | 371.12
# Buy score: -2.97%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                        332.495
# Forward EPS                         14.36275
# Gross Profit (ttm)            49,400,999,936
# Industry                      Semiconductors
# Revenue (ttm)                 63,886,999,552
# Target High Price                      535.0
# Target Low Price                       370.0
# Target Mean Price                   458.5886
# Trailing EPS                            4.76
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   335.00
# Daylow                                    316.30
# Exchange                                     NMS
# ...
