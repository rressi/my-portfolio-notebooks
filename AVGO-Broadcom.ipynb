# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 302.06 | 317.16 | 333.02 | 349.67 | 367.15 | 385.51 | 404.79
# Buy score: 0.07%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         349.41
# Forward EPS                             6.17
# Gross Profit (ttm)            46,253,998,080
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Target High Price                      460.0
# Target Low Price                       273.4
# Target Mean Price                   390.7963
# Trailing EPS                            3.91
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   356.59
# Daylow                                    348.00
# Exchange                                     NMS
# ...
