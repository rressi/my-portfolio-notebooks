# %%
import my_portfolio; my_portfolio.run("AVGO")
# Out:
# No operations found for ticker 'AVGO'
# Prices: 289.44 | 303.92 | 319.11 | 335.07 | 351.82 | 369.41 | 387.88
# Buy score: -0.22%
# No operations found.
#                                         AVGO
# Company Name                        Broadcom
# Current Price                         335.49
# Forward EPS                             6.17
# Gross Profit (ttm)            46,253,998,080
# Industry                      Semiconductors
# Revenue (ttm)                 59,925,999,616
# Target High Price                      420.0
# Target Low Price                       218.0
# Target Mean Price                   370.3649
# Trailing EPS                            3.89
# Website             https://www.broadcom.com
#                                             AVGO
# Currency                                     USD
# Dayhigh                                   344.13
# Daylow                                    334.56
# Exchange                                     NMS
# ...
