# %%
import my_portfolio; my_portfolio.run("ALAB")
# Out:
# Prices: 169.86 | 178.35 | 187.27 | 190.48 | 200.00 | 210.00 | 220.50
# Buy score: -7.43%
# Sell score: 1.01%
# Current return: -3.24 USD
# Breakeven price: 193.05 USD
# <style type="text/css">
# #T_c0508_row1_col0, #T_c0508_row1_col1, #T_c0508_row1_col2, #T_c0508_row1_col3, #T_c0508_row1_col4, #T_c0508_row1_col5, #T_c0508_row1_col6, #T_c0508_row1_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_c0508">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0508_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c0508_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c0508_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c0508_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c0508_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
