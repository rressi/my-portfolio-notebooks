# %%
import my_portfolio; my_portfolio.run("ALAB")
# Out:
# Prices: 140.86 | 147.90 | 155.29 | 154.03 | 161.73 | 169.82 | 178.31
# Buy score: 20.03%
#                       Quantity   Price    Value    Wallet Avg. price  \
# Time
# 2025-11-03 09:30:23   5.000000  190.48   952.40  5.000000     190.48
# 2025-11-04 09:30:48  -5.000000  182.75  -913.75  0.000000       0.00
#
#                     Inv. Cost Inv. Balance Balance
# Time
# 2025-11-03 09:30:23      6.43        -6.43   -6.43
# 2025-11-04 09:30:48      0.00         0.00  -51.47
#                                           ALAB
# Company Name                       Astera Labs
# Current Price                           129.32
# Forward EPS                            3.49065
# Gross Profit (ttm)                 645,260,992
# Industry                        Semiconductors
# Revenue (ttm)                      852,524,992
# Target High Price                        250.0
# Target Low Price                         155.0
# Target Mean Price                    204.47368
# ...
