# %%
import my_portfolio; my_portfolio.run("NBIS")
# Out:
# No operations found for ticker 'NBIS'
# Prices: 92.77 | 97.40 | 102.27 | 94.46 | 99.18 | 104.14 | 109.35
# Buy score: 8.20%
# No operations found.
#                                               NBIS
# Company Name                     Nebius Group N.V.
# Current Price                                87.69
# Forward EPS                                 -2.285
# Gross Profit (ttm)                     214,800,000
# Industry            Internet Content & Information
# Revenue (ttm)                          363,300,000
# Target High Price                            211.0
# Target Low Price                              70.0
# Target Mean Price                            151.5
# Trailing EPS                                 -0.18
# Website                   https://group.nebius.com
#                                          NBIS
# Currency                                  USD
# Dayhigh                                 95.65
# Daylow                                  86.20
# ...
