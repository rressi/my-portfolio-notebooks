# %%
import my_portfolio; my_portfolio.run("NBIS")
# Out:
# No operations found for ticker 'NBIS'
# Prices: 134.08 | 140.79 | 147.83 | 155.22 | 162.98 | 171.13 | 179.68
# Buy score: 6.31%
# No operations found.
#                                               NBIS
# Company Name                     Nebius Group N.V.
# Current Price                               147.16
# Forward EPS                               -1.01619
# Gross Profit (ttm)                     363,600,000
# Industry            Internet Content & Information
# Revenue (ttm)                          529,800,000
# Target High Price                            291.0
# Target Low Price                              85.0
# Target Mean Price                         170.2857
# Trailing EPS                                  0.12
# Website                   https://group.nebius.com
#                                          NBIS
# Currency                                  USD
# Dayhigh                                165.25
# Daylow                                 145.81
# ...
