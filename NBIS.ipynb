# %%
import my_portfolio; my_portfolio.run("NBIS")
# Out:
# Prices: 81.48 | 85.55 | 89.83 | 94.32 | 99.04 | 103.99 | 109.19
# Buy score: -12.25%
# No operations found.
#                                               NBIS
# Company Name                     Nebius Group N.V.
# Current Price                                106.6
# Forward EPS                                   None
# Gross Profit (ttm)                     133,800,000
# Industry            Internet Content & Information
# Revenue (ttm)                          249,300,000
# Target High Price                            184.0
# Target Low Price                              77.0
# Target Mean Price                            127.2
# Trailing EPS                                  0.77
# Website                   https://group.nebius.com
#                                          NBIS
# Currency                                  USD
# Dayhigh                                108.58
# Daylow                                  98.52
# Exchange                                  NMS
# ...
