# %%
import my_portfolio; my_portfolio.run("NBIS")
# Out:
# No operations found for ticker 'NBIS'
# Prices: 190.02 | 199.52 | 209.50 | 219.97 | 230.97 | 242.52 | 254.65
# Buy score: -5.59%
# No operations found.
#                                               NBIS
# Company Name                     Nebius Group N.V.
# Current Price                               222.24
# Forward EPS                                0.36122
# Gross Profit (ttm)                     632,600,000
# Industry            Internet Content & Information
# Revenue (ttm)                          877,900,032
# Target High Price                            380.0
# Target Low Price                             120.0
# Target Mean Price                        244.07143
# Trailing EPS                                   2.6
# Website                         https://nebius.com
#                                          NBIS
# Currency                                  USD
# Dayhigh                                228.49
# Daylow                                 205.00
# ...
