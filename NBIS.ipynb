# %%
import my_portfolio; my_portfolio.run("NBIS")
# Out:
# No operations found for ticker 'NBIS'
# Prices: 102.87 | 108.02 | 113.42 | 119.09 | 125.04 | 131.30 | 137.86
# Buy score: 7.32%
# No operations found.
#                                               NBIS
# Company Name                     Nebius Group N.V.
# Current Price                               109.44
# Forward EPS                                   None
# Gross Profit (ttm)                     133,800,000
# Industry            Internet Content & Information
# Revenue (ttm)                          249,300,000
# Target High Price                            206.0
# Target Low Price                             130.0
# Target Mean Price                            161.4
# Trailing EPS                                  0.77
# Website                   https://group.nebius.com
#                                          NBIS
# Currency                                  USD
# Dayhigh                                121.00
# Daylow                                 108.41
# ...
