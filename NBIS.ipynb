# %%
import my_portfolio; my_portfolio.run("NBIS")
# Out:
# No operations found for ticker 'NBIS'
# Prices: 80.45 | 84.47 | 88.70 | 93.13 | 97.79 | 102.68 | 107.81
# Buy score: -4.97%
# No operations found.
#                                               NBIS
# Company Name                     Nebius Group N.V.
# Current Price                                97.52
# Forward EPS                                  -0.62
# Gross Profit (ttm)                     363,600,000
# Industry            Internet Content & Information
# Revenue (ttm)                          529,800,000
# Target High Price                            211.0
# Target Low Price                              70.0
# Target Mean Price                            145.1
# Trailing EPS                                  0.12
# Website                   https://group.nebius.com
#                                          NBIS
# Currency                                  USD
# Dayhigh                                 99.28
# Daylow                                  93.50
# ...
