# %% [markdown]
# # META - Facebook
#
# - https://www.google.com/finance/quote/META:NASDAQ

# %%
import my_portfolio; my_portfolio.run("META")
# Out:
# Prices: 572.71 | 601.34 | 631.41 | 662.98 | 696.13 | 730.94 | 767.48
# Buy score: 2.24%
#                       Quantity   Price      Value    Wallet Avg. price  \
# Time
# 2025-10-01 11:29:13   2.000000  715.19   1,430.38  2.000000     715.19
# 2025-10-03 13:53:41  -2.000000  712.54  -1,425.08  0.000000       0.00
#
#                     Inv. Cost Inv. Balance Balance
# Time
# 2025-10-01 11:29:13     12.15       -12.15  -12.15
# 2025-10-03 13:53:41      0.00         0.00  -29.61
#                                               META
# Company Name                        Meta Platforms
# Current Price                              648.461
# Forward EPS                               35.67041
# Gross Profit (ttm)                 164,790,992,896
# Industry            Internet Content & Information
# Revenue (ttm)                      200,965,996,544
# Target High Price                           1144.0
# Target Low Price                             700.0
# ...
