# %% [markdown]
# # META - Facebook
#
# - https://www.google.com/finance/quote/META:NASDAQ

# %%
import my_portfolio; my_portfolio.run("META")
# Out:
# Prices: 649.87 | 682.37 | 716.49 | 715.19 | 750.95 | 788.50 | 827.92
# Buy score: 1.12%
# Sell score: 1.31%
#                  Quantity   Price       Tot Wallet Avg. price Balance
# Time
# 2025-10-01 11:29        2  715.19  1,430.38      2     715.19  -12.15
# 2025-10-02 13:37        2  724.54  1,449.08      2        NaN    6.55
#                                               META
# Company Name                        Meta Platforms
# Current Price                               724.54
# Forward EPS                                   25.3
# Gross Profit (ttm)                 146,558,992,384
# Industry            Internet Content & Information
# Revenue (ttm)                      178,803,998,720
# Target High Price                           1086.0
# Target Low Price                             658.0
# Target Mean Price                        867.14404
# Trailing EPS                                 26.61
# Website                https://investor.atmeta.com
# ...
