# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 89.34 | 93.81 | 98.50 | 103.42 | 108.59 | 114.02 | 119.72
# Buy score: -8.41%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                               113.55
# Daylow                                102.90
# Exchange                                 CMX
# Fiftydayaverage                        68.74
# Lastprice                             112.92
# Lastvolume                            62,759
# ...
