# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 68.82 | 72.26 | 75.87 | 79.67 | 83.65 | 87.83 | 92.23
# Buy score: 5.42%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                84.88
# Daylow                                 74.86
# Exchange                                 CMX
# Fiftydayaverage                        77.43
# Lastprice                              75.57
# Lastvolume                            64,498
# ...
