# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 44.07 | 46.27 | 48.58 | 51.01 | 53.56 | 56.24 | 59.05
# Buy score: 0.43%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                51.15
# Daylow                                 50.08
# Exchange                                 CMX
# Fiftydayaverage                        42.91
# Lastprice                              50.79
# Lastvolume                            31,613
# ...
