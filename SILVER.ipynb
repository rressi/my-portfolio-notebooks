# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 94.34 | 99.06 | 104.01 | 109.21 | 114.67 | 120.40 | 126.42
# Buy score: 11.10%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                               118.45
# Daylow                                 95.12
# Exchange                                 CMX
# Fiftydayaverage                        72.25
# Lastprice                              98.30
# Lastvolume                           120,733
# ...
