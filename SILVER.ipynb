# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 65.58 | 68.86 | 72.31 | 75.61 | 79.39 | 83.36 | 87.53
# Buy score: -0.37%
# No operations found.
#                              SI=F
# Company Name        Silver Jul 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                76.29
# Daylow                                 73.50
# Exchange                                 CMX
# Fiftydayaverage                        75.82
# Lastprice                              75.89
# Lastvolume                             8,246
# ...
