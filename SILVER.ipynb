# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 91.60 | 96.18 | 100.99 | 106.04 | 111.34 | 116.91 | 122.75
# Buy score: -5.93%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                               116.17
# Daylow                                110.77
# Exchange                                 CMX
# Fiftydayaverage                        69.79
# Lastprice                             112.69
# Lastvolume                            70,665
# ...
