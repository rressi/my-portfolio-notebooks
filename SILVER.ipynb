# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 94.43 | 99.16 | 104.11 | 109.32 | 114.78 | 120.52 | 126.55
# Buy score: -2.35%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                               121.79
# Daylow                                106.61
# Exchange                                 CMX
# Fiftydayaverage                        70.99
# Lastprice                             111.98
# Lastvolume                           140,166
# ...
