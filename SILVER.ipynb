# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 68.96 | 72.41 | 76.03 | 79.83 | 83.82 | 88.01 | 92.41
# Buy score: 2.91%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                79.26
# Daylow                                 73.75
# Exchange                                 CMX
# Fiftydayaverage                        77.78
# Lastprice                              77.57
# Lastvolume                            48,244
# ...
