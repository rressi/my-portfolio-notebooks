# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 68.74 | 72.17 | 75.78 | 74.46 | 78.19 | 82.09 | 86.20
# Buy score: -2.64%
# No operations found.
#                              SI=F
# Company Name        Silver May 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                76.65
# Daylow                                 75.31
# Exchange                                 CMX
# Fiftydayaverage                        79.57
# Lastprice                              76.32
# Lastvolume                                 4
# ...
