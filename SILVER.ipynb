# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 64.84 | 68.08 | 71.49 | 68.67 | 72.11 | 75.71 | 79.50
# Buy score: 3.35%
# No operations found.
#                              SI=F
# Company Name        Silver Jul 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                67.23
# Daylow                                 63.35
# Exchange                                 CMX
# Fiftydayaverage                        75.26
# Lastprice                              66.45
# Lastvolume                            36,834
# ...
