# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 43.75 | 45.94 | 48.23 | 50.64 | 53.18 | 55.83 | 58.63
# Buy score: -0.84%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                53.38
# Daylow                                 49.86
# Exchange                                 CMX
# Fiftydayaverage                        46.56
# Lastprice                              51.08
# Lastvolume                           110,261
# ...
