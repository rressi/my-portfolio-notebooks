# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 44.95 | 47.20 | 49.56 | 52.03 | 54.64 | 57.37 | 60.24
# Buy score: -11.75%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                58.90
# Daylow                                 57.65
# Exchange                                 CMX
# Fiftydayaverage                        48.54
# Lastprice                              58.97
# Lastvolume                           100,221
# ...
