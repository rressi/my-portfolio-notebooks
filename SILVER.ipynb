# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 68.91 | 72.35 | 75.97 | 77.71 | 81.60 | 85.68 | 89.96
# Buy score: -5.46%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                82.74
# Daylow                                 77.29
# Exchange                                 CMX
# Fiftydayaverage                        79.28
# Lastprice                              82.20
# Lastvolume                            40,140
# ...
