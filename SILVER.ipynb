# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 67.79 | 71.18 | 74.74 | 77.23 | 81.09 | 85.14 | 89.40
# Buy score: 1.06%
# No operations found.
#                              SI=F
# Company Name        Silver May 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                76.67
# Daylow                                 73.85
# Exchange                                 CMX
# Fiftydayaverage                        78.48
# Lastprice                              76.41
# Lastvolume                            43,071
# ...
