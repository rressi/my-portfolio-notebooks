# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 63.21 | 66.37 | 69.69 | 73.17 | 76.83 | 80.67 | 84.71
# Buy score: 1.60%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                74.21
# Daylow                                 70.51
# Exchange                                 CMX
# Fiftydayaverage                        56.17
# Lastprice                              72.02
# Lastvolume                            98,679
# ...
