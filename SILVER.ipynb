# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 55.08 | 57.83 | 60.72 | 63.76 | 66.95 | 70.29 | 73.81
# Buy score: -2.74%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                65.67
# Daylow                                 65.39
# Exchange                                 CMX
# Fiftydayaverage                        52.43
# Lastprice                              65.56
# Lastvolume                             1,686
# ...
