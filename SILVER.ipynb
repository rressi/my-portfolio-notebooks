# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 76.24 | 80.05 | 84.06 | 88.26 | 92.67 | 97.31 | 102.17
# Buy score: 0.23%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                92.64
# Daylow                                 86.57
# Exchange                                 CMX
# Fiftydayaverage                        62.84
# Lastprice                              88.07
# Lastvolume                           131,003
# ...
