# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 77.97 | 81.87 | 85.97 | 90.26 | 94.78 | 99.52 | 104.49
# Buy score: -4.59%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                95.78
# Daylow                                 90.50
# Exchange                                 CMX
# Fiftydayaverage                        63.66
# Lastprice                              94.61
# Lastvolume                           150,583
# ...
