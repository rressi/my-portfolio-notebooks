# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 68.49 | 71.91 | 75.51 | 76.41 | 80.23 | 84.24 | 88.46
# Buy score: -1.67%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                79.40
# Daylow                                 76.30
# Exchange                                 CMX
# Fiftydayaverage                        78.90
# Lastprice                              77.71
# Lastvolume                            20,165
# ...
