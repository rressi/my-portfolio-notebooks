# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 79.16 | 83.12 | 87.27 | 91.64 | 96.22 | 101.03 | 106.08
# Buy score: -1.62%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                95.53
# Daylow                                 92.11
# Exchange                                 CMX
# Fiftydayaverage                        64.59
# Lastprice                              93.14
# Lastvolume                            74,552
# ...
