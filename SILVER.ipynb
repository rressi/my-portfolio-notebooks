# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 92.22 | 96.83 | 101.67 | 106.75 | 112.09 | 117.70 | 123.58
# Buy score: -8.18%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                               117.60
# Daylow                                110.40
# Exchange                                 CMX
# Fiftydayaverage                        69.79
# Lastprice                             116.27
# Lastvolume                           171,671
# ...
