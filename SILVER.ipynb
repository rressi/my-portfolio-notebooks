# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 43.98 | 46.18 | 48.49 | 50.91 | 53.46 | 56.13 | 58.94
# Buy score: -2.88%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                54.42
# Daylow                                 51.99
# Exchange                                 CMX
# Fiftydayaverage                        46.45
# Lastprice                              52.42
# Lastvolume                           119,222
# ...
