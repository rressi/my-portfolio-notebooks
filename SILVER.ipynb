# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 68.21 | 71.62 | 75.20 | 78.96 | 82.91 | 87.06 | 91.41
# Buy score: -5.49%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                85.40
# Daylow                                 83.36
# Exchange                                 CMX
# Fiftydayaverage                        59.62
# Lastprice                              83.55
# Lastvolume                             2,137
# ...
