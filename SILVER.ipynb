# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 59.00 | 61.95 | 65.05 | 68.30 | 71.72 | 75.30 | 79.07
# Buy score: -4.72%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                72.75
# Daylow                                 70.16
# Exchange                                 CMX
# Fiftydayaverage                        53.98
# Lastprice                              71.68
# Lastvolume                            94,695
# ...
