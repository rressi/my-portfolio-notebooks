# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 65.61 | 68.89 | 72.33 | 75.95 | 79.75 | 83.73 | 87.92
# Buy score: 0.79%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                78.90
# Daylow                                 73.53
# Exchange                                 CMX
# Fiftydayaverage                        58.42
# Lastprice                              75.36
# Lastvolume                           113,217
# ...
