# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 50.88 | 53.43 | 56.10 | 58.90 | 61.85 | 64.94 | 68.19
# Buy score: -3.90%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                62.14
# Daylow                                 60.55
# Exchange                                 CMX
# Fiftydayaverage                        50.53
# Lastprice                              61.29
# Lastvolume                            94,892
# ...
