# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 67.80 | 71.19 | 74.75 | 78.15 | 82.05 | 86.16 | 90.46
# Buy score: 6.52%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                78.42
# Daylow                                 71.82
# Exchange                                 CMX
# Fiftydayaverage                        78.17
# Lastprice                              73.36
# Lastvolume                            70,977
# ...
