# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 76.25 | 80.06 | 84.06 | 88.26 | 92.68 | 97.31 | 102.18
# Buy score: -4.94%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                94.75
# Daylow                                 90.50
# Exchange                                 CMX
# Fiftydayaverage                        63.66
# Lastprice                              93.83
# Lastvolume                            86,422
# ...
