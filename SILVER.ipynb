# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 65.75 | 69.04 | 72.49 | 73.11 | 76.77 | 80.61 | 84.64
# Buy score: 7.53%
# No operations found.
#                              SI=F
# Company Name        Silver Jul 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                74.38
# Daylow                                 67.70
# Exchange                                 CMX
# Fiftydayaverage                        76.20
# Lastprice                              68.00
# Lastvolume                            77,016
# ...
