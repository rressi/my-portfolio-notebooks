# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 85.11 | 89.37 | 93.84 | 98.53 | 103.46 | 108.63 | 114.06
# Buy score: -9.88%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                               109.96
# Daylow                                103.31
# Exchange                                 CMX
# Fiftydayaverage                        67.45
# Lastprice                             109.33
# Lastvolume                            79,815
# ...
