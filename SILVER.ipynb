# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 72.85 | 76.49 | 80.32 | 84.33 | 88.55 | 92.97 | 97.62
# Buy score: 9.18%
# No operations found.
#                              SI=F
# Company Name        Silver Jul 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                84.38
# Daylow                                 76.70
# Exchange                                 CMX
# Fiftydayaverage                        77.16
# Lastprice                              77.24
# Lastvolume                            48,500
# ...
