# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 52.40 | 55.02 | 57.77 | 60.66 | 63.70 | 66.88 | 70.22
# Buy score: -0.64%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                65.08
# Daylow                                 61.01
# Exchange                                 CMX
# Fiftydayaverage                        51.15
# Lastprice                              61.06
# Lastvolume                           187,300
# ...
