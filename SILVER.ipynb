# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 45.01 | 47.26 | 49.62 | 52.10 | 54.71 | 57.44 | 60.32
# Buy score: -12.16%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                59.38
# Daylow                                 56.85
# Exchange                                 CMX
# Fiftydayaverage                        48.31
# Lastprice                              59.31
# Lastvolume                           106,377
# ...
