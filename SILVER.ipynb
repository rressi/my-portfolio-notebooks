# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 43.74 | 45.92 | 48.22 | 50.63 | 53.16 | 55.82 | 58.61
# Buy score: 5.33%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                51.62
# Daylow                                 47.12
# Exchange                                 CMX
# Fiftydayaverage                        43.16
# Lastprice                              48.06
# Lastvolume                           130,683
# ...
