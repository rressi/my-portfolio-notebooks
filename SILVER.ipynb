# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 68.72 | 72.16 | 75.76 | 74.26 | 77.98 | 81.87 | 85.97
# Buy score: -1.41%
# No operations found.
#                              SI=F
# Company Name        Silver May 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                76.31
# Daylow                                 75.00
# Exchange                                 CMX
# Fiftydayaverage                        80.31
# Lastprice                              75.32
# Lastvolume                             5,819
# ...
