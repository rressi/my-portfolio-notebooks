# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 79.71 | 83.70 | 87.89 | 92.28 | 96.89 | 101.74 | 106.83
# Buy score: -2.88%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                95.03
# Daylow                                 90.68
# Exchange                                 CMX
# Fiftydayaverage                        65.48
# Lastprice                              95.01
# Lastvolume                            59,591
# ...
