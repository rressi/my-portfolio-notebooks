# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 43.79 | 45.98 | 48.28 | 50.69 | 53.23 | 55.89 | 58.68
# Buy score: -0.61%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                51.57
# Daylow                                 50.37
# Exchange                                 CMX
# Fiftydayaverage                        47.45
# Lastprice                              51.00
# Lastvolume                            15,356
# ...
