# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 50.03 | 52.53 | 55.16 | 57.92 | 60.81 | 63.85 | 67.04
# Buy score: -0.84%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                58.34
# Daylow                                 57.52
# Exchange                                 CMX
# Fiftydayaverage                        50.03
# Lastprice                              58.40
# Lastvolume                            55,972
# ...
