# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 62.93 | 66.08 | 69.38 | 72.85 | 76.49 | 80.31 | 84.33
# Buy score: -4.55%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                76.87
# Daylow                                 75.70
# Exchange                                 CMX
# Fiftydayaverage                        56.63
# Lastprice                              76.32
# Lastvolume                             6,398
# ...
