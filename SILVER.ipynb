# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 41.24 | 43.30 | 45.47 | 47.74 | 50.13 | 52.63 | 55.26
# Buy score: -0.84%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                48.04
# Daylow                                 48.01
# Exchange                                 CMX
# Fiftydayaverage                        45.82
# Lastprice                              48.02
# Lastvolume                                86
# ...
