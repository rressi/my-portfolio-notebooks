# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 73.46 | 77.14 | 80.99 | 85.04 | 89.29 | 93.76 | 98.45
# Buy score: -6.94%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                91.18
# Daylow                                 86.50
# Exchange                                 CMX
# Fiftydayaverage                        80.84
# Lastprice                              91.39
# Lastvolume                            15,772
# ...
