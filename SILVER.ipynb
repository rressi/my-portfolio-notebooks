# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 63.15 | 66.31 | 69.62 | 73.10 | 76.76 | 80.60 | 84.63
# Buy score: -5.86%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                78.07
# Daylow                                 70.67
# Exchange                                 CMX
# Fiftydayaverage                        55.24
# Lastprice                              77.65
# Lastvolume                           145,854
# ...
