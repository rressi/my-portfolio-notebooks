# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 74.35 | 78.07 | 81.98 | 86.07 | 90.38 | 94.90 | 99.64
# Buy score: -4.50%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                93.70
# Daylow                                 86.12
# Exchange                                 CMX
# Fiftydayaverage                        61.96
# Lastprice                              90.13
# Lastvolume                           142,685
# ...
