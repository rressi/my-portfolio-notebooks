# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 64.77 | 68.00 | 71.40 | 74.97 | 78.72 | 82.66 | 86.79
# Buy score: -3.25%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                82.58
# Daylow                                 77.15
# Exchange                                 CMX
# Fiftydayaverage                        57.85
# Lastprice                              77.50
# Lastvolume                            73,800
# ...
