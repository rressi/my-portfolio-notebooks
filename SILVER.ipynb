# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 44.19 | 46.40 | 48.72 | 51.16 | 53.72 | 56.40 | 59.22
# Buy score: -0.71%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                51.62
# Daylow                                 50.08
# Exchange                                 CMX
# Fiftydayaverage                        42.91
# Lastprice                              51.53
# Lastvolume                            90,960
# ...
