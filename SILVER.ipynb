# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 43.77 | 45.96 | 48.26 | 50.67 | 53.20 | 55.86 | 58.66
# Buy score: 4.98%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                48.42
# Daylow                                 46.82
# Exchange                                 CMX
# Fiftydayaverage                        43.27
# Lastprice                              48.26
# Lastvolume                            23,286
# ...
