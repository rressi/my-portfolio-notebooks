# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 69.59 | 73.07 | 76.72 | 80.55 | 84.58 | 88.81 | 93.25
# Buy score: -2.12%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                82.60
# Daylow                                 78.10
# Exchange                                 CMX
# Fiftydayaverage                        75.72
# Lastprice                              82.30
# Lastvolume                            45,698
# ...
