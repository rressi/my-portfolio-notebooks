# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 65.27 | 68.53 | 71.96 | 65.85 | 69.14 | 72.59 | 76.22
# Buy score: -2.05%
# No operations found.
#                              SI=F
# Company Name        Silver Jul 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                68.08
# Daylow                                 65.96
# Exchange                                 CMX
# Fiftydayaverage                        75.73
# Lastprice                              67.22
# Lastvolume                            15,295
# ...
