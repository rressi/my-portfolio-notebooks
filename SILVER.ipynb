# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 43.75 | 45.94 | 48.23 | 50.64 | 53.18 | 55.84 | 58.63
# Buy score: -0.27%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                51.57
# Daylow                                 50.10
# Exchange                                 CMX
# Fiftydayaverage                        47.45
# Lastprice                              50.76
# Lastvolume                            49,647
# ...
