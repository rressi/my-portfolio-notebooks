# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 76.80 | 80.64 | 84.68 | 88.91 | 93.35 | 98.02 | 102.92
# Buy score: -2.63%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                92.64
# Daylow                                 89.21
# Exchange                                 CMX
# Fiftydayaverage                        62.84
# Lastprice                              91.32
# Lastvolume                            39,428
# ...
