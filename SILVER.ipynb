# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 41.31 | 43.37 | 45.54 | 47.82 | 50.21 | 52.72 | 55.36
# Buy score: 1.59%
# No operations found.
#                              SI=F
# Company Name        Silver Dec 25
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                47.97
# Daylow                                 47.02
# Exchange                                 CMX
# Fiftydayaverage                        45.11
# Lastprice                              47.07
# Lastvolume                            29,699
# ...
