# %%
import my_portfolio; my_portfolio.run("SI=F")
# Out:
# No operations found for ticker 'SI=F'
# Prices: 75.10 | 78.85 | 82.80 | 86.94 | 91.28 | 95.85 | 100.64
# Buy score: -0.75%
# No operations found.
#                              SI=F
# Company Name        Silver Mar 26
# Current Price                None
# Forward EPS                  None
# Gross Profit (ttm)           None
# Industry                     None
# Revenue (ttm)                None
# Target High Price            None
# Target Low Price             None
# Target Mean Price            None
# Trailing EPS                 None
# Website                      None
#                                         SI=F
# Currency                                 USD
# Dayhigh                                90.99
# Daylow                                 86.70
# Exchange                                 CMX
# Fiftydayaverage                        81.38
# Lastprice                              87.46
# Lastvolume                            19,265
# ...
