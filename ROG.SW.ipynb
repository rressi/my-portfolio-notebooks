# %%
import my_portfolio; my_portfolio.run("ROG.SW")
# Out:
# No operations found for ticker 'ROG.SW'
# Prices: 304.99 | 320.24 | 336.25 | 353.06 | 370.71 | 389.25 | 408.71
# Buy score: -2.15%
# No operations found.
#                                           ROG.SW
# Company Name                            ROCHE GS
# Current Price                              360.6
# Forward EPS                              21.8369
# Gross Profit (ttm)                47,194,001,408
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     63,355,998,208
# Target High Price                          428.0
# Target Low Price                           230.0
# Target Mean Price                       351.5535
# Trailing EPS                               16.41
# Website                    https://www.roche.com
#                                         ROG.SW
# Currency                                   CHF
# Dayhigh                                 362.30
# Daylow                                  350.30
# ...
