# %%
import my_portfolio; my_portfolio.run("ROG.SW")
# Out:
# Prices: 315.37 | 331.14 | 347.70 | 365.08 | 383.33 | 402.50 | 422.63
# Buy score: -0.11%
#                        Quantity   Price       Value     Wallet Avg. price  \
# Time
# 2026-02-05 09:08:45   50.000000  357.00   17,850.00  50.000000     357.00
# 2026-02-17 09:31:44  -50.000000  365.00  -18,250.00   0.000000       0.00
#
#                     Inv. Cost Inv. Balance Balance
# Time
# 2026-02-05 09:08:45     95.24       -95.24  -95.24
# 2026-02-17 09:31:44      0.00         0.00  209.22
#                                           ROG.SW
# Company Name                            ROCHE GS
# Current Price                              365.5
# Forward EPS                             21.81119
# Gross Profit (ttm)                47,194,001,408
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     63,355,998,208
# Target High Price                          428.0
# Target Low Price                           230.0
# ...
