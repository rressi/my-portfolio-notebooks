# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 161.74 | 169.83 | 178.32 | 192.44 | 202.07 | 212.17 | 222.78
# Buy score: -1.72%
# Sell score: -3.50%
# Current return: -279.62 USD
# Breakeven price: 195.02 USD
# <style type="text/css">
# #T_acb61_row53_col0, #T_acb61_row53_col1, #T_acb61_row53_col2, #T_acb61_row53_col3, #T_acb61_row53_col4, #T_acb61_row53_col5, #T_acb61_row53_col6, #T_acb61_row53_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_acb61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acb61_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_acb61_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_acb61_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_acb61_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_acb61_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
