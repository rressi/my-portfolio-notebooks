# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 162.23 | 170.34 | 178.86 | 185.26 | 194.52 | 204.25 | 214.46
# Buy score: -2.67%
# Sell score: 4.16%
# Current return: 1,405.78 USD
# Breakeven price: 187.34 USD
# <style type="text/css">
# #T_c39fd_row62_col0, #T_c39fd_row62_col1, #T_c39fd_row62_col2, #T_c39fd_row62_col3, #T_c39fd_row62_col4, #T_c39fd_row62_col5, #T_c39fd_row62_col6, #T_c39fd_row62_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_c39fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c39fd_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c39fd_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c39fd_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c39fd_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c39fd_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
