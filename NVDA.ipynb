# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 162.37 | 170.49 | 179.01 | 185.27 | 194.54 | 204.27 | 214.48
# Buy score: 0.10%
# Sell score: 1.35%
# Current return: -5.59 USD
# Breakeven price: 187.83 USD
# <style type="text/css">
# #T_e2066_row58_col0, #T_e2066_row58_col1, #T_e2066_row58_col2, #T_e2066_row58_col3, #T_e2066_row58_col4, #T_e2066_row58_col5, #T_e2066_row58_col6, #T_e2066_row58_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_e2066">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2066_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_e2066_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_e2066_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_e2066_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_e2066_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
