# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 152.25 | 159.86 | 167.86 | 167.35 | 175.72 | 184.50 | 193.73
# Buy score: -3.47%
# Sell score: 9.10%
#                                       NVDA
# Company Name                      NVIDIAon
# Current Price                       183.61
# Forward EPS                           4.12
# Gross Profit (ttm)         115,399,999,488
# Industry                    Semiconductors
# Revenue (ttm)              165,217,992,704
# Target High Price                    270.0
# Target Low Price                     100.0
# Target Mean Price                212.12231
# Trailing EPS                          3.51
# Website             https://www.nvidia.com
#                                             NVDA
# Currency                                     USD
# Dayhigh                                   184.55
# Daylow                                    174.71
# Exchange                                     NMS
# Fiftydayaverage                           175.55
# ...
