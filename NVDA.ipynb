# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 166.67 | 175.01 | 183.76 | 194.50 | 204.23 | 214.44 | 225.16
# Buy score: -0.84%
# Sell score: 0.05%
# Current return: -49.89 USD
# Breakeven price: 197.08 USD
# <style type="text/css">
# #T_0bb98_row52_col0, #T_0bb98_row52_col1, #T_0bb98_row52_col2, #T_0bb98_row52_col3, #T_0bb98_row52_col4, #T_0bb98_row52_col5, #T_0bb98_row52_col6, #T_0bb98_row52_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_0bb98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bb98_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_0bb98_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_0bb98_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_0bb98_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_0bb98_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
