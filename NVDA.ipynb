# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 160.48 | 168.50 | 176.93 | 186.56 | 195.88 | 205.68 | 215.96
# Buy score: -1.15%
# Sell score: 0.74%
# Current return: -157.16 USD
# Breakeven price: 188.72 USD
# <style type="text/css">
# #T_85fd8_row60_col0, #T_85fd8_row60_col1, #T_85fd8_row60_col2, #T_85fd8_row60_col3, #T_85fd8_row60_col4, #T_85fd8_row60_col5, #T_85fd8_row60_col6, #T_85fd8_row60_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_85fd8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85fd8_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_85fd8_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_85fd8_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_85fd8_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_85fd8_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
