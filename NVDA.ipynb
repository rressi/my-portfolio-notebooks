# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 160.54 | 168.57 | 176.99 | 185.27 | 194.54 | 204.27 | 214.48
# Buy score: -2.68%
# Sell score: 1.68%
# Current return: 54.91 USD
# Breakeven price: 187.83 USD
# <style type="text/css">
# #T_046fa_row58_col0, #T_046fa_row58_col1, #T_046fa_row58_col2, #T_046fa_row58_col3, #T_046fa_row58_col4, #T_046fa_row58_col5, #T_046fa_row58_col6, #T_046fa_row58_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_046fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_046fa_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_046fa_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_046fa_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_046fa_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_046fa_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
