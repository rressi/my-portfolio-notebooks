# %%
import my_portfolio

my_portfolio.run(
    security="NVDA",
    invest_ratio=1.06,
)
# Out:
# Prices: 147.05 | 155.87 | 165.22 | 167.35 | 177.39 | 188.03 | 199.32
# Buy score: -1.10%
# Sell score: 5.57%
#                                       NVDA
# Company Name                      NVIDIAon
# Current Price                       176.67
# Forward EPS                           4.12
# Gross Profit (ttm)         115,399,999,488
# Industry                    Semiconductors
# Revenue (ttm)              165,217,992,704
# Target High Price                    270.0
# Target Low Price                     100.0
# Target Mean Price                211.92589
# Trailing EPS                          3.52
# Website             https://www.nvidia.com
#                                             NVDA
# Currency                                     USD
# Dayhigh                                   178.08
# Daylow                                    175.18
# Exchange                                     NMS
# Fiftydayaverage                           175.55
# ...
