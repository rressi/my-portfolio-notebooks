# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 151.29 | 158.85 | 166.79 | 167.35 | 175.72 | 184.50 | 193.73
# Buy score: -0.77%
# Sell score: 5.21%
#                                       NVDA
# Company Name                      NVIDIAon
# Current Price                       176.67
# Forward EPS                           4.12
# Gross Profit (ttm)         115,399,999,488
# Industry                    Semiconductors
# Revenue (ttm)              165,217,992,704
# Target High Price                    270.0
# Target Low Price                     100.0
# Target Mean Price                211.92589
# Trailing EPS                          3.52
# Website             https://www.nvidia.com
#                                             NVDA
# Currency                                     USD
# Dayhigh                                   178.08
# Daylow                                    175.18
# Exchange                                     NMS
# Fiftydayaverage                           175.55
# ...
