# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 159.37 | 167.34 | 175.71 | 185.26 | 194.52 | 204.25 | 214.46
# Buy score: -2.16%
# Sell score: 1.78%
# Current return: 307.05 USD
# Breakeven price: 187.34 USD
# <style type="text/css">
# #T_46717_row62_col0, #T_46717_row62_col1, #T_46717_row62_col2, #T_46717_row62_col3, #T_46717_row62_col4, #T_46717_row62_col5, #T_46717_row62_col6, #T_46717_row62_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_46717">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46717_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_46717_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_46717_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_46717_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_46717_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
