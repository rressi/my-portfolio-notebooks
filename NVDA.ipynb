# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 161.54 | 169.62 | 178.10 | 192.44 | 202.07 | 212.17 | 222.78
# Buy score: -1.70%
# Sell score: -4.70%
# Current return: -348.77 USD
# Breakeven price: 195.02 USD
# <style type="text/css">
# #T_6c62b_row53_col0, #T_6c62b_row53_col1, #T_6c62b_row53_col2, #T_6c62b_row53_col3, #T_6c62b_row53_col4, #T_6c62b_row53_col5, #T_6c62b_row53_col6, #T_6c62b_row53_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_6c62b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c62b_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_6c62b_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_6c62b_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_6c62b_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_6c62b_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
