# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 157.77 | 165.66 | 173.94 | 184.58 | 193.81 | 203.50 | 213.68
# Buy score: -0.39%
# Sell score: -0.66%
# Current return: -75.58 USD
# Breakeven price: 187.14 USD
# <style type="text/css">
# #T_00afd_row47_col0, #T_00afd_row47_col1, #T_00afd_row47_col2, #T_00afd_row47_col3, #T_00afd_row47_col4, #T_00afd_row47_col5, #T_00afd_row47_col6, #T_00afd_row47_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_00afd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00afd_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_00afd_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_00afd_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_00afd_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_00afd_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
