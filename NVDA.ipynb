# %%
import workflow
workflow.run(
    security = "NVDA",
    buy_price = 172.74,
    buy_date = "2025-09-02",
    # start_date = "2025-01-01",
)
# Out:
# Prices: 152.02 | 159.62 | 167.60 | 172.7400 | 181.38 | 190.45 | 199.97
# Buy score: -0.67%
# Sell score: 2.56%
#                                       NVDA
# Company Name                        NVIDIA
# Industry                    Semiconductors
# Revenue (ttm)              165,217,992,704
# Gross Profit (ttm)         115,399,999,488
# Current Price                       177.17
# Target Mean Price                 207.8921
# Target High Price                    270.0
# Target Low Price                     100.0
# Trailing EPS                          3.51
# Forward EPS                           4.12
# Website             https://www.nvidia.com
#                                             NVDA
# Currency                                     USD
# Dayhigh                                   180.28
# Daylow                                    176.48
# Exchange                                     NMS
# Fiftydayaverage                           173.23
# ...
