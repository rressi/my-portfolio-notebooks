# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 158.97 | 166.92 | 175.27 | 185.26 | 194.52 | 204.25 | 214.46
# Buy score: -1.95%
# Sell score: 1.31%
# Current return: 89.55 USD
# Breakeven price: 187.34 USD
# <style type="text/css">
# #T_daa10_row62_col0, #T_daa10_row62_col1, #T_daa10_row62_col2, #T_daa10_row62_col3, #T_daa10_row62_col4, #T_daa10_row62_col5, #T_daa10_row62_col6, #T_daa10_row62_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_daa10">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_daa10_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_daa10_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_daa10_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_daa10_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_daa10_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
