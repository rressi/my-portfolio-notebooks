# %%
import my_portfolio; my_portfolio.run("NVDA")
# Out:
# Prices: 175.88 | 184.67 | 193.90 | 184.58 | 193.81 | 203.50 | 213.68
# Buy score: 4.41%
# Sell score: 5.64%
# Current return: 157.22 USD
# Breakeven price: 187.14 USD
# <style type="text/css">
# #T_72f0c_row47_col0, #T_72f0c_row47_col1, #T_72f0c_row47_col2, #T_72f0c_row47_col3, #T_72f0c_row47_col4, #T_72f0c_row47_col5, #T_72f0c_row47_col6, #T_72f0c_row47_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_72f0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72f0c_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_72f0c_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_72f0c_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_72f0c_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_72f0c_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
