# %%
import my_portfolio; my_portfolio.run(
    security="SPCX",
)
# Out:
# $SPCX: possibly delisted; no price data found  (period=1mo)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import my_portfolio; my_portfolio.run(
#       2     security="SPCX",
#       3 )
#
# File ~/Code/my-portfolio-notebooks/my_portfolio/_workflow.py:939, in run(security, **kwargs)
#     936 def run(security: str, **kwargs):
#     937     (
#     938         Context(security=security, **kwargs)
# --> 939         .load()
#     940         .handle_last_price()
#     941         .compute_SMAs()
#     942         .import_trades()
#     943         .compute_enter_prices()
#     944         .compute_exit_prices()
#     945         .print_last_prices()
#     946         .print_scores()
#     947         .plot()
#     948         .show_operations()
#     949         .show_company_table()
#     950         .show_status()
#     951     )
#
# ...
