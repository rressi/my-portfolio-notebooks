# %%
import workflow
workflow.run(
    security = "GOOG",
)
# Out:
# Prices: 208.73 | 219.16 | 230.12 | 241.63 | 253.71 | 266.39 | 279.71
# Buy score: -3.29%
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               249.85
# Forward EPS                                   8.95
# Gross Profit (ttm)                 218,911,997,952
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Target High Price                            270.0
# Target Low Price                             185.0
# Target Mean Price                        229.19473
# Trailing EPS                                  9.37
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   251.95
# Daylow                                    246.58
# Exchange                                     NMS
# ...
