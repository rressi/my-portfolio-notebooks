# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 244.31 | 256.52 | 269.35 | 282.82 | 296.96 | 311.81 | 327.40
# Buy score: -1.75%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               284.96
# Forward EPS                                   8.95
# Gross Profit (ttm)                 228,095,000,576
# Industry            Internet Content & Information
# Revenue (ttm)                      385,476,001,792
# Target High Price                            345.0
# Target Low Price                             185.0
# Target Mean Price                        311.68823
# Trailing EPS                                 10.12
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   289.43
# Daylow                                    279.01
# ...
