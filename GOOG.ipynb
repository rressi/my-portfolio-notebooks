# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 314.73 | 330.46 | 346.99 | 364.34 | 382.55 | 401.68 | 421.76
# Buy score: 0.75%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               365.76
# Forward EPS                                 14.461
# Gross Profit (ttm)                 255,053,004,800
# Industry            Internet Content & Information
# Revenue (ttm)                      422,498,009,088
# Target High Price                            460.0
# Target Low Price                             195.0
# Target Mean Price                        407.21713
# Trailing EPS                                 13.09
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   369.20
# Daylow                                    361.63
# ...
