# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 290.88 | 305.43 | 320.70 | 336.73 | 353.57 | 371.25 | 389.81
# Buy score: -1.45%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               342.32
# Forward EPS                               13.49868
# Gross Profit (ttm)                 240,300,998,656
# Industry            Internet Content & Information
# Revenue (ttm)                      402,835,996,672
# Target High Price                            405.0
# Target Low Price                             185.0
# Target Mean Price                         363.3553
# Trailing EPS                                 10.82
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   343.69
# Daylow                                    334.05
# ...
