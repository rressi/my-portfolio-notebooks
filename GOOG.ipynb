# %%
import workflow
workflow.run(
    security = "GOOG",
)
# Out:
# Prices: 207.09 | 217.44 | 228.31 | 239.73 | 251.72 | 264.30 | 277.52
# Buy score: -4.65%
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               251.42
# Forward EPS                                   8.95
# Gross Profit (ttm)                 218,911,997,952
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Target High Price                            270.0
# Target Low Price                             185.0
# Target Mean Price                        229.19473
# Trailing EPS                                  9.39
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   253.23
# Daylow                                    249.71
# Exchange                                     NMS
# ...
