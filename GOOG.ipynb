# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 234.26 | 245.98 | 258.27 | 271.19 | 284.75 | 298.98 | 313.93
# Buy score: -4.70%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                                281.9
# Forward EPS                                   8.95
# Gross Profit (ttm)                 218,911,997,952
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Target High Price                            345.0
# Target Low Price                             185.0
# Target Mean Price                            292.1
# Trailing EPS                                 10.13
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   291.90
# Daylow                                    280.45
# ...
