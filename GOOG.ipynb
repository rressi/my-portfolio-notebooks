# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 310.79 | 326.33 | 342.64 | 359.78 | 377.76 | 396.65 | 416.49
# Buy score: -0.70%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               356.56
# Forward EPS                               14.48061
# Gross Profit (ttm)                 255,053,004,800
# Industry            Internet Content & Information
# Revenue (ttm)                      422,498,009,088
# Target High Price                            475.0
# Target Low Price                             195.0
# Target Mean Price                        409.00287
# Trailing EPS                                 13.12
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   358.01
# Daylow                                    343.63
# ...
