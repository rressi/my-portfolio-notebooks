# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 330.26 | 346.78 | 364.11 | 382.32 | 401.44 | 421.51 | 442.58
# Buy score: 1.45%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               376.43
# Forward EPS                               14.48958
# Gross Profit (ttm)                 255,053,004,800
# Industry            Internet Content & Information
# Revenue (ttm)                      422,498,009,088
# Target High Price                            460.0
# Target Low Price                             285.0
# Target Mean Price                          414.736
# Trailing EPS                                  13.1
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   381.65
# Daylow                                    374.30
# ...
