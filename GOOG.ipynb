# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 220.30 | 231.32 | 242.88 | 255.03 | 267.78 | 281.17 | 295.22
# Buy score: -2.21%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               260.51
# Forward EPS                                   8.95
# Gross Profit (ttm)                 218,911,997,952
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Target High Price                            300.0
# Target Low Price                             185.0
# Target Mean Price                        257.39413
# Trailing EPS                                  9.38
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   262.51
# Daylow                                    256.10
# ...
