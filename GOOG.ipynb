# %%
import workflow
workflow.run(
    security = "GOOG",
)
# Out:
# Prices: 210.44 | 220.97 | 232.01 | 243.61 | 255.79 | 268.58 | 282.01
# Buy score: -3.45%
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               252.33
# Forward EPS                                   8.95
# Gross Profit (ttm)                 218,911,997,952
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Target High Price                            285.0
# Target Low Price                             185.0
# Target Mean Price                        232.61578
# Trailing EPS                                  9.37
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   254.14
# Daylow                                    250.11
# Exchange                                     NMS
# ...
