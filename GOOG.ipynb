# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 312.45 | 328.07 | 344.47 | 361.70 | 379.78 | 398.77 | 418.71
# Buy score: -5.41%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               383.22
# Forward EPS                               14.25245
# Gross Profit (ttm)                 255,053,004,800
# Industry            Internet Content & Information
# Revenue (ttm)                      422,498,009,088
# Target High Price                            460.0
# Target Low Price                             185.0
# Target Mean Price                        394.44666
# Trailing EPS                                 13.11
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   383.39
# Daylow                                    375.26
# ...
