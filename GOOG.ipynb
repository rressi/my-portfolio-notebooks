# %%
import workflow
workflow.run(
    security = "GOOG",
)
# Out:
# Prices: 188.94 | 198.38 | 208.30 | 218.7170 | 229.65 | 241.14 | 253.19
# Buy score: -9.39%
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               241.38
# Forward EPS                                   8.95
# Gross Profit (ttm)                 218,911,997,952
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Target High Price                            270.0
# Target Low Price                             185.0
# Target Mean Price                        227.61578
# Trailing EPS                                  9.39
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   242.42
# Daylow                                    238.50
# Exchange                                     NMS
# ...
