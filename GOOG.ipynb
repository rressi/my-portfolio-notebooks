# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 315.46 | 331.23 | 347.80 | 365.19 | 383.45 | 402.62 | 422.75
# Buy score: 1.65%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               367.46
# Forward EPS                                14.4964
# Gross Profit (ttm)                 255,053,004,800
# Industry            Internet Content & Information
# Revenue (ttm)                      422,498,009,088
# Target High Price                            475.0
# Target Low Price                             340.0
# Target Mean Price                        426.61847
# Trailing EPS                                 13.12
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   369.00
# Daylow                                    356.61
# ...
