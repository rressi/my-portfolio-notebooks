# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 274.63 | 288.36 | 302.78 | 317.92 | 333.82 | 350.51 | 368.03
# Buy score: 0.06%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               317.73
# Forward EPS                                   8.95
# Gross Profit (ttm)                 228,095,000,576
# Industry            Internet Content & Information
# Revenue (ttm)                      385,476,001,792
# Target High Price                            380.0
# Target Low Price                             185.0
# Target Mean Price                        314.80588
# Trailing EPS                                 10.13
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   323.10
# Daylow                                    315.60
# ...
