# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 271.65 | 285.24 | 299.50 | 314.47 | 330.20 | 346.71 | 364.04
# Buy score: -0.08%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               314.73
# Forward EPS                               11.20349
# Gross Profit (ttm)                 228,095,000,576
# Industry            Internet Content & Information
# Revenue (ttm)                      385,476,001,792
# Target High Price                            386.0
# Target Low Price                             185.0
# Target Mean Price                        328.20557
# Trailing EPS                                 10.14
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   314.91
# Daylow                                    311.90
# ...
