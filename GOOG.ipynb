# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 283.36 | 297.53 | 312.41 | 328.03 | 344.43 | 361.65 | 379.74
# Buy score: -0.04%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               328.44
# Forward EPS                               11.24762
# Gross Profit (ttm)                 228,095,000,576
# Industry            Internet Content & Information
# Revenue (ttm)                      385,476,001,792
# Target High Price                            400.0
# Target Low Price                             185.0
# Target Mean Price                        337.03888
# Trailing EPS                                 10.12
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   334.03
# Daylow                                    327.97
# ...
