# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 228.85 | 240.29 | 252.31 | 264.92 | 278.17 | 292.08 | 306.68
# Buy score: -2.61%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               272.09
# Forward EPS                                   8.95
# Gross Profit (ttm)                 218,911,997,952
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Target High Price                            310.0
# Target Low Price                             185.0
# Target Mean Price                        267.39413
# Trailing EPS                                  9.37
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   274.18
# Daylow                                    268.43
# ...
