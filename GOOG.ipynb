# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 285.74 | 300.03 | 315.03 | 330.78 | 347.32 | 364.69 | 382.92
# Buy score: 1.64%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               325.45
# Forward EPS                               13.32185
# Gross Profit (ttm)                 240,300,998,656
# Industry            Internet Content & Information
# Revenue (ttm)                      402,835,996,672
# Target High Price                            400.0
# Target Low Price                             185.0
# Target Mean Price                        359.82352
# Trailing EPS                                 10.82
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   326.36
# Daylow                                    317.70
# ...
