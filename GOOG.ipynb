# %%
import workflow
workflow.run(
    security = "GOOG",
)
# Out:
# Prices: 187.31 | 196.67 | 206.50 | 216.8299 | 227.67 | 239.05 | 251.01
# Buy score: -9.95%
#                                               GOOG
# Company Name                              Alphabet
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Gross Profit (ttm)                 218,911,997,952
# Current Price                               240.78
# Target Mean Price                        227.61578
# Target High Price                            270.0
# Target Low Price                             185.0
# Trailing EPS                                  9.39
# Forward EPS                                   8.95
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   242.57
# Daylow                                    236.58
# Exchange                                     NMS
# ...
