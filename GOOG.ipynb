# %%
import workflow
workflow.run(
    security = "GOOG",
)
# Out:
# Prices: 190.97 | 200.52 | 210.54 | 221.07 | 232.12 | 243.73 | 255.91
# Buy score: -12.19%
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               251.76
# Forward EPS                                   8.95
# Gross Profit (ttm)                 218,911,997,952
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Target High Price                            270.0
# Target Low Price                             185.0
# Target Mean Price                        227.61578
# Trailing EPS                                  9.79
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   252.75
# Daylow                                    244.98
# Exchange                                     NMS
# ...
