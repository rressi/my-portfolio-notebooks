# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 225.34 | 236.61 | 248.44 | 260.86 | 273.90 | 287.60 | 301.98
# Buy score: -2.52%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                              267.595
# Forward EPS                                   8.95
# Gross Profit (ttm)                 218,911,997,952
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Target High Price                            310.0
# Target Low Price                             185.0
# Target Mean Price                        267.39413
# Trailing EPS                                  9.37
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   271.38
# Daylow                                    267.50
# ...
