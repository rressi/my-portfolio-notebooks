# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 340.02 | 357.02 | 374.87 | 393.61 | 413.29 | 433.96 | 455.66
# Buy score: 2.11%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               385.39
# Forward EPS                               14.45135
# Gross Profit (ttm)                 255,053,004,800
# Industry            Internet Content & Information
# Revenue (ttm)                      422,498,009,088
# Target High Price                            460.0
# Target Low Price                             340.0
# Target Mean Price                           421.69
# Trailing EPS                                 13.09
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   393.36
# Daylow                                    384.05
# ...
