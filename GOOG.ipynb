# %%
import workflow
workflow.run(
    security = "GOOG",
)
# Out:
# Prices: 191.30 | 200.86 | 210.91 | 221.4536 | 232.53 | 244.15 | 256.36
# Buy score: -8.03%
#                                               GOOG
# Company Name                         Alphabet Inc.
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Gross Profit (ttm)                 218,911,997,952
# Current Price                               240.78
# Target Mean Price                        227.61578
# Target High Price                            270.0
# Target Low Price                             185.0
# Trailing EPS                                  9.39
# Forward EPS                                   8.95
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   242.57
# Daylow                                    236.58
# Exchange                                     NMS
# ...
