# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 225.48 | 236.76 | 248.60 | 261.03 | 274.08 | 287.78 | 302.17
# Buy score: -2.83%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               268.43
# Forward EPS                                   8.95
# Gross Profit (ttm)                 218,911,997,952
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Target High Price                            310.0
# Target Low Price                             185.0
# Target Mean Price                        267.39413
# Trailing EPS                                  9.37
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   271.38
# Daylow                                    267.17
# ...
