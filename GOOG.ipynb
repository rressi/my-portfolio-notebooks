# %%
import my_portfolio; my_portfolio.run("GOOG")
# Out:
# No operations found for ticker 'GOOG'
# Prices: 212.02 | 222.62 | 233.75 | 245.44 | 257.71 | 270.60 | 284.13
# Buy score: 0.03%
# No operations found.
#                                               GOOG
# Company Name                              Alphabet
# Current Price                               245.54
# Forward EPS                                   8.95
# Gross Profit (ttm)                 218,911,997,952
# Industry            Internet Content & Information
# Revenue (ttm)                      371,399,000,064
# Target High Price                            285.0
# Target Low Price                             185.0
# Target Mean Price                           240.65
# Trailing EPS                                  9.23
# Website                            https://abc.xyz
#                                             GOOG
# Currency                                     USD
# Dayhigh                                   247.15
# Daylow                                    239.20
# ...
