# %%
import my_portfolio
my_portfolio.run(
    security = "BTC-EUR",  # Bitcoin
    start_date = "2025-07-01",
    ops=
"""
date, quantity, price
2025-07-26, 0.00019676, 100580
2025-07-29, 0.00048297, 102496
2025-08-12, 0.00048347, 102396
2025-09-02, 0.00015841,  94694
2025-09-02, 0.0001584,   94701
2025-09-09, 0.00020783,  96235
2025-09-16, 0.00020349,  98286
"""
)
# Out:
# Prices: 85,182.26 | 89,441.37 | 93,913.44 | 99823.86 | 104,815.05 | 110,055.81 | 115,558.60
# Buy score: 0.05%
# Sell score: -1.27%
#                         BTC-EUR
# Company Name        Bitcoin EUR
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                    BTC-EUR
# Currency                               EUR
# Dayhigh                          98,914.35
# Daylow                           98,325.30
# Exchange                               CCC
# Fiftydayaverage                  97,846.84
# Lastprice                        98,557.70
# Lastvolume                  20,261,888,000
# Marketcap                             None
# Open                             98,498.69
# ...
