# %%
import workflow
workflow.run(
    security = "BTC-EUR",  # Bitcoin
    start_date = "2025-07-01",
    ops=
"""
date, quantity, price
2025-07-26, 0.00019676, 100580
2025-07-29, 0.00048297, 102496
2025-08-12, 0.00048347, 102396
2025-09-02, 0.00015841,  94694
2025-09-02, 0.0001584,   94701
2025-09-09, 0.00020783,  96235
2025-09-16, 0.00020349,  98286
"""
)
# Out:
# Prices: 84,138.60 | 88,345.53 | 92,762.81 | 99823.86 | 105,009.73 | 110,260.22 | 115,773.23
# Buy score: -1.03%
# Sell score: -1.41%
#                         BTC-EUR
# Company Name        Bitcoin EUR
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                    BTC-EUR
# Currency                               EUR
# Dayhigh                          98,425.73
# Daylow                           98,253.40
# Exchange                               CCC
# Fiftydayaverage                  98,043.15
# Lastprice                        98,416.87
# Lastvolume                  38,563,586,048
# Marketcap                             None
# Open                             98,425.73
# Previousclose                    98,510.49
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose             nan
# Shares                                None
# Tendayaveragevolume         33,070,080,208
# Threemonthaveragevolume     51,256,348,122
# Timezone                               UTC
# Twohundreddayaverage             89,992.01
# Yearchange                             nan
# Yearhigh                        106,252.52
# Yearlow                          53,269.66
