# %%
import workflow
workflow.run(
    security = "BTC-EUR",  # Bitcoin
    start_date = "2025-07-01",
    ops=
"""
date, quantity, price
2025-07-26, 0.00019676, 100580
2025-07-29, 0.00048297, 102496
2025-08-12, 0.00048347, 102396
2025-09-02, 0.00015841,  94694
2025-09-02, 0.0001584,   94701
2025-09-09, 0.00020783,  96235
2025-09-16, 0.00020349,  98286
"""
)
# Out:
# Prices: 84,553.93 | 88,781.62 | 93,220.70 | 99823.86 | 104,815.05 | 110,055.81 | 115,558.60
# Buy score: -1.84%
# Sell score: -0.11%
#                         BTC-EUR
# Company Name        Bitcoin EUR
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                    BTC-EUR
# Currency                               EUR
# Dayhigh                          99,714.17
# Daylow                           98,311.22
# Exchange                               CCC
# Fiftydayaverage                  97,968.41
# Lastprice                        99,714.17
# Lastvolume                  55,718,494,208
# Marketcap                             None
# Open                             98,487.88
# Previousclose                    98,487.83
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose             nan
# Shares                                None
# Tendayaveragevolume         34,824,725,279
# Threemonthaveragevolume     51,145,741,197
# Timezone                               UTC
# Twohundreddayaverage             90,070.05
# Yearchange                             nan
# Yearhigh                        106,252.52
# Yearlow                          53,929.40
