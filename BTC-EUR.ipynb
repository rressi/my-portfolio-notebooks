# %%
import my_portfolio; my_portfolio.run("BTC-EUR")
# Out:
# Prices: 84,824.28 | 89,065.49 | 93,518.77 | 99,823.86 | 104,815.05 | 110,055.81 | 115,558.60
# Buy score: 3.32%
# Sell score: -4.79%
#                         BTC-EUR
# Company Name        Bitcoin EUR
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                    BTC-EUR
# Currency                               EUR
# Dayhigh                          95,666.63
# Daylow                           95,029.01
# Exchange                               CCC
# Fiftydayaverage                  97,871.63
# Lastprice                        95,042.31
# Lastvolume                  55,026,597,888
# Marketcap                             None
# Open                             95,565.15
# ...
