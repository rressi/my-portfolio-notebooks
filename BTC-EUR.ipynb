# %%
import workflow
workflow.run(
    security = "BTC-EUR",  # Bitcoin
    start_date = "2025-07-01",
    ops=
"""
date, quantity, price
2025-07-26, 0.00019676, 100580
2025-07-29, 0.00048297, 102496
2025-08-12, 0.00048347, 102396
2025-09-02, 0.00015841,  94694
2025-09-02, 0.0001584,   94701
2025-09-09, 0.00020783,  96235
"""
)
# Out:
# Prices: 82,582.34 | 86,711.46 | 91,047.03 | 100009.2681 | 105,009.73 | 110,260.22 | 115,773.23
# Buy score: -2.90%
# Sell score: -1.56%
#                         BTC-EUR
# Company Name        Bitcoin EUR
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                    BTC-EUR
# Currency                               EUR
# Dayhigh                          98,993.34
# Daylow                           98,234.03
# Exchange                               CCC
# Fiftydayaverage                  98,225.15
# Lastprice                        98,451.85
# Lastvolume                  25,512,577,024
# Marketcap                             None
# Open                             98,817.00
# Previousclose                    98,819.08
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose       98,815.80
# Shares                                None
# Tendayaveragevolume         37,905,406,169
# Threemonthaveragevolume     51,640,478,912
# Timezone                               UTC
# Twohundreddayaverage             89,775.28
# Yearchange                            0.85
# Yearhigh                        106,252.52
# Yearlow                          51,691.58
