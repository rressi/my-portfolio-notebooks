# %%
import my_portfolio; my_portfolio.run("BTC-EUR")
# Out:
# Prices: 84,808.63 | 89,049.07 | 93,501.52 | 99,823.86 | 104,815.05 | 110,055.81 | 115,558.60
# Buy score: 3.49%
# Sell score: -4.97%
#                         BTC-EUR
# Company Name        Bitcoin EUR
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                    BTC-EUR
# Currency                               EUR
# Dayhigh                          95,666.63
# Daylow                           94,861.22
# Exchange                               CCC
# Fiftydayaverage                  97,871.63
# Lastprice                        94,861.22
# Lastvolume                  54,824,390,656
# Marketcap                             None
# Open                             95,565.15
# ...
