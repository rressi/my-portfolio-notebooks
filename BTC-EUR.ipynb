# %%
import my_portfolio; my_portfolio.run("BTC-EUR")
# Out:
# Prices: 85,159.08 | 89,417.03 | 93,887.88 | 99,823.86 | 104,815.05 | 110,055.81 | 115,558.60
# Buy score: 0.35%
# Sell score: -1.59%
#                         BTC-EUR
# Company Name        Bitcoin EUR
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                    BTC-EUR
# Currency                               EUR
# Dayhigh                          98,637.44
# Daylow                           98,235.83
# Exchange                               CCC
# Fiftydayaverage                  97,862.02
# Lastprice                        98,235.83
# Lastvolume                  18,565,730,304
# Marketcap                             None
# Open                             98,508.06
# ...
