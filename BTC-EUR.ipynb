# %%
import workflow
workflow.run(
    security = "BTC-EUR",  # Bitcoin
    start_date = "2025-07-01",
    ops=
"""
date, quantity, price
2025-07-26, 0.00019676, 100580
2025-07-29, 0.00048297, 102496
2025-08-12, 0.00048347, 102396
2025-09-02, 0.00015841,  94694
2025-09-02, 0.0001584,   94701
2025-09-09, 0.00020783,  96235
"""
)
# Out:
# Prices: 82,662.74 | 86,795.88 | 91,135.67 | 100009.27 | 105,009.73 | 110,260.22 | 115,773.23
# Buy score: -2.32%
# Sell score: -2.05%
#                         BTC-EUR
# Company Name        Bitcoin EUR
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                    BTC-EUR
# Currency                               EUR
# Dayhigh                          98,186.89
# Daylow                           97,788.77
# Exchange                               CCC
# Fiftydayaverage                  98,115.52
# Lastprice                        97,963.12
# Lastvolume                  42,970,759,168
# Marketcap                             None
# Open                             98,112.91
# Previousclose                    98,065.02
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose             nan
# Shares                                None
# Tendayaveragevolume         30,404,753,885
# Threemonthaveragevolume     51,241,001,405
# Timezone                               UTC
# Twohundreddayaverage             89,907.36
# Yearchange                             nan
# Yearhigh                        106,252.52
# Yearlow                          51,809.77
