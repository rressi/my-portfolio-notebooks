# %%
import my_portfolio; my_portfolio.run("BTC-EUR")
# Out:
# Prices: 85,182.83 | 89,441.98 | 93,914.08 | 99823.86 | 104,815.05 | 110,055.81 | 115,558.60
# Buy score: 0.10%
# Sell score: -1.32%
#                         BTC-EUR
# Company Name        Bitcoin EUR
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                    BTC-EUR
# Currency                               EUR
# Dayhigh                          98,637.44
# Daylow                           98,363.91
# Exchange                               CCC
# Fiftydayaverage                  97,862.02
# Lastprice                        98,510.85
# Lastvolume                  19,172,767,744
# Marketcap                             None
# Open                             98,508.06
# ...
