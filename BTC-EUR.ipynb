# %%
import workflow
workflow.run(
    security = "BTC-EUR",  # Bitcoin
    start_date = "2025-07-01",
    ops=
"""
date, quantity, price
2025-07-26, 0.00019676, 100580
2025-07-29, 0.00048297, 102496
2025-08-12, 0.00048347, 102396
2025-09-02, 0.00015841,  94694
2025-09-02, 0.0001584,   94701
2025-09-09, 0.00020783,  96235
2025-09-16, 0.00020349,  98286
"""
)
# Out:
# Prices: 84,804.41 | 89,044.63 | 93,496.86 | 99823.86 | 104,815.05 | 110,055.81 | 115,558.60
# Buy score: -1.19%
# Sell score: -0.47%
#                         BTC-EUR
# Company Name        Bitcoin EUR
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                    BTC-EUR
# Currency                               EUR
# Dayhigh                          99,745.27
# Daylow                           98,311.22
# Exchange                               CCC
# Fiftydayaverage                  97,978.82
# Lastprice                        99,355.52
# Lastvolume                  43,537,068,032
# Marketcap                             None
# Open                             98,487.88
# Previousclose                    98,487.83
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose       98,488.80
# Shares                                None
# Tendayaveragevolume         39,943,132,530
# Threemonthaveragevolume     51,702,089,811
# Timezone                               UTC
# Twohundreddayaverage             90,112.15
# Yearchange                            0.75
# Yearhigh                        106,252.52
# Yearlow                          53,929.40
