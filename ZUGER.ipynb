# %%
import my_portfolio; my_portfolio.run(
    security="ZUGER.SW",
    trades_isin="CH0493891243",
)
# Out:
# Prices: 8,261.74 | 8,674.83 | 9,108.57 | 9,700.00 | 10,185.00 | 10,694.25 | 11,228.96
# Buy score: -0.79%
# Sell score: -0.62%
# Current return: -139.32 CHF
# Breakeven price: 9,779.32 CHF
# <style type="text/css">
# #T_67cb2_row3_col0, #T_67cb2_row3_col1, #T_67cb2_row3_col2, #T_67cb2_row3_col3, #T_67cb2_row3_col4, #T_67cb2_row3_col5, #T_67cb2_row3_col6, #T_67cb2_row3_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_67cb2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67cb2_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_67cb2_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_67cb2_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_67cb2_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_67cb2_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
