# %%
import my_portfolio; my_portfolio.run(
    security="ZUGER.SW",
    trades_isin="CH0493891243",
)
# Out:
# Prices: 7,555.81 | 7,933.61 | 8,330.29 | 8,800.00 | 9,240.00 | 9,702.00 | 10,187.10
# Buy score: 0.23%
# Sell score: -0.91%
# Current return: -156.90 CHF
# Breakeven price: 8,876.90 CHF
# <style type="text/css">
# #T_c4469_row1_col0, #T_c4469_row1_col1, #T_c4469_row1_col2, #T_c4469_row1_col3, #T_c4469_row1_col4, #T_c4469_row1_col5, #T_c4469_row1_col6, #T_c4469_row1_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_c4469">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4469_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c4469_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c4469_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c4469_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c4469_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
