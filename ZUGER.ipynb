# %%
import my_portfolio; my_portfolio.run(
    security="ZUGER.SW",
    trades_isin="CH0493891243",
)
# Out:
# Prices: 8,441.42 | 8,863.49 | 9,306.67 | 9,690.00 | 10,174.50 | 10,683.23 | 11,217.39
# Buy score: -0.69%
# Sell score: 1.55%
# Current return: 141.40 CHF
# Breakeven price: 9,769.30 CHF
# <style type="text/css">
# #T_9003a_row4_col0, #T_9003a_row4_col1, #T_9003a_row4_col2, #T_9003a_row4_col3, #T_9003a_row4_col4, #T_9003a_row4_col5, #T_9003a_row4_col6, #T_9003a_row4_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_9003a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9003a_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_9003a_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_9003a_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_9003a_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_9003a_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
