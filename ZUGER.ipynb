# %%
import my_portfolio; my_portfolio.run(
    security="ZUGER.SW",
    trades_isin="CH0493891243",
)
# Out:
# Prices: 7,708.89 | 8,094.33 | 8,499.05 | 8,924.00 | 9,370.20 | 9,838.71 | 10,330.65
# Buy score: -0.84%
#                       Quantity     Price      Value    Wallet Avg. price  \
# Time
# 2025-11-10 09:51:46   1.000000  8,800.00   8,800.00  1.000000   8,800.00
# 2025-11-20 12:33:27  -1.000000  8,680.00  -8,680.00  0.000000       0.00
#
#                     Inv. Cost Inv. Balance  Balance
# Time
# 2025-11-10 09:51:46     38.45       -38.45   -38.45
# 2025-11-20 12:33:27      0.00         0.00  -197.30
#                                   ZUGER.SW
# Company Name                    ZUGER KB N
# Current Price                       8940.0
# Forward EPS                           None
# Gross Profit (ttm)             328,967,008
# Industry                  Banks - Regional
# Revenue (ttm)                  328,967,008
# Target High Price                     None
# Target Low Price                      None
# Target Mean Price                     None
# ...
