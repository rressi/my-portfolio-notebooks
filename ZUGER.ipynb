# %%
import my_portfolio; my_portfolio.run(
    security="ZUGER.SW",
    trades_isin="CH0493891243",
)
# Out:
# Prices: 9,184.02 | 9,643.22 | 10,125.38 | 11,400.00 | 11,970.00 | 12,568.50 | 13,196.93
# Buy score: 0.28%
# Sell score: -7.46%
# Current return: -3,798.24 CHF
# Breakeven price: 11,499.56 CHF
# <style type="text/css">
# #T_0e462_row7_col0, #T_0e462_row7_col1, #T_0e462_row7_col2, #T_0e462_row7_col3, #T_0e462_row7_col4, #T_0e462_row7_col5, #T_0e462_row7_col6, #T_0e462_row7_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_0e462">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e462_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_0e462_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_0e462_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_0e462_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_0e462_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
