# %%
import my_portfolio; my_portfolio.run(
    security="ZUGER.SW",
    trades_isin="CH0493891243",
)
# Out:
# Prices: 8,247.92 | 8,660.32 | 9,093.33 | 9,700.00 | 10,185.00 | 10,694.25 | 11,228.96
# Buy score: -0.54%
# Sell score: -1.03%
# Current return: -179.32 CHF
# Breakeven price: 9,779.32 CHF
# <style type="text/css">
# #T_b202b_row3_col0, #T_b202b_row3_col1, #T_b202b_row3_col2, #T_b202b_row3_col3, #T_b202b_row3_col4, #T_b202b_row3_col5, #T_b202b_row3_col6, #T_b202b_row3_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_b202b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b202b_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_b202b_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_b202b_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_b202b_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_b202b_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
