# %%
import workflow
workflow.run("CRWD")
# Out:
# Prices: 369.63 | 388.11 | 407.52 | 427.90 | 449.29 | 471.76 | 495.34
# Buy score: -3.84%
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                            444.98
# Forward EPS                                4.27
# Gross Profit (ttm)                3,219,506,944
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,341,102,080
# Target High Price                         610.0
# Target Low Price                          330.0
# Target Mean Price                     469.57562
# Trailing EPS                               -1.2
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 448.32
# Daylow                                  434.80
# Exchange                                   NMS
# Fiftydayaverage                         446.40
# ...
