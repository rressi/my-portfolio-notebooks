# %%
import workflow
workflow.run(
    security = "CRWD",
)
# Out:
# Prices: 364.66 | 382.89 | 402.04 | 422.1415 | 443.25 | 465.41 | 488.68
# Buy score: -2.59%
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,341,102,080
# Gross Profit (ttm)                3,219,506,944
# Current Price                            433.38
# Target Mean Price                     469.57562
# Target High Price                         610.0
# Target Low Price                          330.0
# Trailing EPS                              -1.21
# Forward EPS                                4.27
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 438.26
# Daylow                                  427.10
# Exchange                                   NMS
# Fiftydayaverage                         450.16
# ...
