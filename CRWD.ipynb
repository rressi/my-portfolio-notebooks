# %%
import my_portfolio; my_portfolio.run("CRWD")
# Out:
# No operations found for ticker 'CRWD'
# Prices: 621.70 | 652.79 | 685.42 | 719.70 | 755.68 | 793.46 | 833.14
# Buy score: -6.17%
# No operations found.
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                            768.95
# Forward EPS                             6.17094
# Gross Profit (ttm)                3,599,789,056
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,812,004,864
# Target High Price                         775.0
# Target Low Price                          368.0
# Target Mean Price                      564.2384
# Trailing EPS                              -0.62
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 778.82
# Daylow                                  745.38
# Exchange                                   NMS
# ...
