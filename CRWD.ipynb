# %%
import workflow
workflow.run("CRWD")
# Out:
# Prices: 365.88 | 384.17 | 403.38 | 423.55 | 444.72 | 466.96 | 490.31
# Buy score: -4.77%
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                            444.77
# Forward EPS                                4.27
# Gross Profit (ttm)                3,219,506,944
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,341,102,080
# Target High Price                         610.0
# Target Low Price                          330.0
# Target Mean Price                     469.57562
# Trailing EPS                              -1.25
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 448.87
# Daylow                                  436.75
# Exchange                                   NMS
# Fiftydayaverage                         447.79
# ...
