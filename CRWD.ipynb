# %%
import my_portfolio; my_portfolio.run("CRWD")
# Out:
# No operations found for ticker 'CRWD'
# Prices: 591.39 | 620.96 | 652.00 | 684.60 | 718.83 | 754.78 | 792.51
# Buy score: 0.69%
# No operations found.
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                            684.86
# Forward EPS                             6.24983
# Gross Profit (ttm)                3,827,581,952
# Industry              Software - Infrastructure
# Revenue (ttm)                     5,094,199,808
# Target High Price                         850.0
# Target Low Price                          413.0
# Target Mean Price                       712.371
# Trailing EPS                              -0.14
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 695.91
# Daylow                                  660.92
# Exchange                                   NMS
# ...
