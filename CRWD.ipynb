# %%
import my_portfolio; my_portfolio.run("CRWD")
# Out:
# No operations found for ticker 'CRWD'
# Prices: 441.60 | 463.68 | 486.86 | 511.20 | 536.76 | 563.60 | 591.78
# Buy score: 4.18%
# No operations found.
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                            490.67
# Forward EPS                                4.27
# Gross Profit (ttm)                3,219,506,944
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,341,102,080
# Target High Price                         706.0
# Target Low Price                          330.0
# Target Mean Price                      531.8734
# Trailing EPS                              -1.18
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 501.00
# Daylow                                  477.55
# Exchange                                   NMS
# ...
