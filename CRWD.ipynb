# %%
import my_portfolio; my_portfolio.run("CRWD")
# Out:
# No operations found for ticker 'CRWD'
# Prices: 423.62 | 444.80 | 467.04 | 490.39 | 514.91 | 540.66 | 567.69
# Buy score: 1.50%
# No operations found.
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                            483.16
# Forward EPS                                4.27
# Gross Profit (ttm)                3,219,506,944
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,341,102,080
# Target High Price                         610.0
# Target Low Price                          330.0
# Target Mean Price                      498.9111
# Trailing EPS                              -1.21
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 484.45
# Daylow                                  475.42
# Exchange                                   NMS
# ...
