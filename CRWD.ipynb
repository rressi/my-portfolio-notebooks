# %%
import my_portfolio; my_portfolio.run("CRWD")
# Out:
# No operations found for ticker 'CRWD'
# Prices: 422.03 | 443.13 | 465.29 | 450.40 | 472.92 | 496.57 | 521.40
# Buy score: -1.48%
# No operations found.
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                            457.15
# Forward EPS                             4.83371
# Gross Profit (ttm)                3,390,874,880
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,565,168,128
# Target High Price                         706.0
# Target Low Price                          353.0
# Target Mean Price                      554.3415
# Trailing EPS                              -1.27
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 459.23
# Daylow                                  452.70
# Exchange                                   NMS
# ...
