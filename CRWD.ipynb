# %%
import my_portfolio; my_portfolio.run("CRWD")
# Out:
# No operations found for ticker 'CRWD'
# Prices: 584.36 | 613.58 | 644.26 | 676.47 | 710.30 | 745.81 | 783.10
# Buy score: -7.24%
# No operations found.
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                             731.0
# Forward EPS                             6.17094
# Gross Profit (ttm)                3,599,789,056
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,812,004,864
# Target High Price                         775.0
# Target Low Price                          368.0
# Target Mean Price                        555.92
# Trailing EPS                              -0.66
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 731.49
# Daylow                                  674.94
# Exchange                                   NMS
# ...
