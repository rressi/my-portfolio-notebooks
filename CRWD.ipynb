# %%
import my_portfolio; my_portfolio.run("CRWD")
# Out:
# No operations found for ticker 'CRWD'
# Prices: 353.57 | 371.25 | 389.81 | 408.43 | 428.85 | 450.29 | 472.81
# Buy score: 2.24%
# No operations found.
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                            394.68
# Forward EPS                             6.17242
# Gross Profit (ttm)                3,599,789,056
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,812,004,864
# Target High Price                         706.0
# Target Low Price                          368.0
# Target Mean Price                      489.8584
# Trailing EPS                              -0.63
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 427.02
# Daylow                                  390.81
# Exchange                                   NMS
# ...
