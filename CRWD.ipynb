# %%
import workflow
workflow.run("CRWD")
# Out:
# Prices: 380.21 | 399.22 | 419.18 | 440.14 | 462.15 | 485.26 | 509.52
# Buy score: -12.43%
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                            502.63
# Forward EPS                                4.27
# Gross Profit (ttm)                3,219,506,944
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,341,102,080
# Target High Price                         610.0
# Target Low Price                          330.0
# Target Mean Price                     481.53397
# Trailing EPS                               -1.2
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 504.14
# Daylow                                  462.12
# Exchange                                   NMS
# Fiftydayaverage                         443.95
# ...
