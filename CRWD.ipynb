# %%
import workflow
workflow.run("CRWD")
# Out:
# Prices: 372.42 | 391.04 | 410.60 | 431.13 | 452.68 | 475.32 | 499.08
# Buy score: -3.23%
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                             445.5
# Forward EPS                                4.27
# Gross Profit (ttm)                3,219,506,944
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,341,102,080
# Target High Price                         610.0
# Target Low Price                          330.0
# Target Mean Price                     470.51312
# Trailing EPS                               -1.2
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 454.00
# Daylow                                  434.34
# Exchange                                   NMS
# Fiftydayaverage                         445.19
# ...
