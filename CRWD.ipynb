# %%
import my_portfolio; my_portfolio.run("CRWD")
# Out:
# No operations found for ticker 'CRWD'
# Prices: 443.11 | 465.27 | 488.53 | 509.81 | 535.30 | 562.07 | 590.17
# Buy score: -1.52%
# No operations found.
#                                            CRWD
# Company Name               CrowdStrike Holdings
# Current Price                          517.6695
# Forward EPS                                4.27
# Gross Profit (ttm)                3,219,506,944
# Industry              Software - Infrastructure
# Revenue (ttm)                     4,341,102,080
# Target High Price                         706.0
# Target Low Price                          350.0
# Target Mean Price                     542.68854
# Trailing EPS                              -1.29
# Website             https://www.crowdstrike.com
#                                           CRWD
# Currency                                   USD
# Dayhigh                                 518.29
# Daylow                                  486.30
# Exchange                                   NMS
# ...
