# %%
import workflow
workflow.run(
    security = "XRP-USD",  # Crypto by Ripple
    start_date = "2025-01-01",
)
# Out:
# Prices: 2.51 | 2.64 | 2.77 | 2.9079 | 3.05 | 3.21 | 3.37
# Buy score: -6.93%
#                     XRP-USD
# Company Name        XRP USD
# Current Price          None
# Forward EPS            None
# Gross Profit (ttm)     None
# Industry               None
# Revenue (ttm)          None
# Target High Price      None
# Target Low Price       None
# Target Mean Price      None
# Trailing EPS           None
# Website                None
#                                    XRP-USD
# Currency                               USD
# Dayhigh                               3.18
# Daylow                                3.10
# Exchange                               CCC
# Fiftydayaverage                       3.01
# Lastprice                             3.12
# Lastvolume                   5,940,183,552
# Marketcap                             None
# Open                                  3.11
# Previousclose                         3.11
# Quotetype                   CRYPTOCURRENCY
# ...
