# %%
import my_portfolio; my_portfolio.run("XRP-USD")
# Out:
# Prices: 2.44 | 2.56 | 2.69 | 2.36 | 2.47 | 2.60 | 2.73
# Buy score: -3.31%
# Sell score: 3.96%
# Current return: 46.13 USD
# Breakeven price: 2.40 USD
# <style type="text/css">
# #T_c021b_row16_col0, #T_c021b_row16_col1, #T_c021b_row16_col2, #T_c021b_row16_col3, #T_c021b_row16_col4, #T_c021b_row16_col5, #T_c021b_row16_col6, #T_c021b_row16_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_c021b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c021b_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c021b_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c021b_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c021b_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c021b_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
