# %%
import workflow
workflow.run(
    security = "XRP-USD",  # Crypto by Ripple
    start_date = "2025-01-01",
)
# Out:
# Prices: 2.51 | 2.63 | 2.76 | 2.9005 | 3.05 | 3.20 | 3.36
# Buy score: -4.97%
#                     XRP-USD
# Company Name        XRP USD
# Industry               None
# Revenue (ttm)          None
# Gross Profit (ttm)     None
# Current Price          None
# Target Mean Price      None
# Target High Price      None
# Target Low Price       None
# Trailing EPS           None
# Forward EPS            None
# Website                None
#                                    XRP-USD
# Currency                               USD
# Dayhigh                               3.07
# Daylow                                3.04
# Exchange                               CCC
# Fiftydayaverage                       3.01
# Lastprice                             3.05
# Lastvolume                   5,672,248,832
# Marketcap                             None
# Open                                  3.04
# Previousclose                         3.04
# Quotetype                   CRYPTOCURRENCY
# ...
