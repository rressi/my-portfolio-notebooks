# %%
import workflow
workflow.run(
    security = "XRP-USD",  # Crypto by Ripple
    start_date = "2025-01-01",
)
# Out:
# Prices: 2.48 | 2.61 | 2.74 | 2.8724 | 3.02 | 3.17 | 3.33
# Buy score: -5.56%
#                     XRP-USD
# Company Name        XRP USD
# Industry               None
# Revenue (ttm)          None
# Gross Profit (ttm)     None
# Current Price          None
# Target Mean Price      None
# Target High Price      None
# Target Low Price       None
# Trailing EPS           None
# Forward EPS            None
# Website                None
#                                    XRP-USD
# Currency                               USD
# Dayhigh                               3.04
# Daylow                                2.98
# Exchange                               CCC
# Fiftydayaverage                       3.02
# Lastprice                             3.04
# Lastvolume                   5,226,509,824
# Marketcap                             None
# Open                                  2.98
# Previousclose                         2.98
# Quotetype                   CRYPTOCURRENCY
# ...
