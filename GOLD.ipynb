# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,880.89 | 4,074.94 | 4,278.69 | 4,492.62 | 4,717.25 | 4,953.11 | 5,200.77
# Buy score: -2.16%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,616.90
# Daylow                              4,586.40
# Exchange                                 CMX
# Fiftydayaverage                     4,219.87
# Lastprice                           4,591.60
# Lastvolume                             2,214
# Marketcap                               None
# ...
