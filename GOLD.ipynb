# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,994.93 | 4,194.67 | 4,404.41 | 4,448.42 | 4,670.84 | 4,904.38 | 5,149.60
# Buy score: 1.90%
# No operations found.
#                            GC=F
# Company Name        Gold Aug 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,508.70
# Daylow                              4,336.60
# Exchange                                 CMX
# Fiftydayaverage                     4,624.63
# Lastprice                           4,365.30
# Lastvolume                           173,440
# Marketcap                               None
# ...
