# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,327.50 | 4,543.87 | 4,771.07 | 5,009.62 | 5,260.10 | 5,523.11 | 5,799.26
# Buy score: 0.79%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,122.80
# Daylow                              4,900.00
# Exchange                                 CMX
# Fiftydayaverage                     4,576.92
# Lastprice                           4,970.60
# Lastvolume                           130,167
# Marketcap                               None
# ...
