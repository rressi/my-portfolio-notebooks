# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,305.78 | 4,521.07 | 4,747.12 | 4,984.48 | 5,233.70 | 5,495.39 | 5,770.16
# Buy score: 1.70%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,074.40
# Daylow                              4,854.20
# Exchange                                 CMX
# Fiftydayaverage                     4,607.32
# Lastprice                           4,901.30
# Lastvolume                           160,814
# Marketcap                               None
# ...
