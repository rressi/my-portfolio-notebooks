# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,388.99 | 4,608.44 | 4,838.86 | 5,080.80 | 5,334.84 | 5,601.58 | 5,881.66
# Buy score: -1.87%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,269.40
# Daylow                              5,162.20
# Exchange                                 CMX
# Fiftydayaverage                     4,689.14
# Lastprice                           5,177.60
# Lastvolume                            65,283
# Marketcap                               None
# ...
