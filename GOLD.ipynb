# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,998.63 | 4,198.56 | 4,408.49 | 4,508.14 | 4,733.55 | 4,970.22 | 5,218.74
# Buy score: -0.55%
# No operations found.
#                            GC=F
# Company Name        Gold Aug 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,577.30
# Daylow                              4,529.10
# Exchange                                 CMX
# Fiftydayaverage                     4,630.27
# Lastprice                           4,533.00
# Lastvolume                            25,742
# Marketcap                               None
# ...
