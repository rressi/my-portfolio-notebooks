# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,271.38 | 4,484.95 | 4,709.20 | 4,944.66 | 5,191.89 | 5,451.49 | 5,724.06
# Buy score: -2.80%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,094.70
# Daylow                              4,988.60
# Exchange                                 CMX
# Fiftydayaverage                     4,524.85
# Lastprice                           5,086.60
# Lastvolume                            87,387
# Marketcap                               None
# ...
