# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,486.66 | 3,660.99 | 3,844.04 | 4,036.24 | 4,238.05 | 4,449.95 | 4,672.45
# Buy score: -1.79%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,155.00
# Daylow                              4,102.80
# Exchange                                 CMX
# Fiftydayaverage                     3,887.37
# Lastprice                           4,109.80
# Lastvolume                           172,733
# Marketcap                               None
# ...
