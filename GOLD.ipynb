# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,498.49 | 3,673.41 | 3,857.09 | 4,049.94 | 4,252.44 | 4,465.06 | 4,688.31
# Buy score: 2.28%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,034.20
# Daylow                              3,901.30
# Exchange                                 CMX
# Fiftydayaverage                     3,763.76
# Lastprice                           3,959.50
# Lastvolume                           237,896
# Marketcap                               None
# ...
