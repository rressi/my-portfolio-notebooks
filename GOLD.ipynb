# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,997.54 | 4,197.42 | 4,407.29 | 4,500.86 | 4,725.90 | 4,962.20 | 5,210.31
# Buy score: 0.46%
# No operations found.
#                            GC=F
# Company Name        Gold Aug 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,525.10
# Daylow                              4,479.30
# Exchange                                 CMX
# Fiftydayaverage                     4,626.13
# Lastprice                           4,480.20
# Lastvolume                            37,296
# Marketcap                               None
# ...
