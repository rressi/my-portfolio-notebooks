# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,334.81 | 4,551.55 | 4,779.12 | 5,018.08 | 5,268.98 | 5,532.43 | 5,809.05
# Buy score: -0.44%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,056.80
# Daylow                              4,907.10
# Exchange                                 CMX
# Fiftydayaverage                     4,590.61
# Lastprice                           5,040.40
# Lastvolume                           101,989
# Marketcap                               None
# ...
