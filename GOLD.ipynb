# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,963.38 | 4,161.55 | 4,369.62 | 4,205.40 | 4,415.67 | 4,636.45 | 4,868.28
# Buy score: -0.63%
# No operations found.
#                            GC=F
# Company Name        Gold Aug 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,267.80
# Daylow                              4,191.10
# Exchange                                 CMX
# Fiftydayaverage                     4,599.13
# Lastprice                           4,232.60
# Lastvolume                            63,260
# Marketcap                               None
# ...
