# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,806.15 | 3,996.46 | 4,196.29 | 4,406.10 | 4,626.41 | 4,857.73 | 5,100.61
# Buy score: 1.71%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,363.80
# Daylow                              4,285.00
# Exchange                                 CMX
# Fiftydayaverage                     4,174.30
# Lastprice                           4,325.60
# Lastvolume                             1,837
# Marketcap                               None
# ...
