# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,205.35 | 4,415.62 | 4,636.40 | 4,736.70 | 4,973.53 | 5,222.21 | 5,483.32
# Buy score: -0.09%
# No operations found.
#                            GC=F
# Company Name        Gold Jun 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,757.10
# Daylow                              4,672.20
# Exchange                                 CMX
# Fiftydayaverage                     4,868.22
# Lastprice                           4,740.90
# Lastvolume                           100,809
# Marketcap                               None
# ...
