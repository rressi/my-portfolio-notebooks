# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,261.86 | 4,474.96 | 4,698.70 | 4,933.64 | 5,180.32 | 5,439.34 | 5,711.31
# Buy score: -1.94%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,069.00
# Daylow                              4,988.60
# Exchange                                 CMX
# Fiftydayaverage                     4,524.85
# Lastprice                           5,031.50
# Lastvolume                            46,560
# Marketcap                               None
# ...
