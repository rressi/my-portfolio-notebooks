# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,556.85 | 3,734.69 | 3,921.43 | 4,117.50 | 4,323.37 | 4,539.54 | 4,766.52
# Buy score: -1.14%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,250.00
# Daylow                              4,148.50
# Exchange                                 CMX
# Fiftydayaverage                     3,910.74
# Lastprice                           4,165.10
# Lastvolume                           293,013
# Marketcap                               None
# ...
