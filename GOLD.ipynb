# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,962.04 | 4,160.15 | 4,368.15 | 4,586.56 | 4,815.89 | 5,056.68 | 5,309.52
# Buy score: -0.78%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,637.20
# Daylow                              4,584.00
# Exchange                                 CMX
# Fiftydayaverage                     4,256.92
# Lastprice                           4,622.70
# Lastvolume                           203,927
# Marketcap                               None
# ...
