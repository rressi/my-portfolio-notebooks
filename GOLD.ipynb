# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,300.24 | 4,515.25 | 4,741.01 | 4,978.06 | 5,226.96 | 5,488.31 | 5,762.73
# Buy score: 2.24%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,074.40
# Daylow                              4,854.20
# Exchange                                 CMX
# Fiftydayaverage                     4,607.32
# Lastprice                           4,869.20
# Lastvolume                           141,700
# Marketcap                               None
# ...
