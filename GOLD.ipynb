# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,378.79 | 4,597.73 | 4,827.62 | 5,069.00 | 5,322.45 | 5,588.57 | 5,868.00
# Buy score: -4.37%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,345.00
# Daylow                              5,193.60
# Exchange                                 CMX
# Fiftydayaverage                     4,387.12
# Lastprice                           5,300.40
# Lastvolume                           158,347
# Marketcap                               None
# ...
