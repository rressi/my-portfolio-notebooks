# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,743.89 | 3,931.08 | 4,127.64 | 4,334.02 | 4,550.72 | 4,778.26 | 5,017.17
# Buy score: -0.87%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,379.50
# Daylow                              4,336.30
# Exchange                                 CMX
# Fiftydayaverage                     4,130.97
# Lastprice                           4,371.90
# Lastvolume                           100,331
# Marketcap                               None
# ...
