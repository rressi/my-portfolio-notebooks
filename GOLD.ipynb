# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,162.42 | 4,370.54 | 4,589.07 | 4,818.52 | 5,059.45 | 5,312.42 | 5,578.04
# Buy score: -2.28%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,045.00
# Daylow                              4,805.00
# Exchange                                 CMX
# Fiftydayaverage                     4,491.97
# Lastprice                           4,932.10
# Lastvolume                            79,831
# Marketcap                               None
# ...
