# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,658.96 | 3,841.90 | 4,034.00 | 4,235.70 | 4,447.49 | 4,669.86 | 4,903.35
# Buy score: -1.56%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,387.80
# Daylow                              4,286.00
# Exchange                                 CMX
# Fiftydayaverage                     4,092.78
# Lastprice                           4,302.70
# Lastvolume                           283,739
# Marketcap                               None
# ...
