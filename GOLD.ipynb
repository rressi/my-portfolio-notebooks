# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,763.88 | 3,952.07 | 4,149.68 | 4,357.16 | 4,575.02 | 4,803.77 | 5,043.96
# Buy score: -2.10%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,471.60
# Daylow                              4,437.90
# Exchange                                 CMX
# Fiftydayaverage                     4,178.83
# Lastprice                           4,450.60
# Lastvolume                            12,354
# Marketcap                               None
# ...
