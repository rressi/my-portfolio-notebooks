# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,164.68 | 4,372.92 | 4,591.56 | 4,821.14 | 5,062.20 | 5,315.31 | 5,581.07
# Buy score: -2.53%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,045.00
# Daylow                              4,805.00
# Exchange                                 CMX
# Fiftydayaverage                     4,491.97
# Lastprice                           4,945.20
# Lastvolume                            83,034
# Marketcap                               None
# ...
