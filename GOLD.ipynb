# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,046.77 | 4,249.11 | 4,461.56 | 4,684.64 | 4,918.87 | 5,164.82 | 5,423.06
# Buy score: -3.06%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,891.10
# Daylow                              4,761.50
# Exchange                                 CMX
# Fiftydayaverage                     4,297.64
# Lastprice                           4,832.60
# Lastvolume                           255,352
# Marketcap                               None
# ...
