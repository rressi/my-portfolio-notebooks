# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,994.73 | 4,194.47 | 4,404.19 | 4,446.14 | 4,668.45 | 4,901.87 | 5,146.96
# Buy score: 2.12%
# No operations found.
#                            GC=F
# Company Name        Gold Aug 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,508.70
# Daylow                              4,336.60
# Exchange                                 CMX
# Fiftydayaverage                     4,628.32
# Lastprice                           4,353.90
# Lastvolume                           173,440
# Marketcap                               None
# ...
