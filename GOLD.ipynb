# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,001.80 | 4,201.89 | 4,411.98 | 4,632.58 | 4,864.21 | 5,107.42 | 5,362.79
# Buy score: -2.32%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,756.60
# Daylow                              4,622.20
# Exchange                                 CMX
# Fiftydayaverage                     4,282.06
# Lastprice                           4,742.60
# Lastvolume                           304,468
# Marketcap                               None
# ...
