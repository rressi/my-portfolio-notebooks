# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,243.71 | 4,455.89 | 4,678.69 | 4,912.62 | 5,158.25 | 5,416.16 | 5,686.97
# Buy score: -3.42%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,107.90
# Daylow                              5,002.00
# Exchange                                 CMX
# Fiftydayaverage                     4,350.16
# Lastprice                           5,086.70
# Lastvolume                           131,182
# Marketcap                               None
# ...
