# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,735.34 | 3,922.10 | 4,118.21 | 4,324.12 | 4,540.33 | 4,767.34 | 5,005.71
# Buy score: -0.86%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,368.40
# Daylow                              4,359.30
# Exchange                                 CMX
# Fiftydayaverage                     4,125.04
# Lastprice                           4,361.80
# Lastvolume                             2,741
# Marketcap                               None
# ...
