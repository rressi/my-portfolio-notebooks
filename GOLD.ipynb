# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,289.92 | 4,504.42 | 4,729.64 | 4,966.12 | 5,214.43 | 5,475.15 | 5,748.90
# Buy score: -0.97%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,040.90
# Daylow                              4,971.50
# Exchange                                 CMX
# Fiftydayaverage                     4,636.48
# Lastprice                           5,015.50
# Lastvolume                            46,710
# Marketcap                               None
# ...
