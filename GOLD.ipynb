# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,302.34 | 4,517.46 | 4,743.33 | 4,980.50 | 5,229.53 | 5,491.00 | 5,765.55
# Buy score: -0.44%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,031.90
# Daylow                              4,868.50
# Exchange                                 CMX
# Fiftydayaverage                     4,620.99
# Lastprice                           5,002.30
# Lastvolume                            91,095
# Marketcap                               None
# ...
