# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,927.72 | 4,124.10 | 4,330.31 | 4,292.02 | 4,506.62 | 4,731.95 | 4,968.55
# Buy score: 1.75%
# No operations found.
#                            GC=F
# Company Name        Gold Aug 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,238.10
# Daylow                              4,138.70
# Exchange                                 CMX
# Fiftydayaverage                     4,558.30
# Lastprice                           4,218.20
# Lastvolume                           126,696
# Marketcap                               None
# ...
