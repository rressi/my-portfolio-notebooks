# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,474.10 | 3,647.80 | 3,830.19 | 4,021.70 | 4,222.78 | 4,433.92 | 4,655.62
# Buy score: -0.41%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,041.50
# Daylow                              3,925.10
# Exchange                                 CMX
# Fiftydayaverage                     3,789.85
# Lastprice                           4,038.30
# Lastvolume                           242,543
# Marketcap                               None
# ...
