# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,294.52 | 4,509.24 | 4,734.70 | 4,971.44 | 5,220.01 | 5,481.01 | 5,755.06
# Buy score: 1.44%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,916.00
# Daylow                              4,690.20
# Exchange                                 CMX
# Fiftydayaverage                     4,458.17
# Lastprice                           4,900.80
# Lastvolume                            56,001
# Marketcap                               None
# ...
