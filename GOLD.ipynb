# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,456.59 | 3,629.42 | 3,810.90 | 4,001.44 | 4,201.51 | 4,411.59 | 4,632.17
# Buy score: -2.40%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,115.00
# Daylow                              4,004.20
# Exchange                                 CMX
# Fiftydayaverage                     3,874.60
# Lastprice                           4,099.90
# Lastvolume                           183,726
# Marketcap                               None
# ...
