# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,803.08 | 3,993.23 | 4,192.90 | 4,402.54 | 4,622.67 | 4,853.80 | 5,096.49
# Buy score: -1.15%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,512.40
# Daylow                              4,432.90
# Exchange                                 CMX
# Fiftydayaverage                     4,193.81
# Lastprice                           4,453.60
# Lastvolume                           145,364
# Marketcap                               None
# ...
