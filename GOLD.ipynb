# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,333.01 | 4,549.66 | 4,777.14 | 5,016.00 | 5,266.80 | 5,530.14 | 5,806.65
# Buy score: -0.28%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,043.30
# Daylow                              4,907.10
# Exchange                                 CMX
# Fiftydayaverage                     4,590.61
# Lastprice                           5,030.00
# Lastvolume                            88,983
# Marketcap                               None
# ...
