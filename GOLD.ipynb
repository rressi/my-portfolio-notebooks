# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,650.09 | 3,832.60 | 4,024.23 | 4,225.44 | 4,436.71 | 4,658.55 | 4,891.47
# Buy score: 1.97%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,157.90
# Daylow                              4,021.20
# Exchange                                 CMX
# Fiftydayaverage                     3,697.73
# Lastprice                           4,143.80
# Lastvolume                           107,270
# Marketcap                               None
# ...
