# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,086.58 | 4,290.91 | 4,505.45 | 4,664.30 | 4,897.52 | 5,142.39 | 5,399.51
# Buy score: 2.53%
# No operations found.
#                            GC=F
# Company Name        Gold Jun 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,670.10
# Daylow                              4,535.40
# Exchange                                 CMX
# Fiftydayaverage                     4,741.05
# Lastprice                           4,549.40
# Lastvolume                           105,716
# Marketcap                               None
# ...
