# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,440.92 | 3,612.97 | 3,793.62 | 3,983.30 | 4,182.47 | 4,391.59 | 4,611.17
# Buy score: 0.87%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,951.50
# Daylow                              3,935.70
# Exchange                                 CMX
# Fiftydayaverage                     3,828.43
# Lastprice                           3,949.00
# Lastvolume                            11,338
# Marketcap                               None
# ...
