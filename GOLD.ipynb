# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,152.23 | 4,359.84 | 4,577.83 | 4,806.72 | 5,047.06 | 5,299.41 | 5,564.38
# Buy score: -1.36%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,045.00
# Daylow                              4,805.00
# Exchange                                 CMX
# Fiftydayaverage                     4,491.97
# Lastprice                           4,873.10
# Lastvolume                           181,410
# Marketcap                               None
# ...
