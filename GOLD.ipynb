# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,636.26 | 3,818.07 | 4,008.97 | 4,209.42 | 4,419.89 | 4,640.89 | 4,872.93
# Buy score: -1.22%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,289.90
# Daylow                              4,229.70
# Exchange                                 CMX
# Fiftydayaverage                     3,672.89
# Lastprice                           4,261.40
# Lastvolume                            65,271
# Marketcap                               None
# ...
