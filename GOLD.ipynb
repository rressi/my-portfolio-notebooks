# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,153.14 | 4,360.80 | 4,578.84 | 4,807.78 | 5,048.17 | 5,300.58 | 5,565.61
# Buy score: -2.88%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,970.00
# Daylow                              4,901.20
# Exchange                                 CMX
# Fiftydayaverage                     4,332.87
# Lastprice                           4,950.30
# Lastvolume                           167,999
# Marketcap                               None
# ...
