# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,656.14 | 3,838.95 | 4,030.90 | 4,232.44 | 4,444.06 | 4,666.27 | 4,899.58
# Buy score: -3.29%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,382.30
# Daylow                              4,229.70
# Exchange                                 CMX
# Fiftydayaverage                     3,672.89
# Lastprice                           4,376.50
# Lastvolume                           298,602
# Marketcap                               None
# ...
