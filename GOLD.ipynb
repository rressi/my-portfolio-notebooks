# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,447.51 | 3,619.88 | 3,800.88 | 3,990.92 | 4,190.47 | 4,399.99 | 4,619.99
# Buy score: -0.75%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,043.10
# Daylow                              3,971.30
# Exchange                                 CMX
# Fiftydayaverage                     3,815.92
# Lastprice                           4,021.20
# Lastvolume                           220,476
# Marketcap                               None
# ...
