# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,593.96 | 3,773.66 | 3,962.34 | 4,160.46 | 4,368.48 | 4,586.91 | 4,816.25
# Buy score: 0.40%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,171.50
# Daylow                              4,079.60
# Exchange                                 CMX
# Fiftydayaverage                     3,719.44
# Lastprice                           4,143.90
# Lastvolume                           230,682
# Marketcap                               None
# ...
