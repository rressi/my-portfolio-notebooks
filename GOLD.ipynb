# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,977.89 | 4,176.78 | 4,385.62 | 4,604.90 | 4,835.14 | 5,076.90 | 5,330.75
# Buy score: -1.42%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,698.00
# Daylow                              4,622.20
# Exchange                                 CMX
# Fiftydayaverage                     4,282.06
# Lastprice                           4,677.60
# Lastvolume                           154,274
# Marketcap                               None
# ...
