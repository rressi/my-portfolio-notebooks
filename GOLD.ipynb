# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,637.74 | 3,819.63 | 4,010.61 | 4,211.14 | 4,421.70 | 4,642.78 | 4,874.92
# Buy score: -1.38%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,289.90
# Daylow                              4,229.70
# Exchange                                 CMX
# Fiftydayaverage                     3,672.89
# Lastprice                           4,270.00
# Lastvolume                            93,205
# Marketcap                               None
# ...
