# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,981.00 | 4,180.05 | 4,389.05 | 4,608.50 | 4,838.92 | 5,080.87 | 5,334.91
# Buy score: 0.05%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,625.50
# Daylow                              4,594.60
# Exchange                                 CMX
# Fiftydayaverage                     4,269.24
# Lastprice                           4,606.60
# Lastvolume                            58,294
# Marketcap                               None
# ...
