# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,399.46 | 4,619.43 | 4,850.40 | 5,092.92 | 5,347.57 | 5,614.94 | 5,895.69
# Buy score: -6.03%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,429.70
# Daylow                              5,193.60
# Exchange                                 CMX
# Fiftydayaverage                     4,387.12
# Lastprice                           5,420.00
# Lastvolume                           399,301
# Marketcap                               None
# ...
