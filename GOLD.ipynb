# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,166.40 | 4,374.72 | 4,593.46 | 4,587.86 | 4,817.25 | 5,058.12 | 5,311.02
# Buy score: 0.66%
# No operations found.
#                            GC=F
# Company Name        Gold Jun 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,650.60
# Daylow                              4,552.60
# Exchange                                 CMX
# Fiftydayaverage                     4,833.16
# Lastprice                           4,558.00
# Lastvolume                            32,440
# Marketcap                               None
# ...
