# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,518.24 | 3,694.15 | 3,878.86 | 4,072.80 | 4,276.44 | 4,490.26 | 4,714.78
# Buy score: 0.09%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,109.60
# Daylow                              4,034.00
# Exchange                                 CMX
# Fiftydayaverage                     3,958.29
# Lastprice                           4,069.10
# Lastvolume                            49,707
# Marketcap                               None
# ...
