# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,536.97 | 3,713.81 | 3,899.50 | 4,094.48 | 4,299.20 | 4,514.16 | 4,739.87
# Buy score: -0.05%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,123.80
# Daylow                              4,065.80
# Exchange                                 CMX
# Fiftydayaverage                     3,750.44
# Lastprice                           4,096.40
# Lastvolume                            71,882
# Marketcap                               None
# ...
