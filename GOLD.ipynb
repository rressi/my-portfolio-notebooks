# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,514.18 | 3,689.89 | 3,874.38 | 4,068.10 | 4,271.51 | 4,485.08 | 4,709.33
# Buy score: 0.13%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,085.20
# Daylow                              4,031.80
# Exchange                                 CMX
# Fiftydayaverage                     3,975.23
# Lastprice                           4,076.70
# Lastvolume                               202
# Marketcap                               None
# ...
