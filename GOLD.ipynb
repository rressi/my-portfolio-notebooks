# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,520.73 | 3,696.76 | 3,881.60 | 4,075.68 | 4,279.46 | 4,493.44 | 4,718.11
# Buy score: -0.18%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,109.60
# Daylow                              4,034.00
# Exchange                                 CMX
# Fiftydayaverage                     3,958.29
# Lastprice                           4,083.50
# Lastvolume                           150,840
# Marketcap                               None
# ...
