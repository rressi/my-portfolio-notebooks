# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,443.34 | 4,665.51 | 4,898.78 | 5,143.72 | 5,400.91 | 5,670.95 | 5,954.50
# Buy score: -2.60%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,626.80
# Daylow                              5,126.00
# Exchange                                 CMX
# Fiftydayaverage                     4,409.42
# Lastprice                           5,281.20
# Lastvolume                           439,181
# Marketcap                               None
# ...
