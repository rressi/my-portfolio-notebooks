# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,554.38 | 3,732.10 | 3,918.70 | 4,114.64 | 4,320.37 | 4,536.39 | 4,763.21
# Buy score: -3.65%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,299.60
# Daylow                              4,241.10
# Exchange                                 CMX
# Fiftydayaverage                     4,003.34
# Lastprice                           4,270.40
# Lastvolume                           186,720
# Marketcap                               None
# ...
