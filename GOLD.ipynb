# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,823.54 | 4,014.71 | 4,215.45 | 4,426.22 | 4,647.53 | 4,879.91 | 5,123.90
# Buy score: -1.70%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,555.10
# Daylow                              4,474.30
# Exchange                                 CMX
# Fiftydayaverage                     4,156.13
# Lastprice                           4,502.80
# Lastvolume                           149,923
# Marketcap                               None
# ...
