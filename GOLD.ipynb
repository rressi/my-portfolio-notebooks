# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,385.55 | 4,604.83 | 4,835.07 | 5,076.82 | 5,330.66 | 5,597.19 | 5,877.05
# Buy score: -1.57%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,269.40
# Daylow                              5,109.50
# Exchange                                 CMX
# Fiftydayaverage                     4,689.14
# Lastprice                           5,157.70
# Lastvolume                           114,623
# Marketcap                               None
# ...
