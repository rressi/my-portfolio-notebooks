# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,235.27 | 4,447.03 | 4,669.38 | 4,725.04 | 4,961.29 | 5,209.36 | 5,469.82
# Buy score: -0.93%
# No operations found.
#                            GC=F
# Company Name        Gold Jun 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,810.00
# Daylow                              4,760.40
# Exchange                                 CMX
# Fiftydayaverage                     4,913.49
# Lastprice                           4,769.60
# Lastvolume                            36,792
# Marketcap                               None
# ...
