# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,447.32 | 3,619.68 | 3,800.67 | 3,990.70 | 4,190.23 | 4,399.75 | 4,619.73
# Buy score: 0.12%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,997.00
# Daylow                              3,935.70
# Exchange                                 CMX
# Fiftydayaverage                     3,837.71
# Lastprice                           3,986.00
# Lastvolume                           118,312
# Marketcap                               None
# ...
