# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,780.93 | 3,969.98 | 4,168.48 | 4,376.90 | 4,595.75 | 4,825.53 | 5,066.81
# Buy score: 0.98%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,414.80
# Daylow                              4,325.30
# Exchange                                 CMX
# Fiftydayaverage                     4,174.30
# Lastprice                           4,334.60
# Lastvolume                           116,822
# Marketcap                               None
# ...
