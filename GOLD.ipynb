# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,632.83 | 3,814.48 | 4,005.20 | 4,205.46 | 4,415.73 | 4,636.52 | 4,868.35
# Buy score: -0.27%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,247.90
# Daylow                              4,204.00
# Exchange                                 CMX
# Fiftydayaverage                     4,061.35
# Lastprice                           4,216.70
# Lastvolume                           127,375
# Marketcap                               None
# ...
