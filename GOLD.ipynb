# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,627.43 | 3,808.80 | 3,999.24 | 4,199.20 | 4,409.16 | 4,629.62 | 4,861.10
# Buy score: 2.37%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,175.00
# Daylow                              4,021.20
# Exchange                                 CMX
# Fiftydayaverage                     3,705.53
# Lastprice                           4,105.00
# Lastvolume                           179,109
# Marketcap                               None
# ...
