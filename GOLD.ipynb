# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,309.77 | 4,525.26 | 4,751.52 | 4,989.10 | 5,238.56 | 5,500.48 | 5,775.51
# Buy score: -1.75%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,094.30
# Daylow                              4,999.30
# Exchange                                 CMX
# Fiftydayaverage                     4,651.74
# Lastprice                           5,078.20
# Lastvolume                            99,281
# Marketcap                               None
# ...
