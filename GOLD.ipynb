# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,549.23 | 3,726.69 | 3,913.03 | 4,108.68 | 4,314.11 | 4,529.82 | 4,756.31
# Buy score: -3.11%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,251.10
# Daylow                              4,203.30
# Exchange                                 CMX
# Fiftydayaverage                     4,021.91
# Lastprice                           4,240.50
# Lastvolume                           144,083
# Marketcap                               None
# ...
