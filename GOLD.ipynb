# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,791.66 | 3,981.24 | 4,180.30 | 4,389.32 | 4,608.79 | 4,839.23 | 5,081.19
# Buy score: -2.45%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,501.80
# Daylow                              4,437.90
# Exchange                                 CMX
# Fiftydayaverage                     4,186.68
# Lastprice                           4,499.60
# Lastvolume                           135,402
# Marketcap                               None
# ...
