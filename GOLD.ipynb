# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,824.64 | 4,015.87 | 4,216.67 | 4,427.50 | 4,648.88 | 4,881.32 | 5,125.38
# Buy score: -0.61%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,475.80
# Daylow                              4,415.00
# Exchange                                 CMX
# Fiftydayaverage                     4,200.43
# Lastprice                           4,454.70
# Lastvolume                           172,703
# Marketcap                               None
# ...
