# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,546.02 | 3,723.32 | 3,909.49 | 4,104.96 | 4,310.21 | 4,525.72 | 4,752.00
# Buy score: 0.06%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,215.10
# Daylow                              4,032.60
# Exchange                                 CMX
# Fiftydayaverage                     3,917.78
# Lastprice                           4,102.40
# Lastvolume                           292,858
# Marketcap                               None
# ...
