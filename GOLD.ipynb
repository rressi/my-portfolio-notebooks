# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,902.42 | 4,097.54 | 4,302.42 | 4,517.54 | 4,743.42 | 4,980.59 | 5,229.62
# Buy score: -1.67%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,644.00
# Daylow                              4,576.70
# Exchange                                 CMX
# Fiftydayaverage                     4,232.28
# Lastprice                           4,594.10
# Lastvolume                           246,031
# Marketcap                               None
# ...
