# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,066.20 | 4,269.51 | 4,482.98 | 4,596.58 | 4,826.41 | 5,067.73 | 5,321.12
# Buy score: 2.17%
# No operations found.
#                            GC=F
# Company Name        Gold Jun 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,593.20
# Daylow                              4,467.10
# Exchange                                 CMX
# Fiftydayaverage                     4,718.98
# Lastprice                           4,498.80
# Lastvolume                           112,125
# Marketcap                               None
# ...
