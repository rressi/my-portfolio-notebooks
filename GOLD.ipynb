# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,451.86 | 3,624.45 | 3,805.68 | 3,995.96 | 4,195.76 | 4,405.55 | 4,625.82
# Buy score: -0.76%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,059.90
# Daylow                              4,001.90
# Exchange                                 CMX
# Fiftydayaverage                     3,803.01
# Lastprice                           4,026.70
# Lastvolume                           142,022
# Marketcap                               None
# ...
