# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,490.96 | 3,665.51 | 3,848.78 | 4,041.22 | 4,243.28 | 4,455.45 | 4,678.22
# Buy score: 1.18%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,046.20
# Daylow                              3,930.00
# Exchange                                 CMX
# Fiftydayaverage                     3,776.45
# Lastprice                           3,994.10
# Lastvolume                           226,905
# Marketcap                               None
# ...
