# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,790.74 | 3,980.28 | 4,179.30 | 4,388.26 | 4,607.67 | 4,838.06 | 5,079.96
# Buy score: -2.36%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,503.70
# Daylow                              4,437.90
# Exchange                                 CMX
# Fiftydayaverage                     4,186.68
# Lastprice                           4,494.30
# Lastvolume                           156,740
# Marketcap                               None
# ...
