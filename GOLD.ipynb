# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,781.98 | 3,971.08 | 4,169.64 | 4,378.12 | 4,597.03 | 4,826.88 | 5,068.22
# Buy score: 0.86%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,414.80
# Daylow                              4,319.70
# Exchange                                 CMX
# Fiftydayaverage                     4,174.30
# Lastprice                           4,340.70
# Lastvolume                           148,407
# Marketcap                               None
# ...
