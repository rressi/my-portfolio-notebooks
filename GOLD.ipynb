# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,800.68 | 3,990.71 | 4,190.25 | 4,399.76 | 4,619.75 | 4,850.74 | 5,093.27
# Buy score: -0.90%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,512.40
# Daylow                              4,436.60
# Exchange                                 CMX
# Fiftydayaverage                     4,193.81
# Lastprice                           4,439.70
# Lastvolume                            86,720
# Marketcap                               None
# ...
