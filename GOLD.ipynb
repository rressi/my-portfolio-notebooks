# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,439.39 | 3,611.36 | 3,791.92 | 3,981.52 | 4,180.60 | 4,389.63 | 4,609.11
# Buy score: -0.71%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,999.40
# Daylow                              3,980.80
# Exchange                                 CMX
# Fiftydayaverage                     3,874.60
# Lastprice                           3,999.40
# Lastvolume                               650
# Marketcap                               None
# ...
