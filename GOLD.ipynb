# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,162.94 | 4,371.08 | 4,589.64 | 4,819.12 | 5,060.08 | 5,313.08 | 5,578.73
# Buy score: -2.35%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,045.00
# Daylow                              4,805.00
# Exchange                                 CMX
# Fiftydayaverage                     4,491.97
# Lastprice                           4,934.30
# Lastvolume                            70,535
# Marketcap                               None
# ...
