# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,500.03 | 3,675.03 | 3,858.78 | 4,051.72 | 4,254.31 | 4,467.02 | 4,690.37
# Buy score: 2.10%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,034.20
# Daylow                              3,901.30
# Exchange                                 CMX
# Fiftydayaverage                     3,763.76
# Lastprice                           3,968.40
# Lastvolume                           329,282
# Marketcap                               None
# ...
