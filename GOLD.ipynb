# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,639.18 | 3,821.13 | 4,012.19 | 4,212.80 | 4,423.44 | 4,644.61 | 4,876.84
# Buy score: -0.77%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,248.30
# Daylow                              4,215.30
# Exchange                                 CMX
# Fiftydayaverage                     4,077.31
# Lastprice                           4,245.40
# Lastvolume                           126,162
# Marketcap                               None
# ...
