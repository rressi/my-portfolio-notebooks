# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,448.11 | 3,620.52 | 3,801.54 | 3,991.62 | 4,191.20 | 4,400.76 | 4,620.80
# Buy score: 0.03%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,000.70
# Daylow                              3,935.70
# Exchange                                 CMX
# Fiftydayaverage                     3,837.71
# Lastprice                           3,990.60
# Lastvolume                           159,194
# Marketcap                               None
# ...
