# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,315.54 | 4,531.32 | 4,757.89 | 4,995.78 | 5,245.57 | 5,507.85 | 5,783.24
# Buy score: -2.27%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,144.50
# Daylow                              5,036.30
# Exchange                                 CMX
# Fiftydayaverage                     4,559.85
# Lastprice                           5,111.60
# Lastvolume                           118,439
# Marketcap                               None
# ...
