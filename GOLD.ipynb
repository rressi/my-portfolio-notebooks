# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,087.68 | 4,292.06 | 4,506.67 | 4,732.00 | 4,968.60 | 5,217.03 | 5,477.88
# Buy score: -2.71%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,867.80
# Daylow                              4,772.70
# Exchange                                 CMX
# Fiftydayaverage                     4,314.68
# Lastprice                           4,864.50
# Lastvolume                           158,805
# Marketcap                               None
# ...
