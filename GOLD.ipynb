# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,540.77 | 3,717.81 | 3,903.70 | 4,098.88 | 4,303.82 | 4,519.02 | 4,744.97
# Buy score: 0.21%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,100.00
# Daylow                              4,056.10
# Exchange                                 CMX
# Fiftydayaverage                     3,949.61
# Lastprice                           4,090.30
# Lastvolume                            56,355
# Marketcap                               None
# ...
