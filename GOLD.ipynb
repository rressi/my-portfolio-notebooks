# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,298.97 | 4,513.92 | 4,739.62 | 4,976.60 | 5,225.43 | 5,486.70 | 5,761.04
# Buy score: -2.16%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,097.30
# Daylow                              5,004.50
# Exchange                                 CMX
# Fiftydayaverage                     4,369.61
# Lastprice                           5,086.50
# Lastvolume                            67,169
# Marketcap                               None
# ...
