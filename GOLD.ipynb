# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,459.99 | 4,682.99 | 4,917.14 | 5,163.00 | 5,421.15 | 5,692.21 | 5,976.82
# Buy score: -0.50%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,221.90
# Daylow                              5,170.10
# Exchange                                 CMX
# Fiftydayaverage                     4,726.75
# Lastprice                           5,188.80
# Lastvolume                            30,706
# Marketcap                               None
# ...
