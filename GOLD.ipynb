# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,424.28 | 4,645.50 | 4,877.77 | 5,121.66 | 5,377.74 | 5,646.63 | 5,928.96
# Buy score: -1.74%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,230.00
# Daylow                              5,135.90
# Exchange                                 CMX
# Fiftydayaverage                     4,708.33
# Lastprice                           5,212.60
# Lastvolume                            29,138
# Marketcap                               None
# ...
