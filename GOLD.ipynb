# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,835.08 | 4,026.83 | 4,228.17 | 4,439.58 | 4,661.56 | 4,894.64 | 5,139.37
# Buy score: 1.35%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,420.50
# Daylow                              4,338.80
# Exchange                                 CMX
# Fiftydayaverage                     4,170.91
# Lastprice                           4,380.30
# Lastvolume                           164,718
# Marketcap                               None
# ...
