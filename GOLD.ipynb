# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,977.92 | 4,176.82 | 4,385.66 | 4,604.94 | 4,835.19 | 5,076.95 | 5,330.79
# Buy score: 0.36%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,625.50
# Daylow                              4,539.10
# Exchange                                 CMX
# Fiftydayaverage                     4,269.24
# Lastprice                           4,588.60
# Lastvolume                           211,051
# Marketcap                               None
# ...
