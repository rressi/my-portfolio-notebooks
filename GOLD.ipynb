# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,851.23 | 4,043.79 | 4,245.98 | 4,458.28 | 4,681.19 | 4,915.25 | 5,161.02
# Buy score: 2.39%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,581.30
# Daylow                              4,316.00
# Exchange                                 CMX
# Fiftydayaverage                     4,170.01
# Lastprice                           4,354.30
# Lastvolume                           297,186
# Marketcap                               None
# ...
