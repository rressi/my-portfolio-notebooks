# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,443.29 | 3,615.46 | 3,796.23 | 3,986.04 | 4,185.34 | 4,394.61 | 4,614.34
# Buy score: -0.32%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,011.30
# Daylow                              3,981.60
# Exchange                                 CMX
# Fiftydayaverage                     3,849.12
# Lastprice                           3,998.70
# Lastvolume                            19,397
# Marketcap                               None
# ...
