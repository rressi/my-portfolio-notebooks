# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,549.13 | 3,726.58 | 3,912.91 | 4,108.56 | 4,313.99 | 4,529.69 | 4,756.17
# Buy score: -3.10%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,273.30
# Daylow                              4,225.10
# Exchange                                 CMX
# Fiftydayaverage                     4,016.55
# Lastprice                           4,240.00
# Lastvolume                           164,248
# Marketcap                               None
# ...
