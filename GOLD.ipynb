# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,235.13 | 4,446.89 | 4,669.23 | 4,723.50 | 4,959.68 | 5,207.66 | 5,468.04
# Buy score: -1.00%
# No operations found.
#                            GC=F
# Company Name        Gold Jun 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,791.00
# Daylow                              4,744.90
# Exchange                                 CMX
# Fiftydayaverage                     4,902.70
# Lastprice                           4,761.90
# Lastvolume                             1,277
# Marketcap                               None
# ...
