# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,651.15 | 3,833.71 | 4,025.39 | 4,226.66 | 4,437.99 | 4,659.89 | 4,892.89
# Buy score: 1.84%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,393.60
# Daylow                              4,093.00
# Exchange                                 CMX
# Fiftydayaverage                     3,690.84
# Lastprice                           4,149.90
# Lastvolume                           421,627
# Marketcap                               None
# ...
