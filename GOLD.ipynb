# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,960.83 | 4,158.88 | 4,366.82 | 4,585.16 | 4,814.42 | 5,055.14 | 5,307.90
# Buy score: -0.66%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,637.20
# Daylow                              4,584.00
# Exchange                                 CMX
# Fiftydayaverage                     4,256.92
# Lastprice                           4,615.70
# Lastvolume                           147,464
# Marketcap                               None
# ...
