# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,442.96 | 3,615.11 | 3,795.87 | 3,985.66 | 4,184.94 | 4,394.19 | 4,613.90
# Buy score: 0.63%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,018.00
# Daylow                              3,959.40
# Exchange                                 CMX
# Fiftydayaverage                     3,828.43
# Lastprice                           3,960.80
# Lastvolume                           129,692
# Marketcap                               None
# ...
