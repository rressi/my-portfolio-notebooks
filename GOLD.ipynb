# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,241.68 | 4,453.77 | 4,676.46 | 4,910.28 | 5,155.79 | 5,413.58 | 5,684.26
# Buy score: -3.25%
# No operations found.
#                            GC=F
# Company Name        Gold Feb 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,107.90
# Daylow                              5,002.00
# Exchange                                 CMX
# Fiftydayaverage                     4,350.16
# Lastprice                           5,075.00
# Lastvolume                           209,550
# Marketcap                               None
# ...
