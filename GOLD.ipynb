# %%
import my_portfolio; my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 4,313.40 | 4,529.07 | 4,755.52 | 4,993.30 | 5,242.97 | 5,505.11 | 5,780.37
# Buy score: 0.97%
# No operations found.
#                            GC=F
# Company Name        Gold Apr 26
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             5,074.40
# Daylow                              4,875.20
# Exchange                                 CMX
# Fiftydayaverage                     4,607.32
# Lastprice                           4,945.40
# Lastvolume                            84,717
# Marketcap                               None
# ...
