# %%
import my_portfolio; my_portfolio.run("QCOM")
# Out:
# No operations found for ticker 'QCOM'
# Prices: 144.14 | 151.35 | 158.92 | 144.47 | 151.69 | 159.27 | 167.24
# Buy score: 5.60%
# No operations found.
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         137.34
# Forward EPS                         11.35342
# Gross Profit (ttm)            24,721,999,872
# Industry                      Semiconductors
# Revenue (ttm)                 44,866,998,272
# Target High Price                      200.0
# Target Low Price                       134.0
# Target Mean Price                   163.3077
# Trailing EPS                            4.96
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 139.15
# Daylow                                  135.28
# Exchange                                   NMS
# ...
