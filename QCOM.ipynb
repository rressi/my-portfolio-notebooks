# %%
import my_portfolio
my_portfolio.run(
    security = "QCOM",
)
# Out:
# Prices: 140.53 | 147.55 | 154.93 | 162.68 | 170.81 | 179.35 | 188.32
# Buy score: -2.62%
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         166.85
# Forward EPS                            12.23
# Gross Profit (ttm)            24,085,999,616
# Industry                      Semiconductors
# Revenue (ttm)                 43,256,999,936
# Target High Price                      225.0
# Target Low Price                       140.0
# Target Mean Price                   178.1963
# Trailing EPS                           10.36
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 169.58
# Daylow                                  166.29
# Exchange                                   NMS
# Fiftydayaverage                         156.97
# Lastprice                               166.85
# ...
