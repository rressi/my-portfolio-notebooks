# %%
import my_portfolio; my_portfolio.run("QCOM")
# Out:
# No operations found for ticker 'QCOM'
# Prices: 146.29 | 153.61 | 161.29 | 169.28 | 177.74 | 186.63 | 195.96
# Buy score: 0.85%
# No operations found.
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         166.11
# Forward EPS                            12.23
# Gross Profit (ttm)            24,546,000,896
# Industry                      Semiconductors
# Revenue (ttm)                 44,283,998,208
# Target High Price                      225.0
# Target Low Price                       157.0
# Target Mean Price                  190.12222
# Trailing EPS                            5.02
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 167.51
# Daylow                                  164.11
# Exchange                                   NMS
# ...
