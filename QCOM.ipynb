# %%
import workflow
workflow.run(
    security = "QCOM",
)
# Out:
# Prices: 138.43 | 145.35 | 152.62 | 160.25 | 168.26 | 176.67 | 185.51
# Buy score: -2.37%
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         164.14
# Forward EPS                            12.23
# Gross Profit (ttm)            24,085,999,616
# Industry                      Semiconductors
# Revenue (ttm)                 43,256,999,936
# Target High Price                      225.0
# Target Low Price                       140.0
# Target Mean Price                   178.1963
# Trailing EPS                           10.55
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 165.00
# Daylow                                  161.50
# Exchange                                   NMS
# Fiftydayaverage                         156.40
# Lastprice                               164.14
# ...
