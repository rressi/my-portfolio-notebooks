# %%
import my_portfolio; my_portfolio.run("QCOM")
# Out:
# No operations found for ticker 'QCOM'
# Prices: 119.55 | 125.52 | 131.80 | 138.39 | 145.31 | 152.57 | 160.20
# Buy score: -7.65%
# No operations found.
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         148.85
# Forward EPS                         11.01741
# Gross Profit (ttm)            24,721,999,872
# Industry                      Semiconductors
# Revenue (ttm)                 44,866,998,272
# Target High Price                      200.0
# Target Low Price                       100.0
# Target Mean Price                  150.10345
# Trailing EPS                            4.96
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 151.54
# Daylow                                  143.58
# Exchange                                   NMS
# ...
