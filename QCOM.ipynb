# %%
import my_portfolio
my_portfolio.run(
    security = "QCOM",
)
# Out:
# No operations found for ticker 'QCOM'
# Prices: 142.29 | 149.40 | 156.87 | 164.71 | 172.95 | 181.60 | 190.68
# Buy score: -2.81%
# No operations found.
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         169.53
# Forward EPS                            12.23
# Gross Profit (ttm)            24,085,999,616
# Industry                      Semiconductors
# Revenue (ttm)                 43,256,999,936
# Target High Price                      225.0
# Target Low Price                       140.0
# Target Mean Price                   178.1963
# Trailing EPS                           10.34
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 170.85
# Daylow                                  168.30
# Exchange                                   NMS
# ...
