# %%
import my_portfolio; my_portfolio.run("QCOM")
# Out:
# No operations found for ticker 'QCOM'
# Prices: 142.88 | 150.02 | 157.52 | 138.88 | 145.82 | 153.12 | 160.77
# Buy score: -2.03%
# No operations found.
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         141.74
# Forward EPS                         11.30544
# Gross Profit (ttm)            24,721,999,872
# Industry                      Semiconductors
# Revenue (ttm)                 44,866,998,272
# Target High Price                      200.0
# Target Low Price                       132.0
# Target Mean Price                  160.11111
# Trailing EPS                            4.96
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 142.39
# Daylow                                  139.11
# Exchange                                   NMS
# ...
