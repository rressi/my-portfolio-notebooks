# %%
import workflow
workflow.run(
    security = "QCOM",
)
# Out:
# Prices: 139.92 | 146.92 | 154.26 | 161.98 | 170.08 | 178.58 | 187.51
# Buy score: -3.66%
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         168.13
# Forward EPS                            12.23
# Gross Profit (ttm)            24,085,999,616
# Industry                      Semiconductors
# Revenue (ttm)                 43,256,999,936
# Target High Price                      225.0
# Target Low Price                       140.0
# Target Mean Price                   178.1963
# Trailing EPS                           10.36
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 168.86
# Daylow                                  166.23
# Exchange                                   NMS
# Fiftydayaverage                         156.64
# Lastprice                               168.13
# ...
