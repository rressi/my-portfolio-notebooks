# %%
import my_portfolio; my_portfolio.run("QCOM")
# Out:
# No operations found for ticker 'QCOM'
# Prices: 117.77 | 123.66 | 129.84 | 126.37 | 132.69 | 139.33 | 146.29
# Buy score: -0.67%
# No operations found.
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         127.75
# Forward EPS                         11.08748
# Gross Profit (ttm)            24,721,999,872
# Industry                      Semiconductors
# Revenue (ttm)                 44,866,998,272
# Target High Price                      200.0
# Target Low Price                       100.0
# Target Mean Price                  154.92857
# Trailing EPS                            4.97
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 128.59
# Daylow                                  126.80
# Exchange                                   NMS
# ...
