# %%
import workflow
workflow.run(
    security = "QCOM",
)
# Out:
# Prices: 139.20 | 146.16 | 153.46 | 161.14 | 169.19 | 177.65 | 186.54
# Buy score: -2.50%
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         165.26
# Forward EPS                            12.23
# Gross Profit (ttm)            24,085,999,616
# Industry                      Semiconductors
# Revenue (ttm)                 43,256,999,936
# Target High Price                      225.0
# Target Low Price                       140.0
# Target Mean Price                   178.1963
# Trailing EPS                           10.36
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 166.37
# Daylow                                  163.23
# Exchange                                   NMS
# Fiftydayaverage                         156.52
# Lastprice                               165.26
# ...
