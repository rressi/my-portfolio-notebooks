# %%
import my_portfolio; my_portfolio.run("QCOM")
# Out:
# No operations found for ticker 'QCOM'
# Prices: 203.12 | 213.28 | 223.94 | 235.14 | 246.90 | 259.24 | 272.20
# Buy score: 10.97%
# No operations found.
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         215.94
# Forward EPS                         10.66716
# Gross Profit (ttm)            24,377,999,360
# Industry                      Semiconductors
# Revenue (ttm)                 44,486,000,640
# Target High Price                      300.0
# Target Low Price                       100.0
# Target Mean Price                  177.09677
# Trailing EPS                            9.29
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 238.44
# Daylow                                  215.22
# Exchange                                   NMS
# ...
