# %%
import my_portfolio; my_portfolio.run("QCOM")
# Out:
# No operations found for ticker 'QCOM'
# Prices: 151.58 | 159.16 | 167.12 | 175.47 | 184.25 | 193.46 | 203.13
# Buy score: 2.23%
# No operations found.
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         170.89
# Forward EPS                            12.23
# Gross Profit (ttm)            24,546,000,896
# Industry                      Semiconductors
# Revenue (ttm)                 44,283,998,208
# Target High Price                      225.0
# Target Low Price                       140.0
# Target Mean Price                  186.41852
# Trailing EPS                            5.01
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 174.25
# Daylow                                  168.25
# Exchange                                   NMS
# ...
