# %%
import workflow
workflow.run(
    security = "QCOM",
)
# Out:
# Prices: 136.78 | 143.62 | 150.81 | 158.35 | 166.26 | 174.58 | 183.30
# Buy score: -1.78%
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         161.22
# Forward EPS                            12.23
# Gross Profit (ttm)            24,085,999,616
# Industry                      Semiconductors
# Revenue (ttm)                 43,256,999,936
# Target High Price                      225.0
# Target Low Price                       140.0
# Target Mean Price                   178.1963
# Trailing EPS                           10.32
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 162.68
# Daylow                                  160.21
# Exchange                                   NMS
# Fiftydayaverage                         156.42
# Lastprice                               161.22
# ...
