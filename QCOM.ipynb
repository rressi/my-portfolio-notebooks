# %%
import my_portfolio; my_portfolio.run("QCOM")
# Out:
# No operations found for ticker 'QCOM'
# Prices: 144.88 | 152.13 | 159.73 | 167.72 | 176.11 | 184.91 | 194.16
# Buy score: 0.98%
# No operations found.
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         165.46
# Forward EPS                            12.23
# Gross Profit (ttm)            24,085,999,616
# Industry                      Semiconductors
# Revenue (ttm)                 43,256,999,936
# Target High Price                      225.0
# Target Low Price                       140.0
# Target Mean Price                  178.12692
# Trailing EPS                           10.36
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 171.98
# Daylow                                  165.14
# Exchange                                   NMS
# ...
