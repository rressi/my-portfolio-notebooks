# %%
import my_portfolio
my_portfolio.run(
    security = "QCOM",
)
# Out:
# Prices: 141.35 | 148.41 | 155.84 | 163.63 | 171.81 | 180.40 | 189.42
# Buy score: -3.29%
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                         169.72
# Forward EPS                            12.23
# Gross Profit (ttm)            24,085,999,616
# Industry                      Semiconductors
# Revenue (ttm)                 43,256,999,936
# Target High Price                      225.0
# Target Low Price                       140.0
# Target Mean Price                   178.1963
# Trailing EPS                           10.35
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 170.22
# Daylow                                  165.92
# Exchange                                   NMS
# Fiftydayaverage                         156.97
# Lastprice                               169.72
# ...
