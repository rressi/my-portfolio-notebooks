# %%
import my_portfolio; my_portfolio.run("QCOM")
# Out:
# No operations found for ticker 'QCOM'
# Prices: 144.65 | 151.88 | 159.48 | 147.79 | 155.18 | 162.94 | 171.09
# Buy score: 6.56%
# No operations found.
#                                         QCOM
# Company Name                        QUALCOMM
# Current Price                       138.6933
# Forward EPS                         11.73811
# Gross Profit (ttm)            24,546,000,896
# Industry                      Semiconductors
# Revenue (ttm)                 44,283,998,208
# Target High Price                      225.0
# Target Low Price                       134.0
# Target Mean Price                   176.3077
# Trailing EPS                            4.96
# Website             https://www.qualcomm.com
#                                           QCOM
# Currency                                   USD
# Dayhigh                                 139.20
# Daylow                                  132.73
# Exchange                                   NMS
# ...
