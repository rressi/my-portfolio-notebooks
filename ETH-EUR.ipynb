# %%
import my_portfolio; my_portfolio.run("ETH-EUR")
# Out:
# Prices: 3,305.29 | 3,470.55 | 3,644.08 | 3,675.10 | 3,957.36 | 4,155.23 | 4,362.99
# Buy score: 8.72%
# Sell score: -4.23%
#                          ETH-EUR
# Company Name        Ethereum EUR
# Current Price               None
# Forward EPS                 None
# Gross Profit (ttm)          None
# Industry                    None
# Revenue (ttm)               None
# Target High Price           None
# Target Low Price            None
# Target Mean Price           None
# Trailing EPS                None
# Website                     None
#                                    ETH-EUR
# Currency                               EUR
# Dayhigh                           3,570.70
# Daylow                            3,519.48
# Exchange                               CCC
# Fiftydayaverage                   3,746.04
# Lastprice                         3,519.48
# Lastvolume                  41,703,723,008
# Marketcap                             None
# Open                              3,561.74
# ...
