# %%
import workflow
workflow.run(
    security = "ETH-EUR",  # Ethereum
    ops=
"""
date, quantity, price, currency
2025-08-12,  0.4,        4500.3, USD
2025-08-12,  0.1,        3858.6, EUR
2025-08-13,  0.5,        4686.3, USD
2025-08-14,  0.33,       4555.9, USD
2025-08-14,  0.67,       4500.0, USD
2025-08-15, -1.0,        4416.6, USD
2025-08-15, -1.0,        4417.3, USD
2025-09-02,  0.00531873, 3760.3, EUR
2025-09-09,  0.01076369, 3716.2, EUR
2025-09-14, -0.01608242, 3930.6, EUR
2025-09-16,  0.00522262, 3829.5, EUR
2025-09-16,  0.03159386, 3758.9, EUR
"""
)
# Out:
# Prices: 3,292.81 | 3,457.45 | 3,630.32 | 3768.91 | 4,002.43 | 4,202.55 | 4,412.67
# Buy score: 0.18%
# Sell score: 0.95%
#                          ETH-EUR
# Company Name        Ethereum EUR
# Current Price               None
# Forward EPS                 None
# Gross Profit (ttm)          None
# Industry                    None
# Revenue (ttm)               None
# Target High Price           None
# Target Low Price            None
# Target Mean Price           None
# Trailing EPS                None
# Website                     None
#                                    ETH-EUR
# Currency                               EUR
# Dayhigh                           3,807.49
# Daylow                            3,793.95
# Exchange                               CCC
# Fiftydayaverage                   3,660.76
# Lastprice                         3,804.83
# Lastvolume                  27,729,315,840
# Marketcap                             None
# Open                              3,793.99
# ...
