# %%
import workflow
workflow.run(
    security = "ETH-EUR",  # Ethereum
    start_date = "2025-07-01",
    ops=
"""
date, quantity, price, currency
2025-08-12,  0.4,        4500.3, USD
2025-08-12,  0.1,        3858.6, EUR
2025-08-13,  0.5,        4686.3, USD
2025-08-14,  0.33,       4555.9, USD
2025-08-14,  0.67,       4500.0, USD
2025-08-15, -1.0,        4416.6, USD
2025-08-15, -1.0,        4417.3, USD
2025-09-02,  0.00531873, 3760.3, EUR
2025-09-09,  0.01076369, 3716.2, EUR
2025-09-14, -0.01608242, 3930.6, EUR
"""
)
# Out:
# Prices: 3,265.44 | 3,428.71 | 3,600.15 | nan | 3,969.17 | 4,167.62 | 4,376.00
# Buy score: -3.90%
#                          ETH-EUR
# Company Name        Ethereum EUR
# Current Price               None
# Forward EPS                 None
# Gross Profit (ttm)          None
# Industry                    None
# Revenue (ttm)               None
# Target High Price           None
# Target Low Price            None
# Target Mean Price           None
# Trailing EPS                None
# Website                     None
#                                    ETH-EUR
# Currency                               EUR
# Dayhigh                           3,995.14
# Daylow                            3,908.84
# Exchange                               CCC
# Fiftydayaverage                   3,626.91
# Lastprice                         3,933.42
# Lastvolume                  23,400,871,936
# Marketcap                             None
# Open                              3,978.46
# Previousclose                     3,978.25
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose        3,978.33
# Shares                                None
# Tendayaveragevolume         28,310,318,191
# Threemonthaveragevolume     28,741,217,575
# Timezone                               UTC
# Twohundreddayaverage              2,439.12
# Yearchange                            0.90
# Yearhigh                          4,226.47
# Yearlow                           1,256.32
