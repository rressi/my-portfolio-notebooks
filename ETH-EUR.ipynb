# %%
import my_portfolio; my_portfolio.run("ETH-EUR")
# Out:
# Prices: 3,349.43 | 3,516.90 | 3,692.75 | 3,768.91 | 3,957.36 | 4,155.23 | 4,362.99
# Buy score: 1.89%
# Sell score: 0.97%
#                          ETH-EUR
# Company Name        Ethereum EUR
# Current Price               None
# Forward EPS                 None
# Gross Profit (ttm)          None
# Industry                    None
# Revenue (ttm)               None
# Target High Price           None
# Target Low Price            None
# Target Mean Price           None
# Trailing EPS                None
# Website                     None
#                                    ETH-EUR
# Currency                               EUR
# Dayhigh                           3,824.63
# Daylow                            3,790.20
# Exchange                               CCC
# Fiftydayaverage                   3,714.16
# Lastprice                         3,805.47
# Lastvolume                  14,916,421,632
# Marketcap                             None
# Open                              3,815.26
# ...
