# %%
import my_portfolio
my_portfolio.run(
    security = "ETH-EUR",  # Ethereum
    ops=
"""
date,quantity,price,currency
2025-08-12 21:27:11,0.4,4500.3,USD
2025-08-12 21:38:19,0.1,3858.6,EUR
2025-08-13 15:55:33,0.5,4686.3,USD
2025-08-14 15:16:11,0.33,4555.9,USD
2025-08-14 20:22:16,0.67,4500.0,USD
2025-08-15 17:47:00,-1.0,4416.6,USD
2025-08-15 17:47:00,-1.0,4417.3,USD
2025-09-02 10:00:18,0.00531873,3760.3,EUR
2025-09-09 10:00:22,0.01076369,3716.2,EUR
2025-09-14 22:14:16,-0.01608242,3930.6,EUR
2025-09-16 10:00:20,0.00522262,3829.5,EUR
2025-09-16 14:00:00,0.03159386,3758.9,EUR
"""
)
# Out:
# Prices: 3,349.41 | 3,516.88 | 3,692.72 | 3768.91 | 3,957.36 | 4,155.23 | 4,362.99
# Buy score: 1.55%
# Sell score: 1.31%
#                          ETH-EUR
# Company Name        Ethereum EUR
# Current Price               None
# Forward EPS                 None
# Gross Profit (ttm)          None
# Industry                    None
# Revenue (ttm)               None
# Target High Price           None
# Target Low Price            None
# Target Mean Price           None
# Trailing EPS                None
# Website                     None
#                                    ETH-EUR
# Currency                               EUR
# Dayhigh                           3,835.98
# Daylow                            3,797.09
# Exchange                               CCC
# Fiftydayaverage                   3,698.03
# Lastprice                         3,818.12
# Lastvolume                  15,489,908,736
# Marketcap                             None
# Open                              3,806.67
# ...
