# %%
import workflow
workflow.run(
    security = "ETH-EUR",  # Ethereum
    start_date = "2025-07-01",
    ops=
"""
date, quantity, price, currency
2025-08-12,  0.4,        4500.3, USD
2025-08-12,  0.1,        3858.6, EUR
2025-08-13,  0.5,        4686.3, USD
2025-08-14,  0.33,       4555.9, USD
2025-08-14,  0.67,       4500.0, USD
2025-08-15, -1.0,        4416.6, USD
2025-08-15, -1.0,        4417.3, USD
2025-09-02,  0.00531873, 3760.3, EUR
2025-09-09,  0.01076369, 3716.2, EUR
2025-09-14, -0.01608242, 3930.6, EUR
"""
)
# Out:
# Prices: 3,260.54 | 3,423.57 | 3,594.75 | 3774.49 | 3,963.21 | 4,161.37 | 4,369.44
# Buy score: -1.76%
#                          ETH-EUR
# Company Name        Ethereum EUR
# Current Price               None
# Forward EPS                 None
# Gross Profit (ttm)          None
# Industry                    None
# Revenue (ttm)               None
# Target High Price           None
# Target Low Price            None
# Target Mean Price           None
# Trailing EPS                None
# Website                     None
#                                    ETH-EUR
# Currency                               EUR
# Dayhigh                           3,856.89
# Daylow                            3,833.39
# Exchange                               CCC
# Fiftydayaverage                   3,648.88
# Lastprice                         3,841.96
# Lastvolume                  31,026,964,480
# Marketcap                             None
# Open                              3,847.20
# Previousclose                     3,845.13
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose             nan
# Shares                                None
# Tendayaveragevolume         23,968,526,186
# Threemonthaveragevolume     28,738,590,701
# Timezone                               UTC
# Twohundreddayaverage              2,448.81
# Yearchange                             nan
# Yearhigh                          4,226.47
# Yearlow                           1,256.32
