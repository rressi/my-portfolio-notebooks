# %%
import my_portfolio; my_portfolio.run("ETH-EUR")
# Out:
# Prices: 3,349.73 | 3,517.21 | 3,693.07 | 3768.91 | 3,957.36 | 4,155.23 | 4,362.99
# Buy score: 1.81%
# Sell score: 1.06%
#                          ETH-EUR
# Company Name        Ethereum EUR
# Current Price               None
# Forward EPS                 None
# Gross Profit (ttm)          None
# Industry                    None
# Revenue (ttm)               None
# Target High Price           None
# Target Low Price            None
# Target Mean Price           None
# Trailing EPS                None
# Website                     None
#                                    ETH-EUR
# Currency                               EUR
# Dayhigh                           3,824.63
# Daylow                            3,805.48
# Exchange                               CCC
# Fiftydayaverage                   3,714.16
# Lastprice                         3,808.87
# Lastvolume                  15,612,109,824
# Marketcap                             None
# Open                              3,815.26
# ...
