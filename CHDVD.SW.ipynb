# %%
import my_portfolio; my_portfolio.run("CHDVD.SW")
# Out:
# No operations found for ticker 'CHDVD.SW'
# Prices: 161.20 | 169.26 | 177.73 | 186.61 | 195.94 | 205.74 | 216.03
# Buy score: -0.47%
# No operations found.
#                                     CHDVD.SW
# Company Name        iSh Swiss Div (CH) CHF D
# Current Price                           None
# Forward EPS                             None
# Gross Profit (ttm)                      None
# Industry                                None
# Revenue (ttm)                           None
# Target High Price                       None
# Target Low Price                        None
# Target Mean Price                       None
# Trailing EPS                            None
# Website                                 None
#                                  CHDVD.SW
# Currency                              CHF
# Dayhigh                            187.82
# Daylow                             186.58
# Exchange                              EBS
# Fiftydayaverage                    180.45
# ...
