# %%
import my_portfolio; my_portfolio.run("CHDVD.SW")
# Out:
# No operations found for ticker 'CHDVD.SW'
# Prices: 160.72 | 168.75 | 177.19 | 186.05 | 195.35 | 205.12 | 215.38
# Buy score: -0.42%
# No operations found.
#                                     CHDVD.SW
# Company Name        iSh Swiss Div (CH) CHF D
# Current Price                           None
# Forward EPS                             None
# Gross Profit (ttm)                      None
# Industry                                None
# Revenue (ttm)                           None
# Target High Price                       None
# Target Low Price                        None
# Target Mean Price                       None
# Trailing EPS                            None
# Website                                 None
#                                  CHDVD.SW
# Currency                              CHF
# Dayhigh                            188.02
# Daylow                             186.60
# Exchange                              EBS
# Fiftydayaverage                    180.23
# ...
