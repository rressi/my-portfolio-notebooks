# %%
import my_portfolio; my_portfolio.run("CHDVD.SW")
# Out:
# No operations found for ticker 'CHDVD.SW'
# Prices: 162.98 | 171.12 | 179.68 | 188.66 | 198.10 | 208.00 | 218.40
# Buy score: -0.24%
# No operations found.
#                                     CHDVD.SW
# Company Name        iSh Swiss Div (CH) CHF D
# Current Price                           None
# Forward EPS                             None
# Gross Profit (ttm)                      None
# Industry                                None
# Revenue (ttm)                           None
# Target High Price                       None
# Target Low Price                        None
# Target Mean Price                       None
# Trailing EPS                            None
# Website                                 None
#                                  CHDVD.SW
# Currency                              CHF
# Dayhigh                            189.24
# Daylow                             188.60
# Exchange                              EBS
# Fiftydayaverage                    181.48
# ...
