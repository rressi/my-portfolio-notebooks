# %%
import my_portfolio; my_portfolio.run("CHDVD.SW")
# Out:
# No operations found for ticker 'CHDVD.SW'
# Prices: 153.40 | 161.07 | 169.13 | 177.58 | 186.46 | 195.79 | 205.58
# Buy score: -0.65%
# No operations found.
#                                     CHDVD.SW
# Company Name        iSh Swiss Div (CH) CHF D
# Current Price                           None
# Forward EPS                             None
# Gross Profit (ttm)                      None
# Industry                                None
# Revenue (ttm)                           None
# Target High Price                       None
# Target Low Price                        None
# Target Mean Price                       None
# Trailing EPS                            None
# Website                                 None
#                                  CHDVD.SW
# Currency                              CHF
# Dayhigh                            179.78
# Daylow                             178.04
# Exchange                              EBS
# Fiftydayaverage                    178.84
# ...
