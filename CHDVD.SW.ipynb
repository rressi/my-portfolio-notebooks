# %%
import my_portfolio; my_portfolio.run("CHDVD.SW")
# Out:
# No operations found for ticker 'CHDVD.SW'
# Prices: 157.53 | 165.41 | 173.68 | 182.36 | 191.48 | 201.06 | 211.11
# Buy score: -0.88%
# No operations found.
#                                     CHDVD.SW
# Company Name        iSh Swiss Div (CH) CHF D
# Current Price                           None
# Forward EPS                             None
# Gross Profit (ttm)                      None
# Industry                                None
# Revenue (ttm)                           None
# Target High Price                       None
# Target Low Price                        None
# Target Mean Price                       None
# Trailing EPS                            None
# Website                                 None
#                                  CHDVD.SW
# Currency                              CHF
# Dayhigh                            184.44
# Daylow                             182.90
# Exchange                              EBS
# Fiftydayaverage                    178.29
# ...
