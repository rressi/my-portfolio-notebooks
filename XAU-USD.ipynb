# %%
import workflow
workflow.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,142.72 | 3,299.85 | 3,464.85 | 3638.09 | 3,819.99 | 4,010.99 | 4,211.54
# Buy score: -2.08%
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,732.80
# Daylow                              3,714.10
# Exchange                                 CMX
# Fiftydayaverage                     3,411.11
# Lastprice                           3,715.20
# Lastvolume                            13,242
# Marketcap                               None
# Open                                3,727.30
# ...
