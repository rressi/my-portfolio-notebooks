# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,262.27 | 3,425.38 | 3,596.65 | 3,776.48 | 3,965.30 | 4,163.57 | 4,371.75
# Buy score: -2.10%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,862.20
# Daylow                              3,785.50
# Exchange                                 CMX
# Fiftydayaverage                     3,480.18
# Lastprice                           3,857.50
# Lastvolume                           245,953
# Marketcap                               None
# ...
