# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,445.62 | 3,617.90 | 3,798.80 | 3,988.74 | 4,188.18 | 4,397.59 | 4,617.47
# Buy score: -1.00%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,038.60
# Daylow                              3,961.20
# Exchange                                 CMX
# Fiftydayaverage                     3,579.04
# Lastprice                           4,029.00
# Lastvolume                           346,126
# Marketcap                               None
# ...
