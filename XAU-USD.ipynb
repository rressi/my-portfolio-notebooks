# %%
import my_portfolio
my_portfolio.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,200.48 | 3,360.51 | 3,528.53 | 3,704.96 | 3,890.21 | 4,084.72 | 4,288.95
# Buy score: -1.95%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,792.30
# Daylow                              3,751.90
# Exchange                                 CMX
# Fiftydayaverage                     3,463.79
# Lastprice                           3,778.70
# Lastvolume                           250,580
# Marketcap                               None
# ...
