# %%
import workflow
workflow.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 2,996.37 | 3,146.19 | 3,303.50 | 3468.6700 | 3,642.10 | 3,824.21 | 4,015.42
# Buy score: -5.83%
#                            GC=F
# Company Name        Gold Dec 25
# Industry                   None
# Revenue (ttm)              None
# Gross Profit (ttm)         None
# Current Price              None
# Target Mean Price          None
# Target High Price          None
# Target Low Price           None
# Trailing EPS               None
# Forward EPS                None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,683.90
# Daylow                              3,667.30
# Exchange                                 CMX
# Fiftydayaverage                     3,391.98
# Lastprice                           3,683.30
# Lastvolume                            12,771
# Marketcap                               None
# Open                                3,672.80
# ...
