# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,475.65 | 3,649.43 | 3,831.90 | 4,023.50 | 4,224.68 | 4,435.91 | 4,657.70
# Buy score: -3.64%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,175.50
# Daylow                              4,125.90
# Exchange                                 CMX
# Fiftydayaverage                     3,592.69
# Lastprice                           4,175.40
# Lastvolume                            71,194
# Marketcap                               None
# ...
