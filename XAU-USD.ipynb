# %%
import my_portfolio
my_portfolio.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,159.87 | 3,317.86 | 3,483.75 | 3657.94 | 3,840.84 | 4,032.88 | 4,234.52
# Buy score: -0.37%
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,685.90
# Daylow                              3,658.20
# Exchange                                 CMX
# Fiftydayaverage                     3,439.46
# Lastprice                           3,671.50
# Lastvolume                                80
# Marketcap                               None
# Open                                3,659.00
# ...
