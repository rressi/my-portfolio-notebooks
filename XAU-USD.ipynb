# %%
import workflow
workflow.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,035.04 | 3,186.79 | 3,346.13 | 3513.4333 | 3,689.11 | 3,873.56 | 4,067.24
# Buy score: -4.29%
#                     GC=F
# Company Name        None
# Industry            None
# Revenue (ttm)       None
# Gross Profit (ttm)  None
# Current Price       None
# Target Mean Price   None
# Target High Price   None
# Target Low Price    None
# Trailing EPS        None
# Forward EPS         None
# Website             None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,676.60
# Daylow                              3,670.90
# Exchange                                 CMX
# Fiftydayaverage                     3,391.98
# Lastprice                           3,671.10
# Lastvolume                             1,985
# Marketcap                               None
# Open                                3,672.80
# Previousclose                       3,669.70
# Quotetype                             FUTURE
# ...
