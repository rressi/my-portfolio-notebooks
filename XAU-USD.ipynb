# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,613.90 | 3,794.59 | 3,984.32 | 4,183.54 | 4,392.72 | 4,612.35 | 4,842.97
# Buy score: -0.71%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,392.00
# Daylow                              4,196.00
# Exchange                                 CMX
# Fiftydayaverage                     3,673.36
# Lastprice                           4,213.30
# Lastvolume                           558,913
# Marketcap                               None
# ...
