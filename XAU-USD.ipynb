# %%
import workflow
workflow.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,024.48 | 3,175.70 | 3,334.49 | 3501.21 | 3,676.27 | 3,860.08 | 4,053.09
# Buy score: -5.86%
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,728.40
# Daylow                              3,711.80
# Exchange                                 CMX
# Fiftydayaverage                     3,411.85
# Lastprice                           3,719.00
# Lastvolume                            30,074
# Marketcap                               None
# Open                                3,720.30
# ...
