# %%
import my_portfolio
my_portfolio.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,171.85 | 3,330.44 | 3,496.96 | 3,671.81 | 3,855.40 | 4,048.17 | 4,250.58
# Buy score: -2.78%
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,795.10
# Daylow                              3,773.50
# Exchange                                 CMX
# Fiftydayaverage                     3,439.46
# Lastprice                           3,776.80
# Lastvolume                            36,223
# Marketcap                               None
# Open                                3,781.20
# ...
