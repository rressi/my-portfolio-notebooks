# %%
import my_portfolio
my_portfolio.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,209.00 | 3,369.45 | 3,537.92 | 3,714.82 | 3,900.56 | 4,095.59 | 4,300.37
# Buy score: -1.98%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,814.40
# Daylow                              3,764.00
# Exchange                                 CMX
# Fiftydayaverage                     3,471.47
# Lastprice                           3,789.80
# Lastvolume                           206,111
# Marketcap                               None
# ...
