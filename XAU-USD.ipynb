# %%
import workflow
workflow.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,157.40 | 3,315.27 | 3,481.03 | 3655.08 | 3,837.83 | 4,029.73 | 4,231.21
# Buy score: -0.50%
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,678.20
# Daylow                              3,673.40
# Exchange                                 CMX
# Fiftydayaverage                     3,425.74
# Lastprice                           3,673.40
# Lastvolume                             1,136
# Marketcap                               None
# Open                                3,677.70
# ...
