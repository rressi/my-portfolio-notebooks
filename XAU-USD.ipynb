# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,496.75 | 3,671.58 | 3,855.16 | 4,047.92 | 4,250.32 | 4,462.83 | 4,685.97
# Buy score: -2.82%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,190.90
# Daylow                              4,105.00
# Exchange                                 CMX
# Fiftydayaverage                     3,607.91
# Lastprice                           4,165.50
# Lastvolume                           382,856
# Marketcap                               None
# ...
