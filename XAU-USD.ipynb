# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,297.92 | 3,462.82 | 3,635.96 | 3,817.76 | 4,008.65 | 4,209.08 | 4,419.53
# Buy score: -2.48%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,922.70
# Daylow                              3,880.30
# Exchange                                 CMX
# Fiftydayaverage                     3,498.31
# Lastprice                           3,914.90
# Lastvolume                           104,093
# Marketcap                               None
# ...
