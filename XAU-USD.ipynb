# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,353.97 | 3,521.67 | 3,697.75 | 3,882.64 | 4,076.77 | 4,280.61 | 4,494.64
# Buy score: -2.55%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,994.50
# Daylow                              3,909.20
# Exchange                                 CMX
# Fiftydayaverage                     3,525.99
# Lastprice                           3,984.40
# Lastvolume                           270,611
# Marketcap                               None
# ...
