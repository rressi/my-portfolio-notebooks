# %%
import my_portfolio
my_portfolio.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,182.00 | 3,341.10 | 3,508.15 | 3,683.56 | 3,867.74 | 4,061.12 | 4,264.18
# Buy score: -2.99%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,824.60
# Daylow                              3,772.40
# Exchange                                 CMX
# Fiftydayaverage                     3,447.16
# Lastprice                           3,796.90
# Lastvolume                           284,284
# Marketcap                               None
# ...
