# %%
import workflow
workflow.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,149.35 | 3,306.82 | 3,472.16 | 3645.77 | 3,828.06 | 4,019.46 | 4,220.43
# Buy score: -1.37%
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,705.60
# Daylow                              3,686.60
# Exchange                                 CMX
# Fiftydayaverage                     3,418.24
# Lastprice                           3,696.30
# Lastvolume                            31,536
# Marketcap                               None
# Open                                3,692.50
# ...
