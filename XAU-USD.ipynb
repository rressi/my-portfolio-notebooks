# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,293.33 | 3,458.00 | 3,630.90 | 3,812.44 | 4,003.06 | 4,203.22 | 4,413.38
# Buy score: -1.95%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,895.70
# Daylow                              3,884.10
# Exchange                                 CMX
# Fiftydayaverage                     3,498.31
# Lastprice                           3,888.30
# Lastvolume                             2,900
# Marketcap                               None
# ...
