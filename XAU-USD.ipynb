# %%
import my_portfolio
my_portfolio.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,162.83 | 3,320.97 | 3,487.02 | 3,661.37 | 3,844.44 | 4,036.66 | 4,238.49
# Buy score: -1.20%
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,719.60
# Daylow                              3,664.40
# Exchange                                 CMX
# Fiftydayaverage                     3,440.15
# Lastprice                           3,705.80
# Lastvolume                           181,323
# Marketcap                               None
# Open                                3,677.70
# ...
