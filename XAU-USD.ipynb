# %%
import my_portfolio
my_portfolio.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,190.88 | 3,350.42 | 3,517.94 | 3,693.84 | 3,878.53 | 4,072.46 | 4,276.08
# Buy score: -1.83%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,812.60
# Daylow                              3,749.70
# Exchange                                 CMX
# Fiftydayaverage                     3,455.74
# Lastprice                           3,762.70
# Lastvolume                           228,725
# Marketcap                               None
# ...
