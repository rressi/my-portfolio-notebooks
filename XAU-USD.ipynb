# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,402.76 | 3,572.90 | 3,751.54 | 3,939.12 | 4,136.08 | 4,342.88 | 4,560.02
# Buy score: -2.74%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,051.80
# Daylow                              4,005.60
# Exchange                                 CMX
# Fiftydayaverage                     3,551.63
# Lastprice                           4,050.00
# Lastvolume                            69,951
# Marketcap                               None
# ...
