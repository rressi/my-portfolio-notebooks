# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,522.19 | 3,698.30 | 3,883.22 | 4,077.38 | 4,281.25 | 4,495.31 | 4,720.08
# Buy score: -3.32%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,235.80
# Daylow                              4,157.30
# Exchange                                 CMX
# Fiftydayaverage                     3,623.19
# Lastprice                           4,217.40
# Lastvolume                           285,808
# Marketcap                               None
# ...
