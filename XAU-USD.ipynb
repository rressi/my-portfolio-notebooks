# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,315.89 | 3,481.69 | 3,655.77 | 3,838.56 | 4,030.49 | 4,232.01 | 4,443.61
# Buy score: -1.28%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,899.60
# Daylow                              3,877.00
# Exchange                                 CMX
# Fiftydayaverage                     3,506.88
# Lastprice                           3,888.30
# Lastvolume                            46,695
# Marketcap                               None
# ...
