# %%
import my_portfolio
my_portfolio.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,180.97 | 3,340.02 | 3,507.02 | 3,682.37 | 3,866.49 | 4,059.81 | 4,262.80
# Buy score: -2.71%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,795.10
# Daylow                              3,772.40
# Exchange                                 CMX
# Fiftydayaverage                     3,447.16
# Lastprice                           3,785.00
# Lastvolume                            64,095
# Marketcap                               None
# ...
