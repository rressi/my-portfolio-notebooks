# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,312.33 | 3,477.95 | 3,651.85 | 3,834.44 | 4,026.16 | 4,227.47 | 4,438.84
# Buy score: -0.86%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,923.30
# Daylow                              3,842.80
# Exchange                                 CMX
# Fiftydayaverage                     3,506.88
# Lastprice                           3,867.70
# Lastvolume                           249,152
# Marketcap                               None
# ...
