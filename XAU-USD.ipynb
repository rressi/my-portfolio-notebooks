# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,522.04 | 3,698.14 | 3,883.05 | 4,077.20 | 4,281.06 | 4,495.11 | 4,719.87
# Buy score: -3.30%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,218.60
# Daylow                              4,157.30
# Exchange                                 CMX
# Fiftydayaverage                     3,623.19
# Lastprice                           4,216.50
# Lastvolume                            82,119
# Marketcap                               None
# ...
