# %%
import workflow
workflow.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,007.93 | 3,158.33 | 3,316.25 | 3482.0600 | 3,656.16 | 3,838.97 | 4,030.92
# Buy score: -4.59%
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,656.80
# Daylow                              3,643.00
# Exchange                                 CMX
# Fiftydayaverage                     3,404.12
# Lastprice                           3,649.40
# Lastvolume                               307
# Marketcap                               None
# Open                                3,655.50
# ...
