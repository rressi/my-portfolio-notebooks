# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,616.25 | 3,797.06 | 3,986.91 | 4,186.26 | 4,395.57 | 4,615.35 | 4,846.12
# Buy score: -0.96%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,392.00
# Daylow                              4,216.80
# Exchange                                 CMX
# Fiftydayaverage                     3,657.10
# Lastprice                           4,226.90
# Lastvolume                           475,786
# Marketcap                               None
# ...
