# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,440.80 | 3,544.03 | 3,650.35 | 3,759.86 | 3,872.66 | 3,988.84 | 4,108.50
# Buy score: -1.29%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,814.40
# Daylow                              3,764.00
# Exchange                                 CMX
# Fiftydayaverage                     3,480.85
# Lastprice                           3,809.00
# Lastvolume                           206,111
# Marketcap                               None
# ...
