# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,465.85 | 3,639.15 | 3,821.10 | 4,012.16 | 4,212.77 | 4,423.41 | 4,644.58
# Buy score: -2.59%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,137.20
# Daylow                              4,011.30
# Exchange                                 CMX
# Fiftydayaverage                     3,592.69
# Lastprice                           4,118.60
# Lastvolume                           286,899
# Marketcap                               None
# ...
