# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,588.28 | 3,767.69 | 3,956.08 | 4,153.88 | 4,361.57 | 4,579.65 | 4,808.64
# Buy score: -4.93%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,392.00
# Daylow                              4,291.30
# Exchange                                 CMX
# Fiftydayaverage                     3,639.09
# Lastprice                           4,368.50
# Lastvolume                           130,565
# Marketcap                               None
# ...
