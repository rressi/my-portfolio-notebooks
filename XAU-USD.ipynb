# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,609.86 | 3,790.35 | 3,979.87 | 4,178.86 | 4,387.80 | 4,607.19 | 4,837.55
# Buy score: -0.82%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,358.00
# Daylow                              4,182.20
# Exchange                                 CMX
# Fiftydayaverage                     3,672.89
# Lastprice                           4,189.90
# Lastvolume                             4,705
# Marketcap                               None
# ...
