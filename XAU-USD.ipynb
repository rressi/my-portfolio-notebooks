# %%
import my_portfolio
my_portfolio.run("GC=F")
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,521.43 | 3,697.51 | 3,882.38 | 4,076.50 | 4,280.33 | 4,494.34 | 4,719.06
# Buy score: -3.24%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             4,215.10
# Daylow                              4,157.30
# Exchange                                 CMX
# Fiftydayaverage                     3,623.19
# Lastprice                           4,213.00
# Lastvolume                            75,560
# Marketcap                               None
# ...
