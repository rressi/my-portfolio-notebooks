# %%
import my_portfolio
my_portfolio.run(
    security = "GC=F",  # Gold spot price in USD
    start_date = "2025-01-01",
)
# Out:
# No operations found for ticker 'GC=F'
# Prices: 3,181.77 | 3,340.86 | 3,507.90 | 3,683.30 | 3,867.46 | 4,060.84 | 4,263.88
# Buy score: -2.93%
# No operations found.
#                            GC=F
# Company Name        Gold Dec 25
# Current Price              None
# Forward EPS                None
# Gross Profit (ttm)         None
# Industry                   None
# Revenue (ttm)              None
# Target High Price          None
# Target Low Price           None
# Target Mean Price          None
# Trailing EPS               None
# Website                    None
#                                         GC=F
# Currency                                 USD
# Dayhigh                             3,802.60
# Daylow                              3,791.20
# Exchange                                 CMX
# Fiftydayaverage                     3,447.16
# Lastprice                           3,794.30
# Lastvolume                             9,934
# Marketcap                               None
# ...
