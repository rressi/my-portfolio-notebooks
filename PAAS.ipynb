# %%
import my_portfolio; my_portfolio.run(
    security="PAAS",
    trades_isin="CA6979001089",
)
# Out:
# Prices: 49.33 | 51.80 | 54.39 | 56.59 | 59.42 | 62.39 | 65.51
# Buy score: -4.28%
# Sell score: 5.42%
# Current return: 1,558.92 USD
# Breakeven price: 57.06 USD
# <style type="text/css">
# #T_3f6dc_row12_col0, #T_3f6dc_row12_col1, #T_3f6dc_row12_col2, #T_3f6dc_row12_col3, #T_3f6dc_row12_col4, #T_3f6dc_row12_col5, #T_3f6dc_row12_col6, #T_3f6dc_row12_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_3f6dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f6dc_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_3f6dc_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_3f6dc_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_3f6dc_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_3f6dc_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
