# %%
import my_portfolio; my_portfolio.run(
    security="PAAS",
    trades_isin="CA6979001089",
)
# Out:
# Prices: 47.63 | 50.01 | 52.51 | 53.33 | 56.00 | 58.80 | 61.74
# Buy score: 3.50%
# Sell score: -0.10%
# Current return: -152.88 USD
# Breakeven price: 54.04 USD
# <style type="text/css">
# #T_66751_row7_col0, #T_66751_row7_col1, #T_66751_row7_col2, #T_66751_row7_col3, #T_66751_row7_col4, #T_66751_row7_col5, #T_66751_row7_col6, #T_66751_row7_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_66751">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66751_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_66751_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_66751_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_66751_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_66751_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
