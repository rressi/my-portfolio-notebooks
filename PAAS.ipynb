# %%
import my_portfolio; my_portfolio.run(
    security="PAAS",
    trades_isin="CA6979001089",
)
# Out:
# Prices: 54.00 | 56.70 | 59.54 | 64.62 | 67.85 | 71.24 | 74.80
# Buy score: -4.42%
# Sell score: 1.21%
# Current return: 32.37 USD
# Breakeven price: 65.35 USD
# <style type="text/css">
# #T_ab194_row3_col0, #T_ab194_row3_col1, #T_ab194_row3_col2, #T_ab194_row3_col3, #T_ab194_row3_col4, #T_ab194_row3_col5, #T_ab194_row3_col6, #T_ab194_row3_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_ab194">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab194_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_ab194_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_ab194_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_ab194_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_ab194_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
