# %%
import my_portfolio; my_portfolio.run(
    security="PAAS",
    trades_isin="CA6979001089",
)
# Out:
# Prices: 52.13 | 54.74 | 57.48 | 63.78 | 66.97 | 70.32 | 73.84
# Buy score: 8.23%
# Sell score: -12.58%
# Current return: -8,764.26 USD
# Breakeven price: 64.52 USD
# <style type="text/css">
# #T_60cf9_row5_col0, #T_60cf9_row5_col1, #T_60cf9_row5_col2, #T_60cf9_row5_col3, #T_60cf9_row5_col4, #T_60cf9_row5_col5, #T_60cf9_row5_col6, #T_60cf9_row5_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_60cf9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60cf9_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_60cf9_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_60cf9_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_60cf9_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_60cf9_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
