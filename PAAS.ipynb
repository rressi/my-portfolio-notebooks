# %%
import my_portfolio; my_portfolio.run(
    security="PAAS",
    trades_isin="CA6979001089",
)
# Out:
# Prices: 50.22 | 52.73 | 55.36 | 58.11 | 61.02 | 64.07 | 67.27
# Buy score: 4.01%
# Sell score: -3.82%
# Current return: -1,467.16 USD
# Breakeven price: 58.82 USD
# <style type="text/css">
# #T_126c0_row17_col0, #T_126c0_row17_col1, #T_126c0_row17_col2, #T_126c0_row17_col3, #T_126c0_row17_col4, #T_126c0_row17_col5, #T_126c0_row17_col6, #T_126c0_row17_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_126c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_126c0_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_126c0_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_126c0_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_126c0_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_126c0_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
