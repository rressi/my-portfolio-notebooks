# %%
import my_portfolio; my_portfolio.run(
    security="PAAS",
    trades_isin="CA6979001089",
)
# Out:
# Prices: 53.02 | 55.67 | 58.45 | 64.82 | 68.06 | 71.46 | 75.04
# Buy score: -4.51%
# Sell score: -0.85%
# Current return: -642.17 USD
# Breakeven price: 65.55 USD
# <style type="text/css">
# #T_dec0e_row1_col0, #T_dec0e_row1_col1, #T_dec0e_row1_col2, #T_dec0e_row1_col3, #T_dec0e_row1_col4, #T_dec0e_row1_col5, #T_dec0e_row1_col6, #T_dec0e_row1_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_dec0e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dec0e_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_dec0e_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_dec0e_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_dec0e_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_dec0e_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
