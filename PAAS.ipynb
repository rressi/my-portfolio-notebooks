# %%
import my_portfolio; my_portfolio.run(
    security="PAAS",
    trades_isin="CA6979001089",
)
# Out:
# Prices: 48.42 | 50.84 | 53.38 | 54.59 | 57.32 | 60.19 | 63.20
# Buy score: -4.12%
# Sell score: 7.08%
# Current return: 1,571.22 USD
# Breakeven price: 55.32 USD
# <style type="text/css">
# #T_64067_row9_col0, #T_64067_row9_col1, #T_64067_row9_col2, #T_64067_row9_col3, #T_64067_row9_col4, #T_64067_row9_col5, #T_64067_row9_col6, #T_64067_row9_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_64067">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64067_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_64067_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_64067_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_64067_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_64067_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
