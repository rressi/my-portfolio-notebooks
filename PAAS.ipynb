# %%
import my_portfolio; my_portfolio.run(
    security="PAAS",
    trades_isin="CA6979001089",
)
# Out:
# Prices: 47.59 | 49.96 | 52.46 | 53.61 | 56.30 | 59.11 | 62.07
# Buy score: -2.67%
# Sell score: 5.57%
# Current return: 909.76 USD
# Breakeven price: 54.33 USD
# <style type="text/css">
# #T_5c394_row8_col0, #T_5c394_row8_col1, #T_5c394_row8_col2, #T_5c394_row8_col3, #T_5c394_row8_col4, #T_5c394_row8_col5, #T_5c394_row8_col6, #T_5c394_row8_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_5c394">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c394_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_5c394_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_5c394_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_5c394_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_5c394_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
