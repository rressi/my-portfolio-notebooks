# %%
import my_portfolio; my_portfolio.run(
    security="PAAS",
    trades_isin="CA6979001089",
)
# Out:
# Prices: 54.74 | 57.48 | 60.35 | 63.78 | 66.97 | 70.32 | 73.84
# Buy score: 8.31%
# Sell score: -8.27%
# Current return: -6,014.26 USD
# Breakeven price: 64.52 USD
# <style type="text/css">
# #T_58b20_row5_col0, #T_58b20_row5_col1, #T_58b20_row5_col2, #T_58b20_row5_col3, #T_58b20_row5_col4, #T_58b20_row5_col5, #T_58b20_row5_col6, #T_58b20_row5_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_58b20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58b20_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_58b20_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_58b20_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_58b20_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_58b20_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
