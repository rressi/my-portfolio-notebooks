# %%
import my_portfolio; my_portfolio.run(
    security="PAAS",
    trades_isin="CA6979001089",
)
# Out:
# Prices: 55.67 | 58.45 | 61.38 | 63.78 | 66.97 | 70.32 | 73.84
# Buy score: 2.78%
# Sell score: -1.69%
# Current return: -1,819.26 USD
# Breakeven price: 64.52 USD
# <style type="text/css">
# #T_6a748_row5_col0, #T_6a748_row5_col1, #T_6a748_row5_col2, #T_6a748_row5_col3, #T_6a748_row5_col4, #T_6a748_row5_col5, #T_6a748_row5_col6, #T_6a748_row5_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_6a748">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a748_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_6a748_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_6a748_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_6a748_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_6a748_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
