# %%
import my_portfolio; my_portfolio.run(
    security="PAAS",
    trades_isin="CA6979001089",
)
# Out:
# Prices: 55.51 | 58.28 | 61.19 | 64.62 | 67.85 | 71.24 | 74.80
# Buy score: -2.13%
# Sell score: 1.60%
# Current return: 207.37 USD
# Breakeven price: 65.35 USD
# <style type="text/css">
# #T_21ed3_row3_col0, #T_21ed3_row3_col1, #T_21ed3_row3_col2, #T_21ed3_row3_col3, #T_21ed3_row3_col4, #T_21ed3_row3_col5, #T_21ed3_row3_col6, #T_21ed3_row3_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_21ed3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21ed3_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_21ed3_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_21ed3_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_21ed3_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_21ed3_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
