# %%
import my_portfolio
my_portfolio.run(
    security = "ARM",
)
# Out:
# Prices: 128.71 | 135.14 | 141.90 | 148.99 | 156.44 | 164.27 | 172.48
# Buy score: 4.26%
#                                     ARM
# Company Name               Arm Holdings
# Current Price                    142.91
# Forward EPS                        2.06
# Gross Profit (ttm)        4,003,000,064
# Industry                 Semiconductors
# Revenue (ttm)             4,120,999,936
# Target High Price                 210.0
# Target Low Price                   80.0
# Target Mean Price             152.74242
# Trailing EPS                       0.66
# Website             https://www.arm.com
#                                            ARM
# Currency                                   USD
# Dayhigh                                 145.80
# Daylow                                  142.38
# Exchange                                   NMS
# Fiftydayaverage                         145.45
# Lastprice                               142.91
# Lastvolume                           8,758,400
# ...
