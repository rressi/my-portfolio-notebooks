# %%
import workflow
workflow.run(
    security = "ARM",
)
# Out:
# Prices: 120.76 | 126.80 | 133.14 | 139.7967 | 146.79 | 154.13 | 161.83
# Buy score: -9.63%
#                                     ARM
# Company Name           Arm Holdings plc
# Industry                 Semiconductors
# Revenue (ttm)             4,120,999,936
# Gross Profit (ttm)        4,003,000,064
# Current Price                     154.7
# Target Mean Price             152.74242
# Target High Price                 210.0
# Target Low Price                   80.0
# Trailing EPS                       0.66
# Forward EPS                        2.06
# Website             https://www.arm.com
#                                            ARM
# Currency                                   USD
# Dayhigh                                 158.89
# Daylow                                  152.85
# Exchange                                   NMS
# Fiftydayaverage                         145.48
# Lastprice                               154.70
# Lastvolume                           6,329,361
# ...
