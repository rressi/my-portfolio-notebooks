# %%
import workflow
workflow.run(
    security = "ARM",
)
# Out:
# Prices: 120.62 | 126.65 | 132.99 | 139.6365 | 146.62 | 153.95 | 161.65
# Buy score: -7.30%
#                                     ARM
# Company Name               Arm Holdings
# Current Price                    150.64
# Forward EPS                        2.06
# Gross Profit (ttm)        4,003,000,064
# Industry                 Semiconductors
# Revenue (ttm)             4,120,999,936
# Target High Price                 210.0
# Target Low Price                   80.0
# Target Mean Price             152.74242
# Trailing EPS                       0.66
# Website             https://www.arm.com
#                                            ARM
# Currency                                   USD
# Dayhigh                                 155.55
# Daylow                                  149.02
# Exchange                                   NMS
# Fiftydayaverage                         145.37
# Lastprice                               150.64
# Lastvolume                           3,601,500
# ...
