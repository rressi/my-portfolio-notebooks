# %%
import workflow
workflow.run(
    security = "ARM",
)
# Out:
# Prices: 125.45 | 131.72 | 138.30 | 145.22 | 152.48 | 160.11 | 168.11
# Buy score: -5.61%
#                                     ARM
# Company Name               Arm Holdings
# Current Price                    153.85
# Forward EPS                        2.06
# Gross Profit (ttm)        4,003,000,064
# Industry                 Semiconductors
# Revenue (ttm)             4,120,999,936
# Target High Price                 210.0
# Target Low Price                   80.0
# Target Mean Price             152.74242
# Trailing EPS                       0.66
# Website             https://www.arm.com
#                                            ARM
# Currency                                   USD
# Dayhigh                                 155.80
# Daylow                                  152.35
# Exchange                                   NMS
# Fiftydayaverage                         145.35
# Lastprice                               153.85
# Lastvolume                           2,380,400
# ...
