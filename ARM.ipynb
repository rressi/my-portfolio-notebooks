# %%
import my_portfolio; my_portfolio.run("ARM")
# Out:
# Prices: 129.17 | 135.63 | 142.41 | 144.28 | 151.49 | 159.07 | 167.02
# Buy score: 3.41%
# Sell score: 0.22%
#                                     ARM
# Company Name               Arm Holdings
# Current Price                    144.48
# Forward EPS                        2.06
# Gross Profit (ttm)        4,003,000,064
# Industry                 Semiconductors
# Revenue (ttm)             4,120,999,936
# Target High Price                 210.0
# Target Low Price                   80.0
# Target Mean Price             152.74242
# Trailing EPS                       0.66
# Website             https://www.arm.com
#                                            ARM
# Currency                                   USD
# Dayhigh                                 145.55
# Daylow                                  141.35
# Exchange                                   NMS
# Fiftydayaverage                         145.45
# Lastprice                               144.48
# ...
