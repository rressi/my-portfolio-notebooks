# %%
import my_portfolio; my_portfolio.run("APP")
# Out:
# No operations found for ticker 'APP'
# Prices: 590.42 | 619.94 | 650.94 | 683.48 | 717.66 | 753.54 | 791.22
# Buy score: -4.20%
# No operations found.
#                                          APP
# Company Name                      Applovinon
# Current Price                       713.4556
# Forward EPS                         13.94298
# Gross Profit (ttm)             5,026,252,800
# Industry                Advertising Agencies
# Revenue (ttm)                  6,307,449,856
# Target High Price                      860.0
# Target Low Price                       458.0
# Target Mean Price                   739.9583
# Trailing EPS                            8.47
# Website             https://www.applovin.com
#                                            APP
# Currency                                   USD
# Dayhigh                                 720.99
# Daylow                                  700.00
# Exchange                                   NMS
# ...
