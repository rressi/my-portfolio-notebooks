# %%
import my_portfolio; my_portfolio.run("APP")
# Out:
# No operations found for ticker 'APP'
# Prices: 505.77 | 531.06 | 557.61 | 585.49 | 614.76 | 645.50 | 677.78
# Buy score: 5.64%
# No operations found.
#                                          APP
# Company Name                      Applovinon
# Current Price                         554.22
# Forward EPS                             5.16
# Gross Profit (ttm)             4,510,329,856
# Industry                Advertising Agencies
# Revenue (ttm)                  5,737,590,784
# Target High Price                      850.0
# Target Low Price                       360.0
# Target Mean Price                  634.13043
# Trailing EPS                             7.3
# Website             https://www.applovin.com
#                                            APP
# Currency                                   USD
# Dayhigh                                 568.00
# Daylow                                  547.13
# Exchange                                   NMS
# ...
