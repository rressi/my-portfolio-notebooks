# %%
import my_portfolio; my_portfolio.run("APP")
# Out:
# No operations found for ticker 'APP'
# Prices: 583.27 | 612.43 | 643.05 | 675.21 | 708.97 | 744.41 | 781.64
# Buy score: 21.05%
# No operations found.
#                                          APP
# Company Name                      Applovinon
# Current Price                          587.0
# Forward EPS                             5.16
# Gross Profit (ttm)             4,510,329,856
# Industry                Advertising Agencies
# Revenue (ttm)                  5,737,590,784
# Target High Price                      860.0
# Target Low Price                       250.0
# Target Mean Price                      614.5
# Trailing EPS                            7.25
# Website             https://www.applovin.com
#                                            APP
# Currency                                   USD
# Dayhigh                                 687.00
# Daylow                                  545.00
# Exchange                                   NMS
# ...
