# %%
import my_portfolio; my_portfolio.run("APP")
# Out:
# No operations found for ticker 'APP'
# Prices: 528.00 | 554.40 | 582.12 | 527.28 | 553.65 | 581.33 | 610.39
# Buy score: 0.81%
# No operations found.
#                                          APP
# Company Name                      Applovinon
# Current Price                         520.26
# Forward EPS                             5.16
# Gross Profit (ttm)             5,026,252,800
# Industry                Advertising Agencies
# Revenue (ttm)                  6,307,449,856
# Target High Price                      860.0
# Target Low Price                       394.0
# Target Mean Price                   718.7083
# Trailing EPS                            8.48
# Website             https://www.applovin.com
#                                            APP
# Currency                                   USD
# Dayhigh                                 529.98
# Daylow                                  489.30
# Exchange                                   NMS
# ...
