# %%
import my_portfolio; my_portfolio.run("APP")
# Out:
# No operations found for ticker 'APP'
# Prices: 535.47 | 562.24 | 590.35 | 619.87 | 650.86 | 683.41 | 717.58
# Buy score: 0.02%
# No operations found.
#                                          APP
# Company Name                      Applovinon
# Current Price                       619.7326
# Forward EPS                             5.16
# Gross Profit (ttm)             4,510,329,856
# Industry                Advertising Agencies
# Revenue (ttm)                  5,737,590,784
# Target High Price                      860.0
# Target Low Price                       360.0
# Target Mean Price                     648.75
# Trailing EPS                            7.27
# Website             https://www.applovin.com
#                                            APP
# Currency                                   USD
# Dayhigh                                 633.76
# Daylow                                  617.20
# Exchange                                   NMS
# ...
