# %%
import my_portfolio; my_portfolio.run("APP")
# Out:
# No operations found for ticker 'APP'
# Prices: 535.43 | 562.21 | 590.32 | 619.83 | 650.82 | 683.36 | 717.53
# Buy score: -0.51%
# No operations found.
#                                          APP
# Company Name                      Applovinon
# Current Price                         619.93
# Forward EPS                             5.16
# Gross Profit (ttm)             5,026,252,800
# Industry                Advertising Agencies
# Revenue (ttm)                  6,307,449,856
# Target High Price                      860.0
# Target Low Price                       360.0
# Target Mean Price                   685.7083
# Trailing EPS                            8.49
# Website             https://www.applovin.com
#                                            APP
# Currency                                   USD
# Dayhigh                                 633.59
# Daylow                                  576.41
# Exchange                                   NMS
# ...
