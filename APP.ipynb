# %%
import my_portfolio; my_portfolio.run("APP")
# Out:
# No operations found for ticker 'APP'
# Prices: 390.30 | 409.81 | 430.30 | 451.82 | 474.41 | 498.13 | 523.04
# Buy score: -1.78%
# No operations found.
#                                          APP
# Company Name                      Applovinon
# Current Price                          460.0
# Forward EPS                         21.26488
# Gross Profit (ttm)             4,815,577,088
# Industry                Advertising Agencies
# Revenue (ttm)                  5,480,716,800
# Target High Price                      860.0
# Target Low Price                       340.0
# Target Mean Price                   639.3571
# Trailing EPS                           10.03
# Website             https://www.applovin.com
#                                            APP
# Currency                                   USD
# Dayhigh                                 469.73
# Daylow                                  450.48
# Exchange                                   NMS
# ...
