# %%
import my_portfolio; my_portfolio.run("APP")
# Out:
# No operations found for ticker 'APP'
# Prices: 491.26 | 515.82 | 541.61 | 398.41 | 418.33 | 439.25 | 461.21
# Buy score: 6.43%
# No operations found.
#                                          APP
# Company Name                      Applovinon
# Current Price                         380.62
# Forward EPS                          14.7511
# Gross Profit (ttm)             4,815,577,088
# Industry                Advertising Agencies
# Revenue (ttm)                  5,480,716,800
# Target High Price                      860.0
# Target Low Price                       458.0
# Target Mean Price                   667.6282
# Trailing EPS                           10.05
# Website             https://www.applovin.com
#                                            APP
# Currency                                   USD
# Dayhigh                                 404.00
# Daylow                                  375.70
# Exchange                                   NMS
# ...
