# %%
import my_portfolio; my_portfolio.run("APP")
# Out:
# No operations found for ticker 'APP'
# Prices: 417.15 | 438.01 | 459.91 | 482.91 | 507.05 | 532.40 | 559.02
# Buy score: 0.09%
# No operations found.
#                                          APP
# Company Name                      Applovinon
# Current Price                         482.46
# Forward EPS                         21.92634
# Gross Profit (ttm)             5,447,099,904
# Industry                Advertising Agencies
# Revenue (ttm)                  6,164,192,256
# Target High Price                      860.0
# Target Low Price                       340.0
# Target Mean Price                   644.4667
# Trailing EPS                           11.52
# Website             https://www.applovin.com
#                                            APP
# Currency                                   USD
# Dayhigh                                 503.75
# Daylow                                  478.29
# Exchange                                   NMS
# ...
