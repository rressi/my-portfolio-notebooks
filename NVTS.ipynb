# %%
import my_portfolio
my_portfolio.run(
    security = "NVTS",
)
# Out:
# Prices: 5.44 | 5.72 | 6.00 | 6.30 | 6.62 | 6.95 | 7.29
# Buy score: -12.00%
#                                        NVTS
# Company Name          Navitas Semiconductor
# Current Price                          7.16
# Forward EPS                           -0.21
# Gross Profit (ttm)               18,469,000
# Industry                     Semiconductors
# Revenue (ttm)                    68,167,000
# Target High Price                       8.0
# Target Low Price                        4.4
# Target Mean Price                    6.7375
# Trailing EPS                          -0.68
# Website             https://navitassemi.com
#                                         NVTS
# Currency                                 USD
# Dayhigh                                 7.33
# Daylow                                  6.63
# Exchange                                 NGM
# Fiftydayaverage                         6.71
# Lastprice                               7.16
# ...
