# %%
import my_portfolio; my_portfolio.run("NVTS")
# Out:
# Prices: 12.97 | 13.61 | 14.29 | 17.01 | 17.86 | 18.75 | 19.69
# Buy score: -11.85%
# Sell score: 0.10%
# Current return: -23.32 USD
# Breakeven price: 17.26 USD
# <style type="text/css">
# #T_e016a_row1_col0, #T_e016a_row1_col1, #T_e016a_row1_col2, #T_e016a_row1_col3, #T_e016a_row1_col4, #T_e016a_row1_col5, #T_e016a_row1_col6, #T_e016a_row1_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_e016a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e016a_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_e016a_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_e016a_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_e016a_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_e016a_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
