# %%
import my_portfolio; my_portfolio.run("NVTS")
# Out:
# Prices: 8.59 | 9.02 | 9.47 | 9.03 | 9.48 | 9.95 | 10.45
# Buy score: -6.89%
# Sell score: 3.21%
# Current return: 14.28 USD
# Breakeven price: 9.17 USD
# <style type="text/css">
# #T_d463e_row8_col0, #T_d463e_row8_col1, #T_d463e_row8_col2, #T_d463e_row8_col3, #T_d463e_row8_col4, #T_d463e_row8_col5, #T_d463e_row8_col6, #T_d463e_row8_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_d463e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d463e_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_d463e_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_d463e_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_d463e_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_d463e_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
