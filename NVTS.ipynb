# %%
import workflow
workflow.run(
    security = "NVTS",
)
# Out:
# Prices: 5.19 | 5.45 | 5.72 | 6.01 | 6.31 | 6.62 | 6.95
# Buy score: -10.77%
#                                        NVTS
# Company Name          Navitas Semiconductor
# Current Price                          6.73
# Forward EPS                           -0.21
# Gross Profit (ttm)               18,469,000
# Industry                     Semiconductors
# Revenue (ttm)                    68,167,000
# Target High Price                       8.0
# Target Low Price                        4.4
# Target Mean Price                    6.7375
# Trailing EPS                          -0.66
# Website             https://navitassemi.com
#                                         NVTS
# Currency                                 USD
# Dayhigh                                 6.92
# Daylow                                  6.46
# Exchange                                 NGM
# Fiftydayaverage                         6.69
# Lastprice                               6.73
# ...
