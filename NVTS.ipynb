# %%
import my_portfolio
my_portfolio.run(
    security = "NVTS",
)
# Out:
# Prices: 5.31 | 5.57 | 5.85 | 6.15 | 6.45 | 6.78 | 7.11
# Buy score: -12.33%
#                                        NVTS
# Company Name          Navitas Semiconductor
# Current Price                          7.01
# Forward EPS                           -0.21
# Gross Profit (ttm)               18,469,000
# Industry                     Semiconductors
# Revenue (ttm)                    68,167,000
# Target High Price                       8.0
# Target Low Price                        4.4
# Target Mean Price                    6.7375
# Trailing EPS                          -0.66
# Website             https://navitassemi.com
#                                         NVTS
# Currency                                 USD
# Dayhigh                                 7.16
# Daylow                                  6.52
# Exchange                                 NGM
# Fiftydayaverage                         6.71
# Lastprice                               7.01
# ...
