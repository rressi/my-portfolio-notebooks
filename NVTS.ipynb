# %%
import workflow
workflow.run(
    security = "NVTS",
)
# Out:
# Prices: 5.20 | 5.46 | 5.73 | 6.02 | 6.32 | 6.63 | 6.97
# Buy score: -1.51%
#                                        NVTS
# Company Name          Navitas Semiconductor
# Current Price                          6.11
# Forward EPS                           -0.21
# Gross Profit (ttm)               18,469,000
# Industry                     Semiconductors
# Revenue (ttm)                    68,167,000
# Target High Price                       8.0
# Target Low Price                        4.4
# Target Mean Price                    6.7375
# Trailing EPS                          -0.65
# Website             https://navitassemi.com
#                                         NVTS
# Currency                                 USD
# Dayhigh                                 6.30
# Daylow                                  5.97
# Exchange                                 NGM
# Fiftydayaverage                         6.70
# Lastprice                               6.11
# ...
