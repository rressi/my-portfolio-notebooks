# %%
import my_portfolio; my_portfolio.run("NVTS")
# Out:
# Prices: 7.98 | 8.37 | 8.79 | 8.62 | 9.05 | 9.50 | 9.98
# Buy score: 1.17%
# Sell score: 5.74%
# Current return: 17.45 USD
# Breakeven price: 8.77 USD
# <style type="text/css">
# #T_a9ade_row7_col0, #T_a9ade_row7_col1, #T_a9ade_row7_col2, #T_a9ade_row7_col3, #T_a9ade_row7_col4, #T_a9ade_row7_col5, #T_a9ade_row7_col6, #T_a9ade_row7_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_a9ade">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9ade_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_a9ade_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_a9ade_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_a9ade_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_a9ade_level0_col4" class="col_heading level0 col4" >Avg. price</th>
#       <th id="T_a9ade_level0_col5" class="col_heading level0 col5" >Inv. Cost</th>
# ...
