# %%
import workflow
workflow.run(
    security = "NVTS",
)
# Out:
# Prices: 5.28 | 5.54 | 5.82 | 6.1120 | 6.42 | 6.74 | 7.08
# Buy score: 0.53%
#                                        NVTS
# Company Name          Navitas Semiconductor
# Industry                     Semiconductors
# Revenue (ttm)                    68,167,000
# Gross Profit (ttm)               18,469,000
# Current Price                          6.08
# Target Mean Price                    6.7375
# Target High Price                       8.0
# Target Low Price                        4.4
# Trailing EPS                          -0.71
# Forward EPS                           -0.21
# Website             https://navitassemi.com
#                                         NVTS
# Currency                                 USD
# Dayhigh                                 6.20
# Daylow                                  5.66
# Exchange                                 NGM
# Fiftydayaverage                         6.71
# Lastprice                               6.08
# ...
