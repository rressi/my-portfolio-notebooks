# %%
import my_portfolio
my_portfolio.run(
    security = "NVTS",
)
# Out:
# Prices: 5.54 | 5.82 | 6.11 | 6.41 | 6.73 | 7.07 | 7.42
# Buy score: -6.79%
# No operations found.
#                                        NVTS
# Company Name          Navitas Semiconductor
# Current Price                          6.88
# Forward EPS                           -0.21
# Gross Profit (ttm)               18,469,000
# Industry                     Semiconductors
# Revenue (ttm)                    68,167,000
# Target High Price                       8.0
# Target Low Price                        4.4
# Target Mean Price                    6.7375
# Trailing EPS                          -0.66
# Website             https://navitassemi.com
#                                         NVTS
# Currency                                 USD
# Dayhigh                                 7.17
# Daylow                                  6.72
# Exchange                                 NGM
# Fiftydayaverage                         6.74
# Lastprice                               6.88
# ...
