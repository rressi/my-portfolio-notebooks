# %%
import workflow
workflow.run(
    security = "NVTS",
)
# Out:
# Prices: 5.10 | 5.36 | 5.63 | 5.9080 | 6.20 | 6.51 | 6.84
# Buy score: -2.83%
#                                                  NVTS
# Company Name        Navitas Semiconductor Corporation
# Industry                               Semiconductors
# Revenue (ttm)                              68,167,000
# Gross Profit (ttm)                         18,469,000
# Current Price                                    6.08
# Target Mean Price                              6.7375
# Target High Price                                 8.0
# Target Low Price                                  4.4
# Trailing EPS                                    -0.66
# Forward EPS                                     -0.21
# Website                       https://navitassemi.com
#                                         NVTS
# Currency                                 USD
# Dayhigh                                 6.20
# Daylow                                  5.66
# Exchange                                 NGM
# ...
