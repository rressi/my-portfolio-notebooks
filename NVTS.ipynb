# %%
import my_portfolio; my_portfolio.run("NVTS")
# Out:
# Prices: 11.17 | 11.73 | 12.32 | 13.07 | 13.73 | 14.42 | 15.14
# Buy score: 5.69%
# Sell score: -6.42%
# Current return: -151.81 USD
# Breakeven price: 13.25 USD
# <style type="text/css">
# #T_4cc78_row5_col0, #T_4cc78_row5_col1, #T_4cc78_row5_col2, #T_4cc78_row5_col3, #T_4cc78_row5_col4, #T_4cc78_row5_col5, #T_4cc78_row5_col6, #T_4cc78_row5_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_4cc78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4cc78_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_4cc78_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_4cc78_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_4cc78_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_4cc78_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
