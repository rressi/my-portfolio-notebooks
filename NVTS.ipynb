# %%
import my_portfolio; my_portfolio.run("NVTS")
# Out:
# Prices: 11.38 | 11.95 | 12.54 | 12.95 | 13.60 | 14.28 | 14.99
# Buy score: 1.40%
# Sell score: 0.31%
# Current return: -9.91 USD
# Breakeven price: 13.12 USD
# <style type="text/css">
# #T_33162_row4_col0, #T_33162_row4_col1, #T_33162_row4_col2, #T_33162_row4_col3, #T_33162_row4_col4, #T_33162_row4_col5, #T_33162_row4_col6, #T_33162_row4_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_33162">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33162_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_33162_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_33162_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_33162_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_33162_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
