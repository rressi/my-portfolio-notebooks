# %%
import my_portfolio; my_portfolio.run("NVTS")
# Out:
# No operations found for ticker 'NVTS'
# Prices: 5.70 | 5.99 | 6.29 | 6.60 | 6.93 | 7.28 | 7.64
# Buy score: 2.87%
# No operations found.
#                                        NVTS
# Company Name          Navitas Semiconductor
# Current Price                          6.43
# Forward EPS                           -0.21
# Gross Profit (ttm)               18,469,000
# Industry                     Semiconductors
# Revenue (ttm)                    68,167,000
# Target High Price                       8.0
# Target Low Price                        4.4
# Target Mean Price                    6.7375
# Trailing EPS                          -0.66
# Website             https://navitassemi.com
#                                         NVTS
# Currency                                 USD
# Dayhigh                                 6.48
# Daylow                                  6.22
# Exchange                                 NGM
# Fiftydayaverage                         6.78
# ...
