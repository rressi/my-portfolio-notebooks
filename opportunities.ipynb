# %%
import opportunities
opportunities.find_buy_opportunities(
    sma_lenght=5,
)
# Out:
#    Ticker       Company   Close     SMA  % from SMA
# 5     ARM  Arm Holdings  146.54  151.65       -3.37
# 7    AVGO      Broadcom  345.35  355.10       -2.74
# 29   ORCL      Oracleon  296.62  299.80       -1.06
# ARM - Arm Holdings - buy score: 3.37%
# Prices: 131.00 | 137.55 | 144.43 | 151.65 | 159.23 | 167.20 | 175.56
# Buy score: 3.49%
# AVGO - Broadcom - buy score: 2.74%
# Prices: 306.75 | 322.08 | 338.19 | 355.10 | 372.85 | 391.49 | 411.07
# Buy score: 2.82%
# ORCL - Oracleon - buy score: 1.06%
# Prices: 258.98 | 271.93 | 285.52 | 299.80 | 314.79 | 330.53 | 347.06
# Buy score: 1.07%
