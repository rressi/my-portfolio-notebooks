# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                 Company     Close       SMA  % from SMA
# 28      NOW              ServiceNow    118.01    126.50       -6.71
# 33     PLTR   Palantir Technologies    149.22    158.32       -5.75
# 24     MSFT             Microsofton    434.05    460.01       -5.64
# 16  ETH-USD            Ethereum USD   2739.60   2902.62       -5.62
# 44  XRP-USD                 XRP USD      1.76      1.86       -5.30
# 27     NBIS       Nebius Group N.V.     90.15     94.97       -5.07
# 9   BTC-USD             Bitcoin USD  83041.64  86831.50       -4.36
# 32     ORCL                Oracleon    165.49    172.93       -4.30
# 11     COIN         Coinbase Global    197.70    206.12       -4.09
# 14     CRWV               CoreWeave     98.35    102.21       -3.78
# 12      CRM              Salesforce    214.60    222.91       -3.73
# 5       ARM            Arm Holdings    107.01    111.00       -3.60
# 42      UNH      UnitedHealth Group    292.24    302.58       -3.42
# ...
