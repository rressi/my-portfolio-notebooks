# %%
import opportunities
opportunities.find_buy_opportunities()
# Out:
#    Ticker                         Company   Close    MA20  % from MA20
# 34    TXN  Texas Instruments Incorporated  184.35  196.00        -5.95
# 2     AMD          Advanced Micro Devices  155.67  164.30        -5.25
# 21   MSFT                       Microsoft  501.01  506.16        -1.02
# TXN - Texas Instruments Incorporated - buy score: 5.95%
# AMD - Advanced Micro Devices - buy score: 5.25%
# MSFT - Microsoft - buy score: 1.02%
