# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company     Close       SMA  % from SMA
# 8      AVTR                          Avantor      9.20     10.07       -8.68
# 15     CSCO                    Cisco Systems     76.85     82.09       -6.39
# 18      IBM  International Business Machines    262.38    276.23       -5.01
# 0      AAPL                            Apple    255.78    268.26       -4.65
# 37     SMCI             Super Micro Computer     30.54     31.97       -4.48
# 30     NVTS            Navitas Semiconductor      8.30      8.69       -4.47
# 10     COHR                         Coherent    217.23    225.57       -3.70
# 7      AVGO                         Broadcom    325.17    336.70       -3.42
# 22     META                   Meta Platforms    639.77    661.24       -3.25
# 33     PLTR            Palantir Technologies    131.41    135.73       -3.18
# 31     NFLX                          Netflix     76.87     79.21       -2.95
# ...
