# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company      Close        SMA  % from SMA
# 30     NVTS            Navitas Semiconductor      10.46      12.46      -16.05
# 16  ETH-USD                     Ethereum USD    3221.82    3691.29      -12.72
# 14     CRWV                        CoreWeave     115.75     129.35      -10.52
# 44  XRP-USD                          XRP USD       2.15       2.40      -10.29
# 27     NBIS                Nebius Group N.V.     110.54     122.22       -9.56
# 11     COIN                  Coinbase Global     307.32     331.73       -7.36
# 23     MPWR         Monolithic Power Systems     957.87    1029.69       -6.97
# 9   BTC-USD                      Bitcoin USD  100332.51  107427.97       -6.60
# 19     INTC                          Intelon      37.03      39.60       -6.50
# 37     SMCI             Super Micro Computer      47.40      50.63       -6.39
# 22     META                   Meta Platforms     627.32     666.30       -5.85
# ...
