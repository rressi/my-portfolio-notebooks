# %%
import opportunities
opportunities.find_buy_opportunities(
    sma_lenght=5,
)
# Out:
#    Ticker          Company   Close     SMA  % from SMA
# 7    AVGO         Broadcom  346.17  357.95       -3.29
# 27   NVDA         NVIDIAon  170.29  175.58       -3.01
# 32   RACE     Ferrari N.V.  470.03  477.33       -1.53
# 8    AVTR          Avantor   12.40   12.56       -1.31
# 11   COIN  Coinbase Global  320.56  324.50       -1.21
# 4    ANET  Arista Networks  142.84  144.57       -1.20
# AVGO - Broadcom - buy score: 3.29%
# Prices: 309.21 | 324.67 | 340.91 | 357.95 | 375.85 | 394.64 | 414.37
# Buy score: 3.40%
# NVDA - NVIDIAon - buy score: 3.01%
# Prices: 151.67 | 159.26 | 167.22 | 175.58 | 184.36 | 193.58 | 203.26
# Buy score: 3.11%
# RACE - Ferrari N.V. - buy score: 1.53%
# Prices: 412.79 | 433.43 | 455.11 | 477.33 | 501.20 | 526.26 | 552.57
# Buy score: 1.55%
# AVTR - Avantor - buy score: 1.31%
# Prices: 11.19 | 11.75 | 12.34 | 12.56 | 13.19 | 13.85 | 14.54
# Buy score: 1.32%
# COIN - Coinbase Global - buy score: 1.21%
# ...
