# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#    Ticker                 Company   Close     SMA  % from SMA
# 39   TSLA                   Tesla  433.83  445.54       -2.63
# 0    AAPL                   Apple  262.91  269.22       -2.35
# 1    ADBE                   Adobe  334.43  340.36       -1.74
# 2     AMD  Advanced Micro Devices  213.82  217.58       -1.72
# 31   NFLX                 Netflix   90.76   92.15       -1.51
# TSLA - Tesla - buy score: 2.63%
# Prices: 384.87 | 404.12 | 424.32 | 445.54 | 467.82 | 491.21 | 515.77
# Buy score: 2.70%
# AAPL - Apple - buy score: 2.35%
# Prices: 235.84 | 247.63 | 260.01 | 269.22 | 282.68 | 296.81 | 311.65
# Buy score: 2.41%
# ADBE - Adobe - buy score: 1.74%
# Prices: 294.00 | 308.70 | 324.13 | 340.34 | 357.36 | 375.22 | 393.99
# Buy score: 1.79%
# AMD - Advanced Micro Devices - buy score: 1.72%
# Prices: 196.11 | 205.91 | 216.21 | 217.55 | 228.42 | 239.85 | 251.84
# Buy score: 1.81%
# NFLX - Netflix - buy score: 1.51%
# Prices: 88.96 | 93.41 | 98.08 | 92.15 | 96.76 | 101.60 | 106.68
# ...
