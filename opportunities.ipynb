# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker              Company    Close      SMA  % from SMA
# 36     RIVN    Rivian Automotive    15.02    16.07       -6.52
# 22     META       Meta Platforms   608.75   647.95       -6.05
# 29     NVDA             NVIDIAon   198.45   207.41       -4.32
# 20     KLAC                KLAon  1726.26  1800.36       -4.12
# 24     MSFT          Microsofton   414.44   420.15       -1.36
# 45  ZGLD.SW  Swisscanto GOLD ETF  1055.00  1068.44       -1.26
# RIVN - Rivian Automotive - buy score: 6.52%
# Prices: 13.88 | 14.57 | 15.30 | 16.07 | 16.87 | 17.71 | 18.60
# Buy score: 7.03%
# META - Meta Platforms - buy score: 6.05%
# Prices: 559.72 | 587.71 | 617.09 | 647.95 | 680.35 | 714.36 | 750.08
# Buy score: 6.71%
# NVDA - NVIDIAon - buy score: 4.32%
# Prices: 179.17 | 188.13 | 197.53 | 207.41 | 217.78 | 228.67 | 240.10
# Buy score: 5.35%
# KLAC - KLAon - buy score: 4.12%
# Prices: 1,555.22 | 1,632.98 | 1,714.63 | 1,800.36 | 1,890.38 | 1,984.89 | 2,084.14
# Buy score: 3.24%
# ...
