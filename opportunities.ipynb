# %%
import opportunities
opportunities.find_buy_opportunities(
    sma_lenght=5,
)
# Out:
#      Ticker                Company    Close      SMA  % from SMA
# 16  ETH-EUR           Ethereum EUR  3802.30  3915.62       -2.89
# 4      ANET        Arista Networks   142.16   146.15       -2.73
# 37      TXN      Texas Instruments   177.63   181.36       -2.06
# 28     NVTS  Navitas Semiconductor     5.89     5.98       -1.47
# 39  XRP-EUR                XRP EUR     2.56     2.60       -1.47
# 12      CRM             Salesforce   239.31   242.69       -1.39
# 27     NVDA               NVIDIAon   174.88   176.99       -1.19
# ETH-EUR - Ethereum EUR - buy score: 2.89%
# Prices: 3,382.46 | 3,551.59 | 3,729.16 | 3915.62 | 4,111.40 | 4,316.97 | 4,532.82
# Buy score: 2.98%
# ANET - Arista Networks - buy score: 2.73%
# Prices: 126.25 | 132.56 | 139.19 | 146.15 | 153.46 | 161.13 | 169.18
# Buy score: 2.81%
# TXN - Texas Instruments - buy score: 2.06%
# Prices: 156.66 | 164.50 | 172.72 | 181.36 | 190.43 | 199.95 | 209.94
# Buy score: 2.10%
# ...
