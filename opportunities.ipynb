# %%
import my_portfolio
my_portfolio.find_buy_opportunities(
    sma_lenght=5,
)
# Out:
#      Ticker                 Company   Close     SMA  % from SMA
# 5       ARM            Arm Holdings  142.91  150.11       -4.79
# 7      AVGO                Broadcom  344.94  352.11       -2.04
# 39  XRP-EUR                 XRP EUR    2.53    2.57       -1.52
# 2       AMD  Advanced Micro Devices  157.39  159.22       -1.15
# ARM - Arm Holdings - buy score: 4.79%
# Prices: 129.67 | 136.15 | 142.96 | 150.11 | 157.61 | 165.49 | 173.77
# Buy score: 4.97%
# AVGO - Broadcom - buy score: 2.04%
# Prices: 304.17 | 319.37 | 335.34 | 352.11 | 369.72 | 388.20 | 407.61
# Buy score: 1.92%
# XRP-EUR - XRP EUR - buy score: 1.52%
# Prices: 2.22 | 2.33 | 2.44 | 2.57 | 2.69 | 2.83 | 2.97
# Buy score: 1.54%
# AMD - Advanced Micro Devices - buy score: 1.15%
# Prices: 138.67 | 145.60 | 152.88 | 159.22 | 167.18 | 175.54 | 184.31
# Buy score: 1.41%
