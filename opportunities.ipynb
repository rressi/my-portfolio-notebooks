# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company      Close        SMA  % from SMA
# 22     META                   Meta Platforms     637.71     691.13       -7.73
# 44  XRP-USD                          XRP USD       2.27       2.45       -7.49
# 16  ETH-USD                     Ethereum USD    3577.73    3802.89       -5.92
# 30     NVTS            Navitas Semiconductor      12.23      12.93       -5.45
# 14     CRWV                        CoreWeave     126.66     133.23       -4.93
# 8      AVTR                          Avantor      11.65      12.24       -4.82
# 23     MPWR         Monolithic Power Systems    1005.75    1055.75       -4.74
# 42      UNH               UnitedHealth Group     333.37     348.56       -4.36
# 32     ORCL                         Oracleon     257.15     266.56       -3.53
# 27     NBIS                Nebius Group N.V.     120.31     124.45       -3.33
# 11     COIN                  Coinbase Global     331.14     341.45       -3.02
# ...
