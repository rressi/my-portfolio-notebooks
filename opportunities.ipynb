# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                Company    Close      SMA  % from SMA
# 14     CRWV              CoreWeave    88.94    99.31      -10.44
# 20     KLAC                  KLAon  1410.45  1553.33       -9.20
# 30     NVTS  Navitas Semiconductor     8.62     9.28       -7.13
# 45  ZGLD.SW    Swisscanto GOLD ETF  1078.60  1155.00       -6.61
# 11     COIN        Coinbase Global   187.86   200.41       -6.26
# 24     MSFT            Microsofton   423.37   449.87       -5.89
# 27     NBIS      Nebius Group N.V.    88.16    93.31       -5.52
# 32     ORCL               Oracleon   160.06   168.27       -4.88
# 4      ANET        Arista Networks   138.37   145.02       -4.59
# 33     PLTR  Palantir Technologies   147.76   153.85       -3.96
# 16  ETH-USD           Ethereum USD  2323.60  2416.68       -3.85
# 28      NOW             ServiceNow   118.00   122.63       -3.78
# 12      CRM             Salesforce   210.81   218.73       -3.62
# ...
