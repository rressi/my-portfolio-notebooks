# %%
import opportunities
opportunities.find_buy_opportunities(
    sma_lenght=5,
)
# Out:
#      Ticker            Company    Close      SMA  % from SMA
# 16  ETH-EUR       Ethereum EUR  3770.52  3909.27       -3.55
# 4      ANET    Arista Networks   141.21   145.96       -3.26
# 37      TXN  Texas Instruments   178.13   181.46       -1.83
# 39  XRP-EUR            XRP EUR     2.56     2.60       -1.46
# 12      CRM         Salesforce   239.63   242.75       -1.29
# 27     NVDA           NVIDIAon   174.91   177.00       -1.18
# ETH-EUR - Ethereum EUR - buy score: 3.55%
# Prices: 3,376.97 | 3,545.82 | 3,723.11 | 3909.27 | 4,104.73 | 4,309.97 | 4,525.46
# Buy score: 3.68%
# ANET - Arista Networks - buy score: 3.26%
# Prices: 126.08 | 132.39 | 139.01 | 145.96 | 153.26 | 160.92 | 168.96
# Buy score: 3.36%
# TXN - Texas Instruments - buy score: 1.83%
# Prices: 156.75 | 164.59 | 172.82 | 181.46 | 190.53 | 200.06 | 210.06
# Buy score: 1.87%
# XRP-EUR - XRP EUR - buy score: 1.46%
# Prices: 2.25 | 2.36 | 2.48 | 2.60 | 2.73 | 2.87 | 3.01
# Buy score: 1.48%
# ...
