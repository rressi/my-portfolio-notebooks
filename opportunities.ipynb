# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company      Close        SMA  % from SMA
# 27     NBIS                Nebius Group N.V.     113.44     125.18       -9.38
# 31     ORCL                         Oracleon     291.31     302.99       -3.85
# 36     SMCI             Super Micro Computer      52.18      53.56       -2.58
# 5       ARM                     Arm Holdings     165.61     169.51       -2.30
# 9   BTC-USD                      Bitcoin USD  106982.51  109107.63       -1.95
# 39      TSM  Taiwan Semiconductor Manufactur     295.08     299.69       -1.54
# 16  ETH-USD                     Ethereum USD    3886.07    3945.25       -1.50
# 3      AMZN                       Amazon.com     213.04     215.91       -1.33
# 14     CRWV                        CoreWeave     136.87     138.71       -1.32
# 11     COIN                  Coinbase Global     336.02     340.22       -1.24
# 13     CRWD             CrowdStrike Holdings     484.65     490.69       -1.23
# ...
