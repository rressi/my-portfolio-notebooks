# %%
import opportunities
opportunities.find_buy_opportunities()
# Out:
#    Ticker            Company   Close    MA20  % from MA20
# 37    TXN  Texas Instruments  178.20  194.63        -8.44
# 8    AVTR            Avantor   12.39   12.99        -4.59
# 12    CRM         Salesforce  242.52  248.28        -2.32
# 1    ADBE              Adobe  347.10  353.48        -1.81
# TXN - Texas Instruments - buy score: 8.44%
# Prices: 168.13 | 176.53 | 185.36 | 194.63 | 204.36 | 214.58 | 225.31
# Buy score: 9.22%
# AVTR - Avantor - buy score: 4.59%
# Prices: 11.22 | 11.78 | 12.37 | 12.99 | 13.64 | 14.32 | 15.03
# Buy score: 4.81%
# CRM - Salesforce - buy score: 2.32%
# Prices: 214.47 | 225.20 | 236.46 | 248.28 | 260.70 | 273.73 | 287.42
# Buy score: 2.38%
# ADBE - Adobe - buy score: 1.81%
# Prices: 305.35 | 320.62 | 336.65 | 353.48 | 371.16 | 389.71 | 409.20
# Buy score: 1.84%
