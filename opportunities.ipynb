# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company     Close       SMA  % from SMA
# 30     NVTS            Navitas Semiconductor     18.41     20.58      -10.53
# 14     CRWV                        CoreWeave     95.75    106.47      -10.07
# 10     COHR                         Coherent    347.41    380.27       -8.64
# 27     NBIS                Nebius Group N.V.    190.42    207.73       -8.33
# 38      STX  Seagate Technology Holdings PLC    710.26    773.74       -8.20
# 23     MPWR         Monolithic Power Systems   1437.57   1547.65       -7.11
# 26       MU                Micron Technology    683.72    733.91       -6.84
# 43      WDC                Western Digitalon    442.95    473.38       -6.43
# 39     TSLA                            Tesla    397.65    423.69       -6.15
# 36     RIVN                Rivian Automotive     12.93     13.77       -6.11
# 21     LRCX                   Lam Researchon    267.77    285.01       -6.05
# ...
