# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                Company     Close       SMA  % from SMA
# 36     RIVN      Rivian Automotive     16.67     17.85       -6.59
# 28      NOW             ServiceNow    127.31    134.78       -5.55
# 12      CRM             Salesforce    227.11    240.13       -5.42
# 1      ADBE                  Adobe    296.12    308.45       -4.00
# 35     RACE           Ferrari N.V.    345.23    358.10       -3.59
# 33     PLTR  Palantir Technologies    170.96    176.96       -3.39
# 44  XRP-USD                XRP USD      1.97      2.04       -3.00
# 34     QCOM               QUALCOMM    159.42    163.98       -2.78
# 32     ORCL               Oracleon    191.09    196.30       -2.66
# 16  ETH-USD           Ethereum USD   3194.76   3279.47       -2.58
# 11     COIN        Coinbase Global    241.15    246.39       -2.13
# 9   BTC-USD            Bitcoin USD  92753.41  94512.81       -1.86
# 13     CRWD   CrowdStrike Holdings    453.88    460.92       -1.53
# ...
