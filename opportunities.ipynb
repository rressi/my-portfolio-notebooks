# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                   Company    Close      SMA  % from SMA
# 30     NVTS     Navitas Semiconductor    26.60    29.01       -8.29
# 19     INTC                   Intelon   114.68   120.14       -4.54
# 10     COHR                  Coherent   361.47   375.50       -3.74
# 23     MPWR  Monolithic Power Systems  1566.21  1614.47       -2.99
# 41      TXN         Texas Instruments   305.68   314.64       -2.85
# 17    GOOGL                  Alphabet   380.34   386.23       -1.52
# 44  XRP-USD                   XRP USD     1.30     1.32       -1.46
# 16  ETH-USD              Ethereum USD  1976.51  2003.97       -1.37
# 31     NFLX                   Netflix    86.02    87.20       -1.36
# 29     NVDA                  NVIDIAon   211.14   213.64       -1.17
# 20     KLAC                     KLAon  1921.71  1941.26       -1.01
# NVTS - Navitas Semiconductor - buy score: 8.29%
# Prices: 25.06 | 26.31 | 27.62 | 29.01 | 30.46 | 31.98 | 33.58
# Buy score: 9.13%
# ...
