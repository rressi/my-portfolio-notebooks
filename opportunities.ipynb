# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                Company     Close       SMA  % from SMA
# 19     INTC                Intelon    107.93    114.92       -6.08
# 9   BTC-USD            Bitcoin USD  67008.03  70473.20       -4.92
# 17    GOOGL               Alphabet    361.85    379.50       -4.65
# 30     NVTS  Navitas Semiconductor     25.86     26.94       -4.02
# 16  ETH-USD           Ethereum USD   1873.90   1951.73       -3.99
# 3      AMZN             Amazon.com    256.52    266.85       -3.87
# 22     META         Meta Platforms    597.63    620.23       -3.64
# 11     COIN        Coinbase Global    173.99    180.33       -3.52
# 44  XRP-USD                XRP USD      1.24      1.28       -3.33
# 31     NFLX                Netflix     83.33     85.78       -2.86
# 39     TSLA                  Tesla    423.74    431.57       -1.82
# INTC - Intelon - buy score: 6.08%
# Prices: 99.27 | 104.24 | 109.45 | 114.92 | 120.67 | 126.70 | 133.03
# Buy score: 3.80%
# BTC-USD - Bitcoin USD - buy score: 4.92%
# ...
