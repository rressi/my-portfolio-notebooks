# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company     Close       SMA  % from SMA
# 28      NOW                       ServiceNow    115.29    129.23      -10.79
# 24     MSFT                      Microsofton    422.96    464.28       -8.90
# 42      UNH               UnitedHealth Group    289.82    314.89       -7.96
# 33     PLTR            Palantir Technologies    150.18    162.06       -7.33
# 11     COIN                  Coinbase Global    195.58    209.25       -6.53
# 12      CRM                       Salesforce    211.60    225.11       -6.00
# 8      AVTR                          Avantor     10.74     11.41       -5.80
# 32     ORCL                         Oracleon    164.24    174.31       -5.78
# 5       ARM                     Arm Holdings    106.07    112.34       -5.58
# 30     NVTS            Navitas Semiconductor      9.17      9.69       -5.41
# 13     CRWD             CrowdStrike Holdings    436.11    460.56       -5.31
# ...
