# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company   Close     SMA  % from SMA
# 27     NBIS                Nebius Group N.V.  106.03  115.47       -8.17
# 14     CRWV                        CoreWeave  125.20  134.02       -6.58
# 32     ORCL                         Oracleon  279.85  292.99       -4.49
# 25     MRVL               Marvell Technology   84.63   87.11       -2.84
# 45  ZGLD.SW              Swisscanto GOLD ETF  974.00  999.08       -2.51
# 38      STX  Seagate Technology Holdings PLC  215.22  220.09       -2.21
# 43      WDC                Western Digitalon  120.79  122.98       -1.78
# 7      AVGO                         Broadcom  344.12  349.63       -1.58
# 17    GOOGL                         Alphabet  248.77  252.22       -1.37
# NBIS - Nebius Group N.V. - buy score: 8.17%
# Prices: 99.75 | 104.74 | 109.98 | 115.48 | 121.25 | 127.31 | 133.68
# Buy score: 8.86%
# CRWV - CoreWeave - buy score: 6.58%
# No daily data found for CRWV, cannot compute SMA-150
# ...
