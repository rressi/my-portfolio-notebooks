# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company      Close        SMA  % from SMA
# 34     RACE                     Ferrari N.V.     378.72     430.38      -12.00
# 11     COIN                  Coinbase Global     356.99     372.81       -4.24
# 4      ANET                  Arista Networks     147.45     152.49       -3.30
# 18      IBM  International Business Machines     277.22     285.32       -2.84
# 2       AMD           Advanced Micro Devices     216.42     222.26       -2.63
# 15     CSCO                    Cisco Systems      67.46      68.94       -2.14
# 36     SMCI             Super Micro Computer      54.75      55.87       -2.00
# 32     PLTR            Palantir Technologies     177.21     180.77       -1.97
# 0      AAPL                            Apple     247.66     252.30       -1.84
# 20     KLAC                            KLAon    1025.00    1041.71       -1.60
# 1      ADBE                            Adobe     339.32     344.28       -1.44
# ...
