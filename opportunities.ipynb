# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company    Close      SMA  % from SMA
# 37      STX  Seagate Technology Holdings PLC   225.01   246.44       -8.70
# 42      WDC                Western Digitalon   119.93   127.67       -6.07
# 14     CRWV                        CoreWeave   128.83   134.50       -4.22
# 27     NBIS                Nebius Group N.V.   117.70   122.42       -3.86
# 35     RIVN                Rivian Automotive    13.26    13.71       -3.28
# 21     LRCX                   Lam Researchon   140.35   145.02       -3.22
# 20     KLAC                            KLAon  1084.74  1118.83       -3.05
# 43  XRP-EUR                          XRP EUR     2.46     2.53       -2.89
# 8      AVTR                          Avantor    13.47    13.86       -2.80
# 38     TSLA                            Tesla   433.09   442.33       -2.09
# 6      ASML                ASML Holding N.V.  1002.30  1022.25       -1.95
# ...
