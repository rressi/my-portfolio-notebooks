# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company     Close       SMA  % from SMA
# 10     COHR                         Coherent    173.51    187.99       -7.70
# 38      STX  Seagate Technology Holdings PLC    280.04    299.22       -6.41
# 4      ANET                  Arista Networks    123.25    131.34       -6.16
# 43      WDC                Western Digitalon    185.04    195.98       -5.58
# 2       AMD           Advanced Micro Devices    203.71    214.53       -5.04
# 25     MRVL               Marvell Technology     83.16     87.13       -4.56
# 7      AVGO                         Broadcom    330.74    341.81       -3.24
# 44  XRP-USD                          XRP USD      2.14      2.21       -3.22
# 0      AAPL                            Apple    256.56    263.50       -2.64
# 16  ETH-USD                     Ethereum USD   3112.68   3188.46       -2.38
# 5       ARM                     Arm Holdings    112.66    114.94       -1.99
# ...
