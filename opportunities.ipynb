# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company     Close       SMA  % from SMA
# 32     ORCL                         Oracleon    175.05    185.90       -5.84
# 16  ETH-USD                     Ethereum USD   2988.30   3140.11       -4.83
# 11     COIN                  Coinbase Global    228.99    238.60       -4.03
# 31     NFLX                          Netflix     84.19     87.21       -3.46
# 12      CRM                       Salesforce    221.73    228.40       -2.92
# 27     NBIS                Nebius Group N.V.    100.10    102.80       -2.62
# 7      AVGO                         Broadcom    331.37    339.72       -2.46
# 33     PLTR            Palantir Technologies    168.57    172.71       -2.40
# 14     CRWV                        CoreWeave     92.67     94.79       -2.23
# 28      NOW                       ServiceNow    126.06    128.91       -2.21
# 35     RACE                     Ferrari N.V.    338.03    345.60       -2.19
# ...
