# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company     Close       SMA  % from SMA
# 5       ARM                     Arm Holdings    113.51    120.89       -6.10
# 30     NVTS            Navitas Semiconductor      7.37      7.83       -5.83
# 44  XRP-USD                          XRP USD      1.78      1.89       -5.72
# 37     SMCI             Super Micro Computer     29.37     30.91       -4.99
# 11     COIN                  Coinbase Global    239.20    250.78       -4.62
# 14     CRWV                        CoreWeave     67.68     70.53       -4.05
# 16  ETH-USD                     Ethereum USD   2816.08   2927.29       -3.80
# 28      NOW                       ServiceNow    153.38    158.43       -3.19
# 27     NBIS                Nebius Group N.V.     78.09     80.66       -3.19
# 7      AVGO                         Broadcom    329.88    339.39       -2.80
# 32     ORCL                         Oracleon    180.03    184.41       -2.37
# ...
