# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker             Company   Close     SMA  % from SMA
# 34     QCOM            QUALCOMM  169.27  178.31       -5.07
# 4      ANET     Arista Networks  123.42  126.54       -2.46
# 28      NOW          ServiceNow  142.64  146.07       -2.35
# 1      ADBE               Adobe  327.65  334.95       -2.18
# 36     RIVN   Rivian Automotive   19.15   19.57       -2.15
# 5       ARM        Arm Holdings  111.14  113.44       -2.03
# 25     MRVL  Marvell Technology   82.89   84.45       -1.85
# 44  XRP-USD             XRP USD    2.05    2.08       -1.71
# 22     META      Meta Platforms  641.97  650.08       -1.25
# 42      UNH  UnitedHealth Group  340.51  344.40       -1.13
# QCOM - QUALCOMM - buy score: 5.07%
# Prices: 154.03 | 161.73 | 169.82 | 178.31 | 187.23 | 196.59 | 206.42
# Buy score: 5.07%
# ANET - Arista Networks - buy score: 2.46%
# Prices: 113.51 | 119.19 | 125.14 | 126.54 | 132.86 | 139.51 | 146.48
# Buy score: 2.63%
# NOW - ServiceNow - buy score: 2.35%
# ...
