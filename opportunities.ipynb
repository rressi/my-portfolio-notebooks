# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
# Processing AAPL - Apple...
# Processing ADBE - Adobe...
# Processing AMD - Advanced Micro Devices...
# Processing AMZN - Amazon.com...
# Processing ANET - Arista Networks...
# Processing ARM - Arm Holdings...
# Processing ASML - ASML Holding N.V....
# Processing AVGO - Broadcom...
# Processing AVTR - Avantor...
# Processing BTC-EUR - Bitcoin EUR...
# Processing COHR - Coherent...
# Processing COIN - Coinbase Global...
# Processing CRM - Salesforce...
# Processing CRWD - CrowdStrike Holdings...
# Processing CRWV - CoreWeave...
# Processing CSCO - Cisco Systems...
# Processing ETH-EUR - Ethereum EUR...
# Processing GOOGL - Alphabet...
# Processing IBM - International Business Machines...
# Processing INTC - Intelon...
# Processing KLAC - KLAon...
# Processing LRCX - Lam Researchon...
# Processing META - Meta Platforms...
# Processing MPWR - Monolithic Power Systems...
# Processing MSFT - Microsofton...
# Processing MU - Micron Technology...
# Processing NBIS - Nebius Group N.V....
# ...
