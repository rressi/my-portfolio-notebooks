# %%
import opportunities
opportunities.find_buy_opportunities()
# Out:
# XAU-USD: not enought data points(11)
#    Ticker                   Company   Close    MA20  % from MA20
# 37    TXN         Texas Instruments  182.60  195.45        -6.57
# 8    AVTR                   Avantor   12.31   13.01        -5.40
# 2     AMD    Advanced Micro Devices  158.57  163.18        -2.82
# 12    CRM                Salesforce  242.76  248.28        -2.22
# 15   CSCO             Cisco Systems   66.53   67.54        -1.49
# 19   INTC                   Intelon   24.08   24.40        -1.33
# 1    ADBE                     Adobe  349.36  353.87        -1.27
# 23   MPWR  Monolithic Power Systems  834.14  843.94        -1.16
# TXN - Texas Instruments - buy score: 6.57%
# Prices: 168.83 | 177.28 | 186.14 | 195.4475 | 205.22 | 215.48 | 226.25
# Buy score: 7.04%
# AVTR - Avantor - buy score: 5.4%
# Prices: 11.24 | 11.80 | 12.39 | 13.0130 | 13.66 | 14.35 | 15.06
# Buy score: 5.71%
# AMD - Advanced Micro Devices - buy score: 2.82%
# ...
