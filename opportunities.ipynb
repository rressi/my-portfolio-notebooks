# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
# ZGLD.SW: last_sma is NaN
#      Ticker                          Company     Close       SMA  % from SMA
# 26       MU                Micron Technology    864.01   1007.84      -14.27
# 7      AVGO                         Broadcom    385.73    445.08      -13.34
# 5       ARM                     Arm Holdings    342.93    391.95      -12.51
# 16  ETH-USD                     Ethereum USD   1596.94   1807.84      -11.67
# 14     CRWV                        CoreWeave    100.39    112.69      -10.91
# 37     SMCI             Super Micro Computer     41.64     46.60      -10.65
# 27     NBIS                Nebius Group N.V.    227.81    252.85       -9.90
# 13     CRWD             CrowdStrike Holdings    671.02    737.77       -9.05
# 2       AMD           Advanced Micro Devices    466.38    512.75       -9.04
# 32     ORCL                         Oracleon    213.68    234.62       -8.92
# 11     COIN                  Coinbase Global    152.40    167.27       -8.89
# ...
