# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company     Close       SMA  % from SMA
# 8      AVTR                          Avantor      8.98     10.45      -14.10
# 11     COIN                  Coinbase Global    140.70    157.76      -10.81
# 15     CSCO                    Cisco Systems     75.78     83.84       -9.62
# 18      IBM  International Business Machines    258.31    282.96       -8.71
# 37     SMCI             Super Micro Computer     30.81     32.82       -6.12
# 33     PLTR            Palantir Technologies    128.15    136.43       -6.07
# 16  ETH-USD                     Ethereum USD   1915.03   2013.50       -4.89
# 31     NFLX                          Netflix     76.49     80.40       -4.87
# 30     NVTS            Navitas Semiconductor      8.44      8.81       -4.24
# 9   BTC-USD                      Bitcoin USD  65521.33  68338.55       -4.12
# 10     COHR                         Coherent    219.09    228.26       -4.02
# ...
