# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company   Close     SMA  % from SMA
# 36     RIVN                Rivian Automotive   17.08   18.36       -6.99
# 12      CRM                       Salesforce  233.22  246.64       -5.44
# 28      NOW                       ServiceNow  131.76  137.80       -4.39
# 1      ADBE                            Adobe  303.55  315.90       -3.91
# 34     QCOM                         QUALCOMM  161.94  167.76       -3.47
# 32     ORCL                         Oracleon  192.53  198.33       -2.92
# 8      AVTR                          Avantor   11.98   12.33       -2.83
# 35     RACE                     Ferrari N.V.  355.41  364.46       -2.48
# 24     MSFT                      Microsofton  458.27  468.96       -2.28
# 5       ARM                     Arm Holdings  106.37  108.43       -1.90
# 22     META                   Meta Platforms  623.04  632.94       -1.56
# 44  XRP-USD                          XRP USD    2.07    2.10       -1.44
# ...
