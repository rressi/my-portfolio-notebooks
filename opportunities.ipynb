# %%
import my_portfolio; my_portfolio.find_buy_opportunities()
# Out:
#      Ticker                          Company      Close        SMA  % from SMA
# 30     NVTS            Navitas Semiconductor      10.08      12.38      -18.58
# 37     SMCI             Super Micro Computer      43.37      49.83      -12.97
# 14     CRWV                        CoreWeave     114.28     129.06      -11.45
# 16  ETH-USD                     Ethereum USD    3362.12    3719.35       -9.60
# 4      ANET                  Arista Networks     142.66     155.68       -8.36
# 27     NBIS                Nebius Group N.V.     114.32     122.98       -7.04
# 33     PLTR            Palantir Technologies     183.51     196.90       -6.80
# 44  XRP-USD                          XRP USD       2.26       2.42       -6.76
# 11     COIN                  Coinbase Global     313.60     332.98       -5.82
# 5       ARM                     Arm Holdings     157.36     166.34       -5.40
# 19     INTC                          Intelon      37.63      39.72       -5.27
# ...
