# %%
import workflow
workflow.run(
    security = "XRP-EUR",  # Crypto by Ripple
    start_date = "2025-07-01",
    ops="""
date, quantity, price
2025-09-09, 7.78161671, 2.5702
2025-08-12, 18.2768839, 2.7086
2025-07-29, 18.26609395, 2.7095
"""
)
# Out:
# Prices: 2.15 | 2.26 | 2.37 | 2.6847 | 2.82 | 2.96 | 3.11
# Buy score: -3.64%
# Sell score: -3.63%
#                     XRP-EUR
# Company Name        XRP EUR
# Current Price          None
# Forward EPS            None
# Gross Profit (ttm)     None
# Industry               None
# Revenue (ttm)          None
# Target High Price      None
# Target Low Price       None
# Target Mean Price      None
# Trailing EPS           None
# Website                None
#                                    XRP-EUR
# Currency                               EUR
# Dayhigh                               2.66
# Daylow                                2.57
# Exchange                               CCC
# Fiftydayaverage                       2.58
# Lastprice                             2.59
# Lastvolume                   4,032,723,712
# Marketcap                             None
# Open                                  2.66
# Previousclose                         2.66
# Quotetype                   CRYPTOCURRENCY
# ...
