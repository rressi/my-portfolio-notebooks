# %%
import my_portfolio; my_portfolio.run("XRP-EUR")
# Out:
# Prices: 2.23 | 2.34 | 2.46 | 2.66 | 2.80 | 2.94 | 3.08
# Buy score: 2.23%
# Sell score: -5.19%
#                     XRP-EUR
# Company Name        XRP EUR
# Current Price          None
# Forward EPS            None
# Gross Profit (ttm)     None
# Industry               None
# Revenue (ttm)          None
# Target High Price      None
# Target Low Price       None
# Target Mean Price      None
# Trailing EPS           None
# Website                None
#                                    XRP-EUR
# Currency                               EUR
# Dayhigh                               2.56
# Daylow                                2.53
# Exchange                               CCC
# Fiftydayaverage                       2.57
# Lastprice                             2.53
# Lastvolume                   2,539,422,720
# Marketcap                             None
# Open                                  2.54
# Previousclose                         2.54
# Quotetype                   CRYPTOCURRENCY
# ...
