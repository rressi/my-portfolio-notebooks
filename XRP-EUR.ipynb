# %%
import workflow
workflow.run(
    security = "XRP-EUR",  # Crypto by Ripple
    start_date = "2025-07-01",
    ops="""
date, quantity, price
2025-07-29, 18.26609395, 2.7095
2025-08-12, 18.2768839,  2.7086
2025-09-09,  7.78161671, 2.5702
2025-09-16,  7.83478016, 2.55272
"""
)
# Out:
# Prices: 2.23 | 2.35 | 2.46 | 2.66 | 2.80 | 2.94 | 3.08
# Buy score: -0.59%
# Sell score: -2.34%
#                     XRP-EUR
# Company Name        XRP EUR
# Current Price          None
# Forward EPS            None
# Gross Profit (ttm)     None
# Industry               None
# Revenue (ttm)          None
# Target High Price      None
# Target Low Price       None
# Target Mean Price      None
# Trailing EPS           None
# Website                None
#                                    XRP-EUR
# Currency                               EUR
# Dayhigh                               2.66
# Daylow                                2.60
# Exchange                               CCC
# Fiftydayaverage                       2.57
# Lastprice                             2.60
# Lastvolume                   5,541,315,072
# Marketcap                             None
# Open                                  2.61
# Previousclose                         2.61
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose            2.61
# Shares                                None
# Tendayaveragevolume          4,739,014,346
# Threemonthaveragevolume      5,431,728,875
# Timezone                               UTC
# Twohundreddayaverage                  2.21
# Yearchange                            3.96
# Yearhigh                              3.29
# Yearlow                               0.46
