# %%
import my_portfolio; my_portfolio.run("XRP-EUR")
# Out:
# Prices: 2.21 | 2.32 | 2.44 | 2.60 | 2.80 | 2.94 | 3.08
# Buy score: 7.24%
# Sell score: -8.26%
#                     XRP-EUR
# Company Name        XRP EUR
# Current Price          None
# Forward EPS            None
# Gross Profit (ttm)     None
# Industry               None
# Revenue (ttm)          None
# Target High Price      None
# Target Low Price       None
# Target Mean Price      None
# Trailing EPS           None
# Website                None
#                                    XRP-EUR
# Currency                               EUR
# Dayhigh                               2.43
# Daylow                                2.38
# Exchange                               CCC
# Fiftydayaverage                       2.57
# Lastprice                             2.38
# Lastvolume                   7,436,919,296
# Marketcap                             None
# Open                                  2.42
# Previousclose                         2.42
# Quotetype                   CRYPTOCURRENCY
# ...
