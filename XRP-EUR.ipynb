# %%
import workflow
workflow.run(
    security = "XRP-EUR",  # Crypto by Ripple
    start_date = "2025-07-01",
    ops="""
date, quantity, price
2025-07-29, 18.26609395, 2.7095
2025-08-12, 18.2768839,  2.7086
2025-09-09,  7.78161671, 2.5702
2025-09-16,  7.83478016, 2.55272
"""
)
# Out:
# Prices: 2.22 | 2.33 | 2.44 | 2.66 | 2.82 | 2.96 | 3.11
# Buy score: 0.00%
# Sell score: -3.76%
#                     XRP-EUR
# Company Name        XRP EUR
# Current Price          None
# Forward EPS            None
# Gross Profit (ttm)     None
# Industry               None
# Revenue (ttm)          None
# Target High Price      None
# Target Low Price       None
# Target Mean Price      None
# Trailing EPS           None
# Website                None
#                                    XRP-EUR
# Currency                               EUR
# Dayhigh                               2.57
# Daylow                                2.56
# Exchange                               CCC
# Fiftydayaverage                       2.57
# Lastprice                             2.56
# Lastvolume                   3,943,046,144
# Marketcap                             None
# Open                                  2.56
# Previousclose                         2.57
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose             nan
# Shares                                None
# Tendayaveragevolume          4,118,436,438
# Threemonthaveragevolume      5,365,978,258
# Timezone                               UTC
# Twohundreddayaverage                  2.20
# Yearchange                             nan
# Yearhigh                              3.29
# Yearlow                               0.46
