# %%
import my_portfolio
my_portfolio.run(
    security = "XRP-EUR",  # Crypto by Ripple
    start_date = "2025-07-01",
    ops="""
date, quantity, price
2025-07-29, 18.26609395, 2.7095
2025-08-12, 18.2768839,  2.7086
2025-09-09,  7.78161671, 2.5702
2025-09-16,  7.83478016, 2.55272
"""
)
# Out:
# Prices: 2.24 | 2.35 | 2.47 | 2.66 | 2.80 | 2.94 | 3.08
# Buy score: 2.17%
# Sell score: -4.89%
#                     XRP-EUR
# Company Name        XRP EUR
# Current Price          None
# Forward EPS            None
# Gross Profit (ttm)     None
# Industry               None
# Revenue (ttm)          None
# Target High Price      None
# Target Low Price       None
# Target Mean Price      None
# Trailing EPS           None
# Website                None
#                                    XRP-EUR
# Currency                               EUR
# Dayhigh                               2.56
# Daylow                                2.53
# Exchange                               CCC
# Fiftydayaverage                       2.57
# Lastprice                             2.53
# Lastvolume                   2,711,166,720
# Marketcap                             None
# Open                                  2.55
# Previousclose                         2.55
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose            2.55
# Shares                                None
# Tendayaveragevolume          4,685,564,327
# Threemonthaveragevolume      5,494,357,624
# Timezone                               UTC
# Twohundreddayaverage                  2.21
# Yearchange                            3.76
# Yearhigh                              3.29
# Yearlow                               0.46
