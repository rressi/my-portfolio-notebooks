# %%
import workflow
workflow.run(
    security = "XRP-EUR",  # Crypto by Ripple
    start_date = "2025-07-01",
    ops="""
date, quantity, price
2025-09-09, 7.78161671, 2.5702
2025-08-12, 18.2768839, 2.7086
2025-07-29, 18.26609395, 2.7095
"""
)
# Out:
# Prices: 2.15 | 2.26 | 2.37 | 2.68 | 2.82 | 2.96 | 3.11
# Buy score: -1.68%
# Sell score: -5.65%
#                     XRP-EUR
# Company Name        XRP EUR
# Current Price          None
# Forward EPS            None
# Gross Profit (ttm)     None
# Industry               None
# Revenue (ttm)          None
# Target High Price      None
# Target Low Price       None
# Target Mean Price      None
# Trailing EPS           None
# Website                None
#                                    XRP-EUR
# Currency                               EUR
# Dayhigh                               2.55
# Daylow                                2.53
# Exchange                               CCC
# Fiftydayaverage                       2.58
# Lastprice                             2.53
# Lastvolume                   5,139,877,888
# Marketcap                             None
# Open                                  2.55
# Previousclose                         2.54
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose             nan
# Shares                                None
# Tendayaveragevolume          3,773,154,336
# Threemonthaveragevolume      5,353,054,929
# Timezone                               UTC
# Twohundreddayaverage                  2.20
# Yearchange                             nan
# Yearhigh                              3.29
# Yearlow                               0.46
