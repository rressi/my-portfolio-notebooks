# %%
import workflow
workflow.run(
    security = "XRP-EUR",  # Crypto by Ripple
    start_date = "2025-07-01",
    ops="""
date, quantity, price
2025-07-29, 18.26609395, 2.7095
2025-08-12, 18.2768839,  2.7086
2025-09-09,  7.78161671, 2.5702
2025-09-16,  7.83478016, 2.55272
"""
)
# Out:
# Prices: 2.23 | 2.34 | 2.46 | 2.66 | 2.80 | 2.94 | 3.08
# Buy score: -1.88%
# Sell score: -1.27%
#                     XRP-EUR
# Company Name        XRP EUR
# Current Price          None
# Forward EPS            None
# Gross Profit (ttm)     None
# Industry               None
# Revenue (ttm)          None
# Target High Price      None
# Target Low Price       None
# Target Mean Price      None
# Trailing EPS           None
# Website                None
#                                    XRP-EUR
# Currency                               EUR
# Dayhigh                               2.63
# Daylow                                2.60
# Exchange                               CCC
# Fiftydayaverage                       2.57
# Lastprice                             2.63
# Lastvolume                   5,718,701,056
# Marketcap                             None
# Open                                  2.61
# Previousclose                         2.61
# Quotetype                   CRYPTOCURRENCY
# Regularmarketpreviousclose             nan
# Shares                                None
# Tendayaveragevolume          4,192,321,813
# Threemonthaveragevolume      5,372,305,773
# Timezone                               UTC
# Twohundreddayaverage                  2.21
# Yearchange                             nan
# Yearhigh                              3.29
# Yearlow                               0.46
