# %%
import my_portfolio; my_portfolio.run("XRP-EUR")
# Out:
# Prices: 2.21 | 2.32 | 2.44 | 2.57 | 2.70 | 2.83 | 2.97
# Buy score: -0.92%
# Sell score: 0.66%
#                  Quantity Price     Tot Wallet Avg. price Balance
# Time
# 2025-07-29 05:50       18  2.71   49.49     18       2.71   -0.49
# 2025-08-12 06:49       18  2.71   49.50     37       2.71   -1.01
# 2025-09-09 08:00        8  2.57   20.00     44       2.68   -6.27
# 2025-09-16 08:00        8  2.55   20.00     52       2.66   -7.24
# 2025-09-22 10:58       17  2.39   39.99     69       2.60  -15.88
# 2025-09-23 08:00        8  2.43   20.00     77       2.58  -13.50
# 2025-09-30 08:00        8  2.45   20.00     85       2.57  -12.41
# 2025-10-05 06:57       85  2.59  220.43     85        NaN   -0.74
#                     XRP-EUR
# Company Name        XRP EUR
# Current Price          None
# Forward EPS            None
# Gross Profit (ttm)     None
# Industry               None
# Revenue (ttm)          None
# Target High Price      None
# Target Low Price       None
# ...
