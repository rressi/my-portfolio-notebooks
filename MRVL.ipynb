# %%
import my_portfolio; my_portfolio.run("MRVL")
# Out:
# No operations found for ticker 'MRVL'
# Prices: 78.63 | 82.56 | 86.69 | 91.02 | 95.57 | 100.35 | 105.37
# Buy score: -0.69%
# No operations found.
#                                        MRVL
# Company Name             Marvell Technology
# Current Price                         90.92
# Forward EPS                             2.5
# Gross Profit (ttm)            3,587,699,968
# Industry                     Semiconductors
# Revenue (ttm)                 7,234,899,968
# Target High Price                     122.0
# Target Low Price                       58.2
# Target Mean Price                  90.07421
# Trailing EPS                          -0.12
# Website             https://www.marvell.com
#                                          MRVL
# Currency                                  USD
# Dayhigh                                 92.18
# Daylow                                  85.11
# Exchange                                  NMS
# Fiftydayaverage                         80.70
# ...
