# %%
import my_portfolio; my_portfolio.run("MRVL")
# Out:
# No operations found for ticker 'MRVL'
# Prices: 74.58 | 78.31 | 82.22 | 81.10 | 85.16 | 89.42 | 93.89
# Buy score: -3.03%
# No operations found.
#                                        MRVL
# Company Name             Marvell Technology
# Current Price                       83.6401
# Forward EPS                         3.58025
# Gross Profit (ttm)            3,951,800,064
# Industry                     Semiconductors
# Revenue (ttm)                 7,793,299,968
# Target High Price                     156.0
# Target Low Price                       90.0
# Target Mean Price                 116.90707
# Trailing EPS                           2.84
# Website             https://www.marvell.com
#                                          MRVL
# Currency                                  USD
# Dayhigh                                 83.72
# Daylow                                  80.40
# Exchange                                  NMS
# Fiftydayaverage                         86.58
# ...
