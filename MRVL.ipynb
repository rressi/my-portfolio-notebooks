# %%
import my_portfolio; my_portfolio.run("MRVL")
# Out:
# No operations found for ticker 'MRVL'
# Prices: 77.27 | 81.13 | 85.19 | 89.45 | 93.92 | 98.61 | 103.54
# Buy score: 6.15%
# No operations found.
#                                        MRVL
# Company Name             Marvell Technology
# Current Price                        84.425
# Forward EPS                         3.57683
# Gross Profit (ttm)            3,951,800,064
# Industry                     Semiconductors
# Revenue (ttm)                 7,793,299,968
# Target High Price                     156.0
# Target Low Price                       67.0
# Target Mean Price                 116.32975
# Trailing EPS                           2.68
# Website             https://www.marvell.com
#                                          MRVL
# Currency                                  USD
# Dayhigh                                 89.00
# Daylow                                  83.89
# Exchange                                  NMS
# Fiftydayaverage                         88.25
# ...
