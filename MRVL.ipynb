# %%
import my_portfolio; my_portfolio.run("MRVL")
# Out:
# No operations found for ticker 'MRVL'
# Prices: 81.79 | 85.88 | 90.17 | 94.68 | 99.41 | 104.38 | 109.60
# Buy score: -5.13%
# No operations found.
#                                        MRVL
# Company Name             Marvell Technology
# Current Price                       99.8001
# Forward EPS                             2.5
# Gross Profit (ttm)            3,935,000,064
# Industry                     Semiconductors
# Revenue (ttm)                 7,793,299,968
# Target High Price                     156.0
# Target Low Price                       67.0
# Target Mean Price                 114.63463
# Trailing EPS                           2.84
# Website             https://www.marvell.com
#                                          MRVL
# Currency                                  USD
# Dayhigh                                102.77
# Daylow                                  99.00
# Exchange                                  NMS
# Fiftydayaverage                         87.00
# ...
