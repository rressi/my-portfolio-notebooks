# %%
import my_portfolio; my_portfolio.run("MRVL")
# Out:
# No operations found for ticker 'MRVL'
# Prices: 253.51 | 266.19 | 279.50 | 293.47 | 308.15 | 323.56 | 339.73
# Buy score: -6.54%
# No operations found.
#                                        MRVL
# Company Name             Marvell Technology
# Current Price                        310.58
# Forward EPS                         6.17388
# Gross Profit (ttm)            4,489,600,000
# Industry                     Semiconductors
# Revenue (ttm)                 8,717,100,032
# Target High Price                     385.0
# Target Low Price                      110.0
# Target Mean Price                 238.74557
# Trailing EPS                           2.92
# Website             https://www.marvell.com
#                                           MRVL
# Currency                                   USD
# Dayhigh                                 329.88
# Daylow                                  302.36
# Exchange                                   NMS
# Fiftydayaverage                         197.94
# ...
