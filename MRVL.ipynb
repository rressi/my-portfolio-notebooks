# %%
import my_portfolio; my_portfolio.run("MRVL")
# Out:
# No operations found for ticker 'MRVL'
# Prices: 83.24 | 87.40 | 91.77 | 96.36 | 101.18 | 106.23 | 111.55
# Buy score: 5.18%
# No operations found.
#                                        MRVL
# Company Name             Marvell Technology
# Current Price                        91.615
# Forward EPS                             2.5
# Gross Profit (ttm)            3,951,800,064
# Industry                     Semiconductors
# Revenue (ttm)                 7,793,299,968
# Target High Price                     156.0
# Target Low Price                       67.0
# Target Mean Price                  115.9761
# Trailing EPS                           2.84
# Website             https://www.marvell.com
#                                          MRVL
# Currency                                  USD
# Dayhigh                                 92.61
# Daylow                                  88.92
# Exchange                                  NMS
# Fiftydayaverage                         87.66
# ...
