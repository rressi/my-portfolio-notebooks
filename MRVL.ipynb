# %%
import my_portfolio; my_portfolio.run("MRVL")
# Out:
# No operations found for ticker 'MRVL'
# Prices: 79.68 | 83.66 | 87.85 | 92.24 | 96.85 | 101.69 | 106.78
# Buy score: -7.84%
# No operations found.
#                                        MRVL
# Company Name             Marvell Technology
# Current Price                       100.088
# Forward EPS                             2.5
# Gross Profit (ttm)            3,587,699,968
# Industry                     Semiconductors
# Revenue (ttm)                 7,234,899,968
# Target High Price                     150.0
# Target Low Price                       58.2
# Target Mean Price                 104.92244
# Trailing EPS                           2.84
# Website             https://www.marvell.com
#                                          MRVL
# Currency                                  USD
# Dayhigh                                102.11
# Daylow                                  95.79
# Exchange                                  NMS
# Fiftydayaverage                         86.49
# ...
