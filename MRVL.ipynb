# %%
import my_portfolio; my_portfolio.run("MRVL")
# Out:
# No operations found for ticker 'MRVL'
# Prices: 193.28 | 202.95 | 213.10 | 223.75 | 234.94 | 246.68 | 259.02
# Buy score: -32.92%
# No operations found.
#                                        MRVL
# Company Name             Marvell Technology
# Current Price                        290.79
# Forward EPS                         6.11235
# Gross Profit (ttm)            4,489,600,000
# Industry                     Semiconductors
# Revenue (ttm)                 8,717,100,032
# Target High Price                     300.0
# Target Low Price                      110.0
# Target Mean Price                 222.55122
# Trailing EPS                           2.91
# Website             https://www.marvell.com
#                                           MRVL
# Currency                                   USD
# Dayhigh                                 291.30
# Daylow                                  252.43
# Exchange                                   NMS
# ...
