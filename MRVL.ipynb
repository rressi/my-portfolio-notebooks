# %%
import my_portfolio; my_portfolio.run("MRVL")
# Out:
# No operations found for ticker 'MRVL'
# Prices: 75.85 | 79.65 | 83.63 | 83.79 | 87.98 | 92.37 | 96.99
# Buy score: -0.61%
# No operations found.
#                                        MRVL
# Company Name             Marvell Technology
# Current Price                         84.47
# Forward EPS                         3.58529
# Gross Profit (ttm)            3,951,800,064
# Industry                     Semiconductors
# Revenue (ttm)                 7,793,299,968
# Target High Price                     156.0
# Target Low Price                       67.0
# Target Mean Price                 115.82975
# Trailing EPS                           2.84
# Website             https://www.marvell.com
#                                          MRVL
# Currency                                  USD
# Dayhigh                                 85.01
# Daylow                                  82.65
# Exchange                                  NMS
# Fiftydayaverage                         87.97
# ...
