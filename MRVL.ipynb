# %%
import my_portfolio; my_portfolio.run("MRVL")
# Out:
# No operations found for ticker 'MRVL'
# Prices: 233.67 | 245.35 | 257.62 | 270.50 | 284.03 | 298.23 | 313.14
# Buy score: -1.00%
# No operations found.
#                                        MRVL
# Company Name             Marvell Technology
# Current Price                        280.71
# Forward EPS                         6.17263
# Gross Profit (ttm)            4,489,600,000
# Industry                     Semiconductors
# Revenue (ttm)                 8,717,100,032
# Target High Price                     321.0
# Target Low Price                      110.0
# Target Mean Price                 233.13582
# Trailing EPS                           2.92
# Website             https://www.marvell.com
#                                           MRVL
# Currency                                   USD
# Dayhigh                                 282.32
# Daylow                                  258.43
# Exchange                                   NMS
# Fiftydayaverage                         179.54
# ...
