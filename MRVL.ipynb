# %%
import my_portfolio; my_portfolio.run("MRVL")
# Out:
# No operations found for ticker 'MRVL'
# Prices: 71.08 | 74.63 | 78.36 | 78.90 | 82.85 | 86.99 | 91.34
# Buy score: 0.46%
# No operations found.
#                                        MRVL
# Company Name             Marvell Technology
# Current Price                         78.54
# Forward EPS                         3.46743
# Gross Profit (ttm)            3,951,800,064
# Industry                     Semiconductors
# Revenue (ttm)                 7,793,299,968
# Target High Price                     156.0
# Target Low Price                       85.0
# Target Mean Price                 115.65475
# Trailing EPS                           2.84
# Website             https://www.marvell.com
#                                          MRVL
# Currency                                  USD
# Dayhigh                                 79.14
# Daylow                                  77.18
# Exchange                                  NMS
# Fiftydayaverage                         82.58
# ...
