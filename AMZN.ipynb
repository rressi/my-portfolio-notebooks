# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 209.41 | 219.88 | 230.88 | 245.89 | 258.18 | 271.09 | 284.65
# Buy score: 1.43%
# Sell score: -2.80%
# Current return: -500.52 USD
# Breakeven price: 249.03 USD
# <style type="text/css">
# #T_e0dc7_row23_col0, #T_e0dc7_row23_col1, #T_e0dc7_row23_col2, #T_e0dc7_row23_col3, #T_e0dc7_row23_col4, #T_e0dc7_row23_col5, #T_e0dc7_row23_col6, #T_e0dc7_row23_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_e0dc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0dc7_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_e0dc7_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_e0dc7_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_e0dc7_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_e0dc7_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
