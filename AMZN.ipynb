# %%
import workflow
workflow.run(
    security = "AMZN",
)
# Out:
# Prices: 201.07 | 211.12 | 221.68 | 232.76 | 244.40 | 256.62 | 269.45
# Buy score: 0.49%
#                                            AMZN
# Company Name                         Amazon.com
# Current Price                            231.62
# Forward EPS                                6.15
# Gross Profit (ttm)              332,382,994,432
# Industry                        Internet Retail
# Revenue (ttm)                   670,038,032,384
# Target High Price                         306.0
# Target Low Price                          230.0
# Target Mean Price                      264.7213
# Trailing EPS                               6.55
# Website             https://www.aboutamazon.com
#                                             AMZN
# Currency                                     USD
# Dayhigh                                   234.30
# Daylow                                    228.71
# Exchange                                     NMS
# Fiftydayaverage                           227.13
# ...
