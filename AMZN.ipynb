# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 197.70 | 207.59 | 217.97 | 230.73 | 242.27 | 254.38 | 267.10
# Buy score: -0.76%
# Sell score: -0.07%
# Current return: -68.62 USD
# Breakeven price: 237.42 USD
# <style type="text/css">
# #T_45efa_row16_col0, #T_45efa_row16_col1, #T_45efa_row16_col2, #T_45efa_row16_col3, #T_45efa_row16_col4, #T_45efa_row16_col5, #T_45efa_row16_col6, #T_45efa_row16_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_45efa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45efa_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_45efa_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_45efa_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_45efa_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_45efa_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
