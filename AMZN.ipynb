# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 198.04 | 207.94 | 218.34 | 230.73 | 242.27 | 254.38 | 267.10
# Buy score: -1.22%
# Sell score: -1.73%
# Current return: -106.82 USD
# Breakeven price: 237.42 USD
# <style type="text/css">
# #T_fb1a0_row16_col0, #T_fb1a0_row16_col1, #T_fb1a0_row16_col2, #T_fb1a0_row16_col3, #T_fb1a0_row16_col4, #T_fb1a0_row16_col5, #T_fb1a0_row16_col6, #T_fb1a0_row16_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_fb1a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb1a0_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_fb1a0_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_fb1a0_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_fb1a0_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_fb1a0_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
