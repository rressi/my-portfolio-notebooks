# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 194.33 | 204.05 | 214.25 | 227.50 | 238.88 | 250.82 | 263.36
# Buy score: -1.45%
# Sell score: -0.37%
# Current return: -32.19 USD
# Breakeven price: 230.68 USD
# <style type="text/css">
# #T_1c9a1_row9_col0, #T_1c9a1_row9_col1, #T_1c9a1_row9_col2, #T_1c9a1_row9_col3, #T_1c9a1_row9_col4, #T_1c9a1_row9_col5, #T_1c9a1_row9_col6, #T_1c9a1_row9_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_1c9a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c9a1_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_1c9a1_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_1c9a1_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_1c9a1_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_1c9a1_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
