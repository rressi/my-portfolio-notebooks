# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 195.00 | 204.75 | 214.98 | 216.57 | 227.40 | 238.77 | 250.71
# Buy score: 1.34%
#                    Quantity   Price    Value    Wallet Avg. price Inv. Cost  \
# Time
# 2025-09-24 11:00   3.000000  221.00   663.00  3.000000     221.00      3.00
# 2025-09-24 11:00   1.000000  221.00   221.00  4.000000     221.00      6.33
# 2025-10-03 13:54  -4.000000  219.93  -879.72  0.000000       0.00      0.00
#
#                  Inv. Balance Balance
# Time
# 2025-09-24 11:00        -3.00   -3.00
# 2025-09-24 11:00        -6.33   -6.33
# 2025-10-03 13:54         0.00  -16.95
#                                            AMZN
# Company Name                         Amazon.com
# Current Price                            214.47
# Forward EPS                                6.15
# Gross Profit (ttm)              332,382,994,432
# Industry                        Internet Retail
# Revenue (ttm)                   670,038,032,384
# Target High Price                         306.0
# ...
