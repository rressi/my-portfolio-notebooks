# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 207.84 | 218.23 | 229.15 | 245.89 | 258.18 | 271.09 | 284.65
# Buy score: 0.75%
# Sell score: -2.87%
# Current return: -510.27 USD
# Breakeven price: 249.03 USD
# <style type="text/css">
# #T_38819_row23_col0, #T_38819_row23_col1, #T_38819_row23_col2, #T_38819_row23_col3, #T_38819_row23_col4, #T_38819_row23_col5, #T_38819_row23_col6, #T_38819_row23_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_38819">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38819_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_38819_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_38819_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_38819_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_38819_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
