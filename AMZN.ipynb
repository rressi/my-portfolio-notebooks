# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 195.85 | 205.64 | 215.92 | 226.86 | 238.20 | 250.11 | 262.62
# Buy score: -10.48%
# Sell score: 11.64%
# Current return: 320.12 USD
# Breakeven price: 230.39 USD
# <style type="text/css">
# #T_b1596_row11_col0, #T_b1596_row11_col1, #T_b1596_row11_col2, #T_b1596_row11_col3, #T_b1596_row11_col4, #T_b1596_row11_col5, #T_b1596_row11_col6, #T_b1596_row11_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_b1596">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1596_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_b1596_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_b1596_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_b1596_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_b1596_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
