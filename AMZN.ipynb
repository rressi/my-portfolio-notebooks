# %%
import workflow
workflow.run(
    security = "AMZN",
)
# Out:
# Prices: 200.58 | 210.61 | 221.14 | 232.20 | 243.81 | 256.00 | 268.80
# Buy score: -0.79%
#                                            AMZN
# Company Name                         Amazon.com
# Current Price                            234.05
# Forward EPS                                6.15
# Gross Profit (ttm)              332,382,994,432
# Industry                        Internet Retail
# Revenue (ttm)                   670,038,032,384
# Target High Price                         306.0
# Target Low Price                          230.0
# Target Mean Price                      264.7213
# Trailing EPS                               6.55
# Website             https://www.aboutamazon.com
#                                             AMZN
# Currency                                     USD
# Dayhigh                                   235.90
# Daylow                                    232.23
# Exchange                                     NMS
# Fiftydayaverage                           226.92
# ...
