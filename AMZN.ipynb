# %%
import workflow
workflow.run(
    security = "AMZN",
)
# Out:
# Prices: 198.40 | 208.32 | 218.73 | 229.6675 | 241.15 | 253.21 | 265.87
# Buy score: 0.67%
#                                            AMZN
# Company Name                         Amazon.com
# Current Price                            228.15
# Forward EPS                                6.15
# Gross Profit (ttm)              332,382,994,432
# Industry                        Internet Retail
# Revenue (ttm)                   670,038,032,384
# Target High Price                         306.0
# Target Low Price                          225.0
# Target Mean Price                      263.7377
# Trailing EPS                               6.57
# Website             https://www.aboutamazon.com
#                                             AMZN
# Currency                                     USD
# Dayhigh                                   230.79
# Daylow                                    226.29
# Exchange                                     NMS
# Fiftydayaverage                           226.76
# ...
