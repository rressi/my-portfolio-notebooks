# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 198.21 | 208.12 | 218.52 | 221.00 | 232.05 | 243.65 | 255.84
# Buy score: 4.26%
# Sell score: -1.28%
#                  Quantity   Price     Tot Wallet Avg. price Balance
# Time
# 2025-09-24 11:00        3  221.00  663.00      4     221.00   -6.33
# 2025-09-24 11:00        1  221.00  221.00      4     221.00   -6.33
# 2025-09-26 00:00        4  218.18  872.70      4        NaN  -17.63
#                                            AMZN
# Company Name                         Amazon.com
# Current Price                            218.15
# Forward EPS                                6.15
# Gross Profit (ttm)              332,382,994,432
# Industry                        Internet Retail
# Revenue (ttm)                   670,038,032,384
# Target High Price                         306.0
# Target Low Price                          230.0
# Target Mean Price                     265.29507
# Trailing EPS                               6.56
# Website             https://www.aboutamazon.com
# ...
