# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 203.24 | 213.41 | 224.08 | 240.30 | 252.32 | 264.94 | 278.18
# Buy score: 1.66%
# Sell score: -3.69%
# Current return: -946.86 USD
# Breakeven price: 243.28 USD
# <style type="text/css">
# #T_110cf_row24_col0, #T_110cf_row24_col1, #T_110cf_row24_col2, #T_110cf_row24_col3, #T_110cf_row24_col4, #T_110cf_row24_col5, #T_110cf_row24_col6, #T_110cf_row24_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_110cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_110cf_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_110cf_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_110cf_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_110cf_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_110cf_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
