# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 195.75 | 205.53 | 215.81 | 220.86 | 231.90 | 243.50 | 255.67
# Buy score: 0.47%
#                    Quantity   Price      Tot    Wallet Avg. price Balance
# Time
# 2025-09-24 11:00   3.000000  221.00   663.00  4.000000     221.00   -6.33
# 2025-09-24 11:00   1.000000  221.00   221.00  4.000000     221.00   -6.33
# 2025-10-03 13:54  -4.000000  219.93  -879.72  0.000000       0.00  -16.95
#                                            AMZN
# Company Name                         Amazon.com
# Current Price                            219.51
# Forward EPS                                6.15
# Gross Profit (ttm)              332,382,994,432
# Industry                        Internet Retail
# Revenue (ttm)                   670,038,032,384
# Target High Price                         306.0
# Target Low Price                          230.0
# Target Mean Price                      266.5645
# Trailing EPS                               6.56
# ...
