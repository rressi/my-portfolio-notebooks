# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 194.73 | 204.46 | 214.69 | 215.74 | 226.53 | 237.85 | 249.75
# Buy score: -1.67%
# Sell score: 1.97%
# Current return: -23.88 USD
# Breakeven price: 222.39 USD
# <style type="text/css">
# #T_49a6c_row5_col0, #T_49a6c_row5_col1, #T_49a6c_row5_col2, #T_49a6c_row5_col3, #T_49a6c_row5_col4, #T_49a6c_row5_col5, #T_49a6c_row5_col6, #T_49a6c_row5_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_49a6c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49a6c_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_49a6c_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_49a6c_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_49a6c_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_49a6c_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
