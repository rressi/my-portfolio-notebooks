# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 199.99 | 209.98 | 220.48 | 231.19 | 242.75 | 254.89 | 267.63
# Buy score: -0.22%
# Sell score: 0.35%
# Current return: -83.52 USD
# Breakeven price: 236.19 USD
# <style type="text/css">
# #T_90df2_row18_col0, #T_90df2_row18_col1, #T_90df2_row18_col2, #T_90df2_row18_col3, #T_90df2_row18_col4, #T_90df2_row18_col5, #T_90df2_row18_col6, #T_90df2_row18_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_90df2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90df2_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_90df2_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_90df2_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_90df2_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_90df2_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
