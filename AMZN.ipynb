# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 194.73 | 204.47 | 214.69 | 215.74 | 226.53 | 237.85 | 249.75
# Buy score: -2.70%
# Sell score: 3.09%
# Current return: 0.12 USD
# Breakeven price: 222.39 USD
# <style type="text/css">
# #T_66cca_row5_col0, #T_66cca_row5_col1, #T_66cca_row5_col2, #T_66cca_row5_col3, #T_66cca_row5_col4, #T_66cca_row5_col5, #T_66cca_row5_col6, #T_66cca_row5_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_66cca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66cca_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_66cca_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_66cca_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_66cca_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_66cca_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
