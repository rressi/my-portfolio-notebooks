# %%
import workflow
workflow.run(
    security = "AMZN",
)
# Out:
# Prices: 198.73 | 208.67 | 219.10 | 230.0573 | 241.56 | 253.64 | 266.32
# Buy score: 0.05%
#                                            AMZN
# Company Name                   Amazon.com, Inc.
# Industry                        Internet Retail
# Revenue (ttm)                   670,038,032,384
# Gross Profit (ttm)              332,382,994,432
# Current Price                            229.95
# Target Mean Price                     263.18033
# Target High Price                         306.0
# Target Low Price                          225.0
# Trailing EPS                               6.56
# Forward EPS                                6.15
# Website             https://www.aboutamazon.com
#                                             AMZN
# Currency                                     USD
# Dayhigh                                   231.53
# Daylow                                    229.34
# Exchange                                     NMS
# Fiftydayaverage                           226.41
# ...
