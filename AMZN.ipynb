# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 211.23 | 221.79 | 232.88 | 245.89 | 258.18 | 271.09 | 284.65
# Buy score: -0.73%
# Sell score: 0.18%
# Current return: -134.52 USD
# Breakeven price: 249.03 USD
# <style type="text/css">
# #T_b13b0_row23_col0, #T_b13b0_row23_col1, #T_b13b0_row23_col2, #T_b13b0_row23_col3, #T_b13b0_row23_col4, #T_b13b0_row23_col5, #T_b13b0_row23_col6, #T_b13b0_row23_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_b13b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b13b0_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_b13b0_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_b13b0_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_b13b0_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_b13b0_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
