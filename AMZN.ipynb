# %%
import workflow
workflow.run(
    security = "AMZN",
)
# Out:
# Prices: 200.68 | 210.72 | 221.25 | 232.32 | 243.93 | 256.13 | 268.94
# Buy score: 0.47%
#                                            AMZN
# Company Name                         Amazon.com
# Current Price                            231.23
# Forward EPS                                6.15
# Gross Profit (ttm)              332,382,994,432
# Industry                        Internet Retail
# Revenue (ttm)                   670,038,032,384
# Target High Price                         306.0
# Target Low Price                          230.0
# Target Mean Price                      264.7213
# Trailing EPS                               6.55
# Website             https://www.aboutamazon.com
#                                             AMZN
# Currency                                     USD
# Dayhigh                                   233.48
# Daylow                                    228.79
# Exchange                                     NMS
# Fiftydayaverage                           227.38
# ...
