# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 202.86 | 213.00 | 223.65 | 238.90 | 250.85 | 263.39 | 276.56
# Buy score: 0.12%
# Sell score: -1.82%
# Current return: -746.06 USD
# Breakeven price: 242.02 USD
# <style type="text/css">
# #T_305a7_row25_col0, #T_305a7_row25_col1, #T_305a7_row25_col2, #T_305a7_row25_col3, #T_305a7_row25_col4, #T_305a7_row25_col5, #T_305a7_row25_col6, #T_305a7_row25_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_305a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_305a7_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_305a7_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_305a7_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_305a7_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_305a7_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
