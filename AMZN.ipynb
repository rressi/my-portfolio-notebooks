# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 200.26 | 210.28 | 220.79 | 228.88 | 240.32 | 252.34 | 264.95
# Buy score: -0.82%
# Sell score: 1.76%
# Current return: -12.51 USD
# Breakeven price: 233.21 USD
# <style type="text/css">
# #T_0071e_row19_col0, #T_0071e_row19_col1, #T_0071e_row19_col2, #T_0071e_row19_col3, #T_0071e_row19_col4, #T_0071e_row19_col5, #T_0071e_row19_col6, #T_0071e_row19_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_0071e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0071e_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_0071e_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_0071e_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_0071e_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_0071e_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
