# %%
import my_portfolio; my_portfolio.run("AMZN")
# Out:
# Prices: 200.61 | 210.64 | 221.17 | 232.23 | 243.84 | 256.04 | 268.84
# Buy score: 0.32%
#                                            AMZN
# Company Name                         Amazon.com
# Current Price                            231.48
# Forward EPS                                6.15
# Gross Profit (ttm)              332,382,994,432
# Industry                        Internet Retail
# Revenue (ttm)                   670,038,032,384
# Target High Price                         306.0
# Target Low Price                          230.0
# Target Mean Price                      264.7213
# Trailing EPS                               6.55
# Website             https://www.aboutamazon.com
#                                             AMZN
# Currency                                     USD
# Dayhigh                                   234.16
# Daylow                                    229.70
# Exchange                                     NMS
# Fiftydayaverage                           227.74
# ...
