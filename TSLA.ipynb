# %%
import my_portfolio; my_portfolio.run("TSLA")
# Out:
# Prices: 378.92 | 397.87 | 417.76 | 444.54 | 466.77 | 490.11 | 514.61
# Buy score: -0.71%
# Sell score: -0.62%
# Current return: -18.20 USD
# Breakeven price: 450.87 USD
# <style type="text/css">
# #T_bbb81_row68_col0, #T_bbb81_row68_col1, #T_bbb81_row68_col2, #T_bbb81_row68_col3, #T_bbb81_row68_col4, #T_bbb81_row68_col5, #T_bbb81_row68_col6, #T_bbb81_row68_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_bbb81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbb81_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_bbb81_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_bbb81_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_bbb81_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_bbb81_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
