# %%
import workflow
workflow.run(
    security = "TSLA",  # Tesla, Inc.
    # start_date = "2025-01-01",
)
# Out:
# Prices: 296.62 | 311.45 | 327.02 | 343.3753 | 360.54 | 378.57 | 397.50
# Buy score: -6.90%
#                                      TSLA
# Company Name                  Tesla, Inc.
# Industry               Auto Manufacturers
# Revenue (ttm)              92,719,996,928
# Gross Profit (ttm)         16,206,999,552
# Current Price                      368.81
# Target Mean Price                314.1008
# Target High Price                   500.0
# Target Low Price                    115.0
# Trailing EPS                         1.67
# Forward EPS                          3.24
# Website             https://www.tesla.com
#                                             TSLA
# Currency                                     USD
# Dayhigh                                   368.99
# Daylow                                    347.60
# Exchange                                     NMS
# Fiftydayaverage                           325.56
# Lastprice                                 368.81
# ...
