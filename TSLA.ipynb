# %%
import my_portfolio; my_portfolio.run("TSLA")
# Out:
# Prices: 392.32 | 411.94 | 432.53 | 452.01 | 474.61 | 498.34 | 523.26
# Buy score: 3.34%
# Sell score: -2.77%
# Current return: -75.46 USD
# Breakeven price: 458.36 USD
# <style type="text/css">
# #T_30f74_row82_col0, #T_30f74_row82_col1, #T_30f74_row82_col2, #T_30f74_row82_col3, #T_30f74_row82_col4, #T_30f74_row82_col5, #T_30f74_row82_col6, #T_30f74_row82_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_30f74">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30f74_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_30f74_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_30f74_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_30f74_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_30f74_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
