# %%
import my_portfolio; my_portfolio.run("TSLA")
# Out:
# Prices: 380.01 | 399.01 | 418.96 | 444.54 | 466.77 | 490.11 | 514.61
# Buy score: -2.00%
# Sell score: 0.98%
# Current return: -3.98 USD
# Breakeven price: 450.87 USD
# <style type="text/css">
# #T_3a00b_row68_col0, #T_3a00b_row68_col1, #T_3a00b_row68_col2, #T_3a00b_row68_col3, #T_3a00b_row68_col4, #T_3a00b_row68_col5, #T_3a00b_row68_col6, #T_3a00b_row68_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_3a00b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a00b_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_3a00b_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_3a00b_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_3a00b_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_3a00b_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
