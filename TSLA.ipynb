# %%
import my_portfolio; my_portfolio.run("TSLA")
# Out:
# Prices: 382.76 | 401.90 | 421.99 | 433.13 | 454.79 | 477.53 | 501.40
# Buy score: -0.94%
# Sell score: 3.27%
# Current return: 42.69 USD
# Breakeven price: 441.96 USD
# <style type="text/css">
# #T_f6ebc_row78_col0, #T_f6ebc_row78_col1, #T_f6ebc_row78_col2, #T_f6ebc_row78_col3, #T_f6ebc_row78_col4, #T_f6ebc_row78_col5, #T_f6ebc_row78_col6, #T_f6ebc_row78_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_f6ebc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6ebc_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_f6ebc_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_f6ebc_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_f6ebc_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_f6ebc_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
