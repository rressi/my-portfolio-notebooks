# %%
import my_portfolio; my_portfolio.run("TSLA")
# Out:
# Prices: 337.45 | 354.32 | 372.03 | 390.64 | 410.17 | 430.68 | 452.21
# Buy score: -8.19%
#                                      TSLA
# Company Name                        Tesla
# Current Price                      426.07
# Forward EPS                          3.24
# Gross Profit (ttm)         16,206,999,552
# Industry               Auto Manufacturers
# Revenue (ttm)              92,719,996,928
# Target High Price                   548.0
# Target Low Price                    115.0
# Target Mean Price               331.57684
# Trailing EPS                         1.66
# Website             https://www.tesla.com
#                                             TSLA
# Currency                                     USD
# Dayhigh                                   429.47
# Daylow                                    421.72
# Exchange                                     NMS
# Fiftydayaverage                           340.27
# Lastprice                                 426.07
# ...
