# %%
import my_portfolio; my_portfolio.run("TSLA")
# Out:
# Prices: 395.71 | 415.49 | 436.27 | 452.01 | 474.61 | 498.34 | 523.26
# Buy score: -1.25%
# Sell score: 2.62%
# Current return: 22.04 USD
# Breakeven price: 458.36 USD
# <style type="text/css">
# #T_efa49_row82_col0, #T_efa49_row82_col1, #T_efa49_row82_col2, #T_efa49_row82_col3, #T_efa49_row82_col4, #T_efa49_row82_col5, #T_efa49_row82_col6, #T_efa49_row82_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_efa49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efa49_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_efa49_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_efa49_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_efa49_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_efa49_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
