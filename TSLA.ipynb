# %%
import my_portfolio; my_portfolio.run("TSLA")
# Out:
# Prices: 345.03 | 362.28 | 380.40 | 399.42 | 419.39 | 440.36 | 462.37
# Buy score: -8.46%
#                                      TSLA
# Company Name                        Tesla
# Current Price                      434.21
# Forward EPS                          3.24
# Gross Profit (ttm)         16,206,999,552
# Industry               Auto Manufacturers
# Revenue (ttm)              92,719,996,928
# Target High Price                   548.0
# Target Low Price                    115.0
# Target Mean Price               334.20844
# Trailing EPS                         1.69
# Website             https://www.tesla.com
#                                             TSLA
# Currency                                     USD
# Dayhigh                                   444.98
# Daylow                                    429.13
# Exchange                                     NMS
# Fiftydayaverage                           340.27
# Lastprice                                 434.21
# ...
