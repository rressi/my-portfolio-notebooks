# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 98.64 | 103.57 | 108.75 | 114.19 | 119.90 | 125.89 | 132.19
# Buy score: -8.50%
#                                          CRWV
# Company Name                        CoreWeave
# Current Price                          124.86
# Forward EPS                              None
# Gross Profit (ttm)              2,625,437,952
# Industry            Software - Infrastructure
# Revenue (ttm)                   3,525,790,976
# Target High Price                       180.0
# Target Low Price                         32.0
# Target Mean Price                   129.19261
# Trailing EPS                            -2.32
# Website             https://www.coreweave.com
#                                          CRWV
# Currency                                  USD
# Dayhigh                                129.39
# Daylow                                 122.00
# Exchange                                  NMS
# Fiftydayaverage                        111.85
# ...
