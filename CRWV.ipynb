# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 93.75 | 98.43 | 103.36 | 84.97 | 89.22 | 93.68 | 98.37
# Buy score: -1.36%
# Sell score: 5.05%
# Current return: 616.52 USD
# Breakeven price: 86.18 USD
# <style type="text/css">
# #T_c0891_row30_col0, #T_c0891_row30_col1, #T_c0891_row30_col2, #T_c0891_row30_col3, #T_c0891_row30_col4, #T_c0891_row30_col5, #T_c0891_row30_col6, #T_c0891_row30_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_c0891">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0891_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c0891_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c0891_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c0891_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c0891_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
