# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 106.29 | 111.60 | 117.18 | 102.50 | 107.62 | 113.01 | 118.66
# Buy score: 18.63%
# Sell score: -24.14%
# Current return: -791.57 USD
# Breakeven price: 104.14 USD
# <style type="text/css">
# #T_b5f03_row26_col0, #T_b5f03_row26_col1, #T_b5f03_row26_col2, #T_b5f03_row26_col3, #T_b5f03_row26_col4, #T_b5f03_row26_col5, #T_b5f03_row26_col6, #T_b5f03_row26_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_b5f03">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5f03_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_b5f03_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_b5f03_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_b5f03_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_b5f03_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
