# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 115.07 | 120.82 | 126.86 | 137.50 | 144.38 | 151.59 | 159.17
# Buy score: 5.28%
# Sell score: -7.98%
# Current return: -89.67 USD
# Breakeven price: 139.34 USD
# <style type="text/css">
# #T_221c1_row22_col0, #T_221c1_row22_col1, #T_221c1_row22_col2, #T_221c1_row22_col3, #T_221c1_row22_col4, #T_221c1_row22_col5, #T_221c1_row22_col6, #T_221c1_row22_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_221c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_221c1_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_221c1_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_221c1_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_221c1_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_221c1_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
