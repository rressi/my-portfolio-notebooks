# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 78.24 | 82.15 | 86.26 | 84.97 | 89.22 | 93.68 | 98.37
# Buy score: -5.42%
# Sell score: -6.39%
# Current return: -1,480.11 USD
# Breakeven price: 94.35 USD
# <style type="text/css">
# #T_7cf4d_row31_col0, #T_7cf4d_row31_col1, #T_7cf4d_row31_col2, #T_7cf4d_row31_col3, #T_7cf4d_row31_col4, #T_7cf4d_row31_col5, #T_7cf4d_row31_col6, #T_7cf4d_row31_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_7cf4d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cf4d_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_7cf4d_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_7cf4d_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_7cf4d_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_7cf4d_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
