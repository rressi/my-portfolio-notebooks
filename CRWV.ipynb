# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 97.17 | 102.03 | 107.13 | 84.97 | 89.22 | 93.68 | 98.37
# Buy score: -2.79%
# Sell score: -8.39%
# Current return: -1,667.49 USD
# Breakeven price: 86.18 USD
# <style type="text/css">
# #T_6296f_row30_col0, #T_6296f_row30_col1, #T_6296f_row30_col2, #T_6296f_row30_col3, #T_6296f_row30_col4, #T_6296f_row30_col5, #T_6296f_row30_col6, #T_6296f_row30_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_6296f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6296f_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_6296f_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_6296f_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_6296f_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_6296f_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
