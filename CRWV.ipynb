# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 105.34 | 110.61 | 116.14 | 90.62 | 95.16 | 99.91 | 104.91
# Buy score: 4.02%
# Sell score: -16.97%
# Current return: -1,018.81 USD
# Breakeven price: 92.23 USD
# <style type="text/css">
# #T_d85e5_row29_col0, #T_d85e5_row29_col1, #T_d85e5_row29_col2, #T_d85e5_row29_col3, #T_d85e5_row29_col4, #T_d85e5_row29_col5, #T_d85e5_row29_col6, #T_d85e5_row29_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_d85e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d85e5_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_d85e5_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_d85e5_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_d85e5_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_d85e5_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
