# %%
import workflow
workflow.run("CRWV",
"""
date,quantity,price
2025-08-18,3.0,101.06
2025-08-18,6.0,101.06
2025-08-18,3.0,99.02
2025-08-18,6.0,99.02
2025-08-18,9.0,97.0
2025-08-22,10.0,93.8494
2025-08-27,-5.0,97.0
2025-08-27,-14.0,97.0
2025-08-28,-5.0,105.0
2025-08-28,-13.0,105.0
2025-08-29,19.0,99.1995
2025-09-02,15.0,91.7793
2025-09-09,-3.0,100.7
2025-09-09,-6.0,100.7
2025-09-10,-9.0,110.9406
2025-09-10,-2.0,115.5
2025-09-10,-6.0,115.5
2025-09-12,-8.0,108.0007
""")
# Out:
# Prices: 84.13 | 88.34 | 92.75 | nan | 102.26 | 107.37 | 112.74
# Buy score: -13.01%
#                                          CRWV
# Company Name                        CoreWeave
# Current Price                          111.96
# Forward EPS                              None
# Gross Profit (ttm)              2,625,437,952
# Industry            Software - Infrastructure
# Revenue (ttm)                   3,525,790,976
# Target High Price                       180.0
# Target Low Price                         32.0
# Target Mean Price                    123.9215
# Trailing EPS                            -2.32
# Website             https://www.coreweave.com
#                                          CRWV
# Currency                                  USD
# Dayhigh                                115.31
# Daylow                                 104.07
# Exchange                                  NMS
# Fiftydayaverage                        115.07
# Lastprice                              111.96
# Lastvolume                         32,488,900
# Marketcap                   54,700,520,672.70
# Open                                   113.93
# Previousclose                          114.65
# Quotetype                              EQUITY
# Regularmarketpreviousclose             112.69
# Shares                            488,572,000
# Tendayaveragevolume                30,559,550
# Threemonthaveragevolume            21,164,176
# Timezone                     America/New_York
# Twohundreddayaverage                   102.20
# Yearchange                               1.80
# Yearhigh                               187.00
# Yearlow                                 33.51
