# %%
import workflow
workflow.run(
    security = "CRWV",
    buy_date = "2025-09-02",
    buy_price = 95.92,
)
# Out:
# Prices: 83.59 | 87.77 | 92.16 | 95.9200 | 100.72 | 105.75 | 111.04
# Buy score: -14.13%
# Sell score: 17.48%
#                                          CRWV
# Company Name                        CoreWeave
# Industry            Software - Infrastructure
# Revenue (ttm)                   3,525,790,976
# Gross Profit (ttm)              2,625,437,952
# Current Price                          112.69
# Target Mean Price                    123.9215
# Target High Price                       180.0
# Target Low Price                         32.0
# Trailing EPS                            -2.32
# Forward EPS                              None
# Website             https://www.coreweave.com
#                                          CRWV
# Currency                                  USD
# Dayhigh                                118.64
# Daylow                                 112.13
# Exchange                                  NMS
# Fiftydayaverage                        116.73
# ...
