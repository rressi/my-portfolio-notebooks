# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 104.08 | 109.29 | 114.75 | 84.97 | 89.22 | 93.68 | 98.37
# Buy score: -6.26%
# Sell score: -3.47%
# Current return: -830.84 USD
# Breakeven price: 86.18 USD
# <style type="text/css">
# #T_0e941_row30_col0, #T_0e941_row30_col1, #T_0e941_row30_col2, #T_0e941_row30_col3, #T_0e941_row30_col4, #T_0e941_row30_col5, #T_0e941_row30_col6, #T_0e941_row30_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_0e941">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e941_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_0e941_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_0e941_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_0e941_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_0e941_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
