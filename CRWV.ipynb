# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 76.66 | 80.50 | 84.52 | 84.97 | 89.22 | 93.68 | 98.37
# Buy score: -1.40%
# Sell score: -9.66%
# Current return: -1,758.01 USD
# Breakeven price: 94.35 USD
# <style type="text/css">
# #T_0d76e_row31_col0, #T_0d76e_row31_col1, #T_0d76e_row31_col2, #T_0d76e_row31_col3, #T_0d76e_row31_col4, #T_0d76e_row31_col5, #T_0d76e_row31_col6, #T_0d76e_row31_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_0d76e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d76e_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_0d76e_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_0d76e_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_0d76e_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_0d76e_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
