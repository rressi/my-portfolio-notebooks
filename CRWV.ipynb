# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 106.59 | 111.92 | 117.52 | 109.00 | 114.45 | 120.17 | 126.18
# Buy score: 4.73%
# Sell score: -4.48%
# Current return: -98.10 USD
# Breakeven price: 110.66 USD
# <style type="text/css">
# #T_07780_row25_col0, #T_07780_row25_col1, #T_07780_row25_col2, #T_07780_row25_col3, #T_07780_row25_col4, #T_07780_row25_col5, #T_07780_row25_col6, #T_07780_row25_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_07780">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07780_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_07780_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_07780_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_07780_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_07780_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
