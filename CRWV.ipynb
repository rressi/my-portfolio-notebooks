# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 96.39 | 101.20 | 106.26 | 84.97 | 89.22 | 93.68 | 98.37
# Buy score: -9.41%
# Sell score: 1.88%
# Current return: 78.51 USD
# Breakeven price: 86.18 USD
# <style type="text/css">
# #T_a84b7_row30_col0, #T_a84b7_row30_col1, #T_a84b7_row30_col2, #T_a84b7_row30_col3, #T_a84b7_row30_col4, #T_a84b7_row30_col5, #T_a84b7_row30_col6, #T_a84b7_row30_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_a84b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a84b7_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_a84b7_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_a84b7_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_a84b7_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_a84b7_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
