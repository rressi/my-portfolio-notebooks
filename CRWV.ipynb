# %%
import my_portfolio; my_portfolio.run("CRWV")
# Out:
# Prices: 104.61 | 109.85 | 115.34 | 90.62 | 95.16 | 99.91 | 104.91
# Buy score: -7.67%
# Sell score: -8.97%
# Current return: -583.81 USD
# Breakeven price: 92.23 USD
# <style type="text/css">
# #T_cf9a9_row29_col0, #T_cf9a9_row29_col1, #T_cf9a9_row29_col2, #T_cf9a9_row29_col3, #T_cf9a9_row29_col4, #T_cf9a9_row29_col5, #T_cf9a9_row29_col6, #T_cf9a9_row29_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_cf9a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf9a9_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_cf9a9_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_cf9a9_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_cf9a9_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_cf9a9_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
