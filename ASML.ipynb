# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,520.74 | 1,596.77 | 1,676.61 | 1,760.44 | 1,848.47 | 1,940.89 | 2,037.93
# Buy score: -4.22%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1899.48
# Forward EPS                                    47.85243
# Gross Profit (ttm)                       17,723,299,840
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            33,692,700,672
# Target High Price                             2260.3909
# Target Low Price                               895.0023
# Target Mean Price                              1701.323
# Trailing EPS                                      29.82
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
