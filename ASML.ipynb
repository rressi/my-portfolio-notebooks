# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 863.21 | 906.37 | 951.69 | 999.27 | 1,049.24 | 1,101.70 | 1,156.78
# Buy score: -2.84%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1032.22
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1106.2983
# Target Low Price                               600.5637
# Target Mean Price                              875.9085
# Trailing EPS                                      28.23
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
