# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 997.93 | 1,047.83 | 1,100.22 | 1,155.23 | 1,212.99 | 1,273.64 | 1,337.33
# Buy score: -5.84%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1242.19
# Forward EPS                                   30.839539
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                              1520.499
# Target Low Price                              846.18506
# Target Mean Price                             1167.3453
# Trailing EPS                                      28.45
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
