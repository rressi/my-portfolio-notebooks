# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,285.19 | 1,349.45 | 1,416.92 | 1,487.76 | 1,562.15 | 1,640.26 | 1,722.27
# Buy score: -2.15%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1526.51
# Forward EPS                                   43.947598
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1914.8364
# Target Low Price                               913.7121
# Target Mean Price                             1487.0898
# Trailing EPS                                      29.16
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
