# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,408.11 | 1,478.52 | 1,552.45 | 1,630.07 | 1,711.57 | 1,797.15 | 1,887.01
# Buy score: -4.84%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1705.37
# Forward EPS                                    47.86273
# Gross Profit (ttm)                       17,723,299,840
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            33,692,700,672
# Target High Price                             1999.0707
# Target Low Price                                898.641
# Target Mean Price                             1662.4677
# Trailing EPS                                      30.19
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
