# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 849.41 | 891.88 | 936.48 | 983.30 | 1,032.47 | 1,084.09 | 1,138.30
# Buy score: -4.63%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1031.025
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1104.2235
# Target Low Price                               599.4374
# Target Mean Price                              874.2657
# Trailing EPS                                       29.2
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
