# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,396.19 | 1,466.00 | 1,539.30 | 1,616.27 | 1,697.08 | 1,781.93 | 1,871.03
# Buy score: 0.20%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1612.76
# Forward EPS                                    47.71562
# Gross Profit (ttm)                       17,723,299,840
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            33,692,700,672
# Target High Price                             2006.0613
# Target Low Price                              901.78345
# Target Mean Price                             1668.2811
# Trailing EPS                                       30.0
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
