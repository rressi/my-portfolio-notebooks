# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,111.22 | 1,166.78 | 1,225.12 | 1,286.38 | 1,350.70 | 1,418.23 | 1,489.14
# Buy score: -4.21%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1342.9
# Forward EPS                                   31.110905
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1545.3177
# Target Low Price                               841.1711
# Target Mean Price                             1240.8956
# Trailing EPS                                      28.18
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
