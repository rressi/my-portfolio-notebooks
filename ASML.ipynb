# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 967.49 | 1,015.87 | 1,066.66 | 1,119.99 | 1,175.99 | 1,234.79 | 1,296.53
# Buy score: -8.44%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1228.19
# Forward EPS                                   30.810055
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1525.4913
# Target Low Price                               848.9634
# Target Mean Price                              1167.402
# Trailing EPS                                      30.09
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
