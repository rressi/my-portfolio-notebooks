# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,109.27 | 1,164.73 | 1,222.97 | 1,284.12 | 1,348.32 | 1,415.74 | 1,486.53
# Buy score: -4.36%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1331.6
# Forward EPS                                   31.120258
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1544.7793
# Target Low Price                                840.878
# Target Mean Price                             1240.4633
# Trailing EPS                                      28.23
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
