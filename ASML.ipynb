# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,198.93 | 1,258.88 | 1,321.82 | 1,387.91 | 1,457.31 | 1,530.18 | 1,606.68
# Buy score: -1.04%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1413.01
# Forward EPS                                    43.40249
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1900.1161
# Target Low Price                               917.9402
# Target Mean Price                              1492.399
# Trailing EPS                                      29.11
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
