# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 918.05 | 963.95 | 1,012.15 | 1,062.76 | 1,115.90 | 1,171.69 | 1,230.28
# Buy score: 2.05%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1041.459
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1174.8524
# Target Low Price                               742.8538
# Target Mean Price                            1000.20984
# Trailing EPS                                      27.92
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
