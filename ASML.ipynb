# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,461.53 | 1,534.60 | 1,611.34 | 1,691.90 | 1,776.50 | 1,865.32 | 1,958.59
# Buy score: 3.11%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1641.74
# Forward EPS                                   47.755688
# Gross Profit (ttm)                       17,723,299,840
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            33,692,700,672
# Target High Price                             2252.3135
# Target Low Price                                891.804
# Target Mean Price                              1694.953
# Trailing EPS                                      30.04
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
