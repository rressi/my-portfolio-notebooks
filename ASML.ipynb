# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 879.43 | 923.40 | 969.57 | 1,018.05 | 1,068.95 | 1,122.40 | 1,178.52
# Buy score: -3.78%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1039.33
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1178.9126
# Target Low Price                                745.421
# Target Mean Price                            1016.72107
# Trailing EPS                                      28.06
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
