# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 939.34 | 986.31 | 1,035.62 | 1,087.40 | 1,141.77 | 1,198.86 | 1,258.81
# Buy score: -5.96%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1156.27
# Forward EPS                                   30.743517
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1499.2957
# Target Low Price                               849.9601
# Target Mean Price                             1124.4266
# Trailing EPS                                      28.46
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
