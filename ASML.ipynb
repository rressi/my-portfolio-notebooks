# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,242.26 | 1,304.37 | 1,369.59 | 1,438.07 | 1,509.97 | 1,585.47 | 1,664.74
# Buy score: -0.43%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1444.44
# Forward EPS                                    43.51035
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1908.2673
# Target Low Price                                921.878
# Target Mean Price                             1471.8167
# Trailing EPS                                      29.54
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
