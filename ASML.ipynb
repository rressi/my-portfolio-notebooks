# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 888.34 | 932.76 | 979.40 | 1,028.37 | 1,079.79 | 1,133.78 | 1,190.46
# Buy score: -0.53%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1033.83
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1182.8632
# Target Low Price                              751.30615
# Target Mean Price                             1003.4857
# Trailing EPS                                      28.02
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
