# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,179.79 | 1,238.78 | 1,300.72 | 1,365.75 | 1,434.04 | 1,505.74 | 1,581.03
# Buy score: -1.83%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1389.04
# Forward EPS                                   32.285862
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                              1694.193
# Target Low Price                              916.85236
# Target Mean Price                             1350.7982
# Trailing EPS                                      28.48
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
