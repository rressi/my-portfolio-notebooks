# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 844.87 | 887.11 | 931.47 | 978.04 | 1,026.95 | 1,078.29 | 1,132.21
# Buy score: -0.54%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   983.375
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1178.8331
# Target Low Price                              591.94354
# Target Mean Price                              939.5072
# Trailing EPS                                      27.99
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
