# %%
import workflow
workflow.run(
    security = "ARM",
)
# Out:
# Prices: 121.27 | 127.33 | 133.70 | 140.38 | 147.40 | 154.77 | 162.51
# Buy score: -8.76%
#                                     ARM
# Company Name               Arm Holdings
# Current Price                    153.86
# Forward EPS                        2.06
# Gross Profit (ttm)        4,003,000,064
# Industry                 Semiconductors
# Revenue (ttm)             4,120,999,936
# Target High Price                 210.0
# Target Low Price                   80.0
# Target Mean Price             152.74242
# Trailing EPS                       0.68
# Website             https://www.arm.com
#                                            ARM
# Currency                                   USD
# Dayhigh                                 154.98
# Daylow                                  151.02
# Exchange                                   NMS
# Fiftydayaverage                         145.37
# Lastprice                               153.86
# Lastvolume                           2,564,400
# ...
