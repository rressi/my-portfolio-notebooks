# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,273.97 | 1,337.67 | 1,404.55 | 1,474.78 | 1,548.52 | 1,625.94 | 1,707.24
# Buy score: -1.07%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1490.66
# Forward EPS                                   44.175304
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1893.4241
# Target Low Price                              912.20374
# Target Mean Price                             1483.4181
# Trailing EPS                                      29.27
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
