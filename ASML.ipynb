# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,243.42 | 1,305.59 | 1,370.87 | 1,439.41 | 1,511.38 | 1,586.95 | 1,666.30
# Buy score: -0.46%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1441.39
# Forward EPS                                    43.49941
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1892.0344
# Target Low Price                               914.0359
# Target Mean Price                             1486.0514
# Trailing EPS                                      29.26
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
