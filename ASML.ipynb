# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 868.42 | 911.84 | 957.43 | 1,005.30 | 1,055.57 | 1,108.35 | 1,163.76
# Buy score: -2.50%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1029.27
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1186.9395
# Target Low Price                               731.2821
# Target Mean Price                             972.76544
# Trailing EPS                                       28.0
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
