# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,247.28 | 1,309.65 | 1,375.13 | 1,443.89 | 1,516.08 | 1,591.88 | 1,671.48
# Buy score: -1.47%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1465.385
# Forward EPS                                   44.002842
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1890.9716
# Target Low Price                              911.02216
# Target Mean Price                             1481.4966
# Trailing EPS                                      29.32
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
