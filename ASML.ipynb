# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,045.32 | 1,097.58 | 1,152.46 | 1,210.09 | 1,270.59 | 1,334.12 | 1,400.83
# Buy score: 1.88%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1187.805
# Forward EPS                                    30.84434
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1515.5394
# Target Low Price                                843.425
# Target Mean Price                             1178.4846
# Trailing EPS                                      28.38
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
