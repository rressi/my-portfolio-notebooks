# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# Prices: 747.40 | 784.77 | 824.00 | 865.20 | 908.46 | 953.89 | 1,001.58
# Buy score: -9.54%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                     957.8
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1076.3881
# Target Low Price                              602.82916
# Target Mean Price                              860.9453
# Trailing EPS                                      28.26
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# Dayhigh                                 964.54
# ...
