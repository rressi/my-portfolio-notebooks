# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 883.06 | 927.21 | 973.57 | 1,022.25 | 1,073.36 | 1,127.03 | 1,183.38
# Buy score: 1.71%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1002.3
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1183.0785
# Target Low Price                              594.07526
# Target Mean Price                             926.01337
# Trailing EPS                                      28.16
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
