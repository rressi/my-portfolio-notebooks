# %%
import workflow
workflow.run(
    security = "ARM",
)
# Out:
# Prices: 128.30 | 134.71 | 141.45 | 148.52 | 155.95 | 163.74 | 171.93
# Buy score: 1.35%
#                                     ARM
# Company Name               Arm Holdings
# Current Price                    146.54
# Forward EPS                        2.06
# Gross Profit (ttm)        4,003,000,064
# Industry                 Semiconductors
# Revenue (ttm)             4,120,999,936
# Target High Price                 210.0
# Target Low Price                   80.0
# Target Mean Price             152.74242
# Trailing EPS                       0.66
# Website             https://www.arm.com
#                                            ARM
# Currency                                   USD
# Dayhigh                                 149.24
# Daylow                                  142.00
# Exchange                                   NMS
# Fiftydayaverage                         145.60
# Lastprice                               146.54
# Lastvolume                          12,079,224
# ...
