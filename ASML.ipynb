# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 844.99 | 887.23 | 931.60 | 978.18 | 1,027.08 | 1,078.44 | 1,132.36
# Buy score: -2.80%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1006.31
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1185.1437
# Target Low Price                               730.1757
# Target Mean Price                              967.8694
# Trailing EPS                                      27.92
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
