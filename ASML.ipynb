# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# Prices: 733.44 | 770.11 | 808.62 | 849.05 | 891.50 | 936.08 | 982.88
# Buy score: -8.91%
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    932.15
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1072.4688
# Target Low Price                               600.6342
# Target Mean Price                              857.8105
# Trailing EPS                                      28.43
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# Dayhigh                                 938.65
# Daylow                                  925.87
# ...
