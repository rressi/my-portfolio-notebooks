# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 845.09 | 887.35 | 931.71 | 978.30 | 1,027.21 | 1,078.58 | 1,132.50
# Buy score: 0.13%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    984.66
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1179.7891
# Target Low Price                               592.4235
# Target Mean Price                             940.26904
# Trailing EPS                                      27.96
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
