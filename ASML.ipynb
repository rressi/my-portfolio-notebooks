# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,201.56 | 1,261.64 | 1,324.72 | 1,390.96 | 1,460.50 | 1,533.53 | 1,610.21
# Buy score: 2.62%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1355.385
# Forward EPS                                   43.376053
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                               1888.91
# Target Low Price                              912.52655
# Target Mean Price                             1483.5975
# Trailing EPS                                      29.19
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
