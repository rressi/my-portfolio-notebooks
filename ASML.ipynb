# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 897.41 | 942.29 | 989.40 | 1,038.87 | 1,090.81 | 1,145.35 | 1,202.62
# Buy score: -1.37%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1053.29
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1188.2435
# Target Low Price                               754.7235
# Target Mean Price                             1008.0502
# Trailing EPS                                      27.98
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
