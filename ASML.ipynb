# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 872.92 | 899.11 | 926.08 | 953.86 | 982.48 | 1,011.95 | 1,042.31
# Buy score: 0.36%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    951.52
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1069.0785
# Target Low Price                              598.73553
# Target Mean Price                              855.0988
# Trailing EPS                                      28.26
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# Dayhigh                                 955.22
# ...
