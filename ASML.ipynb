# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 911.64 | 957.22 | 1,005.08 | 1,055.33 | 1,108.10 | 1,163.51 | 1,221.68
# Buy score: -0.96%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1065.52
# Forward EPS                                   30.478737
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1344.8038
# Target Low Price                               762.6399
# Target Mean Price                             1071.6853
# Trailing EPS                                      28.46
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
