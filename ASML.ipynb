# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 885.76 | 930.04 | 976.55 | 1,025.37 | 1,076.64 | 1,130.47 | 1,187.00
# Buy score: 1.38%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1011.37
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1188.7722
# Target Low Price                               751.6552
# Target Mean Price                             1012.0604
# Trailing EPS                                      28.05
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
