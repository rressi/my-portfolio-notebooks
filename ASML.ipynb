# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 889.02 | 933.47 | 980.14 | 1,029.15 | 1,080.60 | 1,134.63 | 1,191.37
# Buy score: 0.34%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1025.68
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1181.9078
# Target Low Price                               747.3149
# Target Mean Price                             1006.2165
# Trailing EPS                                      27.97
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
