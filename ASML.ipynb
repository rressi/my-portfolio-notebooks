# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 885.58 | 929.86 | 976.35 | 1,025.17 | 1,076.43 | 1,130.25 | 1,186.76
# Buy score: 0.45%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1025.02
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1182.3917
# Target Low Price                               728.4802
# Target Mean Price                              968.5332
# Trailing EPS                                      28.09
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
