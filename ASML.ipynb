# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,215.03 | 1,275.78 | 1,339.57 | 1,406.55 | 1,476.88 | 1,550.72 | 1,628.26
# Buy score: -1.78%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1432.0
# Forward EPS                                   44.185177
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1903.0516
# Target Low Price                              919.35834
# Target Mean Price                             1494.7046
# Trailing EPS                                       29.4
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
