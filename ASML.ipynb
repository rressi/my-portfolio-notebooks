# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,253.36 | 1,316.03 | 1,381.83 | 1,450.93 | 1,523.47 | 1,599.65 | 1,679.63
# Buy score: -0.52%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1457.7
# Forward EPS                                    47.50866
# Gross Profit (ttm)                       17,723,299,840
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            33,692,700,672
# Target High Price                             2001.1726
# Target Low Price                               907.1764
# Target Mean Price                              1662.064
# Trailing EPS                                      30.32
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
