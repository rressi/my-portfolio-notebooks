# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,123.90 | 1,180.10 | 1,239.10 | 1,301.06 | 1,366.11 | 1,434.41 | 1,506.13
# Buy score: -4.23%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1358.766
# Forward EPS                                    31.28886
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1583.7809
# Target Low Price                               900.8384
# Target Mean Price                             1314.9102
# Trailing EPS                                      28.12
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
