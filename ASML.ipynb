# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,222.31 | 1,283.43 | 1,347.60 | 1,414.98 | 1,485.73 | 1,560.02 | 1,638.02
# Buy score: -0.95%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1422.92
# Forward EPS                                   40.916332
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                              1864.206
# Target Low Price                               924.1906
# Target Mean Price                             1397.7483
# Trailing EPS                                       28.8
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
