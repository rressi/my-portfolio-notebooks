# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,202.73 | 1,262.86 | 1,326.00 | 1,391.69 | 1,461.27 | 1,534.33 | 1,611.05
# Buy score: -6.11%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1478.28
# Forward EPS                                   44.792576
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             2005.9081
# Target Low Price                               907.3892
# Target Mean Price                             1502.4205
# Trailing EPS                                      28.83
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
