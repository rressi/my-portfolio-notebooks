# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,313.08 | 1,378.73 | 1,447.67 | 1,520.05 | 1,596.05 | 1,675.86 | 1,759.65
# Buy score: 4.12%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1459.97
# Forward EPS                                   47.573627
# Gross Profit (ttm)                       17,723,299,840
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            33,692,700,672
# Target High Price                             1996.0565
# Target Low Price                                897.286
# Target Mean Price                              1657.245
# Trailing EPS                                      30.04
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
