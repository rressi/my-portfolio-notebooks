# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 889.45 | 933.92 | 980.62 | 1,029.65 | 1,081.13 | 1,135.19 | 1,191.95
# Buy score: -0.52%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1033.1
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1184.6511
# Target Low Price                              752.44183
# Target Mean Price                            1005.00256
# Trailing EPS                                      27.89
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
