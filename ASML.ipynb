# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 963.49 | 1,011.66 | 1,062.24 | 1,115.36 | 1,171.12 | 1,229.68 | 1,291.16
# Buy score: -0.19%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1117.53
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1328.0563
# Target Low Price                               753.1424
# Target Mean Price                             1059.3744
# Trailing EPS                                      28.26
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
