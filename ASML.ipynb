# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,201.74 | 1,261.82 | 1,324.91 | 1,359.48 | 1,427.45 | 1,498.82 | 1,573.76
# Buy score: -6.86%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1448.64
# Forward EPS                                     43.7685
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1999.3418
# Target Low Price                              904.41895
# Target Mean Price                             1497.5024
# Trailing EPS                                      28.83
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
