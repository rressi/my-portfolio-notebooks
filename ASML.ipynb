# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,211.46 | 1,272.03 | 1,335.63 | 1,402.41 | 1,472.53 | 1,546.16 | 1,623.47
# Buy score: -8.53%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1454.59
# Forward EPS                                    40.69685
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1712.6633
# Target Low Price                                926.848
# Target Mean Price                             1364.8925
# Trailing EPS                                       28.8
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
