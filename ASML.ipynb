# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 920.60 | 966.63 | 1,014.96 | 1,065.71 | 1,119.00 | 1,174.95 | 1,233.69
# Buy score: 0.90%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1056.21
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1174.7177
# Target Low Price                              742.76855
# Target Mean Price                             1000.0951
# Trailing EPS                                      27.95
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
