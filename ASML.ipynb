# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 923.66 | 969.84 | 1,018.34 | 1,069.25 | 1,122.72 | 1,178.85 | 1,237.80
# Buy score: -0.13%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1069.86
# Forward EPS                                   30.431068
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1340.6956
# Target Low Price                               760.3101
# Target Mean Price                             1068.4114
# Trailing EPS                                      28.46
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
