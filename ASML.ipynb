# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 916.10 | 961.90 | 1,010.00 | 1,060.50 | 1,113.52 | 1,169.20 | 1,227.66
# Buy score: 3.26%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1030.14
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1175.2572
# Target Low Price                              743.10974
# Target Mean Price                            1000.55444
# Trailing EPS                                      26.99
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
