# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,222.69 | 1,283.83 | 1,348.02 | 1,415.42 | 1,486.19 | 1,560.50 | 1,638.52
# Buy score: 2.26%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1427.02
# Forward EPS                                    47.80391
# Gross Profit (ttm)                       17,723,299,840
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            33,692,700,672
# Target High Price                             1994.1514
# Target Low Price                              904.94794
# Target Mean Price                             1657.8408
# Trailing EPS                                      30.25
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
