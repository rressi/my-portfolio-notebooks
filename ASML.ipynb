# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 774.36 | 813.08 | 853.74 | 896.42 | 941.24 | 988.31 | 1,037.72
# Buy score: -5.33%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    946.94
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                              1072.217
# Target Low Price                               600.4932
# Target Mean Price                             857.60913
# Trailing EPS                                      28.23
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# Dayhigh                                 953.60
# ...
