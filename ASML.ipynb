# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 907.02 | 952.38 | 999.99 | 1,049.99 | 1,102.49 | 1,157.62 | 1,215.50
# Buy score: -1.70%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1068.15
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1181.4913
# Target Low Price                               750.4349
# Target Mean Price                            1002.32196
# Trailing EPS                                       28.0
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
