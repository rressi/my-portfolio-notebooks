# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 835.34 | 877.10 | 920.96 | 967.01 | 1,015.36 | 1,066.13 | 1,119.43
# Buy score: -3.33%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1003.27
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1073.6038
# Target Low Price                              601.26984
# Target Mean Price                             859.33704
# Trailing EPS                                       29.2
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
