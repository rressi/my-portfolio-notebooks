# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 855.22 | 897.98 | 942.88 | 990.03 | 1,039.53 | 1,091.51 | 1,146.08
# Buy score: 4.21%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    936.19
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1182.8036
# Target Low Price                              593.93726
# Target Mean Price                              942.6716
# Trailing EPS                                      28.04
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
