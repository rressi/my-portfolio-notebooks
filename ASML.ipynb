# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 939.10 | 986.06 | 1,035.36 | 1,087.13 | 1,141.48 | 1,198.56 | 1,258.49
# Buy score: -4.46%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1137.9
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1339.3917
# Target Low Price                               755.5166
# Target Mean Price                             1063.5159
# Trailing EPS                                      28.16
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
