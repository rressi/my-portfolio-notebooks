# %%
import workflow
workflow.run(
    security = "ARM",
)
# Out:
# Prices: 127.34 | 133.71 | 140.40 | 147.41 | 154.79 | 162.53 | 170.65
# Buy score: -3.88%
#                                     ARM
# Company Name               Arm Holdings
# Current Price                    153.37
# Forward EPS                        2.06
# Gross Profit (ttm)        4,003,000,064
# Industry                 Semiconductors
# Revenue (ttm)             4,120,999,936
# Target High Price                 210.0
# Target Low Price                   80.0
# Target Mean Price             152.74242
# Trailing EPS                       0.66
# Website             https://www.arm.com
#                                            ARM
# Currency                                   USD
# Dayhigh                                 154.66
# Daylow                                  150.10
# Exchange                                   NMS
# Fiftydayaverage                         145.48
# Lastprice                               153.37
# Lastvolume                           2,488,300
# ...
