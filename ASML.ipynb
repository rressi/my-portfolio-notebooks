# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,226.11 | 1,287.42 | 1,351.79 | 1,419.38 | 1,490.35 | 1,564.87 | 1,643.11
# Buy score: 0.74%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1408.895
# Forward EPS                                    44.14172
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1906.2358
# Target Low Price                               918.3761
# Target Mean Price                             1493.4556
# Trailing EPS                                      29.43
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
