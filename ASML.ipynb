# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 915.06 | 960.81 | 1,008.85 | 1,059.29 | 1,112.26 | 1,167.87 | 1,226.26
# Buy score: 2.50%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1036.31
# Forward EPS                                   30.418373
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1338.0231
# Target Low Price                              758.79456
# Target Mean Price                             1067.3247
# Trailing EPS                                      28.43
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
