# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,168.59 | 1,227.02 | 1,288.37 | 1,352.79 | 1,420.43 | 1,491.45 | 1,566.03
# Buy score: -2.51%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1387.635
# Forward EPS                                   31.881445
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1677.6904
# Target Low Price                               907.9216
# Target Mean Price                             1337.6404
# Trailing EPS                                      28.43
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
