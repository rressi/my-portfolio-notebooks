# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 919.85 | 965.84 | 1,014.13 | 1,064.84 | 1,118.08 | 1,173.98 | 1,232.68
# Buy score: -0.30%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1068.045
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1173.8679
# Target Low Price                               745.5928
# Target Mean Price                              995.8546
# Trailing EPS                                      28.07
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
