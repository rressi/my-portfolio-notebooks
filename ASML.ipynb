# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,145.36 | 1,202.62 | 1,262.75 | 1,325.89 | 1,392.19 | 1,461.80 | 1,534.89
# Buy score: -1.75%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1349.5
# Forward EPS                                    31.47255
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1592.8691
# Target Low Price                               906.0077
# Target Mean Price                             1322.4556
# Trailing EPS                                      28.25
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
