# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 824.81 | 866.06 | 909.36 | 954.83 | 1,002.57 | 1,052.70 | 1,105.33
# Buy score: -0.82%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    962.61
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                              1071.085
# Target Low Price                               599.8592
# Target Mean Price                              856.7037
# Trailing EPS                                      28.26
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
