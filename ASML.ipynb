# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,132.80 | 1,189.44 | 1,248.91 | 1,311.36 | 1,376.92 | 1,445.77 | 1,518.06
# Buy score: -1.60%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1332.56
# Forward EPS                                   31.387474
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1594.3629
# Target Low Price                              906.85736
# Target Mean Price                             1323.6958
# Trailing EPS                                      28.12
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
