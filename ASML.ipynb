# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,189.25 | 1,248.72 | 1,311.15 | 1,376.71 | 1,445.55 | 1,517.82 | 1,593.71
# Buy score: -2.75%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1413.35
# Forward EPS                                   32.493675
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1696.2031
# Target Low Price                               917.9402
# Target Mean Price                             1351.7747
# Trailing EPS                                      28.69
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
