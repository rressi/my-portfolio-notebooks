# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 761.08 | 799.13 | 839.09 | 881.04 | 925.09 | 971.35 | 1,019.92
# Buy score: -8.61%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    963.51
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1078.2947
# Target Low Price                                603.897
# Target Mean Price                              862.4703
# Trailing EPS                                      28.26
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# Dayhigh                                 977.48
# ...
