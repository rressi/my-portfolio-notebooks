# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 908.90 | 954.35 | 1,002.06 | 1,052.17 | 1,104.78 | 1,160.02 | 1,218.02
# Buy score: 1.66%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1029.2
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1180.9532
# Target Low Price                               746.7113
# Target Mean Price                            1005.40375
# Trailing EPS                                      27.79
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
