# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,180.31 | 1,239.33 | 1,301.30 | 1,366.36 | 1,434.68 | 1,506.41 | 1,581.73
# Buy score: -1.85%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1392.08
# Forward EPS                                   31.787092
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1680.2539
# Target Low Price                               909.3089
# Target Mean Price                             1339.6844
# Trailing EPS                                      28.32
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
