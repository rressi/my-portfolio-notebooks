# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 885.60 | 929.88 | 976.38 | 1,025.20 | 1,076.46 | 1,130.28 | 1,186.79
# Buy score: 1.46%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1010.48
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1191.4016
# Target Low Price                              753.31775
# Target Mean Price                            1014.29895
# Trailing EPS                                      28.11
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
