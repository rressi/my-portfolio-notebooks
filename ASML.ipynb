# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 841.79 | 883.88 | 928.07 | 974.48 | 1,023.20 | 1,074.36 | 1,128.08
# Buy score: -0.93%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    983.18
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1185.0059
# Target Low Price                               595.0431
# Target Mean Price                              944.4267
# Trailing EPS                                      27.92
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
