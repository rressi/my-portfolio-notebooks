# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,074.63 | 1,128.36 | 1,184.78 | 1,244.02 | 1,306.22 | 1,371.53 | 1,440.11
# Buy score: -2.64%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1281.23
# Forward EPS                                   30.997536
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1518.5466
# Target Low Price                               845.0986
# Target Mean Price                             1204.5172
# Trailing EPS                                      28.28
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
