# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 922.87 | 969.02 | 1,017.47 | 1,068.34 | 1,121.76 | 1,177.85 | 1,236.74
# Buy score: -0.68%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                 1075.6038
# Forward EPS                                   30.494282
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1341.0107
# Target Low Price                              760.48883
# Target Mean Price                             1068.6626
# Trailing EPS                                      28.57
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
