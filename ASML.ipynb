# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 879.08 | 923.03 | 969.19 | 1,017.65 | 1,068.53 | 1,121.95 | 1,178.05
# Buy score: 2.27%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1004.06
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                              1184.644
# Target Low Price                                749.045
# Target Mean Price                            1008.37946
# Trailing EPS                                      28.11
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
