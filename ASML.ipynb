# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 919.94 | 965.93 | 1,014.23 | 1,064.94 | 1,118.19 | 1,174.10 | 1,232.80
# Buy score: -0.25%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                 1067.6158
# Forward EPS                                     30.5005
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1343.3789
# Target Low Price                              761.83185
# Target Mean Price                             1070.5498
# Trailing EPS                                      28.54
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
