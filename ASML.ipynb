# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,275.20 | 1,338.96 | 1,405.91 | 1,476.21 | 1,550.02 | 1,627.52 | 1,708.89
# Buy score: -1.49%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1497.8
# Forward EPS                                   44.023003
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1894.3175
# Target Low Price                              912.63416
# Target Mean Price                              1484.118
# Trailing EPS                                      29.21
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
