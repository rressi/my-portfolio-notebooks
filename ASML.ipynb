# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 959.57 | 1,007.55 | 1,057.93 | 1,110.83 | 1,166.37 | 1,224.69 | 1,285.92
# Buy score: 2.97%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1080.85
# Forward EPS                                   30.429422
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1340.0659
# Target Low Price                              759.95306
# Target Mean Price                             1068.9543
# Trailing EPS                                      27.24
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
