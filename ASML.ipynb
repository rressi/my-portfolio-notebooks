# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 878.75 | 922.69 | 968.82 | 1,017.26 | 1,068.12 | 1,121.53 | 1,177.61
# Buy score: -2.60%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1044.455
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1186.5245
# Target Low Price                               731.0264
# Target Mean Price                             971.91846
# Trailing EPS                                       28.0
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
