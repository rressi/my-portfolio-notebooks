# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,123.18 | 1,179.34 | 1,238.30 | 1,300.22 | 1,365.23 | 1,433.49 | 1,505.17
# Buy score: -4.00%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1354.39
# Forward EPS                                    31.34808
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1543.1664
# Target Low Price                                  840.0
# Target Mean Price                             1239.1681
# Trailing EPS                                      28.23
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
