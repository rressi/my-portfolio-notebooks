# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 897.28 | 942.14 | 989.25 | 1,038.71 | 1,090.64 | 1,145.18 | 1,202.43
# Buy score: -1.50%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1052.48
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1187.4126
# Target Low Price                               754.1958
# Target Mean Price                            1007.34534
# Trailing EPS                                      27.98
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
