# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 919.08 | 965.04 | 1,013.29 | 1,063.95 | 1,117.15 | 1,173.01 | 1,231.66
# Buy score: -0.08%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1064.76
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                              1175.222
# Target Low Price                               746.4529
# Target Mean Price                              997.0034
# Trailing EPS                                      28.28
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
