# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 952.04 | 999.64 | 1,049.63 | 1,102.11 | 1,157.21 | 1,215.07 | 1,275.83
# Buy score: -0.97%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1112.85
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1337.3618
# Target Low Price                              754.37164
# Target Mean Price                             1061.6526
# Trailing EPS                                      28.18
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
