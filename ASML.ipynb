# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 825.61 | 866.89 | 910.23 | 955.74 | 1,003.53 | 1,053.71 | 1,106.39
# Buy score: -1.70%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    968.09
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1071.8394
# Target Low Price                              600.28174
# Target Mean Price                              857.9248
# Trailing EPS                                      28.17
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
