# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,225.91 | 1,287.20 | 1,351.56 | 1,419.14 | 1,490.10 | 1,564.60 | 1,642.83
# Buy score: 0.24%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                 1415.7949
# Forward EPS                                   43.303875
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1911.6843
# Target Low Price                              923.52875
# Target Mean Price                             1430.2991
# Trailing EPS                                      29.17
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
