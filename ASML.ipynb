# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,338.36 | 1,405.28 | 1,475.54 | 1,549.32 | 1,626.79 | 1,708.13 | 1,793.53
# Buy score: 3.72%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                 1493.7633
# Forward EPS                                    47.99537
# Gross Profit (ttm)                       17,723,299,840
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            33,692,700,672
# Target High Price                             1992.6996
# Target Low Price                               899.7907
# Target Mean Price                             1660.6151
# Trailing EPS                                      30.42
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
