# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 893.64 | 938.32 | 985.24 | 1,034.50 | 1,086.23 | 1,140.54 | 1,197.57
# Buy score: -4.26%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1080.5
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1303.3248
# Target Low Price                               752.2669
# Target Mean Price                             1043.8488
# Trailing EPS                                      28.09
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
