# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,232.01 | 1,293.62 | 1,358.30 | 1,426.21 | 1,497.52 | 1,572.40 | 1,651.02
# Buy score: -2.46%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                 1462.1628
# Forward EPS                                     44.1354
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1892.7546
# Target Low Price                               911.8812
# Target Mean Price                             1482.8937
# Trailing EPS                                      29.39
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
