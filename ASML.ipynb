# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 913.30 | 958.96 | 1,006.91 | 1,057.26 | 1,110.12 | 1,165.62 | 1,223.91
# Buy score: -1.92%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1075.45
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1178.7573
# Target Low Price                              748.69836
# Target Mean Price                             1000.0026
# Trailing EPS                                      28.06
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
