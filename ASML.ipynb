# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,079.46 | 1,133.43 | 1,190.11 | 1,249.61 | 1,312.09 | 1,377.70 | 1,446.58
# Buy score: -1.89%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1270.16
# Forward EPS                                   30.967695
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1515.1863
# Target Low Price                              843.22845
# Target Mean Price                             1201.8517
# Trailing EPS                                      28.19
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
