# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,234.14 | 1,295.84 | 1,360.64 | 1,428.67 | 1,500.10 | 1,575.11 | 1,653.86
# Buy score: -0.88%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1441.365
# Forward EPS                                   44.141357
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1887.6372
# Target Low Price                               909.4158
# Target Mean Price                             1478.8844
# Trailing EPS                                      29.37
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
