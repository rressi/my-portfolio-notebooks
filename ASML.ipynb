# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,224.98 | 1,286.23 | 1,350.54 | 1,418.07 | 1,488.97 | 1,563.42 | 1,641.59
# Buy score: 2.22%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1406.61
# Forward EPS                                    44.20058
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1901.2704
# Target Low Price                               915.9839
# Target Mean Price                             1489.5653
# Trailing EPS                                      29.26
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
