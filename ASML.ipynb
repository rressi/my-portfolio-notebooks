# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 843.29 | 885.46 | 929.73 | 976.22 | 1,025.03 | 1,076.28 | 1,130.09
# Buy score: -1.58%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  991.8772
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1182.3917
# Target Low Price                               593.7304
# Target Mean Price                             942.34326
# Trailing EPS                                      27.96
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
