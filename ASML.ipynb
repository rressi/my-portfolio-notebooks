# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 867.60 | 910.98 | 956.53 | 1,004.36 | 1,054.57 | 1,107.30 | 1,162.67
# Buy score: -1.97%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1024.54
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1189.2958
# Target Low Price                               732.7338
# Target Mean Price                             974.69653
# Trailing EPS                                      27.94
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
