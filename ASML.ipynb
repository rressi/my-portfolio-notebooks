# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 958.90 | 1,006.85 | 1,057.19 | 1,110.05 | 1,165.55 | 1,223.83 | 1,285.02
# Buy score: 0.04%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                  1109.555
# Forward EPS                                   30.173313
# Gross Profit (ttm)                       16,979,300,352
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,212,000,768
# Target High Price                             1332.0874
# Target Low Price                              755.42847
# Target Mean Price                               1062.59
# Trailing EPS                                      28.23
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
