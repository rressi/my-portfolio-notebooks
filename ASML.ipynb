# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,225.86 | 1,287.15 | 1,351.51 | 1,419.09 | 1,490.04 | 1,564.54 | 1,642.77
# Buy score: 0.52%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    1411.7
# Forward EPS                                   44.093452
# Gross Profit (ttm)                       17,258,000,384
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,667,299,840
# Target High Price                             1907.5946
# Target Low Price                               919.0307
# Target Mean Price                               1494.52
# Trailing EPS                                       29.4
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
