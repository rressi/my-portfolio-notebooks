# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 1,616.69 | 1,697.53 | 1,782.40 | 1,871.52 | 1,965.10 | 2,063.35 | 2,166.52
# Buy score: -3.96%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                   1929.68
# Forward EPS                                   47.975105
# Gross Profit (ttm)                       17,723,299,840
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            33,692,700,672
# Target High Price                             2341.5068
# Target Low Price                              886.59174
# Target Mean Price                             1723.9801
# Trailing EPS                                       30.1
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
