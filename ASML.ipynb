# %%
import my_portfolio; my_portfolio.run("ASML")
# Out:
# No operations found for ticker 'ASML'
# Prices: 786.92 | 826.27 | 867.58 | 910.96 | 956.51 | 1,004.33 | 1,054.55
# Buy score: -4.46%
# No operations found.
#                                                    ASML
# Company Name                          ASML Holding N.V.
# Current Price                                    949.55
# Forward EPS                                        26.7
# Gross Profit (ttm)                       16,892,399,616
# Industry            Semiconductor Equipment & Materials
# Revenue (ttm)                            32,163,299,328
# Target High Price                             1065.0881
# Target Low Price                               596.5007
# Target Mean Price                              851.9071
# Trailing EPS                                      28.41
# Website                            https://www.asml.com
#                                           ASML
# Currency                                   USD
# ...
