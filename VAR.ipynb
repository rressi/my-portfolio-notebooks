# %%
import my_portfolio; my_portfolio.run("VAR.OL")
# Out:
# Prices: 38.48 | 40.40 | 42.42 | 41.93 | 44.03 | 46.23 | 48.54
# Buy score: -2.44%
# Sell score: 0.92%
# Current return: -2,831.46 NOK
# Breakeven price: 42.60 NOK
# <style type="text/css">
# #T_c98d3_row16_col0, #T_c98d3_row16_col1, #T_c98d3_row16_col2, #T_c98d3_row16_col3, #T_c98d3_row16_col4, #T_c98d3_row16_col5, #T_c98d3_row16_col6, #T_c98d3_row16_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_c98d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c98d3_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c98d3_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c98d3_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c98d3_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c98d3_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
