# %%
import my_portfolio; my_portfolio.run("AAPL")
# Out:
# Prices: 235.84 | 247.63 | 260.01 | 265.82 | 279.11 | 293.07 | 307.72
# Buy score: 2.43%
# Sell score: -1.13%
# Current return: -214.12 USD
# Breakeven price: 269.95 USD
# <style type="text/css">
# #T_fb9cc_row33_col0, #T_fb9cc_row33_col1, #T_fb9cc_row33_col2, #T_fb9cc_row33_col3, #T_fb9cc_row33_col4, #T_fb9cc_row33_col5, #T_fb9cc_row33_col6, #T_fb9cc_row33_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_fb9cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb9cc_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_fb9cc_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_fb9cc_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_fb9cc_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_fb9cc_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
