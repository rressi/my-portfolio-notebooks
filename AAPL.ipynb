# %%
import my_portfolio; my_portfolio.run("AAPL")
# Out:
# Prices: 234.81 | 246.55 | 258.87 | 261.67 | 274.75 | 288.49 | 302.92
# Buy score: 0.03%
# Sell score: -0.61%
# Current return: -509.12 USD
# Breakeven price: 265.16 USD
# <style type="text/css">
# #T_10d83_row36_col0, #T_10d83_row36_col1, #T_10d83_row36_col2, #T_10d83_row36_col3, #T_10d83_row36_col4, #T_10d83_row36_col5, #T_10d83_row36_col6, #T_10d83_row36_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_10d83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10d83_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_10d83_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_10d83_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_10d83_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_10d83_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
