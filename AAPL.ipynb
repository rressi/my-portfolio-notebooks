# %%
import my_portfolio; my_portfolio.run("AAPL")
# Out:
# Prices: 233.75 | 245.44 | 257.71 | 259.43 | 272.40 | 286.02 | 300.32
# Buy score: 2.29%
# Sell score: -4.40%
# Current return: -1,793.65 USD
# Breakeven price: 262.96 USD
# <style type="text/css">
# #T_81aaa_row37_col0, #T_81aaa_row37_col1, #T_81aaa_row37_col2, #T_81aaa_row37_col3, #T_81aaa_row37_col4, #T_81aaa_row37_col5, #T_81aaa_row37_col6, #T_81aaa_row37_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_81aaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81aaa_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_81aaa_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_81aaa_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_81aaa_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_81aaa_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
