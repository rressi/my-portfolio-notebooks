# %%
import my_portfolio; my_portfolio.run("AAPL")
# Out:
# Prices: 205.47 | 215.74 | 226.53 | 237.85 | 249.75 | 262.23 | 275.35
# Buy score: -7.25%
#                                      AAPL
# Company Name                        Apple
# Current Price                      256.08
# Forward EPS                          8.31
# Gross Profit (ttm)        190,739,005,440
# Industry             Consumer Electronics
# Revenue (ttm)             408,624,988,160
# Target High Price                   310.0
# Target Low Price                    175.0
# Target Mean Price               242.31557
# Trailing EPS                         6.58
# Website             https://www.apple.com
#                                             AAPL
# Currency                                     USD
# Dayhigh                                   256.64
# Daylow                                    248.12
# Exchange                                     NMS
# Fiftydayaverage                           223.93
# Lastprice                                 256.08
# ...
