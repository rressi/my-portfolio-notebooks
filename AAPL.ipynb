# %%
import my_portfolio; my_portfolio.run("AAPL")
# Out:
# Prices: 231.81 | 243.40 | 255.57 | 266.06 | 279.36 | 293.33 | 308.00
# Buy score: -4.67%
# Sell score: 5.80%
# Current return: 82.36 USD
# Breakeven price: 269.71 USD
# <style type="text/css">
# #T_d8a60_row28_col0, #T_d8a60_row28_col1, #T_d8a60_row28_col2, #T_d8a60_row28_col3, #T_d8a60_row28_col4, #T_d8a60_row28_col5, #T_d8a60_row28_col6, #T_d8a60_row28_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_d8a60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8a60_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_d8a60_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_d8a60_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_d8a60_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_d8a60_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
