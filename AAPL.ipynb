# %%
import my_portfolio; my_portfolio.run("AAPL")
# Out:
# Prices: 233.02 | 244.67 | 256.90 | 254.25 | 266.96 | 280.31 | 294.32
# Buy score: 0.80%
# Sell score: -2.82%
# Current return: -2,088.06 USD
# Breakeven price: 257.51 USD
# <style type="text/css">
# #T_d33b4_row39_col0, #T_d33b4_row39_col1, #T_d33b4_row39_col2, #T_d33b4_row39_col3, #T_d33b4_row39_col4, #T_d33b4_row39_col5, #T_d33b4_row39_col6, #T_d33b4_row39_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_d33b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d33b4_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_d33b4_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_d33b4_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_d33b4_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_d33b4_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
