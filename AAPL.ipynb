# %%
import my_portfolio; my_portfolio.run("AAPL")
# Out:
# Prices: 233.43 | 245.10 | 257.36 | 259.43 | 272.40 | 286.02 | 300.32
# Buy score: 0.73%
# Sell score: -3.74%
# Current return: -1,587.12 USD
# Breakeven price: 262.96 USD
# <style type="text/css">
# #T_978dc_row37_col0, #T_978dc_row37_col1, #T_978dc_row37_col2, #T_978dc_row37_col3, #T_978dc_row37_col4, #T_978dc_row37_col5, #T_978dc_row37_col6, #T_978dc_row37_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_978dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_978dc_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_978dc_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_978dc_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_978dc_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_978dc_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
