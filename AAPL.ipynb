# %%
import my_portfolio; my_portfolio.run("AAPL")
# Out:
# Prices: 232.62 | 244.25 | 256.46 | 254.25 | 266.96 | 280.31 | 294.32
# Buy score: -1.09%
# Sell score: -1.23%
# Current return: -1,278.64 USD
# Breakeven price: 257.51 USD
# <style type="text/css">
# #T_c7c15_row39_col0, #T_c7c15_row39_col1, #T_c7c15_row39_col2, #T_c7c15_row39_col3, #T_c7c15_row39_col4, #T_c7c15_row39_col5, #T_c7c15_row39_col6, #T_c7c15_row39_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_c7c15">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7c15_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c7c15_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c7c15_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c7c15_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c7c15_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
