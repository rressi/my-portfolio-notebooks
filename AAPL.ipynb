# %%
import workflow
workflow.run(
    security = "AAPL",
)
# Out:
# Prices: 200.47 | 210.49 | 221.02 | 232.0687 | 243.67 | 255.86 | 268.65
# Buy score: 0.89%
#                                      AAPL
# Company Name                   Apple Inc.
# Industry             Consumer Electronics
# Revenue (ttm)             408,624,988,160
# Gross Profit (ttm)        190,739,005,440
# Current Price                      230.03
# Target Mean Price               238.79794
# Target High Price                   300.0
# Target Low Price                    175.0
# Trailing EPS                          6.6
# Forward EPS                          8.31
# Website             https://www.apple.com
#                                             AAPL
# Currency                                     USD
# Dayhigh                                   230.45
# Daylow                                    226.65
# Exchange                                     NMS
# Fiftydayaverage                           220.25
# Lastprice                                 230.03
# ...
