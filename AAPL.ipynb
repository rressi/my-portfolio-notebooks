# %%
import my_portfolio; my_portfolio.run("AAPL")
# Out:
# Prices: 235.31 | 247.07 | 259.42 | 263.09 | 276.25 | 290.06 | 304.56
# Buy score: 0.10%
# Sell score: -1.18%
# Current return: -354.11 USD
# Breakeven price: 267.08 USD
# <style type="text/css">
# #T_c3844_row35_col0, #T_c3844_row35_col1, #T_c3844_row35_col2, #T_c3844_row35_col3, #T_c3844_row35_col4, #T_c3844_row35_col5, #T_c3844_row35_col6, #T_c3844_row35_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_c3844">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3844_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c3844_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c3844_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c3844_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c3844_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
