# %%
import my_portfolio; my_portfolio.run("AAPL")
# Out:
# Prices: 203.90 | 214.09 | 224.79 | 236.03 | 247.84 | 260.23 | 273.24
# Buy score: -3.93%
#                                      AAPL
# Company Name                        Apple
# Current Price                       245.5
# Forward EPS                          8.31
# Gross Profit (ttm)        190,739,005,440
# Industry             Consumer Electronics
# Revenue (ttm)             408,624,988,160
# Target High Price                   300.0
# Target Low Price                    175.0
# Target Mean Price               241.31557
# Trailing EPS                         6.58
# Website             https://www.apple.com
#                                             AAPL
# Currency                                     USD
# Dayhigh                                   246.30
# Daylow                                    240.21
# Exchange                                     NMS
# Fiftydayaverage                           223.93
# Lastprice                                 245.50
# ...
