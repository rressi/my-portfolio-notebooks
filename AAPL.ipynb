# %%
import my_portfolio; my_portfolio.run("AAPL")
# Out:
# Prices: 229.69 | 241.17 | 253.23 | 266.06 | 279.36 | 293.33 | 308.00
# Buy score: -1.24%
# Sell score: 1.19%
# Current return: -3.39 USD
# Breakeven price: 269.71 USD
# <style type="text/css">
# #T_4fbb5_row28_col0, #T_4fbb5_row28_col1, #T_4fbb5_row28_col2, #T_4fbb5_row28_col3, #T_4fbb5_row28_col4, #T_4fbb5_row28_col5, #T_4fbb5_row28_col6, #T_4fbb5_row28_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_4fbb5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4fbb5_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_4fbb5_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_4fbb5_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_4fbb5_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_4fbb5_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
