# %%
import workflow
workflow.run(
    security = "SMCI",
    # start_date = "2025-01-01",
)
# Out:
# Prices: 37.16 | 39.01 | 40.97 | 43.0135 | 45.16 | 47.42 | 49.79
# Buy score: -2.13%
#                                           SMCI
# Company Name              Super Micro Computer
# Industry                     Computer Hardware
# Revenue (ttm)                   21,972,041,728
# Gross Profit (ttm)               2,429,922,048
# Current Price                            43.95
# Target Mean Price                      50.0625
# Target High Price                         93.0
# Target Low Price                          15.0
# Trailing EPS                              1.68
# Forward EPS                               4.24
# Website             https://www.supermicro.com
#                                          SMCI
# Currency                                  USD
# Dayhigh                                 44.51
# Daylow                                  43.46
# Exchange                                  NMS
# Fiftydayaverage                         48.27
# ...
