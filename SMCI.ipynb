# %%
import my_portfolio; my_portfolio.run("SMCI")
# Out:
# No operations found for ticker 'SMCI'
# Prices: 44.60 | 46.83 | 49.17 | 51.62 | 54.21 | 56.92 | 59.76
# Buy score: 1.73%
# No operations found.
#                                           SMCI
# Company Name              Super Micro Computer
# Current Price                           50.745
# Forward EPS                               4.24
# Gross Profit (ttm)               2,429,922,048
# Industry                     Computer Hardware
# Revenue (ttm)                   21,972,041,728
# Target High Price                         93.0
# Target Low Price                          30.0
# Target Mean Price                      53.1875
# Trailing EPS                              1.68
# Website             https://www.supermicro.com
#                                          SMCI
# Currency                                  USD
# Dayhigh                                 53.01
# Daylow                                  50.55
# Exchange                                  NMS
# ...
