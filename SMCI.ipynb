# %%
import my_portfolio; my_portfolio.run("SMCI")
# Out:
# No operations found for ticker 'SMCI'
# Prices: 26.92 | 28.27 | 29.68 | 31.17 | 32.72 | 34.36 | 36.08
# Buy score: 1.10%
# No operations found.
#                                           SMCI
# Company Name              Super Micro Computer
# Current Price                          30.8255
# Forward EPS                            2.96094
# Gross Profit (ttm)               2,250,259,968
# Industry                     Computer Hardware
# Revenue (ttm)                   28,057,104,384
# Target High Price                         63.0
# Target Low Price                          15.0
# Target Mean Price                      41.3125
# Trailing EPS                              1.37
# Website             https://www.supermicro.com
#                                          SMCI
# Currency                                  USD
# Dayhigh                                 31.20
# Daylow                                  30.29
# Exchange                                  NMS
# ...
