# %%
import my_portfolio
my_portfolio.run(
    security = "SMCI",
    # start_date = "2025-01-01",
)
# Out:
# Prices: 38.25 | 40.16 | 42.17 | 44.28 | 46.49 | 48.81 | 51.26
# Buy score: -3.35%
#                                           SMCI
# Company Name              Super Micro Computer
# Current Price                            45.81
# Forward EPS                               4.24
# Gross Profit (ttm)               2,429,922,048
# Industry                     Computer Hardware
# Revenue (ttm)                   21,972,041,728
# Target High Price                         93.0
# Target Low Price                          15.0
# Target Mean Price                     49.82353
# Trailing EPS                              1.68
# Website             https://www.supermicro.com
#                                          SMCI
# Currency                                  USD
# Dayhigh                                 46.52
# Daylow                                  45.45
# Exchange                                  NMS
# Fiftydayaverage                         47.77
# ...
