# %%
import my_portfolio; my_portfolio.run("SMCI")
# Out:
# No operations found for ticker 'SMCI'
# Prices: 28.00 | 29.40 | 30.87 | 31.76 | 33.35 | 35.02 | 36.77
# Buy score: -4.09%
# No operations found.
#                                           SMCI
# Company Name              Super Micro Computer
# Current Price                            33.12
# Forward EPS                             3.0186
# Gross Profit (ttm)               2,121,714,944
# Industry                     Computer Hardware
# Revenue (ttm)                   21,052,575,744
# Target High Price                         93.0
# Target Low Price                          15.0
# Target Mean Price                     46.70588
# Trailing EPS                              1.27
# Website             https://www.supermicro.com
#                                          SMCI
# Currency                                  USD
# Dayhigh                                 33.49
# Daylow                                  32.61
# Exchange                                  NMS
# ...
