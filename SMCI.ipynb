# %%
import my_portfolio
my_portfolio.run(
    security = "SMCI",
    # start_date = "2025-01-01",
)
# Out:
# Prices: 37.78 | 39.67 | 41.65 | 43.74 | 45.92 | 48.22 | 50.63
# Buy score: -4.80%
#                                           SMCI
# Company Name              Super Micro Computer
# Current Price                            45.94
# Forward EPS                               4.24
# Gross Profit (ttm)               2,429,922,048
# Industry                     Computer Hardware
# Revenue (ttm)                   21,972,041,728
# Target High Price                         93.0
# Target Low Price                          15.0
# Target Mean Price                     49.82353
# Trailing EPS                              1.68
# Website             https://www.supermicro.com
#                                          SMCI
# Currency                                  USD
# Dayhigh                                 46.33
# Daylow                                  44.54
# Exchange                                  NMS
# Fiftydayaverage                         47.94
# ...
