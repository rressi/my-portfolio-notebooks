# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 53.38 | 56.05 | 58.85 | 61.79 | 64.88 | 68.12 | 71.53
# Buy score: 2.81%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  58.22
# Forward EPS                     0.34
# Gross Profit (ttm)       342,031,008
# Industry             Capital Markets
# Revenue (ttm)            501,023,008
# Target High Price              100.0
# Target Low Price                24.0
# Target Mean Price               63.5
# Trailing EPS                    0.39
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 61.01
# Daylow                                  57.28
# Exchange                                  NMS
# Fiftydayaverage                         43.76
# Lastprice                               58.22
# Lastvolume                         17,896,750
# ...
