# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 55.85 | 58.64 | 61.58 | 64.66 | 67.89 | 71.28 | 74.85
# Buy score: 8.12%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  61.83
# Forward EPS                     0.34
# Gross Profit (ttm)       342,031,008
# Industry             Capital Markets
# Revenue (ttm)            501,023,008
# Target High Price              100.0
# Target Low Price                24.0
# Target Mean Price           56.41667
# Trailing EPS                    0.39
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 68.94
# Daylow                                  61.10
# Exchange                                  NMS
# Fiftydayaverage                         35.60
# Lastprice                               61.83
# Lastvolume                         45,637,400
# ...
