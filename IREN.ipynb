# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 53.48 | 56.15 | 58.96 | 61.91 | 65.00 | 68.25 | 71.66
# Buy score: -5.51%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  64.14
# Forward EPS                     0.34
# Gross Profit (ttm)       342,031,008
# Industry             Capital Markets
# Revenue (ttm)            501,023,008
# Target High Price               85.0
# Target Low Price                24.0
# Target Mean Price           48.58333
# Trailing EPS                    0.39
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 67.79
# Daylow                                  61.79
# Exchange                                  NMS
# Fiftydayaverage                         32.53
# Lastprice                               64.14
# Lastvolume                         46,754,500
# ...
