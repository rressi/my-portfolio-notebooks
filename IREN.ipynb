# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 46.08 | 48.38 | 50.80 | 49.40 | 51.87 | 54.46 | 57.18
# Buy score: -0.01%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  48.85
# Forward EPS                     0.34
# Gross Profit (ttm)       480,748,000
# Industry             Capital Markets
# Revenue (ttm)            688,553,984
# Target High Price              136.0
# Target Low Price                24.0
# Target Mean Price           80.58333
# Trailing EPS                    1.74
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 50.67
# Daylow                                  46.50
# Exchange                                  NMS
# Fiftydayaverage                         53.34
# Lastprice                               48.85
# Lastvolume                         37,714,300
# ...
