# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 56.56 | 59.39 | 62.35 | 65.47 | 68.75 | 72.18 | 75.79
# Buy score: -2.79%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                   66.6
# Forward EPS                    -0.94
# Gross Profit (ttm)       517,816,992
# Industry             Capital Markets
# Revenue (ttm)            757,073,984
# Target High Price              126.0
# Target Low Price                41.0
# Target Mean Price           79.84429
# Trailing EPS                    0.77
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 69.57
# Daylow                                  64.26
# Exchange                                  NMS
# Fiftydayaverage                         48.75
# Lastprice                               66.60
# Lastvolume                         51,342,300
# ...
