# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 35.88 | 37.68 | 39.56 | 36.82 | 38.66 | 40.59 | 42.62
# Buy score: -6.58%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  39.32
# Forward EPS                    1.265
# Gross Profit (ttm)       515,827,008
# Industry             Capital Markets
# Revenue (ttm)            757,102,016
# Target High Price              125.0
# Target Low Price                26.0
# Target Mean Price           72.06667
# Trailing EPS                    1.44
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 40.74
# Daylow                                  37.70
# Exchange                                  NMS
# Fiftydayaverage                         41.54
# Lastprice                               39.32
# Lastvolume                         35,181,200
# ...
