# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 58.76 | 61.70 | 64.79 | 68.03 | 71.43 | 75.00 | 78.75
# Buy score: 6.88%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  62.38
# Forward EPS                     0.34
# Gross Profit (ttm)       455,062,016
# Industry             Capital Markets
# Revenue (ttm)            686,932,992
# Target High Price              142.0
# Target Low Price                24.0
# Target Mean Price           73.83333
# Trailing EPS                    1.74
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 65.71
# Daylow                                  58.38
# Exchange                                  NMS
# Fiftydayaverage                         49.90
# Lastprice                               62.38
# Lastvolume                         53,108,600
# ...
