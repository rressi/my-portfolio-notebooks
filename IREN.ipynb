# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 44.19 | 46.40 | 48.72 | 51.16 | 53.72 | 56.40 | 59.22
# Buy score: -4.48%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                 53.558
# Forward EPS                  0.83677
# Gross Profit (ttm)       480,748,000
# Industry             Capital Markets
# Revenue (ttm)            688,553,984
# Target High Price              136.0
# Target Low Price                39.0
# Target Mean Price           84.84615
# Trailing EPS                    1.74
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 53.99
# Daylow                                  50.75
# Exchange                                  NMS
# Fiftydayaverage                         47.32
# Lastprice                               53.56
# Lastvolume                         24,100,931
# ...
