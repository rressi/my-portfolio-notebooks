# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 54.13 | 56.83 | 59.68 | 62.66 | 65.79 | 69.08 | 72.54
# Buy score: -5.36%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                 66.189
# Forward EPS                     0.34
# Gross Profit (ttm)       342,031,008
# Industry             Capital Markets
# Revenue (ttm)            501,023,008
# Target High Price              142.0
# Target Low Price                24.0
# Target Mean Price               68.0
# Trailing EPS                    0.39
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 66.24
# Daylow                                  63.30
# Exchange                                  NMS
# Fiftydayaverage                         46.28
# Lastprice                               66.16
# Lastvolume                          6,327,276
# ...
