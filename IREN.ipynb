# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 47.57 | 49.95 | 52.45 | 45.91 | 48.20 | 50.61 | 53.14
# Buy score: 5.15%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  43.66
# Forward EPS                     0.34
# Gross Profit (ttm)       480,748,000
# Industry             Capital Markets
# Revenue (ttm)            688,553,984
# Target High Price              136.0
# Target Low Price                24.0
# Target Mean Price           81.84615
# Trailing EPS                    1.74
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 44.37
# Daylow                                  39.93
# Exchange                                  NMS
# Fiftydayaverage                         55.03
# Lastprice                               43.67
# Lastvolume                         52,397,583
# ...
