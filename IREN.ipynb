# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 55.34 | 58.11 | 61.01 | 64.06 | 67.27 | 70.63 | 74.16
# Buy score: -6.30%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  66.96
# Forward EPS                     0.34
# Gross Profit (ttm)       342,031,008
# Industry             Capital Markets
# Revenue (ttm)            501,023,008
# Target High Price              142.0
# Target Low Price                24.0
# Target Mean Price           72.16667
# Trailing EPS                    0.39
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 75.79
# Daylow                                  66.67
# Exchange                                  NMS
# Fiftydayaverage                         47.65
# Lastprice                               66.96
# Lastvolume                         50,148,995
# ...
