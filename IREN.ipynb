# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 41.58 | 43.66 | 45.85 | 45.46 | 47.74 | 50.12 | 52.63
# Buy score: -2.94%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  46.84
# Forward EPS                  0.83677
# Gross Profit (ttm)       480,748,000
# Industry             Capital Markets
# Revenue (ttm)            688,553,984
# Target High Price              136.0
# Target Low Price                39.0
# Target Mean Price               83.0
# Trailing EPS                    1.74
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 47.58
# Daylow                                  42.55
# Exchange                                  NMS
# Fiftydayaverage                         48.50
# Lastprice                               46.84
# Lastvolume                         25,922,279
# ...
