# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 39.19 | 41.15 | 43.21 | 45.37 | 47.63 | 50.02 | 52.52
# Buy score: -1.34%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  45.66
# Forward EPS                    1.265
# Gross Profit (ttm)       515,827,008
# Industry             Capital Markets
# Revenue (ttm)            757,102,016
# Target High Price              105.0
# Target Low Price                26.0
# Target Mean Price               70.4
# Trailing EPS                    1.44
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 47.40
# Daylow                                  45.15
# Exchange                                  NMS
# Fiftydayaverage                         41.92
# Lastprice                               45.66
# Lastvolume                         25,952,800
# ...
