# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 51.46 | 54.04 | 56.74 | 59.57 | 62.55 | 65.68 | 68.96
# Buy score: -1.25%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  59.96
# Forward EPS                    -0.94
# Gross Profit (ttm)       517,816,992
# Industry             Capital Markets
# Revenue (ttm)            757,073,984
# Target High Price              126.0
# Target Low Price                41.0
# Target Mean Price           80.93333
# Trailing EPS                    0.77
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 61.53
# Daylow                                  58.00
# Exchange                                  NMS
# Fiftydayaverage                         53.97
# Lastprice                               59.96
# Lastvolume                         39,394,600
# ...
