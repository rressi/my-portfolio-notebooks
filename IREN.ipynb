# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 39.41 | 41.38 | 43.45 | 45.62 | 47.90 | 50.29 | 52.81
# Buy score: -3.15%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  47.08
# Forward EPS                     0.34
# Gross Profit (ttm)       342,031,008
# Industry             Capital Markets
# Revenue (ttm)            501,023,008
# Target High Price               82.0
# Target Low Price                24.0
# Target Mean Price               48.0
# Trailing EPS                    0.44
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 48.15
# Daylow                                  45.93
# Exchange                                  NMS
# Fiftydayaverage                         26.91
# Lastprice                               47.08
# Lastvolume                         28,025,200
# ...
