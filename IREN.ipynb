# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 47.52 | 49.89 | 52.39 | 47.73 | 50.12 | 52.63 | 55.26
# Buy score: 2.72%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                46.4478
# Forward EPS                     0.34
# Gross Profit (ttm)       480,748,000
# Industry             Capital Markets
# Revenue (ttm)            688,553,984
# Target High Price              136.0
# Target Low Price                24.0
# Target Mean Price           81.38462
# Trailing EPS                    1.74
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 47.67
# Daylow                                  44.26
# Exchange                                  NMS
# Fiftydayaverage                         54.85
# Lastprice                               46.45
# Lastvolume                         11,525,644
# ...
