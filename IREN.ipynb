# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 39.60 | 41.58 | 43.66 | 42.35 | 44.47 | 46.69 | 49.03
# Buy score: -3.85%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                 44.045
# Forward EPS                 -0.20254
# Gross Profit (ttm)       515,827,008
# Industry             Capital Markets
# Revenue (ttm)            757,102,016
# Target High Price              125.0
# Target Low Price                37.0
# Target Mean Price           79.30769
# Trailing EPS                    1.44
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 45.68
# Daylow                                  40.83
# Exchange                                  NMS
# Fiftydayaverage                         45.84
# Lastprice                               44.04
# Lastvolume                         18,238,337
# ...
