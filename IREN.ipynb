# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 36.29 | 38.10 | 40.01 | 35.91 | 37.70 | 39.59 | 41.57
# Buy score: -2.79%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  37.06
# Forward EPS                    1.265
# Gross Profit (ttm)       515,827,008
# Industry             Capital Markets
# Revenue (ttm)            757,102,016
# Target High Price              125.0
# Target Low Price                26.0
# Target Mean Price           73.46667
# Trailing EPS                    1.45
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 38.10
# Daylow                                  35.25
# Exchange                                  NMS
# Fiftydayaverage                         42.01
# Lastprice                               37.06
# Lastvolume                         27,580,200
# ...
