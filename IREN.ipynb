# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 45.65 | 47.93 | 50.33 | 52.85 | 55.49 | 58.26 | 61.18
# Buy score: 11.70%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                47.3099
# Forward EPS                   -1.345
# Gross Profit (ttm)       517,816,992
# Industry             Capital Markets
# Revenue (ttm)            757,073,984
# Target High Price               None
# Target Low Price                None
# Target Mean Price               None
# Trailing EPS                    0.77
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 49.13
# Daylow                                  46.00
# Exchange                                  NMS
# Fiftydayaverage                         45.00
# Lastprice                               47.26
# Lastvolume                         17,000,800
# ...
