# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 48.46 | 50.89 | 53.43 | 56.10 | 58.91 | 61.85 | 64.95
# Buy score: 1.47%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  55.23
# Forward EPS                   -1.345
# Gross Profit (ttm)       517,816,992
# Industry             Capital Markets
# Revenue (ttm)            757,073,984
# Target High Price              105.0
# Target Low Price                41.0
# Target Mean Price           74.07143
# Trailing EPS                    0.77
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 56.79
# Daylow                                  54.96
# Exchange                                  NMS
# Fiftydayaverage                         44.46
# Lastprice                               55.28
# Lastvolume                          5,708,295
# ...
