# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 51.86 | 54.45 | 57.17 | 60.03 | 63.03 | 66.18 | 69.49
# Buy score: -7.03%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  64.57
# Forward EPS                     0.34
# Gross Profit (ttm)       342,031,008
# Industry             Capital Markets
# Revenue (ttm)            501,023,008
# Target High Price              100.0
# Target Low Price                24.0
# Target Mean Price              62.75
# Trailing EPS                    0.39
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 66.00
# Daylow                                  63.69
# Exchange                                  NMS
# Fiftydayaverage                         42.10
# Lastprice                               64.57
# Lastvolume                          7,578,630
# ...
