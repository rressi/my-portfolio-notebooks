# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 48.99 | 51.44 | 54.02 | 56.72 | 59.55 | 62.53 | 65.66
# Buy score: 18.28%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  47.95
# Forward EPS                     0.34
# Gross Profit (ttm)       480,748,000
# Industry             Capital Markets
# Revenue (ttm)            688,553,984
# Target High Price              136.0
# Target Low Price                24.0
# Target Mean Price               76.0
# Trailing EPS                    1.74
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 50.18
# Daylow                                  44.55
# Exchange                                  NMS
# Fiftydayaverage                         52.21
# Lastprice                               47.96
# Lastvolume                         37,172,395
# ...
