# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 54.18 | 56.89 | 59.74 | 62.72 | 65.86 | 69.15 | 72.61
# Buy score: 17.81%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  54.35
# Forward EPS                    -0.94
# Gross Profit (ttm)       517,816,992
# Industry             Capital Markets
# Revenue (ttm)            757,073,984
# Target High Price              126.0
# Target Low Price                41.0
# Target Mean Price           81.07143
# Trailing EPS                    0.77
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 59.28
# Daylow                                  51.04
# Exchange                                  NMS
# Fiftydayaverage                         49.63
# Lastprice                               54.35
# Lastvolume                         63,010,611
# ...
