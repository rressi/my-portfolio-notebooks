# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 54.95 | 57.69 | 60.58 | 63.61 | 66.79 | 70.13 | 73.63
# Buy score: -10.25%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                 70.895
# Forward EPS                     0.34
# Gross Profit (ttm)       342,031,008
# Industry             Capital Markets
# Revenue (ttm)            501,023,008
# Target High Price              142.0
# Target Low Price                24.0
# Target Mean Price           72.16667
# Trailing EPS                    0.39
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 72.16
# Daylow                                  67.70
# Exchange                                  NMS
# Fiftydayaverage                         46.76
# Lastprice                               70.89
# Lastvolume                         12,896,262
# ...
