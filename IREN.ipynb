# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 40.08 | 41.28 | 42.52 | 43.79 | 45.11 | 46.46 | 47.85
# Buy score: 4.77%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  41.86
# Forward EPS                     0.34
# Gross Profit (ttm)       342,031,008
# Industry             Capital Markets
# Revenue (ttm)            501,023,008
# Target High Price               82.0
# Target Low Price                23.0
# Target Mean Price           43.91667
# Trailing EPS                    0.39
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 44.08
# Daylow                                  39.70
# Exchange                                  NMS
# Fiftydayaverage                         25.20
# Lastprice                               41.86
# Lastvolume                         59,488,500
# ...
