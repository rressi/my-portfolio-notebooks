# %%
import my_portfolio; my_portfolio.run("IREN")
# Out:
# No operations found for ticker 'IREN'
# Prices: 46.59 | 48.92 | 51.37 | 47.79 | 50.18 | 52.68 | 55.32
# Buy score: -5.32%
# No operations found.
#                                 IREN
# Company Name            IREN LIMITED
# Current Price                  50.46
# Forward EPS                     0.34
# Gross Profit (ttm)       480,748,000
# Industry             Capital Markets
# Revenue (ttm)            688,553,984
# Target High Price              136.0
# Target Low Price                24.0
# Target Mean Price           80.53846
# Trailing EPS                    1.74
# Website             https://iren.com
#                                          IREN
# Currency                                  USD
# Dayhigh                                 50.76
# Daylow                                  48.96
# Exchange                                  NMS
# Fiftydayaverage                         53.59
# Lastprice                               50.49
# Lastvolume                          4,451,417
# ...
