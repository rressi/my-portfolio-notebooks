# %%
import my_portfolio; my_portfolio.run(
    security="HL",
)
# Out:
# Prices: 19.25 | 20.21 | 21.22 | 22.11 | 23.22 | 24.38 | 25.60
# Buy score: -0.22%
# Sell score: 0.23%
# Current return: -527.92 USD
# Breakeven price: 22.34 USD
# <style type="text/css">
# #T_22634_row8_col0, #T_22634_row8_col1, #T_22634_row8_col2, #T_22634_row8_col3, #T_22634_row8_col4, #T_22634_row8_col5, #T_22634_row8_col6, #T_22634_row8_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_22634">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22634_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_22634_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_22634_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_22634_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_22634_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
