# %%
import my_portfolio; my_portfolio.run(
    security="HL",
)
# Out:
# Prices: 19.25 | 20.21 | 21.22 | 22.77 | 23.91 | 25.10 | 26.36
# Buy score: 4.92%
# Sell score: -6.74%
# Current return: -1,763.90 USD
# Breakeven price: 23.00 USD
# <style type="text/css">
# #T_3367c_row1_col0, #T_3367c_row1_col1, #T_3367c_row1_col2, #T_3367c_row1_col3, #T_3367c_row1_col4, #T_3367c_row1_col5, #T_3367c_row1_col6, #T_3367c_row1_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_3367c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3367c_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_3367c_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_3367c_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_3367c_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_3367c_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
