# %%
import my_portfolio; my_portfolio.run(
    security="HL",
)
# Out:
# Prices: 19.25 | 20.21 | 21.22 | 22.13 | 23.24 | 24.40 | 25.62
# Buy score: 4.36%
# Sell score: -3.52%
# Current return: -2,011.66 USD
# Breakeven price: 22.36 USD
# <style type="text/css">
# #T_1290d_row7_col0, #T_1290d_row7_col1, #T_1290d_row7_col2, #T_1290d_row7_col3, #T_1290d_row7_col4, #T_1290d_row7_col5, #T_1290d_row7_col6, #T_1290d_row7_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_1290d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1290d_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_1290d_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_1290d_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_1290d_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_1290d_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
