# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# No operations found for ticker 'ORCL'
# Prices: 250.04 | 262.54 | 275.67 | 289.45 | 303.92 | 319.12 | 335.07
# Buy score: 3.87%
# No operations found.
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          281.24
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       400.0
# Target Low Price                    175.14314
# Target Mean Price                   330.86865
# Trailing EPS                             4.27
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 284.00
# Daylow                                  275.90
# Exchange                                   NYQ
# ...
