# %%
import workflow
workflow.run(
    security = "ORCL",
)
# Out:
# Prices: 239.66 | 251.64 | 264.22 | 277.44 | 291.31 | 305.87 | 321.17
# Buy score: -7.95%
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          301.41
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       410.0
# Target Low Price                        183.1
# Target Mean Price                   333.49274
# Trailing EPS                             4.32
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 308.66
# Daylow                                  295.03
# Exchange                                   NYQ
# Fiftydayaverage                         247.67
# ...
