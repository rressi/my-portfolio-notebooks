# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# No operations found for ticker 'ORCL'
# Prices: 251.02 | 263.58 | 276.75 | 290.59 | 305.12 | 320.38 | 336.40
# Buy score: -0.95%
# No operations found.
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          293.04
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       415.0
# Target Low Price                        175.0
# Target Mean Price                   333.11514
# Trailing EPS                             4.31
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 307.72
# Daylow                                  292.01
# Exchange                                   NYQ
# ...
