# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# Prices: 241.58 | 253.66 | 266.34 | 285.00 | 299.25 | 314.21 | 329.92
# Buy score: -0.41%
# Sell score: -1.47%
# Current return: -50.34 USD
# Breakeven price: 289.19 USD
# <style type="text/css">
# #T_f7b45_row2_col0, #T_f7b45_row2_col1, #T_f7b45_row2_col2, #T_f7b45_row2_col3, #T_f7b45_row2_col4, #T_f7b45_row2_col5, #T_f7b45_row2_col6, #T_f7b45_row2_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_f7b45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7b45_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_f7b45_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_f7b45_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_f7b45_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_f7b45_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
