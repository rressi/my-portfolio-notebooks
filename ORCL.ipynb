# %%
import my_portfolio
my_portfolio.run(
    security = "ORCL",
)
# Out:
# Prices: 252.57 | 265.20 | 278.46 | 292.38 | 307.00 | 322.35 | 338.47
# Buy score: -5.27%
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          308.66
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       410.0
# Target Low Price                        183.1
# Target Mean Price                   333.49274
# Trailing EPS                             4.32
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 311.11
# Daylow                                  297.32
# Exchange                                   NYQ
# Fiftydayaverage                         251.70
# ...
