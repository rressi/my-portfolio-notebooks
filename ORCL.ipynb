# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# No operations found for ticker 'ORCL'
# Prices: 264.84 | 278.08 | 291.99 | 306.59 | 321.92 | 338.01 | 354.91
# Buy score: -0.49%
# No operations found.
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          308.36
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       410.0
# Target Low Price                        183.1
# Target Mean Price                    338.3109
# Trailing EPS                             4.33
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 312.47
# Daylow                                  300.03
# Exchange                                   NYQ
# ...
