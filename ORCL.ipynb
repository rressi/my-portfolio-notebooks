# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# No operations found for ticker 'ORCL'
# Prices: 263.41 | 276.58 | 290.41 | 304.93 | 320.18 | 336.19 | 353.00
# Buy score: 4.67%
# No operations found.
#                                          ORCL
# Company Name                         Oracleon
# Current Price                        291.2919
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       410.0
# Target Low Price                        175.0
# Target Mean Price                   333.50766
# Trailing EPS                             4.32
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 298.75
# Daylow                                  288.55
# Exchange                                   NYQ
# ...
