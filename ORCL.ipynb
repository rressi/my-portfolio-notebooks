# %%
import my_portfolio
my_portfolio.run(
    security = "ORCL",
)
# Out:
# Prices: 260.32 | 273.33 | 287.00 | 301.35 | 316.42 | 332.24 | 348.85
# Buy score: -7.79%
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          328.15
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       410.0
# Target Low Price                        183.1
# Target Mean Price                   336.06848
# Trailing EPS                             4.33
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 329.50
# Daylow                                  306.92
# Exchange                                   NYQ
# Fiftydayaverage                         251.70
# ...
