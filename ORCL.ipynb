# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# Prices: 241.24 | 253.30 | 265.97 | 244.47 | 256.69 | 269.53 | 283.01
# Buy score: 1.52%
#                       Quantity   Price      Value    Wallet Avg. price  \
# Time
# 2025-10-27 09:30:29   4.000000  285.00   1,140.00  4.000000     285.00
# 2025-10-27 09:30:30   2.000000  285.00     570.00  6.000000     285.00
# 2025-10-30 11:35:01  -6.000000  259.82  -1,558.92  0.000000       0.00
#
#                     Inv. Cost Inv. Balance  Balance
# Time
# 2025-10-27 09:30:29      6.71        -6.71    -6.71
# 2025-10-27 09:30:30     12.57       -12.57   -12.57
# 2025-10-30 11:35:01      0.00         0.00  -176.03
#                                          ORCL
# Company Name                         Oracleon
# Current Price                         240.815
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# ...
