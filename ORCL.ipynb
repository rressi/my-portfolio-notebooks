# %%
import workflow
workflow.run(
    security = "ORCL",
)
# Out:
# Prices: 246.02 | 258.32 | 271.24 | 284.80 | 299.04 | 313.99 | 329.69
# Buy score: -3.99%
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          296.62
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       410.0
# Target Low Price                        183.1
# Target Mean Price                   333.49274
# Trailing EPS                             4.31
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 303.82
# Daylow                                  292.00
# Exchange                                   NYQ
# Fiftydayaverage                         249.01
# ...
