# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# Prices: 213.50 | 224.18 | 235.39 | 207.57 | 217.95 | 228.85 | 240.29
# Buy score: 12.04%
# Sell score: -9.37%
# Current return: -461.28 USD
# Breakeven price: 211.19 USD
# <style type="text/css">
# #T_dd0fe_row6_col0, #T_dd0fe_row6_col1, #T_dd0fe_row6_col2, #T_dd0fe_row6_col3, #T_dd0fe_row6_col4, #T_dd0fe_row6_col5, #T_dd0fe_row6_col6, #T_dd0fe_row6_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_dd0fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd0fe_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_dd0fe_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_dd0fe_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_dd0fe_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_dd0fe_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
