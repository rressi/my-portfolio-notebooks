# %%
import workflow
workflow.run(
    security = "ORCL",
)
# Out:
# Prices: 214.89 | 225.63 | 236.91 | 248.76 | 261.20 | 274.26 | 287.97
# Buy score: -17.67%
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          302.14
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       410.0
# Target Low Price                        183.1
# Target Mean Price                   333.49274
# Trailing EPS                             4.47
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 307.03
# Daylow                                  297.29
# Exchange                                   NYQ
# Fiftydayaverage                         244.89
# ...
