# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# No operations found for ticker 'ORCL'
# Prices: 255.66 | 268.45 | 281.87 | 295.96 | 310.76 | 326.30 | 342.61
# Buy score: 4.69%
# No operations found.
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          282.73
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       410.0
# Target Low Price                    175.14314
# Target Mean Price                   331.29724
# Trailing EPS                             4.31
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 285.98
# Daylow                                  279.65
# Exchange                                   NYQ
# ...
