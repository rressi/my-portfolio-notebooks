# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# Prices: 216.71 | 227.55 | 238.92 | 222.00 | 233.10 | 244.75 | 256.99
# Buy score: -0.83%
# Sell score: -0.55%
# Current return: -58.78 USD
# Breakeven price: 226.67 USD
# <style type="text/css">
# #T_af18b_row5_col0, #T_af18b_row5_col1, #T_af18b_row5_col2, #T_af18b_row5_col3, #T_af18b_row5_col4, #T_af18b_row5_col5, #T_af18b_row5_col6, #T_af18b_row5_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_af18b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af18b_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_af18b_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_af18b_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_af18b_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_af18b_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
