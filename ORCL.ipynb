# %%
import workflow
workflow.run(
    security = "ORCL",
)
# Out:
# Prices: 232.93 | 244.57 | 256.80 | 269.64 | 283.12 | 297.28 | 312.14
# Buy score: -12.07%
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          306.65
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       410.0
# Target Low Price                        183.1
# Target Mean Price                   333.49274
# Trailing EPS                             4.32
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 319.97
# Daylow                                  302.27
# Exchange                                   NYQ
# Fiftydayaverage                         246.18
# ...
