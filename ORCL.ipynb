# %%
import workflow
workflow.run(
    security = "ORCL",
)
# Out:
# Prices: 212.56 | 223.19 | 234.35 | 246.0675 | 258.37 | 271.29 | 284.85
# Buy score: -15.78%
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          292.18
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       410.0
# Target Low Price                        183.1
# Target Mean Price                   330.34122
# Trailing EPS                             4.32
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 307.97
# Daylow                                  291.75
# Exchange                                   NYQ
# Fiftydayaverage                         244.89
# ...
