# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# No operations found for ticker 'ORCL'
# Prices: 261.73 | 274.82 | 288.56 | 302.99 | 318.14 | 334.04 | 350.75
# Buy score: 3.79%
# No operations found.
#                                          ORCL
# Company Name                         Oracleon
# Current Price                          291.31
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       430.0
# Target Low Price                    175.14314
# Target Mean Price                   345.19482
# Trailing EPS                             4.31
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 304.28
# Daylow                                  287.50
# Exchange                                   NYQ
# ...
