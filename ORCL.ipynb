# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# No operations found for ticker 'ORCL'
# Prices: 256.57 | 269.40 | 282.87 | 297.01 | 311.86 | 327.46 | 343.83
# Buy score: -1.00%
# No operations found.
#                                          ORCL
# Company Name                         Oracleon
# Current Price                           299.0
# Forward EPS                              7.16
# Gross Profit (ttm)             41,113,001,984
# Industry            Software - Infrastructure
# Revenue (ttm)                  59,017,998,336
# Target High Price                       415.0
# Target Low Price                    175.14314
# Target Mean Price                    333.9298
# Trailing EPS                             4.31
# Website                https://www.oracle.com
#                                           ORCL
# Currency                                   USD
# Dayhigh                                 304.42
# Daylow                                  291.98
# Exchange                                   NYQ
# ...
