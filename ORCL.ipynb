# %%
import my_portfolio; my_portfolio.run("ORCL")
# Out:
# Prices: 218.78 | 229.72 | 241.21 | 222.00 | 233.10 | 244.75 | 256.99
# Buy score: -3.49%
# Sell score: -1.01%
# Current return: -69.08 USD
# Breakeven price: 226.67 USD
# <style type="text/css">
# #T_55dc8_row5_col0, #T_55dc8_row5_col1, #T_55dc8_row5_col2, #T_55dc8_row5_col3, #T_55dc8_row5_col4, #T_55dc8_row5_col5, #T_55dc8_row5_col6, #T_55dc8_row5_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_55dc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55dc8_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_55dc8_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_55dc8_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_55dc8_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_55dc8_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
