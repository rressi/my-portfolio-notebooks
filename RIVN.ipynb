# %%
import my_portfolio; my_portfolio.run("RIVN")
# Out:
# Prices: 11.85 | 12.44 | 13.07 | 13.43 | 14.10 | 14.81 | 15.55
# Buy score: -2.15%
# Sell score: 0.30%
# Current return: -10.02 USD
# Breakeven price: 13.71 USD
# <style type="text/css">
# #T_fd507_row11_col0, #T_fd507_row11_col1, #T_fd507_row11_col2, #T_fd507_row11_col3, #T_fd507_row11_col4, #T_fd507_row11_col5, #T_fd507_row11_col6, #T_fd507_row11_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_fd507">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd507_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_fd507_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_fd507_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_fd507_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_fd507_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
