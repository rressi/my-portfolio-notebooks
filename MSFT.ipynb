# %%
import my_portfolio
my_portfolio.run("MSFT")
# Out:
# Prices: 439.26 | 461.22 | 484.28 | 508.49 | 533.92 | 560.61 | 588.65
# Buy score: -1.43%
#                                          MSFT
# Company Name                      Microsofton
# Current Price                          514.45
# Forward EPS                             14.95
# Gross Profit (ttm)            193,893,007,360
# Industry            Software - Infrastructure
# Revenue (ttm)                 281,723,994,112
# Target High Price                       700.0
# Target Low Price                        483.0
# Target Mean Price                    615.7916
# Trailing EPS                            13.63
# Website             https://www.microsoft.com
#                                             MSFT
# Currency                                     USD
# Dayhigh                                   517.74
# Daylow                                    512.54
# Exchange                                     NMS
# Fiftydayaverage                           511.64
# ...
