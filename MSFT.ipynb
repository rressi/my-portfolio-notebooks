# %%
import my_portfolio; my_portfolio.run("MSFT")
# Out:
# Prices: 367.04 | 385.40 | 404.67 | 424.90 | 446.14 | 468.45 | 491.87
# Buy score: -5.58%
#                       Quantity   Price      Value    Wallet Avg. price  \
# Time
# 2025-10-29 14:31:31   1.000000  539.76     539.76  1.000000     539.76
# 2025-10-31 10:19:28   1.000000  517.61     517.61  2.000000     528.68
# 2025-10-31 10:20:37  -2.000000  517.20  -1,034.39  0.000000       0.00
#
#                     Inv. Cost Inv. Balance Balance
# Time
# 2025-10-29 14:31:31      5.81        -5.81   -5.81
# 2025-10-31 10:19:28     11.59       -33.74  -33.74
# 2025-10-31 10:20:37      0.00         0.00  -46.14
#                                          MSFT
# Company Name                      Microsofton
# Current Price                          450.24
# Forward EPS                          19.33773
# Gross Profit (ttm)            217,409,994,752
# Industry            Software - Infrastructure
# Revenue (ttm)                 318,272,995,328
# Target High Price                       870.0
# ...
