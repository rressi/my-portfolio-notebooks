# %%
import my_portfolio
my_portfolio.run("MSFT")
# Out:
# Prices: 437.85 | 459.75 | 482.73 | 506.87 | 532.21 | 558.82 | 586.76
# Buy score: -2.14%
#                                          MSFT
# Company Name                      Microsofton
# Current Price                          517.93
# Forward EPS                             14.95
# Gross Profit (ttm)            193,893,007,360
# Industry            Software - Infrastructure
# Revenue (ttm)                 281,723,994,112
# Target High Price                       700.0
# Target Low Price                        483.0
# Target Mean Price                    615.7916
# Trailing EPS                            13.62
# Website             https://www.microsoft.com
#                                             MSFT
# Currency                                     USD
# Dayhigh                                   519.30
# Daylow                                    510.31
# Exchange                                     NMS
# Fiftydayaverage                           511.64
# ...
