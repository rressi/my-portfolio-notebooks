# %%
import my_portfolio; my_portfolio.run("MSFT")
# Out:
# Prices: 460.34 | 483.36 | 507.53 | 539.76 | 566.75 | 595.08 | 624.84
# Buy score: 0.93%
# Sell score: -2.18%
# Current return: -23.39 USD
# Breakeven price: 551.38 USD
# <style type="text/css">
# #T_817d9_row1_col0, #T_817d9_row1_col1, #T_817d9_row1_col2, #T_817d9_row1_col3, #T_817d9_row1_col4, #T_817d9_row1_col5, #T_817d9_row1_col6, #T_817d9_row1_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_817d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_817d9_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_817d9_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_817d9_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_817d9_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_817d9_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
