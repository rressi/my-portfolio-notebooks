# %%
import workflow
workflow.run("MSFT")
# Out:
# Prices: 436.30 | 458.12 | 481.02 | 504.53 | 529.75 | 556.24 | 584.05
# Buy score: -1.08%
#                                          MSFT
# Company Name                      Microsofton
# Current Price                          510.02
# Forward EPS                             14.95
# Gross Profit (ttm)            193,893,007,360
# Industry            Software - Infrastructure
# Revenue (ttm)                 281,723,994,112
# Target High Price                       700.0
# Target Low Price                        483.0
# Target Mean Price                    615.3839
# Trailing EPS                            13.64
# Website             https://www.microsoft.com
#                                             MSFT
# Currency                                     USD
# Dayhigh                                   511.29
# Daylow                                    505.93
# Exchange                                     NMS
# Fiftydayaverage                           510.95
# ...
