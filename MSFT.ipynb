# %%
import workflow
workflow.run("MSFT")
# Out:
# Prices: 436.46 | 458.28 | 481.19 | 504.58 | 529.80 | 556.30 | 584.11
# Buy score: -0.76%
#                                          MSFT
# Company Name                      Microsofton
# Current Price                          508.45
# Forward EPS                             14.95
# Gross Profit (ttm)            193,893,007,360
# Industry            Software - Infrastructure
# Revenue (ttm)                 281,723,994,112
# Target High Price                       700.0
# Target Low Price                        483.0
# Target Mean Price                    615.7916
# Trailing EPS                            13.62
# Website             https://www.microsoft.com
#                                             MSFT
# Currency                                     USD
# Dayhigh                                   513.07
# Daylow                                    507.66
# Exchange                                     NMS
# Fiftydayaverage                           511.22
# ...
