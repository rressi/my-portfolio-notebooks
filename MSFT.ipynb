# %%
import workflow
workflow.run(
    security = "MSFT",
)
# Out:
# Prices: 437.24 | 459.11 | 482.06 | 506.1642 | 531.47 | 558.05 | 585.95
# Buy score: 1.03%
#                                          MSFT
# Company Name                        Microsoft
# Industry            Software - Infrastructure
# Revenue (ttm)                 281,723,994,112
# Gross Profit (ttm)            193,893,007,360
# Current Price                          501.01
# Target Mean Price                    615.3839
# Target High Price                       700.0
# Target Low Price                        483.0
# Trailing EPS                            13.66
# Forward EPS                             14.95
# Website             https://www.microsoft.com
#                                             MSFT
# Currency                                     USD
# Dayhigh                                   503.17
# Daylow                                    497.88
# Exchange                                     NMS
# Fiftydayaverage                           509.84
# ...
