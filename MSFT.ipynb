# %%
import my_portfolio; my_portfolio.run("MSFT")
# Out:
# No operations found for ticker 'MSFT'
# Prices: 456.10 | 478.90 | 502.85 | 527.99 | 554.39 | 582.11 | 611.21
# Buy score: -2.89%
# No operations found.
#                                          MSFT
# Company Name                      Microsofton
# Current Price                        543.7209
# Forward EPS                             14.95
# Gross Profit (ttm)            193,893,007,360
# Industry            Software - Infrastructure
# Revenue (ttm)                 281,723,994,112
# Target High Price                       730.0
# Target Low Price                        483.0
# Target Mean Price                   621.06885
# Trailing EPS                            13.66
# Website             https://www.microsoft.com
#                                             MSFT
# Currency                                     USD
# Dayhigh                                   553.72
# Daylow                                    542.46
# Exchange                                     NMS
# ...
