# %%
import workflow
workflow.run(
    security = "MSFT",
)
# Out:
# Prices: 434.93 | 456.68 | 479.51 | 503.4847 | 528.66 | 555.09 | 582.85
# Buy score: 0.49%
#                                          MSFT
# Company Name            Microsoft Corporation
# Industry            Software - Infrastructure
# Revenue (ttm)                 281,723,994,112
# Gross Profit (ttm)            193,893,007,360
# Current Price                          501.01
# Target Mean Price                    615.3839
# Target High Price                       700.0
# Target Low Price                        483.0
# Trailing EPS                            13.66
# Forward EPS                             14.95
# Website             https://www.microsoft.com
#                                             MSFT
# Currency                                     USD
# Dayhigh                                   503.17
# Daylow                                    497.88
# Exchange                                     NMS
# Fiftydayaverage                           509.84
# ...
