# %%
import my_portfolio; my_portfolio.run("MSFT")
# Out:
# No operations found for ticker 'MSFT'
# Prices: 447.65 | 470.04 | 493.54 | 518.21 | 544.12 | 571.33 | 599.90
# Buy score: -0.82%
# No operations found.
#                                          MSFT
# Company Name                      Microsofton
# Current Price                           522.5
# Forward EPS                             14.95
# Gross Profit (ttm)            193,893,007,360
# Industry            Software - Infrastructure
# Revenue (ttm)                 281,723,994,112
# Target High Price                       710.0
# Target Low Price                        483.0
# Target Mean Price                    621.2663
# Trailing EPS                            13.64
# Website             https://www.microsoft.com
#                                             MSFT
# Currency                                     USD
# Dayhigh                                   523.95
# Daylow                                    518.63
# Exchange                                     NMS
# ...
