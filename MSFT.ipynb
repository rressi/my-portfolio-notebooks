# %%
import my_portfolio; my_portfolio.run("MSFT")
# Out:
# No operations found for ticker 'MSFT'
# Prices: 441.56 | 463.63 | 486.82 | 511.16 | 536.71 | 563.55 | 591.73
# Buy score: 0.81%
# No operations found.
#                                          MSFT
# Company Name                      Microsofton
# Current Price                          507.03
# Forward EPS                             14.95
# Gross Profit (ttm)            193,893,007,360
# Industry            Software - Infrastructure
# Revenue (ttm)                 281,723,994,112
# Target High Price                       700.0
# Target Low Price                        483.0
# Target Mean Price                   616.46234
# Trailing EPS                            13.62
# Website             https://www.microsoft.com
#                                             MSFT
# Currency                                     USD
# Dayhigh                                   510.01
# Daylow                                    505.04
# Exchange                                     NMS
# ...
