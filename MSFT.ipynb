# %%
import my_portfolio; my_portfolio.run("MSFT")
# Out:
# Prices: 459.00 | 481.95 | 506.05 | 539.76 | 566.75 | 595.08 | 624.84
# Buy score: -1.42%
# Sell score: -0.14%
# Current return: -12.36 USD
# Breakeven price: 551.38 USD
# <style type="text/css">
# #T_fafbe_row1_col0, #T_fafbe_row1_col1, #T_fafbe_row1_col2, #T_fafbe_row1_col3, #T_fafbe_row1_col4, #T_fafbe_row1_col5, #T_fafbe_row1_col6, #T_fafbe_row1_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_fafbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fafbe_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_fafbe_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_fafbe_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_fafbe_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_fafbe_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
