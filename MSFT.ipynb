# %%
import workflow
workflow.run("MSFT")
# Out:
# Prices: 436.74 | 458.57 | 481.50 | 505.5780 | 530.86 | 557.40 | 585.27
# Buy score: -0.85%
#                                          MSFT
# Company Name                      Microsofton
# Current Price                           509.9
# Forward EPS                             14.95
# Gross Profit (ttm)            193,893,007,360
# Industry            Software - Infrastructure
# Revenue (ttm)                 281,723,994,112
# Target High Price                       700.0
# Target Low Price                        483.0
# Target Mean Price                    615.3839
# Trailing EPS                            13.67
# Website             https://www.microsoft.com
#                                             MSFT
# Currency                                     USD
# Dayhigh                                   512.55
# Daylow                                    503.85
# Exchange                                     NMS
# Fiftydayaverage                           510.39
# ...
