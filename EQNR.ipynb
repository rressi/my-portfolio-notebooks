# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 313.63 | 329.31 | 345.78 | 358.88 | 376.83 | 395.67 | 415.45
# Buy score: -2.40%
# Sell score: -1.05%
# Current return: -128,687.15 NOK
# Breakeven price: 380.84 NOK
# <style type="text/css">
# #T_e86c9_row35_col0, #T_e86c9_row35_col1, #T_e86c9_row35_col2, #T_e86c9_row35_col3, #T_e86c9_row35_col4, #T_e86c9_row35_col5, #T_e86c9_row35_col6, #T_e86c9_row35_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_e86c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e86c9_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_e86c9_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_e86c9_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_e86c9_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_e86c9_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
