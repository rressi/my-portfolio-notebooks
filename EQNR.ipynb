# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 301.08 | 316.13 | 331.94 | 317.92 | 333.82 | 350.51 | 368.03
# Buy score: -0.35%
# Sell score: 0.15%
# Current return: -9,464.42 NOK
# Breakeven price: 321.55 NOK
# <style type="text/css">
# #T_12633_row59_col0, #T_12633_row59_col1, #T_12633_row59_col2, #T_12633_row59_col3, #T_12633_row59_col4, #T_12633_row59_col5, #T_12633_row59_col6, #T_12633_row59_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_12633">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12633_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_12633_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_12633_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_12633_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_12633_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
