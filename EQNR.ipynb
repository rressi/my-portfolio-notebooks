# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 218.86 | 229.80 | 241.30 | 258.40 | 271.32 | 284.89 | 299.13
# Buy score: -1.03%
# Sell score: -0.93%
# Current return: -2,842.62 NOK
# Breakeven price: 261.69 NOK
# <style type="text/css">
# #T_0627f_row3_col0, #T_0627f_row3_col1, #T_0627f_row3_col2, #T_0627f_row3_col3, #T_0627f_row3_col4, #T_0627f_row3_col5, #T_0627f_row3_col6, #T_0627f_row3_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_0627f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0627f_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_0627f_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_0627f_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_0627f_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_0627f_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
