# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 331.68 | 348.26 | 365.68 | 390.32 | 409.84 | 430.33 | 451.85
# Buy score: 4.37%
# Sell score: -5.75%
# Current return: -104,636.20 NOK
# Breakeven price: 394.06 NOK
# <style type="text/css">
# #T_1b88e_row17_col0, #T_1b88e_row17_col1, #T_1b88e_row17_col2, #T_1b88e_row17_col3, #T_1b88e_row17_col4, #T_1b88e_row17_col5, #T_1b88e_row17_col6, #T_1b88e_row17_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_1b88e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b88e_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_1b88e_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_1b88e_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_1b88e_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_1b88e_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
