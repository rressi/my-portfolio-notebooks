# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 313.28 | 328.95 | 345.39 | 360.68 | 378.71 | 397.65 | 417.53
# Buy score: -0.13%
# Sell score: -5.12%
# Current return: -178,910.79 NOK
# Breakeven price: 386.93 NOK
# <style type="text/css">
# #T_20c16_row33_col0, #T_20c16_row33_col1, #T_20c16_row33_col2, #T_20c16_row33_col3, #T_20c16_row33_col4, #T_20c16_row33_col5, #T_20c16_row33_col6, #T_20c16_row33_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_20c16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20c16_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_20c16_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_20c16_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_20c16_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_20c16_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
