# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 331.64 | 348.23 | 365.64 | 390.32 | 409.84 | 430.33 | 451.85
# Buy score: 4.64%
# Sell score: -6.00%
# Current return: -108,636.20 NOK
# Breakeven price: 394.06 NOK
# <style type="text/css">
# #T_c782a_row17_col0, #T_c782a_row17_col1, #T_c782a_row17_col2, #T_c782a_row17_col3, #T_c782a_row17_col4, #T_c782a_row17_col5, #T_c782a_row17_col6, #T_c782a_row17_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_c782a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c782a_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c782a_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c782a_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c782a_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c782a_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
