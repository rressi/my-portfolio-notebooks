# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 313.67 | 329.35 | 345.82 | 358.47 | 376.83 | 395.67 | 415.45
# Buy score: -2.80%
# Sell score: -0.52%
# Current return: -120,229.34 NOK
# Breakeven price: 378.86 NOK
# <style type="text/css">
# #T_d995a_row36_col0, #T_d995a_row36_col1, #T_d995a_row36_col2, #T_d995a_row36_col3, #T_d995a_row36_col4, #T_d995a_row36_col5, #T_d995a_row36_col6, #T_d995a_row36_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_d995a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d995a_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_d995a_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_d995a_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_d995a_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_d995a_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
