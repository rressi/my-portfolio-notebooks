# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 231.55 | 243.13 | 255.28 | 278.50 | 292.43 | 307.05 | 322.40
# Buy score: -4.54%
# Sell score: 0.83%
# Current return: -339.07 NOK
# Breakeven price: 281.14 NOK
# <style type="text/css">
# #T_6c072_row7_col0, #T_6c072_row7_col1, #T_6c072_row7_col2, #T_6c072_row7_col3, #T_6c072_row7_col4, #T_6c072_row7_col5, #T_6c072_row7_col6, #T_6c072_row7_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_6c072">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c072_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_6c072_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_6c072_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_6c072_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_6c072_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
