# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 308.90 | 324.34 | 340.56 | 380.12 | 399.13 | 419.08 | 440.04
# Buy score: -2.71%
# Sell score: -5.92%
# Current return: -131,527.83 NOK
# Breakeven price: 383.91 NOK
# <style type="text/css">
# #T_9a7a3_row18_col0, #T_9a7a3_row18_col1, #T_9a7a3_row18_col2, #T_9a7a3_row18_col3, #T_9a7a3_row18_col4, #T_9a7a3_row18_col5, #T_9a7a3_row18_col6, #T_9a7a3_row18_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_9a7a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a7a3_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_9a7a3_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_9a7a3_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_9a7a3_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_9a7a3_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
