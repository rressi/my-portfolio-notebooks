# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 294.65 | 309.38 | 324.85 | 317.92 | 333.82 | 350.51 | 368.03
# Buy score: -3.15%
# Sell score: 4.40%
# Current return: 31,035.58 NOK
# Breakeven price: 321.55 NOK
# <style type="text/css">
# #T_88188_row59_col0, #T_88188_row59_col1, #T_88188_row59_col2, #T_88188_row59_col3, #T_88188_row59_col4, #T_88188_row59_col5, #T_88188_row59_col6, #T_88188_row59_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_88188">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88188_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_88188_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_88188_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_88188_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_88188_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
