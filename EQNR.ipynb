# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 312.91 | 328.56 | 344.98 | 358.18 | 376.09 | 394.89 | 414.64
# Buy score: 0.09%
# Sell score: -1.45%
# Current return: -145,630.22 NOK
# Breakeven price: 377.27 NOK
# <style type="text/css">
# #T_c71fc_row38_col0, #T_c71fc_row38_col1, #T_c71fc_row38_col2, #T_c71fc_row38_col3, #T_c71fc_row38_col4, #T_c71fc_row38_col5, #T_c71fc_row38_col6, #T_c71fc_row38_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_c71fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c71fc_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c71fc_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c71fc_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c71fc_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c71fc_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
