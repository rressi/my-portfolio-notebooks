# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 240.06 | 252.06 | 264.67 | 278.50 | 292.43 | 307.05 | 322.40
# Buy score: -0.36%
# Sell score: 0.14%
# Current return: -2,239.07 NOK
# Breakeven price: 281.14 NOK
# <style type="text/css">
# #T_04a6b_row7_col0, #T_04a6b_row7_col1, #T_04a6b_row7_col2, #T_04a6b_row7_col3, #T_04a6b_row7_col4, #T_04a6b_row7_col5, #T_04a6b_row7_col6, #T_04a6b_row7_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_04a6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04a6b_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_04a6b_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_04a6b_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_04a6b_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_04a6b_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
