# %%
import my_portfolio; my_portfolio.run("EQNR.OL")
# Out:
# Prices: 311.17 | 326.73 | 343.07 | 380.12 | 399.13 | 419.08 | 440.04
# Buy score: -4.00%
# Sell score: -1.32%
# Current return: -45,366.98 NOK
# Breakeven price: 386.44 NOK
# <style type="text/css">
# #T_bf814_row24_col0, #T_bf814_row24_col1, #T_bf814_row24_col2, #T_bf814_row24_col3, #T_bf814_row24_col4, #T_bf814_row24_col5, #T_bf814_row24_col6, #T_bf814_row24_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_bf814">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf814_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_bf814_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_bf814_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_bf814_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_bf814_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
