# %%
import workflow
workflow.run(
    security = "ETH-USD",  # Ethereum
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,819.05 | 4,010.00 | 4,210.50 | 4421.0233 | 4,642.07 | 4,874.18 | 5,117.89
# Buy score: -2.07%
#                          ETH-USD
# Company Name        Ethereum USD
# Industry                    None
# Revenue (ttm)               None
# Gross Profit (ttm)          None
# Current Price               None
# Target Mean Price           None
# Target High Price           None
# Target Low Price            None
# Trailing EPS                None
# Forward EPS                 None
# Website                     None
#                                    ETH-USD
# Currency                               USD
# Dayhigh                           4,531.06
# Daylow                            4,454.40
# Exchange                               CCC
# Fiftydayaverage                   4,186.03
# Lastprice                         4,514.61
# Lastvolume                  38,789,816,320
# Marketcap                             None
# Open                              4,461.06
# ...
