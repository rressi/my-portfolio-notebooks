# %%
import workflow
workflow.run(
    security = "ETH-USD",  # Ethereum
    # start_date = "2025-01-01",
)
# Out:
# Prices: 3,808.95 | 3,999.40 | 4,199.37 | 4409.3368 | 4,629.80 | 4,861.29 | 5,104.36
# Buy score: -5.38%
#                          ETH-USD
# Company Name        Ethereum USD
# Current Price               None
# Forward EPS                 None
# Gross Profit (ttm)          None
# Industry                    None
# Revenue (ttm)               None
# Target High Price           None
# Target Low Price            None
# Target Mean Price           None
# Trailing EPS                None
# Website                     None
#                                    ETH-USD
# Currency                               USD
# Dayhigh                           4,761.22
# Daylow                            4,609.13
# Exchange                               CCC
# Fiftydayaverage                   4,211.68
# Lastprice                         4,660.14
# Lastvolume                  38,711,549,952
# Marketcap                             None
# Open                              4,715.19
# ...
