# %%
import workflow
workflow.run(
    security = "ETH-USD",  # Ethereum
    start_date = "2025-01-01",
)
# Out:
# Prices: 3,766.49 | 3,954.81 | 4,152.55 | 4360.1788 | 4,578.19 | 4,807.10 | 5,047.45
# Buy score: -0.35%
#                          ETH-USD
# Company Name        Ethereum USD
# Industry                    None
# Revenue (ttm)               None
# Gross Profit (ttm)          None
# Current Price               None
# Target Mean Price           None
# Target High Price           None
# Target Low Price            None
# Trailing EPS                None
# Forward EPS                 None
# Website                     None
#                                    ETH-USD
# Currency                               USD
# Dayhigh                           4,383.69
# Daylow                            4,340.29
# Exchange                               CCC
# Fiftydayaverage                   4,171.35
# Lastprice                         4,375.28
# Lastvolume                  39,130,996,736
# Marketcap                             None
# Open                              4,348.68
# ...
