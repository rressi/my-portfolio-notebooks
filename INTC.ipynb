# %%
import workflow
workflow.run(
    security = "INTC",
)
# Out:
# Prices: 21.29 | 22.35 | 23.47 | 24.64 | 25.87 | 27.17 | 28.53
# Buy score: -1.04%
#                                      INTC
# Company Name                      Intelon
# Current Price                        24.9
# Forward EPS                          0.97
# Gross Profit (ttm)         17,471,000,576
# Industry                   Semiconductors
# Revenue (ttm)              53,070,000,128
# Target High Price                    28.0
# Target Low Price                     14.0
# Target Mean Price                22.17571
# Trailing EPS                        -4.77
# Website             https://www.intel.com
#                                           INTC
# Currency                                   USD
# Dayhigh                                  25.26
# Daylow                                   24.45
# Exchange                                   NMS
# Fiftydayaverage                          22.99
# Lastprice                                24.90
# ...
