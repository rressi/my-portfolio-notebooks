# %%
import workflow
workflow.run(
    security = "INTC",
    # start_date = "2025-01-01",
    # sma_lenght = 5,
)
# Out:
# Prices: 21.14 | 22.20 | 23.31 | 24.4760 | 25.70 | 26.98 | 28.33
# Buy score: 1.64%
#                                      INTC
# Company Name                      Intelon
# Current Price                       24.08
# Forward EPS                          0.97
# Gross Profit (ttm)         17,471,000,576
# Industry                   Semiconductors
# Revenue (ttm)              53,070,000,128
# Target High Price                    28.0
# Target Low Price                     14.0
# Target Mean Price                22.17571
# Trailing EPS                        -4.77
# Website             https://www.intel.com
#                                           INTC
# Currency                                   USD
# Dayhigh                                  24.63
# Daylow                                   24.05
# Exchange                                   NMS
# Fiftydayaverage                          22.88
# Lastprice                                24.08
# ...
