# %%
import my_portfolio; my_portfolio.run("INTC")
# Out:
# Prices: 23.03 | 24.19 | 25.40 | 26.67 | 28.00 | 29.40 | 30.87
# Buy score: -9.21%
# No operations found.
#                                      INTC
# Company Name                      Intelon
# Current Price                       29.34
# Forward EPS                          0.97
# Gross Profit (ttm)         17,471,000,576
# Industry                   Semiconductors
# Revenue (ttm)              53,070,000,128
# Target High Price                    43.0
# Target Low Price                     14.0
# Target Mean Price                24.86528
# Trailing EPS                        -4.77
# Website             https://www.intel.com
#                                           INTC
# Currency                                   USD
# Dayhigh                                  30.20
# Daylow                                   28.82
# Exchange                                   NMS
# Fiftydayaverage                          23.38
# Lastprice                                29.34
# ...
