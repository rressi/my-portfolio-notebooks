# %%
import my_portfolio; my_portfolio.run("INTC")
# Out:
# Prices: 32.81 | 34.45 | 36.18 | 38.40 | 40.32 | 42.34 | 44.45
# Buy score: -0.49%
# Sell score: -4.09%
# Current return: -104.25 USD
# Breakeven price: 38.92 USD
# <style type="text/css">
# #T_37753_row30_col0, #T_37753_row30_col1, #T_37753_row30_col2, #T_37753_row30_col3, #T_37753_row30_col4, #T_37753_row30_col5, #T_37753_row30_col6, #T_37753_row30_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_37753">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37753_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_37753_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_37753_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_37753_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_37753_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
