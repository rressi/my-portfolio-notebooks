# %%
import my_portfolio; my_portfolio.run("INTC")
# Out:
# Prices: 32.33 | 33.94 | 35.64 | 37.75 | 39.64 | 41.62 | 43.70
# Buy score: -1.57%
# Sell score: 0.71%
# Current return: -6.11 USD
# Breakeven price: 38.26 USD
# <style type="text/css">
# #T_5b7e6_row19_col0, #T_5b7e6_row19_col1, #T_5b7e6_row19_col2, #T_5b7e6_row19_col3, #T_5b7e6_row19_col4, #T_5b7e6_row19_col5, #T_5b7e6_row19_col6, #T_5b7e6_row19_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_5b7e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b7e6_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_5b7e6_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_5b7e6_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_5b7e6_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_5b7e6_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
