# %%
import my_portfolio; my_portfolio.run("INTC")
# Out:
# Prices: 32.43 | 34.05 | 35.75 | 37.62 | 39.51 | 41.48 | 43.56
# Buy score: -0.02%
# Sell score: -0.21%
# Current return: -29.66 USD
# Breakeven price: 38.14 USD
# <style type="text/css">
# #T_14579_row21_col0, #T_14579_row21_col1, #T_14579_row21_col2, #T_14579_row21_col3, #T_14579_row21_col4, #T_14579_row21_col5, #T_14579_row21_col6, #T_14579_row21_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_14579">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14579_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_14579_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_14579_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_14579_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_14579_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
