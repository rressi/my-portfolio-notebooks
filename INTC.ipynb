# %%
import workflow
workflow.run(
    security = "INTC",
    # start_date = "2025-01-01",
)
# Out:
# Prices: 21.07 | 22.13 | 23.23 | 24.3935 | 25.61 | 26.89 | 28.24
# Buy score: -0.88%
#                                      INTC
# Company Name                        Intel
# Industry                   Semiconductors
# Revenue (ttm)              53,070,000,128
# Gross Profit (ttm)         17,471,000,576
# Current Price                       24.61
# Target Mean Price                22.17571
# Target High Price                    28.0
# Target Low Price                     14.0
# Trailing EPS                        -4.77
# Forward EPS                          0.97
# Website             https://www.intel.com
#                                           INTC
# Currency                                   USD
# Dayhigh                                  24.93
# Daylow                                   24.57
# Exchange                                   NMS
# Fiftydayaverage                          22.80
# Lastprice                                24.61
# ...
