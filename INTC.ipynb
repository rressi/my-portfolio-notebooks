# %%
import my_portfolio; my_portfolio.run("INTC")
# Out:
# Prices: 31.93 | 33.53 | 35.21 | 37.75 | 39.64 | 41.62 | 43.70
# Buy score: -3.25%
# Sell score: 1.22%
# Current return: -1.34 USD
# Breakeven price: 38.26 USD
# <style type="text/css">
# #T_35096_row19_col0, #T_35096_row19_col1, #T_35096_row19_col2, #T_35096_row19_col3, #T_35096_row19_col4, #T_35096_row19_col5, #T_35096_row19_col6, #T_35096_row19_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_35096">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35096_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_35096_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_35096_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_35096_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_35096_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
