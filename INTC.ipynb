# %%
import workflow
workflow.run(
    security = "INTC",
)
# Out:
# Prices: 21.80 | 22.89 | 24.04 | 25.24 | 26.50 | 27.82 | 29.22
# Buy score: -17.44%
#                                      INTC
# Company Name                      Intelon
# Current Price                       30.57
# Forward EPS                          0.97
# Gross Profit (ttm)         17,471,000,576
# Industry                   Semiconductors
# Revenue (ttm)              53,070,000,128
# Target High Price                    34.0
# Target Low Price                     14.0
# Target Mean Price                22.66143
# Trailing EPS                        -4.77
# Website             https://www.intel.com
#                                           INTC
# Currency                                   USD
# Dayhigh                                  32.38
# Daylow                                   30.16
# Exchange                                   NMS
# Fiftydayaverage                          23.02
# Lastprice                                30.57
# ...
