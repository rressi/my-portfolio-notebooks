# %%
import workflow
workflow.run(
    security = "INTC",
    # start_date = "2025-01-01",
    # sma_lenght = 5,
)
# Out:
# Prices: 21.09 | 22.15 | 23.25 | 24.42 | 25.64 | 26.92 | 28.26
# Buy score: -1.43%
#                                      INTC
# Company Name                      Intelon
# Current Price                       24.77
# Forward EPS                          0.97
# Gross Profit (ttm)         17,471,000,576
# Industry                   Semiconductors
# Revenue (ttm)              53,070,000,128
# Target High Price                    28.0
# Target Low Price                     14.0
# Target Mean Price                22.17571
# Trailing EPS                        -4.91
# Website             https://www.intel.com
#                                           INTC
# Currency                                   USD
# Dayhigh                                  25.46
# Daylow                                   24.22
# Exchange                                   NMS
# Fiftydayaverage                          22.88
# Lastprice                                24.77
# ...
