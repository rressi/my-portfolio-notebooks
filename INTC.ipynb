# %%
import my_portfolio; my_portfolio.run("INTC")
# Out:
# Prices: 22.24 | 23.35 | 24.52 | 25.75 | 27.03 | 28.39 | 29.81
# Buy score: -12.96%
#                                      INTC
# Company Name                      Intelon
# Current Price                       29.58
# Forward EPS                          0.97
# Gross Profit (ttm)         17,471,000,576
# Industry                   Semiconductors
# Revenue (ttm)              53,070,000,128
# Target High Price                    43.0
# Target Low Price                     14.0
# Target Mean Price                24.61528
# Trailing EPS                        -4.77
# Website             https://www.intel.com
#                                           INTC
# Currency                                   USD
# Dayhigh                                  30.63
# Daylow                                   29.33
# Exchange                                   NMS
# Fiftydayaverage                          23.27
# Lastprice                                29.58
# ...
