# %%
import my_portfolio; my_portfolio.run("INTC")
# Out:
# Prices: 32.87 | 34.51 | 36.24 | 38.40 | 40.32 | 42.34 | 44.45
# Buy score: 1.99%
# Sell score: -5.55%
# Current return: -132.26 USD
# Breakeven price: 38.92 USD
# <style type="text/css">
# #T_97e2f_row30_col0, #T_97e2f_row30_col1, #T_97e2f_row30_col2, #T_97e2f_row30_col3, #T_97e2f_row30_col4, #T_97e2f_row30_col5, #T_97e2f_row30_col6, #T_97e2f_row30_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_97e2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97e2f_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_97e2f_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_97e2f_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_97e2f_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_97e2f_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
