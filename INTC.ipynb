# %%
import my_portfolio; my_portfolio.run("INTC")
# Out:
# Prices: 32.83 | 34.48 | 36.20 | 38.40 | 40.32 | 42.34 | 44.45
# Buy score: -5.40%
# Sell score: 2.66%
# Current return: 25.24 USD
# Breakeven price: 38.92 USD
# <style type="text/css">
# #T_f129a_row30_col0, #T_f129a_row30_col1, #T_f129a_row30_col2, #T_f129a_row30_col3, #T_f129a_row30_col4, #T_f129a_row30_col5, #T_f129a_row30_col6, #T_f129a_row30_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_f129a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f129a_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_f129a_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_f129a_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_f129a_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_f129a_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
