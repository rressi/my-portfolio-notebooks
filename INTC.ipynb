# %%
import workflow
workflow.run(
    security = "INTC",
)
# Out:
# Prices: 21.21 | 22.27 | 23.38 | 24.55 | 25.78 | 27.07 | 28.42
# Buy score: -2.84%
#                                      INTC
# Company Name                      Intelon
# Current Price                       25.27
# Forward EPS                          0.97
# Gross Profit (ttm)         17,471,000,576
# Industry                   Semiconductors
# Revenue (ttm)              53,070,000,128
# Target High Price                    28.0
# Target Low Price                     14.0
# Target Mean Price                22.17571
# Trailing EPS                        -4.77
# Website             https://www.intel.com
#                                           INTC
# Currency                                   USD
# Dayhigh                                  25.34
# Daylow                                   24.69
# Exchange                                   NMS
# Fiftydayaverage                          22.92
# Lastprice                                25.27
# ...
