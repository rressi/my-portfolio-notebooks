# %%
import my_portfolio; my_portfolio.run("INTC")
# Out:
# Prices: 34.99 | 36.73 | 38.57 | 39.99 | 41.99 | 44.09 | 46.29
# Buy score: 2.60%
# Sell score: -1.29%
# Current return: -45.40 USD
# Breakeven price: 40.61 USD
# <style type="text/css">
# #T_13982_row27_col0, #T_13982_row27_col1, #T_13982_row27_col2, #T_13982_row27_col3, #T_13982_row27_col4, #T_13982_row27_col5, #T_13982_row27_col6, #T_13982_row27_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_13982">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13982_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_13982_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_13982_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_13982_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_13982_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
