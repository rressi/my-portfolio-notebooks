# %%
import my_portfolio; my_portfolio.run("INTC")
# Out:
# Prices: 32.35 | 33.96 | 35.66 | 37.75 | 39.64 | 41.62 | 43.70
# Buy score: -1.09%
# Sell score: 0.28%
# Current return: -10.22 USD
# Breakeven price: 38.26 USD
# <style type="text/css">
# #T_acdbe_row19_col0, #T_acdbe_row19_col1, #T_acdbe_row19_col2, #T_acdbe_row19_col3, #T_acdbe_row19_col4, #T_acdbe_row19_col5, #T_acdbe_row19_col6, #T_acdbe_row19_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_acdbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acdbe_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_acdbe_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_acdbe_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_acdbe_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_acdbe_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
