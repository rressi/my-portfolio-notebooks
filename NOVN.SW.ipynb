# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 104.34 | 109.56 | 115.04 | 115.98 | 121.77 | 127.86 | 134.26
# Buy score: 2.31%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                              113.7
# Forward EPS                             7.729071
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      138.86954
# Target Low Price                        91.03012
# Target Mean Price                     120.789955
# Trailing EPS                                5.62
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 116.20
# Daylow                                  113.32
# ...
