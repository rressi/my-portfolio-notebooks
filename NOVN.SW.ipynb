# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 102.29 | 107.41 | 112.78 | 115.57 | 121.35 | 127.42 | 133.79
# Buy score: -2.14%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                              118.1
# Forward EPS                             7.586208
# Gross Profit (ttm)                42,746,998,784
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,577,998,848
# Target High Price                      140.31784
# Target Low Price                        95.21514
# Target Mean Price                      122.19989
# Trailing EPS                                5.43
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 118.34
# Daylow                                  117.00
# ...
