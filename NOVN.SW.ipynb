# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 101.46 | 106.54 | 111.86 | 117.46 | 123.33 | 129.50 | 135.97
# Buy score: -1.94%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             119.84
# Forward EPS                             7.561447
# Gross Profit (ttm)                42,974,998,528
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      132.10506
# Target Low Price                        85.86525
# Target Mean Price                      113.25456
# Trailing EPS                                5.54
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 119.90
# Daylow                                  117.16
# ...
