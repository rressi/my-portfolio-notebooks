# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 102.10 | 107.20 | 112.56 | 117.22 | 123.09 | 129.24 | 135.70
# Buy score: -1.94%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             119.54
# Forward EPS                             7.649887
# Gross Profit (ttm)                42,746,998,784
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,577,998,848
# Target High Price                      140.94052
# Target Low Price                        95.63767
# Target Mean Price                      122.69029
# Trailing EPS                                 5.5
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 119.56
# Daylow                                  117.04
# ...
