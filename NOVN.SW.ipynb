# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 110.03 | 115.53 | 121.31 | 127.37 | 133.74 | 140.43 | 147.45
# Buy score: -0.92%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             128.56
# Forward EPS                             7.723964
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      138.84984
# Target Low Price                        89.50407
# Target Mean Price                      116.09855
# Trailing EPS                                5.55
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 128.68
# Daylow                                  126.98
# ...
