# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 105.06 | 110.32 | 115.83 | 121.62 | 127.71 | 134.09 | 140.79
# Buy score: -0.41%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             121.76
# Forward EPS                               7.7966
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                       141.4999
# Target Low Price                        90.84927
# Target Mean Price                      121.30634
# Trailing EPS                                5.66
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 123.62
# Daylow                                  121.74
# ...
