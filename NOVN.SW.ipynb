# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 102.89 | 108.03 | 113.43 | 119.10 | 125.06 | 131.31 | 137.88
# Buy score: 0.53%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             118.48
# Forward EPS                             7.726645
# Gross Profit (ttm)                42,746,998,784
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,577,998,848
# Target High Price                      144.21803
# Target Low Price                        97.86169
# Target Mean Price                      125.19122
# Trailing EPS                                5.58
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 118.84
# Daylow                                  117.96
# ...
