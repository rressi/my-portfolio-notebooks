# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 110.43 | 115.95 | 121.75 | 127.84 | 134.23 | 140.94 | 147.99
# Buy score: -0.65%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             128.68
# Forward EPS                             7.749445
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      138.72072
# Target Low Price                        89.42083
# Target Mean Price                     115.990585
# Trailing EPS                                5.52
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 129.16
# Daylow                                  128.52
# ...
