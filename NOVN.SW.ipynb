# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 101.16 | 106.22 | 111.53 | 117.11 | 122.96 | 129.11 | 135.57
# Buy score: -0.84%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                              118.1
# Forward EPS                             7.561447
# Gross Profit (ttm)                42,974,998,528
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      133.28294
# Target Low Price                        85.81556
# Target Mean Price                     112.606514
# Trailing EPS                                5.75
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 118.54
# Daylow                                  117.54
# ...
