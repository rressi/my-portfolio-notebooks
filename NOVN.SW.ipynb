# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 100.50 | 105.53 | 110.80 | 116.34 | 122.16 | 128.27 | 134.68
# Buy score: -2.23%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                              118.7
# Forward EPS                             7.567848
# Gross Profit (ttm)                42,981,998,592
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,371,998,720
# Target High Price                      133.38242
# Target Low Price                         85.8796
# Target Mean Price                      112.69056
# Trailing EPS                                5.75
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 120.08
# Daylow                                  113.26
# ...
