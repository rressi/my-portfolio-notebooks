# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 108.30 | 113.72 | 119.41 | 125.38 | 131.64 | 138.23 | 145.14
# Buy score: -2.49%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             128.38
# Forward EPS                             7.469316
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      138.08589
# Target Low Price                        89.01161
# Target Mean Price                      115.39124
# Trailing EPS                                 5.5
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 129.14
# Daylow                                  126.82
# ...
