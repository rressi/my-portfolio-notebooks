# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 102.79 | 107.93 | 113.33 | 118.99 | 124.94 | 131.19 | 137.75
# Buy score: -0.96%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             120.14
# Forward EPS                             7.570529
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      130.37053
# Target Low Price                        84.73785
# Target Mean Price                      112.41359
# Trailing EPS                                5.55
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 121.40
# Daylow                                  119.74
# ...
