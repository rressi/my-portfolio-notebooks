# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 102.90 | 108.04 | 113.44 | 119.12 | 125.07 | 131.33 | 137.89
# Buy score: -1.36%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             120.76
# Forward EPS                             7.570529
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      131.23184
# Target Low Price                       85.297676
# Target Mean Price                      113.15627
# Trailing EPS                                5.55
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 121.40
# Daylow                                  120.54
# ...
