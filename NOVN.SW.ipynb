# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 105.95 | 111.25 | 116.81 | 122.65 | 128.78 | 135.22 | 141.98
# Buy score: -2.09%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             125.14
# Forward EPS                             7.499503
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      134.38745
# Target Low Price                       88.765396
# Target Mean Price                      114.16182
# Trailing EPS                                 5.5
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 125.42
# Daylow                                  123.60
# ...
