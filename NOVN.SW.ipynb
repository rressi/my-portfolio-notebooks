# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 104.27 | 109.49 | 114.96 | 120.71 | 126.74 | 133.08 | 139.73
# Buy score: -1.93%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                              123.1
# Forward EPS                             7.488625
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      130.86829
# Target Low Price                        85.06138
# Target Mean Price                      112.84279
# Trailing EPS                                5.55
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 123.20
# Daylow                                  120.92
# ...
