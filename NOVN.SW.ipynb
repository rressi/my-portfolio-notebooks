# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 103.64 | 108.83 | 114.27 | 114.40 | 120.12 | 126.13 | 132.43
# Buy score: 0.39%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                              114.0
# Forward EPS                             7.795889
# Gross Profit (ttm)                42,746,998,784
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,577,998,848
# Target High Price                      139.99133
# Target Low Price                        94.99358
# Target Mean Price                      121.57868
# Trailing EPS                                5.51
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 116.06
# Daylow                                  113.96
# ...
