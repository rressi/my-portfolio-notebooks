# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 108.30 | 113.72 | 119.40 | 125.37 | 131.64 | 138.22 | 145.13
# Buy score: -2.33%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             128.36
# Forward EPS                             7.465473
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                       138.0895
# Target Low Price                        89.01393
# Target Mean Price                     115.166275
# Trailing EPS                                 5.5
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 128.42
# Daylow                                  126.82
# ...
