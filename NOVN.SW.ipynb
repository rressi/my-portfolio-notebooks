# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 105.94 | 111.23 | 116.80 | 122.64 | 128.77 | 135.21 | 141.97
# Buy score: -1.94%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             125.08
# Forward EPS                             7.499503
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      134.45746
# Target Low Price                        88.81164
# Target Mean Price                      114.22129
# Trailing EPS                                 5.5
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 125.42
# Daylow                                  123.60
# ...
