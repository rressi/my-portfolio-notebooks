# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 102.12 | 107.23 | 112.59 | 118.22 | 124.13 | 130.33 | 136.85
# Buy score: 1.06%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             116.98
# Forward EPS                             7.610178
# Gross Profit (ttm)                42,746,998,784
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,577,998,848
# Target High Price                      139.76654
# Target Low Price                        94.84104
# Target Mean Price                      121.58506
# Trailing EPS                                 5.5
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 117.40
# Daylow                                  116.70
# ...
