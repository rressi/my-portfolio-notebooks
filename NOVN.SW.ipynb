# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 109.74 | 115.22 | 120.98 | 127.03 | 133.38 | 140.05 | 147.06
# Buy score: 0.64%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             126.46
# Forward EPS                             7.531059
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      139.13318
# Target Low Price                        89.68671
# Target Mean Price                      116.33391
# Trailing EPS                                 5.5
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 127.24
# Daylow                                  125.32
# ...
