# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 105.05 | 110.31 | 115.82 | 121.61 | 127.69 | 134.08 | 140.78
# Buy score: -1.70%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                              123.8
# Forward EPS                              7.47477
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      134.66747
# Target Low Price                        88.95035
# Target Mean Price                      114.39969
# Trailing EPS                                5.49
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 124.18
# Daylow                                  121.92
# ...
