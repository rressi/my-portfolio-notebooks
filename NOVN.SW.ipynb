# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 109.04 | 114.50 | 120.22 | 126.23 | 132.54 | 139.17 | 146.13
# Buy score: -1.32%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             127.38
# Forward EPS                             7.504793
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      138.62926
# Target Low Price                        89.36188
# Target Mean Price                      115.87291
# Trailing EPS                                5.51
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 129.54
# Daylow                                  127.38
# ...
