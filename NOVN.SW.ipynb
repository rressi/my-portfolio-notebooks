# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 109.52 | 115.00 | 120.75 | 126.78 | 133.12 | 139.78 | 146.77
# Buy score: 0.18%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             126.56
# Forward EPS                             7.509649
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      139.12064
# Target Low Price                        89.67862
# Target Mean Price                      116.28362
# Trailing EPS                                 5.5
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 128.08
# Daylow                                  126.42
# ...
