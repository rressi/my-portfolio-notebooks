# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 101.40 | 106.47 | 111.79 | 114.82 | 120.56 | 126.58 | 132.91
# Buy score: -2.58%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             117.98
# Forward EPS                             7.691237
# Gross Profit (ttm)                42,746,998,784
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,577,998,848
# Target High Price                      142.05562
# Target Low Price                        96.39434
# Target Mean Price                      123.57182
# Trailing EPS                                 5.5
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 118.00
# Daylow                                  115.94
# ...
