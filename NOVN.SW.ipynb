# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 110.13 | 115.64 | 121.42 | 127.49 | 133.87 | 140.56 | 147.59
# Buy score: -1.35%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             129.16
# Forward EPS                             7.723964
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                       138.7261
# Target Low Price                         89.4243
# Target Mean Price                      115.99509
# Trailing EPS                                5.55
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 129.58
# Daylow                                  126.98
# ...
