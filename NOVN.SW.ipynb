# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 101.41 | 106.48 | 111.80 | 115.16 | 120.92 | 126.96 | 133.31
# Buy score: 2.07%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             112.82
# Forward EPS                             7.645328
# Gross Profit (ttm)                42,746,998,784
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,577,998,848
# Target High Price                      140.83168
# Target Low Price                        95.56382
# Target Mean Price                     122.574356
# Trailing EPS                                5.46
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 114.22
# Daylow                                  112.54
# ...
