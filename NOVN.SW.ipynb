# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 105.31 | 110.58 | 116.11 | 121.91 | 128.01 | 134.41 | 141.13
# Buy score: -1.05%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                              123.2
# Forward EPS                             7.859874
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                       141.7386
# Target Low Price                        92.86237
# Target Mean Price                      121.64376
# Trailing EPS                                5.66
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 123.34
# Daylow                                  121.74
# ...
