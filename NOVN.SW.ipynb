# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 103.45 | 108.62 | 114.05 | 119.76 | 125.74 | 132.03 | 138.63
# Buy score: -2.22%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                             122.48
# Forward EPS                             7.771097
# Gross Profit (ttm)                42,746,998,784
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,577,998,848
# Target High Price                      142.23761
# Target Low Price                        96.51783
# Target Mean Price                      123.47208
# Trailing EPS                                5.55
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 122.90
# Daylow                                  121.18
# ...
