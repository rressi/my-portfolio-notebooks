# %%
import my_portfolio; my_portfolio.run("NOVN.SW")
# Out:
# No operations found for ticker 'NOVN.SW'
# Prices: 111.18 | 116.74 | 122.58 | 128.71 | 135.14 | 141.90 | 149.00
# Buy score: -0.76%
# No operations found.
#                                          NOVN.SW
# Company Name                          NOVARTIS N
# Current Price                              129.7
# Forward EPS                             7.744586
# Gross Profit (ttm)                43,053,998,080
# Industry            Drug Manufacturers - General
# Revenue (ttm)                     56,674,000,896
# Target High Price                      138.60774
# Target Low Price                        89.34801
# Target Mean Price                     115.896126
# Trailing EPS                                5.54
# Website                 https://www.novartis.com
#                                        NOVN.SW
# Currency                                   CHF
# Dayhigh                                 129.92
# Daylow                                  128.90
# ...
