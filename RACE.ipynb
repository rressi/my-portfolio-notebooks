# %%
import my_portfolio; my_portfolio.run(
    security="RACE",
    trades_isin="NL0011585146",
)
# Out:
# Prices: 403.91 | 424.11 | 445.31 | 380.00 | 399.00 | 418.95 | 439.90
# Buy score: 6.70%
# Sell score: 0.83%
#                    Quantity   Price        Tot    Wallet Avg. price Balance
# Time
# 2025-06-03 05:33   3.000000  474.96   1,424.88  3.000000     474.96  -26.88
# 2025-06-13 10:20  -3.000000  466.21  -1,398.64  0.000000       0.00  -79.93
# 2025-10-13 14:30   3.000000  380.00   1,140.00  5.000000     380.00  -92.78
# 2025-10-13 14:30   2.000000  380.00     760.00  5.000000     380.00  -92.78
# 2025-10-14 15:30   5.000000  383.17   1,915.85  5.000000        NaN  -76.93
#                                        RACE
# Company Name                   Ferrari N.V.
# Current Price                        383.17
# Forward EPS                            9.53
# Gross Profit (ttm)            3,562,913,024
# Industry                 Auto Manufacturers
# Revenue (ttm)                 6,958,282,752
# Target High Price                  580.5178
# Target Low Price                  439.52512
# ...
