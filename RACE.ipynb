# %%
import my_portfolio; my_portfolio.run(
    security="RACE",
    trades_isin="NL0011585146",
)
# Out:
# Prices: 312.94 | 328.59 | 345.02 | 385.61 | 404.89 | 425.14 | 446.39
# Buy score: -7.08%
# Sell score: 0.72%
# Current return: -25.50 USD
# Breakeven price: 389.67 USD
# <style type="text/css">
# #T_5cbd2_row6_col0, #T_5cbd2_row6_col1, #T_5cbd2_row6_col2, #T_5cbd2_row6_col3, #T_5cbd2_row6_col4, #T_5cbd2_row6_col5, #T_5cbd2_row6_col6, #T_5cbd2_row6_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_5cbd2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cbd2_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_5cbd2_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_5cbd2_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_5cbd2_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_5cbd2_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
