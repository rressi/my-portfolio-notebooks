# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 132.31 | 138.92 | 145.87 | 156.68 | 164.51 | 172.74 | 181.38
# Buy score: -3.32%
# Sell score: 1.11%
# Current return: -11.72 CHF
# Breakeven price: 159.59 CHF
# <style type="text/css">
# #T_3a499_row8_col0, #T_3a499_row8_col1, #T_3a499_row8_col2, #T_3a499_row8_col3, #T_3a499_row8_col4, #T_3a499_row8_col5, #T_3a499_row8_col6, #T_3a499_row8_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_3a499">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a499_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_3a499_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_3a499_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_3a499_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_3a499_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
