# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 155.02 | 162.77 | 170.90 | 171.59 | 180.17 | 189.18 | 198.64
# Buy score: -1.42%
# Sell score: -0.16%
# Current return: -107.62 CHF
# Breakeven price: 172.40 CHF
# <style type="text/css">
# #T_b38f6_row51_col0, #T_b38f6_row51_col1, #T_b38f6_row51_col2, #T_b38f6_row51_col3, #T_b38f6_row51_col4, #T_b38f6_row51_col5, #T_b38f6_row51_col6, #T_b38f6_row51_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_b38f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b38f6_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_b38f6_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_b38f6_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_b38f6_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_b38f6_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
