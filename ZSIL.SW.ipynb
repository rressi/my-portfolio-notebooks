# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 160.95 | 168.99 | 177.44 | 176.73 | 185.56 | 194.84 | 204.58
# Buy score: -7.63%
# Sell score: 14.13%
# Current return: 2,425.68 CHF
# Breakeven price: 177.44 CHF
# <style type="text/css">
# #T_9d7d3_row16_col0, #T_9d7d3_row16_col1, #T_9d7d3_row16_col2, #T_9d7d3_row16_col3, #T_9d7d3_row16_col4, #T_9d7d3_row16_col5, #T_9d7d3_row16_col6, #T_9d7d3_row16_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_9d7d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d7d3_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_9d7d3_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_9d7d3_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_9d7d3_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_9d7d3_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
