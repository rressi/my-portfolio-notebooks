# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 192.41 | 202.03 | 212.13 | 218.28 | 229.20 | 240.66 | 252.69
# Buy score: -10.53%
# Sell score: 14.05%
# Current return: 15,408.68 CHF
# Breakeven price: 218.13 CHF
# <style type="text/css">
# #T_1551a_row28_col0, #T_1551a_row28_col1, #T_1551a_row28_col2, #T_1551a_row28_col3, #T_1551a_row28_col4, #T_1551a_row28_col5, #T_1551a_row28_col6, #T_1551a_row28_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_1551a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1551a_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_1551a_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_1551a_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_1551a_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_1551a_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
