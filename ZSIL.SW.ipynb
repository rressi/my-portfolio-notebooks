# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 102.81 | 107.95 | 113.34 | 119.01 | 124.96 | 131.21 | 137.77
# Buy score: 1.25%
#                      Quantity   Price       Value      Wallet Avg. price  \
# Time
# 2025-10-13 09:02    38.000000  117.96    4,482.48   38.000000     117.96
# 2025-10-13 09:02    62.000000  117.94    7,312.28  100.000000     117.95
# 2025-10-14 09:03   100.000000  118.76   11,876.00  200.000000     118.35
# 2025-10-17 16:10  -200.000000  117.10  -23,420.00    0.000000       0.00
#
#                  Inv. Cost Inv. Balance  Balance
# Time
# 2025-10-13 09:02      4.00        -4.00    -4.00
# 2025-10-13 09:02     21.95       -22.71   -22.71
# 2025-10-14 09:03     44.00        37.24    37.24
# 2025-10-17 16:10      0.00         0.00  -327.16
#                                           ZSIL.SW
# Company Name        Swisscanto Silver ETF-A (CHF)
# Current Price                                None
# Forward EPS                                  None
# Gross Profit (ttm)                           None
# ...
