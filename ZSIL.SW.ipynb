# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 153.69 | 161.37 | 169.44 | 171.59 | 180.17 | 189.18 | 198.64
# Buy score: 5.31%
# Sell score: -5.44%
# Current return: -1,995.84 CHF
# Breakeven price: 172.24 CHF
# <style type="text/css">
# #T_fd94f_row49_col0, #T_fd94f_row49_col1, #T_fd94f_row49_col2, #T_fd94f_row49_col3, #T_fd94f_row49_col4, #T_fd94f_row49_col5, #T_fd94f_row49_col6, #T_fd94f_row49_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_fd94f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd94f_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_fd94f_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_fd94f_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_fd94f_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_fd94f_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
