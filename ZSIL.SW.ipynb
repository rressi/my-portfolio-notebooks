# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 157.96 | 165.85 | 174.15 | 192.74 | 202.38 | 212.50 | 223.12
# Buy score: -5.68%
# Sell score: 0.38%
# Current return: 34.91 CHF
# Breakeven price: 193.36 CHF
# <style type="text/css">
# #T_4cef2_row56_col0, #T_4cef2_row56_col1, #T_4cef2_row56_col2, #T_4cef2_row56_col3, #T_4cef2_row56_col4, #T_4cef2_row56_col5, #T_4cef2_row56_col6, #T_4cef2_row56_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_4cef2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4cef2_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_4cef2_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_4cef2_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_4cef2_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_4cef2_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
