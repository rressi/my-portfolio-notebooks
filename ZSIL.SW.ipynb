# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 172.05 | 180.66 | 189.69 | 176.73 | 185.56 | 194.84 | 204.58
# Buy score: -3.50%
# Sell score: 16.79%
# Current return: 2,895.68 CHF
# Breakeven price: 177.44 CHF
# <style type="text/css">
# #T_06643_row16_col0, #T_06643_row16_col1, #T_06643_row16_col2, #T_06643_row16_col3, #T_06643_row16_col4, #T_06643_row16_col5, #T_06643_row16_col6, #T_06643_row16_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_06643">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06643_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_06643_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_06643_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_06643_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_06643_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
