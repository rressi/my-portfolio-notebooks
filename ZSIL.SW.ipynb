# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 98.87 | 103.82 | 109.01 | 117.95 | 123.84 | 130.04 | 136.54
# Buy score: -3.00%
# Sell score: 0.04%
#                  Quantity   Price        Tot Wallet Avg. price Balance
# Time
# 2025-10-13 09:02       38  117.96   4,482.48    100     117.95  -20.71
# 2025-10-13 09:02       62  117.94   7,312.28    100     117.95  -22.71
# 2025-10-13 17:28      100  118.00  11,800.00    100        NaN  -16.71
#                                           ZSIL.SW
# Company Name        Swisscanto Silver ETF-A (CHF)
# Current Price                                None
# Forward EPS                                  None
# Gross Profit (ttm)                           None
# Industry                                     None
# Revenue (ttm)                                None
# Target High Price                            None
# Target Low Price                             None
# Target Mean Price                            None
# Trailing EPS                                 None
# ...
