# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 181.02 | 190.07 | 199.57 | 212.67 | 223.30 | 234.47 | 246.19
# Buy score: -0.21%
# Sell score: -1.25%
# Current return: -1,875.08 CHF
# Breakeven price: 213.13 CHF
# <style type="text/css">
# #T_3ee2c_row26_col0, #T_3ee2c_row26_col1, #T_3ee2c_row26_col2, #T_3ee2c_row26_col3, #T_3ee2c_row26_col4, #T_3ee2c_row26_col5, #T_3ee2c_row26_col6, #T_3ee2c_row26_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_3ee2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ee2c_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_3ee2c_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_3ee2c_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_3ee2c_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_3ee2c_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
