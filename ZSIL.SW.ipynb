# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 153.70 | 161.39 | 169.46 | 171.59 | 180.17 | 189.18 | 198.64
# Buy score: 4.86%
# Sell score: -4.95%
# Current return: -1,827.84 CHF
# Breakeven price: 172.24 CHF
# <style type="text/css">
# #T_7c52c_row49_col0, #T_7c52c_row49_col1, #T_7c52c_row49_col2, #T_7c52c_row49_col3, #T_7c52c_row49_col4, #T_7c52c_row49_col5, #T_7c52c_row49_col6, #T_7c52c_row49_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_7c52c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c52c_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_7c52c_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_7c52c_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_7c52c_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_7c52c_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
