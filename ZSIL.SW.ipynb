# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 185.85 | 195.14 | 204.90 | 212.67 | 223.30 | 234.47 | 246.19
# Buy score: -3.91%
# Sell score: 5.28%
# Current return: 4,634.72 CHF
# Breakeven price: 212.31 CHF
# <style type="text/css">
# #T_a42e9_row27_col0, #T_a42e9_row27_col1, #T_a42e9_row27_col2, #T_a42e9_row27_col3, #T_a42e9_row27_col4, #T_a42e9_row27_col5, #T_a42e9_row27_col6, #T_a42e9_row27_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_a42e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a42e9_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_a42e9_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_a42e9_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_a42e9_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_a42e9_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
