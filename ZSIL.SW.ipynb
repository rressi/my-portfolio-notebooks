# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 202.51 | 212.63 | 223.27 | 218.28 | 229.20 | 240.66 | 252.69
# Buy score: -4.63%
# Sell score: 12.61%
# Current return: 13,833.68 CHF
# Breakeven price: 218.13 CHF
# <style type="text/css">
# #T_ff85f_row28_col0, #T_ff85f_row28_col1, #T_ff85f_row28_col2, #T_ff85f_row28_col3, #T_ff85f_row28_col4, #T_ff85f_row28_col5, #T_ff85f_row28_col6, #T_ff85f_row28_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_ff85f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff85f_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_ff85f_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_ff85f_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_ff85f_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_ff85f_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
