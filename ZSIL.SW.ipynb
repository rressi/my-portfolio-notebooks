# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 102.93 | 108.08 | 113.49 | 117.76 | 123.65 | 129.83 | 136.32
# Buy score: 0.35%
# Sell score: 0.83%
# Current return: 54.10 CHF
# Breakeven price: 118.20 CHF
# <style type="text/css">
# #T_4da44_row5_col0, #T_4da44_row5_col1, #T_4da44_row5_col2, #T_4da44_row5_col3, #T_4da44_row5_col4, #T_4da44_row5_col5, #T_4da44_row5_col6, #T_4da44_row5_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_4da44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4da44_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_4da44_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_4da44_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_4da44_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_4da44_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
