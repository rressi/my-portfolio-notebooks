# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 152.51 | 160.13 | 168.14 | 171.59 | 180.17 | 189.18 | 198.64
# Buy score: 3.36%
# Sell score: -0.59%
# Current return: -331.84 CHF
# Breakeven price: 172.24 CHF
# <style type="text/css">
# #T_baad5_row49_col0, #T_baad5_row49_col1, #T_baad5_row49_col2, #T_baad5_row49_col3, #T_baad5_row49_col4, #T_baad5_row49_col5, #T_baad5_row49_col6, #T_baad5_row49_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_baad5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_baad5_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_baad5_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_baad5_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_baad5_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_baad5_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
