# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 146.64 | 153.97 | 161.67 | 174.25 | 182.97 | 192.12 | 201.72
# Buy score: -7.05%
# Sell score: 4.80%
# Current return: 361.75 CHF
# Breakeven price: 175.38 CHF
# <style type="text/css">
# #T_f60aa_row13_col0, #T_f60aa_row13_col1, #T_f60aa_row13_col2, #T_f60aa_row13_col3, #T_f60aa_row13_col4, #T_f60aa_row13_col5, #T_f60aa_row13_col6, #T_f60aa_row13_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_f60aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f60aa_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_f60aa_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_f60aa_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_f60aa_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_f60aa_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
