# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 141.85 | 148.95 | 156.39 | 172.40 | 181.02 | 190.07 | 199.57
# Buy score: -5.83%
# Sell score: 1.15%
# Current return: 32.03 CHF
# Breakeven price: 173.31 CHF
# <style type="text/css">
# #T_71cb8_row12_col0, #T_71cb8_row12_col1, #T_71cb8_row12_col2, #T_71cb8_row12_col3, #T_71cb8_row12_col4, #T_71cb8_row12_col5, #T_71cb8_row12_col6, #T_71cb8_row12_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_71cb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71cb8_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_71cb8_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_71cb8_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_71cb8_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_71cb8_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
