# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 191.18 | 200.74 | 210.78 | 218.28 | 229.20 | 240.66 | 252.69
# Buy score: -8.58%
# Sell score: 10.91%
# Current return: 11,983.68 CHF
# Breakeven price: 218.13 CHF
# <style type="text/css">
# #T_922a9_row28_col0, #T_922a9_row28_col1, #T_922a9_row28_col2, #T_922a9_row28_col3, #T_922a9_row28_col4, #T_922a9_row28_col5, #T_922a9_row28_col6, #T_922a9_row28_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_922a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_922a9_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_922a9_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_922a9_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_922a9_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_922a9_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
