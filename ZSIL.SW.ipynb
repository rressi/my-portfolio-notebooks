# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 152.18 | 159.79 | 167.78 | 176.25 | 185.07 | 194.32 | 204.04
# Buy score: 1.96%
# Sell score: -1.97%
# Current return: -206.66 CHF
# Breakeven price: 176.91 CHF
# <style type="text/css">
# #T_8912a_row15_col0, #T_8912a_row15_col1, #T_8912a_row15_col2, #T_8912a_row15_col3, #T_8912a_row15_col4, #T_8912a_row15_col5, #T_8912a_row15_col6, #T_8912a_row15_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_8912a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8912a_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_8912a_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_8912a_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_8912a_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_8912a_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
