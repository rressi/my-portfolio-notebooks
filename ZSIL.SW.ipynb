# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 172.43 | 181.05 | 190.10 | 195.91 | 205.70 | 215.99 | 226.79
# Buy score: -4.45%
# Sell score: 6.63%
# Current return: 4,774.22 CHF
# Breakeven price: 196.96 CHF
# <style type="text/css">
# #T_d2644_row21_col0, #T_d2644_row21_col1, #T_d2644_row21_col2, #T_d2644_row21_col3, #T_d2644_row21_col4, #T_d2644_row21_col5, #T_d2644_row21_col6, #T_d2644_row21_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_d2644">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2644_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_d2644_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_d2644_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_d2644_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_d2644_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
