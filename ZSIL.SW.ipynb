# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 100.21 | 105.22 | 110.48 | 118.35 | 124.27 | 130.49 | 137.01
# Buy score: -1.69%
# Sell score: -0.30%
#                  Quantity   Price        Tot Wallet Avg. price  Balance
# Time
# 2025-10-13 09:02       38  117.96   4,482.48     38     117.96    -4.00
# 2025-10-13 09:02       62  117.94   7,312.28    100     117.95   -22.71
# 2025-10-14 09:03      100  118.76  11,876.00    200     118.35    37.24
# 2025-10-14 17:20      200  118.00  23,600.00    200        NaN  -114.76
#                                           ZSIL.SW
# Company Name        Swisscanto Silver ETF-A (CHF)
# Current Price                                None
# Forward EPS                                  None
# Gross Profit (ttm)                           None
# Industry                                     None
# Revenue (ttm)                                None
# Target High Price                            None
# Target Low Price                             None
# ...
