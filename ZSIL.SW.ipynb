# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 149.89 | 157.38 | 165.25 | 176.25 | 185.07 | 194.32 | 204.04
# Buy score: -1.54%
# Sell score: -0.02%
# Current return: -34.66 CHF
# Breakeven price: 176.91 CHF
# <style type="text/css">
# #T_5d8ea_row15_col0, #T_5d8ea_row15_col1, #T_5d8ea_row15_col2, #T_5d8ea_row15_col3, #T_5d8ea_row15_col4, #T_5d8ea_row15_col5, #T_5d8ea_row15_col6, #T_5d8ea_row15_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_5d8ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d8ea_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_5d8ea_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_5d8ea_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_5d8ea_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_5d8ea_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
