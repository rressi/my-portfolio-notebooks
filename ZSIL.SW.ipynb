# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 157.98 | 165.88 | 174.18 | 193.54 | 203.22 | 213.38 | 224.05
# Buy score: -6.17%
# Sell score: 0.68%
# Current return: 51.76 CHF
# Breakeven price: 194.34 CHF
# <style type="text/css">
# #T_5a05f_row54_col0, #T_5a05f_row54_col1, #T_5a05f_row54_col2, #T_5a05f_row54_col3, #T_5a05f_row54_col4, #T_5a05f_row54_col5, #T_5a05f_row54_col6, #T_5a05f_row54_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_5a05f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a05f_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_5a05f_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_5a05f_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_5a05f_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_5a05f_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
