# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 138.03 | 144.93 | 152.18 | 172.40 | 181.02 | 190.07 | 199.57
# Buy score: -7.27%
# Sell score: -0.04%
# Current return: -29.77 CHF
# Breakeven price: 173.31 CHF
# <style type="text/css">
# #T_f6443_row12_col0, #T_f6443_row12_col1, #T_f6443_row12_col2, #T_f6443_row12_col3, #T_f6443_row12_col4, #T_f6443_row12_col5, #T_f6443_row12_col6, #T_f6443_row12_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_f6443">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6443_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_f6443_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_f6443_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_f6443_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_f6443_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
