# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 181.06 | 190.11 | 199.62 | 212.67 | 223.30 | 234.47 | 246.19
# Buy score: -2.03%
# Sell score: 0.60%
# Current return: 494.92 CHF
# Breakeven price: 213.13 CHF
# <style type="text/css">
# #T_392eb_row26_col0, #T_392eb_row26_col1, #T_392eb_row26_col2, #T_392eb_row26_col3, #T_392eb_row26_col4, #T_392eb_row26_col5, #T_392eb_row26_col6, #T_392eb_row26_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_392eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_392eb_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_392eb_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_392eb_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_392eb_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_392eb_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
