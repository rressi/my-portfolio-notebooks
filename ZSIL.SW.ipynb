# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 101.28 | 106.34 | 111.66 | 118.35 | 124.27 | 130.49 | 137.01
# Buy score: -2.22%
# Sell score: 1.31%
#                  Quantity   Price      Value Wallet Avg. price Inv. Cost  \
# Time
# 2025-10-13 09:02       38  117.96   4,482.48     38     117.96      4.00
# 2025-10-13 09:02       62  117.94   7,312.28    100     117.95     21.95
# 2025-10-14 09:03      100  118.76  11,876.00    200     118.35     44.00
# 2025-10-15 17:29      200  119.90  23,980.00    200        NaN     44.00
#
#                  Inv. Balance Balance
# Time
# 2025-10-13 09:02        -4.00   -4.00
# 2025-10-13 09:02       -22.71  -22.71
# 2025-10-14 09:03        37.24   37.24
# 2025-10-15 17:29       265.24  265.24
#                                           ZSIL.SW
# Company Name        Swisscanto Silver ETF-A (CHF)
# Current Price                                None
# Forward EPS                                  None
# Gross Profit (ttm)                           None
# ...
