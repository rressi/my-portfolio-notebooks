# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# No operations found for ticker 'ZSIL.SW'
# Prices: 97.61 | 102.49 | 107.62 | 113.00 | 118.65 | 124.58 | 130.81
# Buy score: -1.52%
# No operations found.
#                                           ZSIL.SW
# Company Name        Swisscanto Silver ETF-A (CHF)
# Current Price                                None
# Forward EPS                                  None
# Gross Profit (ttm)                           None
# Industry                                     None
# Revenue (ttm)                                None
# Target High Price                            None
# Target Low Price                             None
# Target Mean Price                            None
# Trailing EPS                                 None
# Website                                      None
#                                   ZSIL.SW
# Currency                              CHF
# Dayhigh                            117.28
# Daylow                             112.00
# Exchange                              EBS
# ...
