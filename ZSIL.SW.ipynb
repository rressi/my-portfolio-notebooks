# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 161.53 | 169.61 | 178.09 | 178.09 | 187.00 | 196.35 | 206.16
# Buy score: 10.87%
# Sell score: -5.30%
# Current return: -989.51 CHF
# Breakeven price: 178.56 CHF
# <style type="text/css">
# #T_dce3a_row33_col0, #T_dce3a_row33_col1, #T_dce3a_row33_col2, #T_dce3a_row33_col3, #T_dce3a_row33_col4, #T_dce3a_row33_col5, #T_dce3a_row33_col6, #T_dce3a_row33_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_dce3a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dce3a_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_dce3a_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_dce3a_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_dce3a_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_dce3a_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
