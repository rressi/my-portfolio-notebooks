# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 157.66 | 165.54 | 173.82 | 176.73 | 185.56 | 194.84 | 204.58
# Buy score: -6.40%
# Sell score: 10.33%
# Current return: 1,753.68 CHF
# Breakeven price: 177.44 CHF
# <style type="text/css">
# #T_395c8_row16_col0, #T_395c8_row16_col1, #T_395c8_row16_col2, #T_395c8_row16_col3, #T_395c8_row16_col4, #T_395c8_row16_col5, #T_395c8_row16_col6, #T_395c8_row16_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_395c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_395c8_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_395c8_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_395c8_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_395c8_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_395c8_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
