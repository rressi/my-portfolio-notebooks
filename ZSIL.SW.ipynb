# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 179.05 | 188.00 | 197.40 | 212.00 | 222.60 | 233.73 | 245.42
# Buy score: -2.83%
# Sell score: 0.61%
# Current return: 344.66 CHF
# Breakeven price: 212.44 CHF
# <style type="text/css">
# #T_3ebe8_row24_col0, #T_3ebe8_row24_col1, #T_3ebe8_row24_col2, #T_3ebe8_row24_col3, #T_3ebe8_row24_col4, #T_3ebe8_row24_col5, #T_3ebe8_row24_col6, #T_3ebe8_row24_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_3ebe8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ebe8_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_3ebe8_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_3ebe8_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_3ebe8_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_3ebe8_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
