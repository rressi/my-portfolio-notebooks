# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 191.45 | 201.02 | 211.08 | 218.28 | 229.20 | 240.66 | 252.69
# Buy score: -9.04%
# Sell score: 11.62%
# Current return: 12,758.68 CHF
# Breakeven price: 218.13 CHF
# <style type="text/css">
# #T_566b0_row28_col0, #T_566b0_row28_col1, #T_566b0_row28_col2, #T_566b0_row28_col3, #T_566b0_row28_col4, #T_566b0_row28_col5, #T_566b0_row28_col6, #T_566b0_row28_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_566b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_566b0_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_566b0_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_566b0_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_566b0_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_566b0_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
