# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 162.57 | 170.69 | 179.23 | 194.48 | 204.20 | 214.41 | 225.13
# Buy score: -6.12%
# Sell score: 3.07%
# Current return: 2,144.25 CHF
# Breakeven price: 195.09 CHF
# <style type="text/css">
# #T_ff6c3_row57_col0, #T_ff6c3_row57_col1, #T_ff6c3_row57_col2, #T_ff6c3_row57_col3, #T_ff6c3_row57_col4, #T_ff6c3_row57_col5, #T_ff6c3_row57_col6, #T_ff6c3_row57_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_ff6c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff6c3_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_ff6c3_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_ff6c3_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_ff6c3_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_ff6c3_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
