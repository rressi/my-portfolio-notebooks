# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 151.67 | 159.26 | 167.22 | 176.50 | 185.33 | 194.59 | 204.32
# Buy score: -4.05%
# Sell score: 3.68%
# Current return: 263.70 CHF
# Breakeven price: 177.73 CHF
# <style type="text/css">
# #T_09f31_row42_col0, #T_09f31_row42_col1, #T_09f31_row42_col2, #T_09f31_row42_col3, #T_09f31_row42_col4, #T_09f31_row42_col5, #T_09f31_row42_col6, #T_09f31_row42_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_09f31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09f31_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_09f31_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_09f31_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_09f31_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_09f31_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
