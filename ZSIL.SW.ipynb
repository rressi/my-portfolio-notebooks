# %%
import my_portfolio; my_portfolio.run("ZSIL.SW")
# Out:
# Prices: 165.85 | 174.14 | 182.85 | 194.00 | 203.70 | 213.88 | 224.58
# Buy score: -0.27%
# Sell score: -0.77%
# Current return: -1,765.69 CHF
# Breakeven price: 195.44 CHF
# <style type="text/css">
# #T_fea31_row63_col0, #T_fea31_row63_col1, #T_fea31_row63_col2, #T_fea31_row63_col3, #T_fea31_row63_col4, #T_fea31_row63_col5, #T_fea31_row63_col6, #T_fea31_row63_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_fea31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fea31_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_fea31_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_fea31_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_fea31_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_fea31_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
