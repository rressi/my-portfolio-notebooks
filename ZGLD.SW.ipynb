# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 837.51 | 879.38 | 923.35 | 969.65 | 1,018.13 | 1,069.04 | 1,122.49
# Buy score: -0.27%
# Sell score: 0.25%
# Current return: -51.10 CHF
# Breakeven price: 984.88 CHF
# <style type="text/css">
# #T_3407c_row19_col0, #T_3407c_row19_col1, #T_3407c_row19_col2, #T_3407c_row19_col3, #T_3407c_row19_col4, #T_3407c_row19_col5, #T_3407c_row19_col6, #T_3407c_row19_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_3407c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3407c_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_3407c_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_3407c_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_3407c_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_3407c_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
