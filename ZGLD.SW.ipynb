# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 779.48 | 818.45 | 859.37 | 897.52 | 942.39 | 989.51 | 1,038.99
# Buy score: -1.23%
# Sell score: 1.79%
#                  Quantity   Price        Tot Wallet Avg. price Balance
# Time
# 2025-09-22 15:58        1  877.10     877.10      1     877.10   -8.50
# 2025-09-24 10:45        1  889.40     889.40      2     883.25   -4.70
# 2025-09-29 09:53       16  899.30  14,388.80     18     897.52   -9.20
# 2025-10-02 09:34       18  913.60  16,444.80     18        NaN  248.20
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
# ...
