# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 1,016.63 | 1,067.46 | 1,120.84 | 1,190.36 | 1,249.88 | 1,312.37 | 1,377.99
# Buy score: -1.30%
# Sell score: 0.17%
# Current return: -167.23 CHF
# Breakeven price: 1,193.45 CHF
# <style type="text/css">
# #T_82e6f_row30_col0, #T_82e6f_row30_col1, #T_82e6f_row30_col2, #T_82e6f_row30_col3, #T_82e6f_row30_col4, #T_82e6f_row30_col5, #T_82e6f_row30_col6, #T_82e6f_row30_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_82e6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82e6f_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_82e6f_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_82e6f_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_82e6f_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_82e6f_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
