# %%
import workflow
workflow.run(
    security = "ZGLD.SW",
    start_date= "2025-01-01"
)
# Out:
# Prices: 741.03 | 778.09 | 816.99 | 857.84 | 900.73 | 945.77 | 993.06
# Buy score: -0.38%
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# Dayhigh                            869.60
# Daylow                             861.10
# Exchange                              EBS
# Fiftydayaverage                    813.35
# Lastprice                          861.10
# Lastvolume                         12,156
# Marketcap                            None
# ...
