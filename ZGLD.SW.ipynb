# %%
import workflow
workflow.run(
    security = "ZGLD.SW",
    start_date= "2025-01-01"
)
# Out:
# Prices: 718.48 | 754.40 | 792.12 | 831.73 | 873.31 | 916.98 | 962.83
# Buy score: -3.90%
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# Dayhigh                            865.50
# Daylow                             859.00
# Exchange                              EBS
# Fiftydayaverage                    811.86
# Lastprice                          865.50
# Lastvolume                          9,776
# Marketcap                            None
# ...
