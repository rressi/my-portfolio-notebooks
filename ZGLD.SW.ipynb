# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 988.71 | 1,038.15 | 1,090.06 | 1,157.20 | 1,211.78 | 1,272.37 | 1,335.99
# Buy score: -1.81%
# Sell score: 1.00%
# Current return: 310.90 CHF
# Breakeven price: 1,160.42 CHF
# <style type="text/css">
# #T_6e877_row25_col0, #T_6e877_row25_col1, #T_6e877_row25_col2, #T_6e877_row25_col3, #T_6e877_row25_col4, #T_6e877_row25_col5, #T_6e877_row25_col6, #T_6e877_row25_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_6e877">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e877_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_6e877_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_6e877_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_6e877_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_6e877_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
