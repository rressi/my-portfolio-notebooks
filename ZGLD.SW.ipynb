# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 748.67 | 786.10 | 825.41 | 877.10 | 920.96 | 967.00 | 1,015.35
# Buy score: -2.59%
# Sell score: 1.44%
#                  Quantity   Price     Tot Wallet Avg. price Balance
# Time
# 2025-09-22 15:58        1  877.10  877.10      1     877.10   -8.50
# 2025-09-23 17:00        1  889.70  889.70      1        NaN    4.10
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# Dayhigh                            893.20
# ...
