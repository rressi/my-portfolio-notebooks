# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 845.73 | 888.02 | 932.42 | 961.00 | 1,009.05 | 1,059.50 | 1,112.48
# Buy score: 0.64%
# Sell score: 1.23%
# Current return: -3.00 CHF
# Breakeven price: 974.30 CHF
# <style type="text/css">
# #T_d6247_row17_col0, #T_d6247_row17_col1, #T_d6247_row17_col2, #T_d6247_row17_col3, #T_d6247_row17_col4, #T_d6247_row17_col5, #T_d6247_row17_col6, #T_d6247_row17_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_d6247">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6247_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_d6247_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_d6247_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_d6247_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_d6247_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
