# %%
import workflow
workflow.run(
    security = "ZGLD.SW",
    start_date= "2025-01-01"
)
# Out:
# Prices: 742.01 | 779.11 | 818.07 | 858.97 | 901.92 | 947.01 | 994.37
# Buy score: -0.29%
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# Dayhigh                            861.50
# Daylow                             855.10
# Exchange                              EBS
# Fiftydayaverage                    814.96
# Lastprice                          861.50
# Lastvolume                         12,033
# Marketcap                            None
# ...
