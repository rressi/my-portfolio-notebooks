# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 857.91 | 900.81 | 945.85 | 943.00 | 990.15 | 1,039.66 | 1,091.64
# Buy score: -0.39%
# Sell score: 5.73%
# Current return: 2,499.30 CHF
# <style type="text/css">
# #T_edd58_row6_col0, #T_edd58_row6_col1, #T_edd58_row6_col2, #T_edd58_row6_col3, #T_edd58_row6_col4, #T_edd58_row6_col5, #T_edd58_row6_col6, #T_edd58_row6_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_edd58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edd58_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_edd58_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_edd58_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_edd58_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_edd58_level0_col4" class="col_heading level0 col4" >Avg. price</th>
#       <th id="T_edd58_level0_col5" class="col_heading level0 col5" >Inv. Cost</th>
# ...
