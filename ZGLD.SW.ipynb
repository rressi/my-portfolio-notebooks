# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 812.24 | 836.61 | 861.71 | 883.25 | 909.75 | 937.04 | 965.15
# Buy score: -0.89%
# Sell score: 1.39%
#                  Quantity   Price       Tot Wallet Avg. price Balance
# Time
# 2025-09-22 15:58        1  877.10    877.10      1     877.10   -8.50
# 2025-09-24 10:45        1  889.40    889.40      2     883.25   -4.70
# 2025-09-26 17:28        2  895.50  1,791.00      2        NaN    7.50
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# ...
