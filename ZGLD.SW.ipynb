# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 985.26 | 1,034.52 | 1,086.25 | 1,139.00 | 1,195.95 | 1,255.75 | 1,318.53
# Buy score: -1.39%
# Sell score: 1.55%
# Current return: 110.10 CHF
# Breakeven price: 1,145.59 CHF
# <style type="text/css">
# #T_664bc_row40_col0, #T_664bc_row40_col1, #T_664bc_row40_col2, #T_664bc_row40_col3, #T_664bc_row40_col4, #T_664bc_row40_col5, #T_664bc_row40_col6, #T_664bc_row40_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_664bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_664bc_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_664bc_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_664bc_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_664bc_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_664bc_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
