# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 978.45 | 1,027.37 | 1,078.74 | 1,130.28 | 1,186.79 | 1,246.13 | 1,308.44
# Buy score: 1.44%
# Sell score: -1.21%
# Current return: -461.00 CHF
# Breakeven price: 1,135.04 CHF
# <style type="text/css">
# #T_4d136_row46_col0, #T_4d136_row46_col1, #T_4d136_row46_col2, #T_4d136_row46_col3, #T_4d136_row46_col4, #T_4d136_row46_col5, #T_4d136_row46_col6, #T_4d136_row46_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_4d136">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d136_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_4d136_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_4d136_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_4d136_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_4d136_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
