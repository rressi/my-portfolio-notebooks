# %%
import workflow
workflow.run(
    security = "ZGLD.SW",
    start_date= "2025-01-01"
)
# Out:
# Prices: 742.62 | 779.76 | 818.74 | 859.68 | 902.66 | 947.80 | 995.19
# Buy score: 0.42%
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# Dayhigh                            861.50
# Daylow                             854.60
# Exchange                              EBS
# Fiftydayaverage                    816.43
# Lastprice                          856.10
# Lastvolume                         11,278
# Marketcap                            None
# ...
