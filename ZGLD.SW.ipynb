# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 989.82 | 1,039.31 | 1,091.28 | 1,154.08 | 1,211.78 | 1,272.37 | 1,335.99
# Buy score: -2.28%
# Sell score: 1.60%
# Current return: 776.72 CHF
# Breakeven price: 1,157.07 CHF
# <style type="text/css">
# #T_d8d73_row24_col0, #T_d8d73_row24_col1, #T_d8d73_row24_col2, #T_d8d73_row24_col3, #T_d8d73_row24_col4, #T_d8d73_row24_col5, #T_d8d73_row24_col6, #T_d8d73_row24_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_d8d73">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8d73_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_d8d73_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_d8d73_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_d8d73_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_d8d73_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
