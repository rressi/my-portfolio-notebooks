# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 894.73 | 939.46 | 986.44 | 1,040.40 | 1,092.42 | 1,147.04 | 1,204.39
# Buy score: -2.01%
# Sell score: 1.60%
# Current return: 124.58 CHF
# Breakeven price: 1,044.54 CHF
# <style type="text/css">
# #T_cb660_row21_col0, #T_cb660_row21_col1, #T_cb660_row21_col2, #T_cb660_row21_col3, #T_cb660_row21_col4, #T_cb660_row21_col5, #T_cb660_row21_col6, #T_cb660_row21_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_cb660">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb660_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_cb660_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_cb660_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_cb660_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_cb660_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
