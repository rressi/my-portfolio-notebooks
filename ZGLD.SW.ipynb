# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 752.96 | 790.61 | 830.14 | 883.25 | 927.41 | 973.78 | 1,022.47
# Buy score: -1.77%
# Sell score: 0.47%
#                  Quantity   Price       Tot Wallet Avg. price Balance
# Time
# 2025-09-22 15:58        1  877.10    877.10      1     877.10   -8.50
# 2025-09-24 10:45        1  889.40    889.40      2     883.25   -4.70
# 2025-09-25 17:00        2  887.40  1,774.80      2        NaN   -8.70
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# ...
