# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 997.73 | 1,047.62 | 1,100.00 | 1,190.36 | 1,249.88 | 1,312.37 | 1,377.99
# Buy score: 7.06%
# Sell score: -9.37%
# Current return: -18,879.91 CHF
# Breakeven price: 1,213.66 CHF
# <style type="text/css">
# #T_a3a7f_row32_col0, #T_a3a7f_row32_col1, #T_a3a7f_row32_col2, #T_a3a7f_row32_col3, #T_a3a7f_row32_col4, #T_a3a7f_row32_col5, #T_a3a7f_row32_col6, #T_a3a7f_row32_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_a3a7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3a7f_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_a3a7f_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_a3a7f_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_a3a7f_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_a3a7f_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
