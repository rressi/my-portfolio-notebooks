# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 1,007.99 | 1,058.39 | 1,111.31 | 1,162.91 | 1,221.06 | 1,282.11 | 1,346.21
# Buy score: -3.29%
# Sell score: 3.76%
# Current return: 2,827.56 CHF
# Breakeven price: 1,166.21 CHF
# <style type="text/css">
# #T_b889f_row26_col0, #T_b889f_row26_col1, #T_b889f_row26_col2, #T_b889f_row26_col3, #T_b889f_row26_col4, #T_b889f_row26_col5, #T_b889f_row26_col6, #T_b889f_row26_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_b889f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b889f_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_b889f_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_b889f_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_b889f_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_b889f_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
