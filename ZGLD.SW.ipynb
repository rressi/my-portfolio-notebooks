# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 972.65 | 1,021.28 | 1,072.34 | 1,133.82 | 1,190.51 | 1,250.04 | 1,312.54
# Buy score: -0.80%
# Sell score: 0.10%
# Current return: -30.12 CHF
# Breakeven price: 1,136.51 CHF
# <style type="text/css">
# #T_172bb_row35_col0, #T_172bb_row35_col1, #T_172bb_row35_col2, #T_172bb_row35_col3, #T_172bb_row35_col4, #T_172bb_row35_col5, #T_172bb_row35_col6, #T_172bb_row35_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_172bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_172bb_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_172bb_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_172bb_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_172bb_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_172bb_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
