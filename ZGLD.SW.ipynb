# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 981.98 | 1,031.07 | 1,082.63 | 1,130.28 | 1,186.79 | 1,246.13 | 1,308.44
# Buy score: -0.94%
# Sell score: 1.53%
# Current return: 204.44 CHF
# Breakeven price: 1,127.16 CHF
# <style type="text/css">
# #T_c7de0_row48_col0, #T_c7de0_row48_col1, #T_c7de0_row48_col2, #T_c7de0_row48_col3, #T_c7de0_row48_col4, #T_c7de0_row48_col5, #T_c7de0_row48_col6, #T_c7de0_row48_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_c7de0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7de0_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_c7de0_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_c7de0_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_c7de0_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_c7de0_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
