# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 845.09 | 887.35 | 931.71 | 969.65 | 1,018.13 | 1,069.04 | 1,122.49
# Buy score: -1.05%
# Sell score: 1.96%
# Current return: 15.30 CHF
# Breakeven price: 984.88 CHF
# <style type="text/css">
# #T_e3881_row19_col0, #T_e3881_row19_col1, #T_e3881_row19_col2, #T_e3881_row19_col3, #T_e3881_row19_col4, #T_e3881_row19_col5, #T_e3881_row19_col6, #T_e3881_row19_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_e3881">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3881_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_e3881_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_e3881_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_e3881_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_e3881_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
