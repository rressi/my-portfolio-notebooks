# %%
import workflow
workflow.run(
    security = "ZGLD.SW",
    start_date= "2025-01-01"
)
# Out:
# Prices: 715.61 | 751.39 | 788.96 | 828.4050 | 869.83 | 913.32 | 958.98
# Buy score: -4.09%
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# Dayhigh                            865.30
# Daylow                             862.00
# Exchange                              EBS
# Fiftydayaverage                    810.26
# Lastprice                          863.70
# Lastvolume                          9,625
# Marketcap                            None
# ...
