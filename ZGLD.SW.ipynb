# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 976.03 | 1,024.83 | 1,076.08 | 1,130.28 | 1,186.79 | 1,246.13 | 1,308.44
# Buy score: -1.01%
# Sell score: 0.98%
# Current return: 159.00 CHF
# Breakeven price: 1,135.04 CHF
# <style type="text/css">
# #T_22524_row46_col0, #T_22524_row46_col1, #T_22524_row46_col2, #T_22524_row46_col3, #T_22524_row46_col4, #T_22524_row46_col5, #T_22524_row46_col6, #T_22524_row46_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_22524">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22524_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_22524_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_22524_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_22524_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_22524_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
