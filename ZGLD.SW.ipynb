# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 750.56 | 788.09 | 827.50 | 883.25 | 927.41 | 973.78 | 1,022.47
# Buy score: -1.89%
# Sell score: 0.27%
#                  Quantity   Price       Tot Wallet Avg. price Balance
# Time
# 2025-09-22 15:58        1  877.10    877.10      1     877.10   -8.50
# 2025-09-24 10:45        1  889.40    889.40      2     883.25   -4.70
# 2025-09-24 17:00        2  885.60  1,771.20      2        NaN  -12.30
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# ...
