# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 977.17 | 1,026.03 | 1,077.33 | 1,154.08 | 1,211.78 | 1,272.37 | 1,335.99
# Buy score: -2.50%
# Sell score: 0.53%
# Current return: 156.72 CHF
# Breakeven price: 1,157.07 CHF
# <style type="text/css">
# #T_1703a_row24_col0, #T_1703a_row24_col1, #T_1703a_row24_col2, #T_1703a_row24_col3, #T_1703a_row24_col4, #T_1703a_row24_col5, #T_1703a_row24_col6, #T_1703a_row24_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_1703a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1703a_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_1703a_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_1703a_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_1703a_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_1703a_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
