# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 746.07 | 783.37 | 822.54 | 863.67 | 906.85 | 952.20 | 999.81
# Buy score: -1.74%
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# Dayhigh                            879.20
# Daylow                             875.00
# Exchange                              EBS
# Fiftydayaverage                    819.68
# Lastprice                          879.00
# Lastvolume                         20,827
# Marketcap                            None
# ...
