# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 748.07 | 785.47 | 824.74 | 865.98 | 909.28 | 954.74 | 1,002.48
# Buy score: -1.89%
# No operations found.
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# Dayhigh                            882.70
# Daylow                             882.70
# Exchange                              EBS
# Fiftydayaverage                    819.69
# Lastprice                          882.70
# Lastvolume                            221
# ...
