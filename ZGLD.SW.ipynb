# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 788.93 | 828.38 | 869.79 | 898.74 | 943.67 | 990.86 | 1,040.40
# Buy score: -0.32%
# Sell score: 1.94%
#                  Quantity   Price        Tot Wallet Avg. price Balance
# Time
# 2025-09-22 15:58        1  877.10     877.10      1     877.10   -8.50
# 2025-09-24 10:45        1  889.40     889.40      2     883.25   -4.70
# 2025-09-29 09:53       16  899.30  14,388.80     18     897.52   -9.20
# 2025-10-02 17:19        2  909.70   1,819.40     20     898.74  164.80
# 2025-10-03 17:16       20  916.20  18,324.00     20        NaN  294.80
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# ...
