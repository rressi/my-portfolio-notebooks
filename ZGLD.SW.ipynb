# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 985.88 | 1,035.17 | 1,086.93 | 1,133.40 | 1,190.07 | 1,249.57 | 1,312.05
# Buy score: -0.39%
# Sell score: 1.09%
# Current return: 161.76 CHF
# Breakeven price: 1,137.71 CHF
# <style type="text/css">
# #T_78e49_row45_col0, #T_78e49_row45_col1, #T_78e49_row45_col2, #T_78e49_row45_col3, #T_78e49_row45_col4, #T_78e49_row45_col5, #T_78e49_row45_col6, #T_78e49_row45_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_78e49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78e49_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_78e49_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_78e49_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_78e49_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_78e49_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
