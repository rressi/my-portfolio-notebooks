# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 822.16 | 863.27 | 906.43 | 960.17 | 1,008.17 | 1,058.58 | 1,111.51
# Buy score: 0.93%
# Sell score: -1.79%
# Current return: -95.20 CHF
# Breakeven price: 974.73 CHF
# <style type="text/css">
# #T_2ee92_row18_col0, #T_2ee92_row18_col1, #T_2ee92_row18_col2, #T_2ee92_row18_col3, #T_2ee92_row18_col4, #T_2ee92_row18_col5, #T_2ee92_row18_col6, #T_2ee92_row18_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_2ee92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ee92_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_2ee92_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_2ee92_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_2ee92_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_2ee92_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
