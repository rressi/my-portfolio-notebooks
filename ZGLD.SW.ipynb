# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 865.15 | 908.41 | 953.83 | 948.07 | 995.48 | 1,045.25 | 1,097.51
# Buy score: -1.87%
# Sell score: 7.65%
# Current return: 3,756.60 CHF
# Breakeven price: 952.30 CHF
# <style type="text/css">
# #T_42d74_row7_col0, #T_42d74_row7_col1, #T_42d74_row7_col2, #T_42d74_row7_col3, #T_42d74_row7_col4, #T_42d74_row7_col5, #T_42d74_row7_col6, #T_42d74_row7_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_42d74">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42d74_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_42d74_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_42d74_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_42d74_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_42d74_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
