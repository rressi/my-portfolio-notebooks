# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 744.11 | 781.32 | 820.38 | 861.40 | 904.47 | 949.69 | 997.18
# Buy score: -0.60%
#                                 ZGLD.SW
# Company Name        Swisscanto GOLD ETF
# Current Price                      None
# Forward EPS                        None
# Gross Profit (ttm)                 None
# Industry                           None
# Revenue (ttm)                      None
# Target High Price                  None
# Target Low Price                   None
# Target Mean Price                  None
# Trailing EPS                       None
# Website                            None
#                                   ZGLD.SW
# Currency                              CHF
# Dayhigh                            868.00
# Daylow                             860.50
# Exchange                              EBS
# Fiftydayaverage                    818.02
# Lastprice                          866.60
# Lastvolume                         12,104
# Marketcap                            None
# ...
