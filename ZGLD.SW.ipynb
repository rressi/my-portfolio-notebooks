# %%
import my_portfolio; my_portfolio.run("ZGLD.SW")
# Out:
# Prices: 891.79 | 936.38 | 983.20 | 1,040.40 | 1,092.42 | 1,147.04 | 1,204.39
# Buy score: -1.06%
# Sell score: 0.29%
# Current return: -11.42 CHF
# Breakeven price: 1,044.54 CHF
# <style type="text/css">
# #T_4c098_row21_col0, #T_4c098_row21_col1, #T_4c098_row21_col2, #T_4c098_row21_col3, #T_4c098_row21_col4, #T_4c098_row21_col5, #T_4c098_row21_col6, #T_4c098_row21_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_4c098">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c098_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_4c098_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_4c098_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_4c098_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_4c098_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
