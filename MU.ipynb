# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 801.11 | 841.17 | 883.22 | 927.39 | 973.76 | 1,022.44 | 1,073.57
# Buy score: -5.09%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                       995.87
# Forward EPS                      112.16951
# Gross Profit (ttm)          33,962,999,808
# Industry                    Semiconductors
# Revenue (ttm)               58,119,000,064
# Target High Price                   1750.0
# Target Low Price                     249.0
# Target Mean Price                  828.725
# Trailing EPS                         21.21
# Website             https://www.micron.com
#                                               MU
# Currency                                     USD
# Dayhigh                                   996.77
# Daylow                                    895.50
# Exchange                                     NMS
# ...
