# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 368.68 | 387.12 | 406.47 | 426.80 | 448.14 | 470.54 | 494.07
# Buy score: -3.31%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                        437.8
# Forward EPS                       43.54298
# Gross Profit (ttm)          19,171,000,320
# Industry                    Semiconductors
# Revenue (ttm)               42,311,999,488
# Target High Price                    500.0
# Target Low Price                     196.0
# Target Mean Price                  371.675
# Trailing EPS                         10.51
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 442.43
# Daylow                                  410.00
# Exchange                                   NMS
# Fiftydayaverage                         299.42
# ...
