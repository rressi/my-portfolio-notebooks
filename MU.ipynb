# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 408.37 | 428.79 | 450.23 | 472.74 | 496.38 | 521.20 | 547.26
# Buy score: -4.37%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                       496.72
# Forward EPS                      101.07363
# Gross Profit (ttm)          33,962,999,808
# Industry                    Semiconductors
# Revenue (ttm)               58,119,000,064
# Target High Price                    852.0
# Target Low Price                     249.0
# Target Mean Price                  533.725
# Trailing EPS                         21.21
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 506.99
# Daylow                                  489.36
# Exchange                                   NMS
# Fiftydayaverage                         414.81
# ...
