# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 335.47 | 352.24 | 369.86 | 388.35 | 407.77 | 428.16 | 449.56
# Buy score: -4.68%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                        407.4
# Forward EPS                       43.41293
# Gross Profit (ttm)          19,171,000,320
# Industry                    Semiconductors
# Revenue (ttm)               42,311,999,488
# Target High Price                    500.0
# Target Low Price                     196.0
# Target Mean Price                382.23077
# Trailing EPS                         10.53
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 410.06
# Daylow                                  386.57
# Exchange                                   NMS
# Fiftydayaverage                         319.82
# ...
