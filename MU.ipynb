# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 450.35 | 472.87 | 496.51 | 521.34 | 547.40 | 574.77 | 603.51
# Buy score: -4.43%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                       542.21
# Forward EPS                       101.4692
# Gross Profit (ttm)          33,962,999,808
# Industry                    Semiconductors
# Revenue (ttm)               58,119,000,064
# Target High Price                   1000.0
# Target Low Price                     249.0
# Target Mean Price                 551.4048
# Trailing EPS                          21.2
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 545.91
# Daylow                                  510.21
# Exchange                                   NMS
# Fiftydayaverage                         425.66
# ...
