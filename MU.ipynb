# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 365.79 | 384.08 | 403.29 | 423.45 | 444.62 | 466.85 | 490.20
# Buy score: -1.48%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                      429.935
# Forward EPS                       44.55368
# Gross Profit (ttm)          19,171,000,320
# Industry                    Semiconductors
# Revenue (ttm)               42,311,999,488
# Target High Price                    523.0
# Target Low Price                     196.0
# Target Mean Price                390.89743
# Trailing EPS                         10.52
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 436.25
# Daylow                                  416.16
# Exchange                                   NMS
# Fiftydayaverage                         348.00
# ...
