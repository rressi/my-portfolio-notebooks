# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 211.39 | 221.96 | 233.06 | 244.71 | 256.94 | 269.79 | 283.28
# Buy score: -6.00%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                       260.33
# Forward EPS                       21.20003
# Gross Profit (ttm)          14,872,999,936
# Industry                    Semiconductors
# Revenue (ttm)               37,377,998,848
# Target High Price                    362.0
# Target Low Price                     107.0
# Target Mean Price                240.67567
# Trailing EPS                           7.6
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 261.32
# Daylow                                  250.58
# Exchange                                   NMS
# Fiftydayaverage                         217.63
# ...
