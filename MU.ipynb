# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 218.14 | 229.05 | 240.50 | 252.53 | 265.16 | 278.41 | 292.34
# Buy score: 4.59%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                       241.14
# Forward EPS                       21.50252
# Gross Profit (ttm)          14,872,999,936
# Industry                    Semiconductors
# Revenue (ttm)               37,377,998,848
# Target High Price                    362.0
# Target Low Price                     107.0
# Target Mean Price                244.72221
# Trailing EPS                          7.09
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 255.82
# Daylow                                  239.38
# Exchange                                   NMS
# Fiftydayaverage                         221.09
# ...
