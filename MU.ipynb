# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 910.06 | 955.56 | 1,003.34 | 1,053.51 | 1,106.18 | 1,161.49 | 1,219.57
# Buy score: -11.07%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                      1133.99
# Forward EPS                       119.4339
# Gross Profit (ttm)          33,962,999,808
# Industry                    Semiconductors
# Revenue (ttm)               58,119,000,064
# Target High Price                   1750.0
# Target Low Price                     249.0
# Target Mean Price                    945.6
# Trailing EPS                         21.21
# Website             https://www.micron.com
#                                               MU
# Currency                                     USD
# Dayhigh                                 1,149.43
# Daylow                                  1,092.79
# Exchange                                     NMS
# ...
