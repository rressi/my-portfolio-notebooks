# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 347.97 | 365.37 | 383.63 | 400.83 | 420.88 | 441.92 | 464.02
# Buy score: -4.46%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                       420.59
# Forward EPS                       97.94317
# Gross Profit (ttm)          33,962,999,808
# Industry                    Semiconductors
# Revenue (ttm)               58,119,000,064
# Target High Price                    750.0
# Target Low Price                     249.0
# Target Mean Price                  526.475
# Trailing EPS                          21.2
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 423.86
# Daylow                                  410.05
# Exchange                                   NMS
# Fiftydayaverage                         402.96
# ...
