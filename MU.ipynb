# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 204.06 | 214.27 | 224.98 | 236.23 | 248.04 | 260.44 | 273.47
# Buy score: -3.04%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                       243.63
# Forward EPS                          12.87
# Gross Profit (ttm)          14,872,999,936
# Industry                    Semiconductors
# Revenue (ttm)               37,377,998,848
# Target High Price                    338.0
# Target Low Price                     107.0
# Target Mean Price                228.27779
# Trailing EPS                          7.59
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 248.99
# Daylow                                  241.61
# Exchange                                   NMS
# Fiftydayaverage                         214.07
# ...
