# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 308.76 | 324.20 | 340.41 | 357.43 | 375.30 | 394.06 | 413.77
# Buy score: -8.21%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                       389.38
# Forward EPS                       42.37608
# Gross Profit (ttm)          19,171,000,320
# Industry                    Semiconductors
# Revenue (ttm)               42,311,999,488
# Target High Price                    500.0
# Target Low Price                     107.0
# Target Mean Price                344.46155
# Trailing EPS                         10.51
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 391.22
# Daylow                                  366.73
# Exchange                                   NMS
# Fiftydayaverage                         268.63
# ...
