# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 341.77 | 358.85 | 376.80 | 395.64 | 415.42 | 436.19 | 458.00
# Buy score: -4.99%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                      416.408
# Forward EPS                       43.41293
# Gross Profit (ttm)          19,171,000,320
# Industry                    Semiconductors
# Revenue (ttm)               42,311,999,488
# Target High Price                    500.0
# Target Low Price                     196.0
# Target Mean Price                387.23077
# Trailing EPS                          10.5
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 438.77
# Daylow                                  411.16
# Exchange                                   NMS
# Fiftydayaverage                         323.29
# ...
