# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 338.90 | 355.84 | 373.64 | 392.32 | 411.93 | 432.53 | 454.16
# Buy score: 1.86%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                       385.17
# Forward EPS                       43.04733
# Gross Profit (ttm)          19,171,000,320
# Industry                    Semiconductors
# Revenue (ttm)               42,311,999,488
# Target High Price                    500.0
# Target Low Price                     196.0
# Target Mean Price                374.53845
# Trailing EPS                         10.54
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 389.75
# Daylow                                  370.69
# Exchange                                   NMS
# Fiftydayaverage                         313.78
# ...
