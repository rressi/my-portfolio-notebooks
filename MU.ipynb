# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 633.66 | 665.34 | 698.61 | 733.54 | 770.21 | 808.73 | 849.16
# Buy score: 7.58%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                      681.885
# Forward EPS                       102.5821
# Gross Profit (ttm)          33,962,999,808
# Industry                    Semiconductors
# Revenue (ttm)               58,119,000,064
# Target High Price                   1100.0
# Target Low Price                     249.0
# Target Mean Price                612.65857
# Trailing EPS                          21.2
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 701.14
# Daylow                                  652.21
# Exchange                                   NMS
# Fiftydayaverage                         492.46
# ...
