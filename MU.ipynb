# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 772.24 | 810.85 | 851.39 | 893.96 | 938.66 | 985.59 | 1,034.87
# Buy score: -7.34%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                        971.0
# Forward EPS                      105.28448
# Gross Profit (ttm)          33,962,999,808
# Industry                    Semiconductors
# Revenue (ttm)               58,119,000,064
# Target High Price                   1750.0
# Target Low Price                     249.0
# Target Mean Price                  702.975
# Trailing EPS                         21.17
# Website             https://www.micron.com
#                                               MU
# Currency                                     USD
# Dayhigh                                   981.00
# Daylow                                    940.51
# Exchange                                     NMS
# Fiftydayaverage                           557.56
# ...
