# %%
import my_portfolio; my_portfolio.run("MU")
# Out:
# No operations found for ticker 'MU'
# Prices: 870.61 | 914.14 | 959.84 | 1,007.84 | 1,058.23 | 1,111.14 | 1,166.70
# Buy score: 17.57%
# No operations found.
#                                         MU
# Company Name             Micron Technology
# Current Price                       864.01
# Forward EPS                      105.95201
# Gross Profit (ttm)          33,962,999,808
# Industry                    Semiconductors
# Revenue (ttm)               58,119,000,064
# Target High Price                   1750.0
# Target Low Price                     249.0
# Target Mean Price                  739.475
# Trailing EPS                         21.17
# Website             https://www.micron.com
#                                             MU
# Currency                                   USD
# Dayhigh                                 961.89
# Daylow                                  864.01
# Exchange                                   NMS
# Fiftydayaverage                         617.36
# ...
