# %%
import my_portfolio; my_portfolio.run("TSM")
# Out:
# Prices: 260.85 | 273.89 | 287.59 | 292.75 | 317.07 | 332.92 | 349.57
# Buy score: 3.35%
# Current return: -54.40 USD
# Breakeven price: 297.63 USD
# <style type="text/css">
# #T_39242_row14_col0, #T_39242_row14_col1, #T_39242_row14_col2, #T_39242_row14_col3, #T_39242_row14_col4, #T_39242_row14_col5, #T_39242_row14_col6, #T_39242_row14_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_39242">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39242_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_39242_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_39242_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_39242_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_39242_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
