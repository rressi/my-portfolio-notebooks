# %%
import my_portfolio; my_portfolio.run("TSM")
# Out:
# Prices: 279.80 | 293.79 | 308.48 | 323.00 | 339.15 | 356.11 | 373.91
# Buy score: -2.49%
# Sell score: 2.84%
# Current return: 104.22 USD
# Breakeven price: 326.97 USD
# <style type="text/css">
# #T_170cd_row17_col0, #T_170cd_row17_col1, #T_170cd_row17_col2, #T_170cd_row17_col3, #T_170cd_row17_col4, #T_170cd_row17_col5, #T_170cd_row17_col6, #T_170cd_row17_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_170cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_170cd_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_170cd_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_170cd_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_170cd_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_170cd_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
