# %%
import workflow
workflow.run(
    security = "TSM",  # TSMC
)
# Out:
# Prices: 208.29 | 218.70 | 229.64 | 241.12 | 253.17 | 265.83 | 279.12
# Buy score: -7.75%
#                                                 TSM
# Company Name        Taiwan Semiconductor Manufactur
# Current Price                                261.38
# Forward EPS                                    8.08
# Gross Profit (ttm)                1,992,488,124,416
# Industry                             Semiconductors
# Revenue (ttm)                     3,401,198,862,336
# Target High Price                             320.0
# Target Low Price                              210.0
# Target Mean Price                            275.49
# Trailing EPS                                   9.28
# Website                        https://www.tsmc.com
#                                              TSM
# Currency                                     USD
# Dayhigh                                   262.80
# Daylow                                    258.75
# Exchange                                     NYQ
# ...
