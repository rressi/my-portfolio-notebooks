# %%
import workflow
workflow.run(
    security = "TSM",  # TSMC
)
# Out:
# Prices: 207.31 | 217.68 | 228.56 | 239.9920 | 251.99 | 264.59 | 277.82
# Buy score: -7.46%
#                                                 TSM
# Company Name        Taiwan Semiconductor Manufactur
# Current Price                                259.33
# Forward EPS                                    8.08
# Gross Profit (ttm)                1,992,488,124,416
# Industry                             Semiconductors
# Revenue (ttm)                     3,401,198,862,336
# Target High Price                             306.0
# Target Low Price                              210.0
# Target Mean Price                         274.15668
# Trailing EPS                                   9.21
# Website                        https://www.tsmc.com
#                                              TSM
# Currency                                     USD
# Dayhigh                                   260.95
# Daylow                                    258.38
# Exchange                                     NYQ
# ...
