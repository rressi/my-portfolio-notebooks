# %%
import my_portfolio; my_portfolio.run("TSM")
# Out:
# Prices: 252.05 | 264.65 | 277.89 | 292.75 | 299.94 | 314.94 | 330.68
# Buy score: 0.34%
# Current return: -129.30 USD
# Breakeven price: 297.63 USD
# <style type="text/css">
# #T_41352_row14_col0, #T_41352_row14_col1, #T_41352_row14_col2, #T_41352_row14_col3, #T_41352_row14_col4, #T_41352_row14_col5, #T_41352_row14_col6, #T_41352_row14_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_41352">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41352_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_41352_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_41352_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_41352_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_41352_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
