# %%
import my_portfolio; my_portfolio.run("TSM")
# Out:
# Prices: 259.48 | 272.46 | 286.08 | 292.75 | 307.39 | 322.76 | 338.89
# Buy score: -2.79%
# Sell score: 5.55%
# Current return: 113.60 USD
# Breakeven price: 297.63 USD
# <style type="text/css">
# #T_34bb0_row14_col0, #T_34bb0_row14_col1, #T_34bb0_row14_col2, #T_34bb0_row14_col3, #T_34bb0_row14_col4, #T_34bb0_row14_col5, #T_34bb0_row14_col6, #T_34bb0_row14_col7 {
#   font-weight: bold;
#   background-color: green;
# }
# </style>
# <table id="T_34bb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34bb0_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_34bb0_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_34bb0_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_34bb0_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_34bb0_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
