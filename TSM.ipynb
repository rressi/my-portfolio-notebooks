# %%
import my_portfolio; my_portfolio.run("TSM")
# Out:
# Prices: 247.97 | 260.37 | 273.39 | 292.75 | 307.39 | 322.76 | 338.89
# Buy score: -2.79%
# Sell score: -0.96%
# Current return: -76.80 USD
# Breakeven price: 297.63 USD
# <style type="text/css">
# #T_09238_row14_col0, #T_09238_row14_col1, #T_09238_row14_col2, #T_09238_row14_col3, #T_09238_row14_col4, #T_09238_row14_col5, #T_09238_row14_col6, #T_09238_row14_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_09238">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09238_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_09238_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_09238_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_09238_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_09238_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
