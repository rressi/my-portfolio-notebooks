# %%
import workflow
workflow.run(
    security = "TSM",  # TSMC
)
# Out:
# Prices: 206.52 | 216.85 | 227.69 | 239.0755 | 251.03 | 263.58 | 276.76
# Buy score: -7.66%
#                                                 TSM
# Company Name        Taiwan Semiconductor Manufactur
# Industry                             Semiconductors
# Revenue (ttm)                     3,401,198,862,336
# Gross Profit (ttm)                1,992,488,124,416
# Current Price                                258.91
# Target Mean Price                         274.15668
# Target High Price                             306.0
# Target Low Price                              210.0
# Trailing EPS                                   9.17
# Forward EPS                                    8.08
# Website                        https://www.tsmc.com
#                                              TSM
# Currency                                     USD
# Dayhigh                                   261.64
# Daylow                                    258.23
# Exchange                                     NYQ
# ...
