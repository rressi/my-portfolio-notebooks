# %%
import workflow
workflow.run(
    security = "TSM",  # TSMC
)
# Out:
# Prices: 207.26 | 217.62 | 228.50 | 239.9280 | 251.92 | 264.52 | 277.75
# Buy score: -7.33%
#                                                                   TSM
# Company Name        Taiwan Semiconductor Manufacturing Company Lim...
# Industry                                               Semiconductors
# Revenue (ttm)                                       3,401,198,862,336
# Gross Profit (ttm)                                  1,992,488,124,416
# Current Price                                                  258.91
# Target Mean Price                                           274.15668
# Target High Price                                               306.0
# Target Low Price                                                210.0
# Trailing EPS                                                     9.17
# Forward EPS                                                      8.08
# Website                                          https://www.tsmc.com
# ...
