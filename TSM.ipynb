# %%
import my_portfolio; my_portfolio.run("TSM")
# Out:
# Prices: 251.89 | 264.49 | 277.71 | 292.75 | 299.47 | 314.44 | 330.17
# Buy score: -1.59%
# Current return: -78.20 USD
# Breakeven price: 297.63 USD
# <style type="text/css">
# #T_4bdd7_row14_col0, #T_4bdd7_row14_col1, #T_4bdd7_row14_col2, #T_4bdd7_row14_col3, #T_4bdd7_row14_col4, #T_4bdd7_row14_col5, #T_4bdd7_row14_col6, #T_4bdd7_row14_col7 {
#   font-weight: bold;
#   background-color: red;
# }
# </style>
# <table id="T_4bdd7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bdd7_level0_col0" class="col_heading level0 col0" >Quantity</th>
#       <th id="T_4bdd7_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_4bdd7_level0_col2" class="col_heading level0 col2" >Value</th>
#       <th id="T_4bdd7_level0_col3" class="col_heading level0 col3" >Wallet</th>
#       <th id="T_4bdd7_level0_col4" class="col_heading level0 col4" >Avg. price</th>
# ...
