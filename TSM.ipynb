# %%
import workflow
workflow.run(
    security = "TSM",  # TSMC
)
# Out:
# Prices: 222.44 | 233.57 | 245.24 | 257.51 | 270.38 | 283.90 | 298.10
# Buy score: -4.14%
#                                                 TSM
# Company Name        Taiwan Semiconductor Manufactur
# Current Price                                268.64
# Forward EPS                                    8.08
# Gross Profit (ttm)                1,992,488,124,416
# Industry                             Semiconductors
# Revenue (ttm)                     3,401,198,862,336
# Target High Price                             325.0
# Target Low Price                              210.0
# Target Mean Price                         278.82333
# Trailing EPS                                   9.22
# Website                        https://www.tsmc.com
#                                              TSM
# Currency                                     USD
# Dayhigh                                   270.51
# Daylow                                    257.99
# Exchange                                     NYQ
# ...
